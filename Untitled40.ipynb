# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepaManjunath/Assignment1/blob/master/Untitled40.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q '/content/gdrive/My Drive/EIP4/hvc_data.zip'
# look for `hvc_annotations.csv` file and `resized` dir
# %ls '/content/gdrive/My Drive/EIP4/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# hvc_data/  hvc_data.zip

# %%
# %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation , Dropout
from keras.layers import AveragePooling2D, Input, Flatten ,GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.callbacks import ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()
# Out:
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
# 3    male         Good  45-55  ...        Neutral  Front-Frontish  resized/4.jpg
# 4  female         Good  35-45  ...        Neutral  Front-Frontish  resized/5.jpg
#
# [5 rows x 9 columns]

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
import numpy as np


def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=32, shuffle=True,augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.batch_size = batch_size
        #self.labels = labels
        #self.list_IDs = list_IDs
        #self.n_channels = n_channels
        #self.n_classes = n_classes
        #self.shuffle = shuffle
        self.on_epoch_end()
        self.augmentation=augmentation
        
        
        #self.on_epoch_end()

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

            
    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        images = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
        if self.augmentation is not None:
           images=self.augmentation.flow(images,shuffle=False).next()
           
        target = {
                       "gender_output": items[_gender_cols_].values,
                       "image_quality_output": items[_imagequality_cols_].values,
                       "age_output": items[_age_cols_].values,
                       "weight_output": items[_weight_cols_].values,
                       "bag_output": items[_carryingbag_cols_].values,
                       "pose_output": items[_bodypose_cols_].values,
                       "footwear_output": items[_footwear_cols_].values,
                       "emotion_output": items[_emotion_cols_].values,
        }
        return images, target
    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
            
   # def __PersonDataGenerator(self,train_df,batch_size=32,augmentation):
      
    #     train_gen = np.stack(train_df, batch_size=32,augmentation=ImageDataGenerator(featurewise_center=False,
     #                           samplewise_center=False,
      #                          featurewise_std_normalization=False,
       #                         samplewise_std_normalization=False,
        #                        zca_whitening=False,
         #                       zca_epsilon=1e-06,
          #                      rotation_range=25,
           #                     width_shift_range=0.1,
            #                    height_shift_range=0.1,
             #                   brightness_range=None,
              #                  shear_range=0.0,
               #                 zoom_range=0.0,
                #                channel_shift_range=0.0,
                 #               fill_mode='nearest',
                  #              cval=0.0,
                   #             horizontal_flip=True,
                    #            vertical_flip=True,
                     #           rescale=None,
                      #          preprocessing_function=get_random_eraser(v_l=0, v_h=1),
                       #         data_format=None,
                        #        validation_split=0.0
                         #       ))
         #image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
          #    if self.augmentation is not None:
           #  image=self.augmentation.flow(image,shuffle=False).next()

   # def on_epoch_end(self):
    #    """Updates indexes after each epoch"""
     #   if self.shuffle == True:
      #      self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
len(train_df)
# Out:
# 11537

# %%
train_df.head()
# Out:
#               image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 8394    resized/8395.jpg              0  ...                        1              0
# 3017    resized/3018.jpg              0  ...                        1              0
# 12784  resized/12786.jpg              0  ...                        1              0
# 1935    resized/1936.jpg              0  ...                        1              0
# 9993    resized/9994.jpg              0  ...                        0              1
#
# [5 rows x 28 columns]

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df,batch_size=32,
                                augmentation=ImageDataGenerator(rescale=1./255,width_shift_range=0.1,
	                                                              height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
	                                                              horizontal_flip=True, fill_mode="nearest", 
                                                                rotation_range=25,preprocessing_function=get_random_eraser(v_l=0, v_h=1)                                                                    
	                                                                                  ))
                       
                                                            
	                                                                                      

                             
                                                        
                                                          



#train_gen = PersonDataGenerator(train_df, batch_size=32,augmentation=True)
                                
valid_gen = PersonDataGenerator(val_df, batch_size=32, shuffle=False,
                                augmentation=ImageDataGenerator(rescale=1./255))

# %%
# get number of output units from data
images, targets = next(iter(valid_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
#from classification_models.resnet import ResNet18, preprocess_input
import keras.applications.resnet 
from keras.applications.inception_v3 import InceptionV3

from keras.applications.resnet import ResNet50

backbone = InceptionV3(
    weights=None, 
    include_top=False, 
    input_tensor=Input(shape=(224, 224, 3))
)
#backbone = resnet_v1((224,224,3),8)
  


neck = backbone.output
neck = Flatten(name="flatten")(neck)
neck = Dense(512, activation="relu")(neck)


def build_tower(in_layer):
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.0812)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.0812)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.0812)(in_layer)
    neck = Dense(28, activation="relu")(neck)
    
    
    return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="sigmoid",name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("pose", build_tower(neck))


model = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
import numpy as np
import tensorflow as tf
import keras

# %%
EPOCHS=24
LEARNING_RATE=1
BATCH_SIZE1=32
BATCH_SIZE2=64
MOMENTUM=0.9

# %%
len_train=len(train_df)
batches_per_epoch = len_train//BATCH_SIZE1

# %%
lr_schedule = lambda t: np.interp([t], [0, (EPOCHS+1)//5, (EPOCHS)], [0.1, LEARNING_RATE, 0.1] )[0]
print(lr_schedule)

#lr_schedule = lambda t: np.interp([t],[0,(EPOCHS+1)//5, (EPOCHS-6)],[0.4, LEARNING_RATE, 0.4])[0]
global_step = tf.train.get_or_create_global_step()
lr_func = lambda: lr_schedule(global_step/batches_per_epoch)/BATCH_SIZE1
#opt.apply_gradients( global_step=global_step)
#opt = tf.train.MomentumOptimizer(lr_func,momentum=MOMENTUM,use_nesterov=False)
# Out:
# <function <lambda> at 0x7f72f0ce4f28>

# %%
#t = time.time()
#test_set = tf.data.Dataset.from_tensor_slices((val_df)).batch(BATCH_SIZE)

def lr_schedule1(epoch):
    for epoch1 in range((EPOCHS)):
    #if epoch<=24:
      
         if epoch==epoch1:
          break
     
   
   # tf.keras.backend.set_learning_phase(1)
         opt = tf.train.MomentumOptimizer(lr_func,momentum=MOMENTUM,use_nesterov=False)
         #opt1 = SGD(lr=lr_schedule(epoch+1),momentum=0.9)
        #if epoch==epoch1:
         # break
          
    print('epoch:', epoch, 'lr:', lr_schedule(epoch))
    return(lr_schedule(epoch))

      
     
    #tf.keras.backend.set_learning_phase(0)
    
      #  print('epoch:', epoch+1, 'lr:', lr_schedule(epoch+1))
  #return (lr_schedule(epoch+1))
    #else:
   
    #tf.keras.backend.set_learning_phase(1)
     #   opt = tf.train.MomentumOptimizer(lr_func1,momentum=MOMENTUM,use_nesterov=False)
      #  opt = SGD(lr=lr_schedule(epoch+1),momentum=0.9)
        #model.compile(
         #           optimizer=opt,
          #          loss="categorical_crossentropy", 
           #         loss_weights=loss_weights, 
            #        metrics=["accuracy"]
             #       )
        #model.fit_generator(
         #            generator=train_gen,
          #           validation_data=valid_gen,
           #          use_multiprocessing=True,
            #         workers=6, 
             #        epochs=10,
              #       verbose=1,
      
               #      callbacks=callbacks
                #         )
        #LRFind.plot_loss()

       
    #tf.keras.backend.set_learning_phase(0)
       # print('epoch:', epoch+1, 'lr:', lr_schedule1(epoch+1))

# %%
# model.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=32, epochs=10)

# %%
import matplotlib.pyplot as plt
import keras.backend as K
from keras.callbacks import Callback


class LRFinder(Callback):
    
    '''
    A simple callback for finding the optimal learning rate range for your model + dataset. 
    
    # Usage
        ```python
            lr_finder = LRFinder(min_lr=1e-5, 
                                 max_lr=1e-2, 
                                 steps_per_epoch=np.ceil(epoch_size/batch_size), 
                                 epochs=3)
            model.fit(X_train, Y_train, callbacks=[lr_finder])
            
            lr_finder.plot_loss()
        ```
    
    # Arguments
        min_lr: The lower bound of the learning rate range for the experiment.
        max_lr: The upper bound of the learning rate range for the experiment.
        steps_per_epoch: Number of mini-batches in the dataset. Calculated as `np.ceil(epoch_size/batch_size)`. 
        epochs: Number of epochs to run experiment. Usually between 2 and 4 epochs is sufficient. 
        
    # References
        Blog post: jeremyjordan.me/nn-learning-rate
        Original paper: https://arxiv.org/abs/1506.01186
    '''
    
    def __init__(self, min_lr=1e-5, max_lr=1e-2, steps_per_epoch=5.625, epochs=24):
        super().__init__()
        
        self.min_lr = min_lr
        self.max_lr = max_lr
        self.total_iterations = steps_per_epoch * epochs
        self.iteration = 0
        self.history = {}
        
    def clr(self):
        '''Calculate the learning rate.'''
        x = self.iteration / self.total_iterations 
        return self.min_lr + (self.max_lr-self.min_lr) * x
        
    def on_train_begin(self, logs=None):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.min_lr)
        
    def on_batch_end(self, epoch, logs=None):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.iteration += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.iteration)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
            
        K.set_value(self.model.optimizer.lr, self.clr())
 
    def plot_lr(self):
        '''Helper function to quickly inspect the learning rate schedule.'''
        plt.plot(self.history['iterations'], self.history['lr'])
        plt.yscale('log')
        plt.xlabel('Iteration')
        plt.ylabel('Learning rate')
        plt.show()
        
    def plot_loss(self):
        '''Helper function to quickly observe the learning rate experiment results.'''
        plt.plot(self.history['lr'], self.history['loss'])
        plt.xscale('log')
        plt.xlabel('Learning rate')
        plt.ylabel('Loss')
        plt.show()

# %%
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
#for i in range(EPOCHS):
#lr_scheduler = LearningRateScheduler(lr_schedule1)

# %%
#lr_schedule = lambda t: np.interp([t], [0, (EPOCHS+1)//5, (EPOCHS-6)], [0.4, LEARNING_RATE, 0.4])[0]
#global_step = tf.train.get_or_create_global_step()
#opt.apply_gradients(zip(grads, var), global_step=global_step

# %%
def lr_Schedule(epoch):
  
   # lr=0.00148 
    lr = 1e-3
    #if epoch > 70:
     # lr*= 1e-3
    #if epoch > 40:
     #   lr *= 1e-1
    #if epoch > 30:
      #  lr *= 1e-0
    #if epoch > 20:
     #  lr *= 1e-0
    if epoch > 10:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
#from keras.callbacks import ModelCheckpoint,LearningRateScheduler

#LRFind=LRFinder(min_lr=1e-5, max_lr=10, steps_per_epoch=(2036//32), epochs=50)
lr_scheduler = LearningRateScheduler(lr_Schedule)
#LRFind.on_tain_begin()
#for i in range(EPOCHS):
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [lr_scheduler,lr_reducer]

# %%
losses = {
 	"gender_output": "binary_crossentropy",
 	"image_quality_output": "binary_crossentropy",
 	"age_output": "binary_crossentropy",
 	"weight_output": "binary_crossentropy",
  "bag_output": "binary_crossentropy",
  "pose_output": "binary_crossentropy",
  "footwear_output": "binary_crossentropy",   
  "emotion_output": "binary_crossentropy",
       

 }
loss_weights = {"gender_output": 0.2, "image_quality_output": 0.3, "age_output": 0.5, "weight_output": 0.4,"bag_output":0.3,"pose_output":0.3,"footwear_output":0.3,"emotion_output":0.4}
model.summary()

opt = SGD(lr=0.0142,momentum=0.9)
#opt = tf.train.MomentumOptimizer(lr=lr_schedule(epoch+1),momentum=MOMENTUM,use_nesterov=False)
#opt.( global_step=global_step)
model.compile(
    optimizer=opt,
    loss="binary_crossentropy", 
    #from_logits=True,
    #loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
    loss_weights=loss_weights, 
    metrics=["accuracy"]
)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 111, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 111, 111, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 111, 111, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 109, 109, 32) 9216        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 109, 109, 32) 96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 109, 109, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 109, 109, 64) 18432       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 109, 109, 64) 192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 109, 109, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 54, 54, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 54, 54, 80)   5120        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 54, 54, 80)   240         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 54, 54, 80)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 52, 52, 192)  138240      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 52, 52, 192)  576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 52, 52, 192)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 192)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 25, 25, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 25, 25, 64)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 25, 25, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 25, 25, 48)   9216        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 25, 25, 96)   55296       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 25, 25, 48)   144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 25, 25, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 25, 25, 48)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 25, 25, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 25, 25, 192)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 25, 25, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 25, 25, 64)   76800       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 25, 25, 96)   82944       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 25, 25, 32)   6144        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 25, 25, 64)   192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 25, 25, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 25, 25, 96)   288         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 25, 25, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 25, 25, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 25, 25, 96)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 25, 25, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 25, 25, 256)  0           activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 25, 25, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 25, 25, 64)   192         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 25, 25, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 25, 25, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 25, 25, 96)   55296       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 48)   144         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 25, 25, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 25, 25, 48)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 25, 25, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 25, 25, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 25, 25, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 25, 25, 64)   76800       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 25, 25, 96)   82944       activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 25, 25, 64)   16384       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 64)   192         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 25, 25, 96)   288         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 25, 25, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 25, 25, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 25, 25, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 25, 25, 96)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 25, 25, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 25, 25, 288)  0           activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 25, 25, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 25, 25, 64)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 25, 25, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 25, 25, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 25, 25, 96)   55296       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 25, 25, 48)   144         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 25, 25, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 25, 25, 48)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 25, 25, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 25, 25, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 25, 25, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 25, 25, 64)   76800       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 25, 25, 96)   82944       activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 25, 25, 64)   18432       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 25, 25, 64)   192         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 25, 25, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 25, 25, 96)   288         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 25, 25, 64)   192         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 25, 25, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 25, 25, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 25, 25, 96)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 25, 25, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 25, 25, 288)  0           activation_20[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 25, 25, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 25, 25, 64)   192         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 25, 25, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 25, 25, 96)   55296       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 25, 25, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 25, 25, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 12, 12, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 12, 12, 96)   82944       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 12, 12, 384)  1152        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 12, 12, 96)   288         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 12, 12, 384)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 96)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 12, 12, 768)  0           activation_27[0][0]
#                                                                  activation_30[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 12, 12, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 12, 12, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 12, 12, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 12, 12, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 12, 12, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 12, 12, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 12, 12, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 12, 12, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 12, 12, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 12, 12, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 12, 12, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 12, 12, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 12, 12, 128)  114688      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 12, 12, 128)  114688      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 12, 12, 128)  384         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 12, 12, 128)  384         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 12, 12, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 12, 12, 128)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 12, 12, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 12, 12, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 12, 12, 192)  172032      activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 12, 12, 192)  172032      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 12, 12, 192)  576         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 12, 12, 192)  576         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 12, 12, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 12, 12, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 12, 12, 192)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 12, 12, 192)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 12, 12, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 12, 12, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 12, 12, 768)  0           activation_31[0][0]
#                                                                  activation_34[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 12, 12, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 12, 12, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 12, 12, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 12, 12, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 12, 12, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 12, 12, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 12, 12, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 12, 12, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 12, 12, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 12, 12, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 12, 12, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 12, 12, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 12, 12, 160)  179200      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 12, 12, 160)  179200      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 12, 12, 160)  480         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 12, 12, 160)  480         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 12, 12, 160)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 12, 12, 160)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 12, 12, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 12, 12, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 12, 12, 192)  215040      activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 12, 12, 192)  215040      activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 12, 12, 192)  576         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 12, 12, 192)  576         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 12, 12, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 12, 12, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 12, 12, 192)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 12, 12, 192)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 12, 12, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 12, 12, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 12, 12, 768)  0           activation_41[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 12, 12, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 12, 12, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 12, 12, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 12, 12, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 12, 12, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 12, 12, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 12, 12, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 12, 12, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 12, 12, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 12, 12, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 12, 12, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 12, 12, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 12, 12, 160)  179200      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 12, 12, 160)  179200      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 12, 12, 160)  480         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 12, 12, 160)  480         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 12, 12, 160)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 12, 12, 160)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 12, 12, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 12, 12, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 12, 12, 192)  215040      activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 12, 12, 192)  215040      activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 12, 12, 192)  576         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 12, 12, 192)  576         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 12, 12, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 12, 12, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 12, 12, 192)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 12, 12, 192)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 12, 12, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 12, 12, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 12, 12, 768)  0           activation_51[0][0]
#                                                                  activation_54[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_60[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 12, 12, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 12, 12, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 12, 12, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 12, 12, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 12, 12, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 12, 12, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 12, 12, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 12, 12, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 12, 12, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 12, 12, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 12, 12, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 12, 12, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 12, 12, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 12, 12, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 12, 12, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 12, 12, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 12, 12, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 12, 12, 192)  258048      activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 12, 12, 192)  258048      activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 12, 12, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 12, 12, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 12, 12, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 12, 12, 192)  576         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 12, 12, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 12, 12, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 12, 12, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 12, 12, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 12, 12, 768)  0           activation_61[0][0]
#                                                                  activation_64[0][0]
#                                                                  activation_69[0][0]
#                                                                  activation_70[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 5, 5, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 5, 5, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 5, 5, 384)    1152        conv2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 5, 5, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 5, 5, 384)    1152        conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 5, 5, 192)    245760      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 5, 5, 320)    960         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 5, 5, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 5, 5, 384)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 5, 5, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 5, 5, 384)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 5, 5, 192)    576         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 5, 5, 320)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 5, 5, 768)    0           activation_79[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 5, 5, 768)    0           activation_83[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 5, 5, 192)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 5, 5, 2048)   0           activation_77[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_85[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 5, 5, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 5, 5, 448)    1344        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 5, 5, 448)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 5, 5, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 5, 5, 384)    1548288     activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 5, 5, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 5, 5, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 5, 5, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 5, 5, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 5, 5, 384)    442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 5, 5, 384)    442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 5, 5, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 5, 5, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 5, 5, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 5, 5, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 5, 5, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 5, 5, 384)    1152        conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 5, 5, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 5, 5, 384)    1152        conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 5, 5, 192)    393216      average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 5, 5, 320)    960         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 5, 5, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 5, 5, 384)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 5, 5, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 5, 5, 384)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 5, 5, 192)    576         conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 5, 5, 320)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 5, 5, 768)    0           activation_88[0][0]
#                                                                  activation_89[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 5, 5, 768)    0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 5, 5, 192)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 5, 5, 2048)   0           activation_86[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_94[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 51200)        0           mixed10[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          26214912    flatten[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 28)           14364       dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 28)           14364       dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 28)           14364       dropout_9[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 28)           14364       dropout_12[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 28)           14364       dropout_15[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 28)           14364       dropout_18[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 28)           14364       dropout_24[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 28)           14364       dropout_21[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            58          dense_4[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Dense)    (None, 3)            87          dense_7[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            145         dense_10[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            116         dense_13[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            87          dense_16[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            87          dense_19[0][0]
# __________________________________________________________________________________________________
# pose_output (Dense)             (None, 3)            87          dense_25[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            116         dense_22[0][0]
# ==================================================================================================
# Total params: 48,133,391
# Trainable params: 48,098,959
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
#for i in range(EPOCHS):
model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    #validation_steps=2036//32,
    use_multiprocessing=True,
    workers=2, 
    epochs=200,
    verbose=1,
    #callbacks=callbacks
    )
LRFind.plot_loss()
# Out:
# Epoch 1/200
# 360/360 [==============================] - 200s 556ms/step - loss: 1.3810 - gender_output_loss: 0.6740 - image_quality_output_loss: 0.5846 - age_output_loss: 0.4601 - weight_output_loss: 0.4303 - bag_output_loss: 0.5525 - footwear_output_loss: 0.5939 - pose_output_loss: 0.5543 - emotion_output_loss: 0.3962 - gender_output_acc: 0.5720 - image_quality_output_acc: 0.6944 - age_output_acc: 0.7978 - weight_output_acc: 0.8149 - bag_output_acc: 0.7050 - footwear_output_acc: 0.6798 - pose_output_acc: 0.7425 - emotion_output_acc: 0.8540 - val_loss: 1.3611 - val_gender_output_loss: 0.6631 - val_image_quality_output_loss: 0.5821 - val_age_output_loss: 0.4603 - val_weight_output_loss: 0.4191 - val_bag_output_loss: 0.5432 - val_footwear_output_loss: 0.5854 - val_pose_output_loss: 0.5477 - val_emotion_output_loss: 0.3830 - val_gender_output_acc: 0.5908 - val_image_quality_output_acc: 0.6971 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8177 - val_bag_output_acc: 0.7126 - val_footwear_output_acc: 0.6738 - val_pose_output_acc: 0.7442 - val_emotion_output_acc: 0.8601
# Epoch 2/200
# 360/360 [==============================] - 183s 509ms/step - loss: 1.3602 - gender_output_loss: 0.6584 - image_quality_output_loss: 0.5803 - age_output_loss: 0.4558 - weight_output_loss: 0.4242 - bag_output_loss: 0.5465 - footwear_output_loss: 0.5734 - pose_output_loss: 0.5489 - emotion_output_loss: 0.3907 - gender_output_acc: 0.5950 - image_quality_output_acc: 0.6990 - age_output_acc: 0.7997 - weight_output_acc: 0.8170 - bag_output_acc: 0.7104 - footwear_output_acc: 0.6961 - pose_output_acc: 0.7440 - emotion_output_acc: 0.8551 - val_loss: 1.3532 - val_gender_output_loss: 0.6499 - val_image_quality_output_loss: 0.5805 - val_age_output_loss: 0.4583 - val_weight_output_loss: 0.4164 - val_bag_output_loss: 0.5495 - val_footwear_output_loss: 0.5832 - val_pose_output_loss: 0.5387 - val_emotion_output_loss: 0.3799 - val_gender_output_acc: 0.6220 - val_image_quality_output_acc: 0.7029 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8177 - val_bag_output_acc: 0.7105 - val_footwear_output_acc: 0.6887 - val_pose_output_acc: 0.7480 - val_emotion_output_acc: 0.8601
# Epoch 3/200
# 360/360 [==============================] - 186s 517ms/step - loss: 1.3548 - gender_output_loss: 0.6498 - image_quality_output_loss: 0.5789 - age_output_loss: 0.4551 - weight_output_loss: 0.4243 - bag_output_loss: 0.5434 - footwear_output_loss: 0.5680 - pose_output_loss: 0.5470 - emotion_output_loss: 0.3908 - gender_output_acc: 0.6151 - image_quality_output_acc: 0.7001 - age_output_acc: 0.7993 - weight_output_acc: 0.8170 - bag_output_acc: 0.7142 - footwear_output_acc: 0.7052 - pose_output_acc: 0.7438 - emotion_output_acc: 0.8548 - val_loss: 1.3449 - val_gender_output_loss: 0.6506 - val_image_quality_output_loss: 0.5776 - val_age_output_loss: 0.4582 - val_weight_output_loss: 0.4160 - val_bag_output_loss: 0.5394 - val_footwear_output_loss: 0.5655 - val_pose_output_loss: 0.5451 - val_emotion_output_loss: 0.3775 - val_gender_output_acc: 0.6198 - val_image_quality_output_acc: 0.7047 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8177 - val_bag_output_acc: 0.7141 - val_footwear_output_acc: 0.6992 - val_pose_output_acc: 0.7480 - val_emotion_output_acc: 0.8601
# Epoch 4/200
# 360/360 [==============================] - 189s 524ms/step - loss: 1.3467 - gender_output_loss: 0.6439 - image_quality_output_loss: 0.5768 - age_output_loss: 0.4534 - weight_output_loss: 0.4215 - bag_output_loss: 0.5400 - footwear_output_loss: 0.5596 - pose_output_loss: 0.5451 - emotion_output_loss: 0.3905 - gender_output_acc: 0.6231 - image_quality_output_acc: 0.7006 - age_output_acc: 0.7997 - weight_output_acc: 0.8176 - bag_output_acc: 0.7167 - footwear_output_acc: 0.7110 - pose_output_acc: 0.7443 - emotion_output_acc: 0.8546 - val_loss: 1.3373 - val_gender_output_loss: 0.6337 - val_image_quality_output_loss: 0.5774 - val_age_output_loss: 0.4597 - val_weight_output_loss: 0.4159 - val_bag_output_loss: 0.5334 - val_footwear_output_loss: 0.5522 - val_pose_output_loss: 0.5495 - val_emotion_output_loss: 0.3765 - val_gender_output_acc: 0.6367 - val_image_quality_output_acc: 0.7037 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8177 - val_bag_output_acc: 0.7141 - val_footwear_output_acc: 0.7116 - val_pose_output_acc: 0.7480 - val_emotion_output_acc: 0.8601
# Epoch 5/200
# 360/360 [==============================] - 185s 514ms/step - loss: 1.3379 - gender_output_loss: 0.6278 - image_quality_output_loss: 0.5762 - age_output_loss: 0.4526 - weight_output_loss: 0.4208 - bag_output_loss: 0.5366 - footwear_output_loss: 0.5519 - pose_output_loss: 0.5421 - emotion_output_loss: 0.3891 - gender_output_acc: 0.6416 - image_quality_output_acc: 0.6995 - age_output_acc: 0.7997 - weight_output_acc: 0.8174 - bag_output_acc: 0.7194 - footwear_output_acc: 0.7181 - pose_output_acc: 0.7442 - emotion_output_acc: 0.8550 - val_loss: 2.5341 - val_gender_output_loss: 1.3179 - val_image_quality_output_loss: 0.9005 - val_age_output_loss: 0.8345 - val_weight_output_loss: 0.7272 - val_bag_output_loss: 1.1483 - val_footwear_output_loss: 1.0859 - val_pose_output_loss: 1.0198 - val_emotion_output_loss: 0.7903 - val_gender_output_acc: 0.6352 - val_image_quality_output_acc: 0.7037 - val_age_output_acc: 0.7806 - val_weight_output_acc: 0.8177 - val_bag_output_acc: 0.7174 - val_footwear_output_acc: 0.6668 - val_pose_output_acc: 0.7480 - val_emotion_output_acc: 0.8601
# Epoch 6/200
# 360/360 [==============================] - 184s 510ms/step - loss: 1.3329 - gender_output_loss: 0.6209 - image_quality_output_loss: 0.5743 - age_output_loss: 0.4521 - weight_output_loss: 0.4204 - bag_output_loss: 0.5378 - footwear_output_loss: 0.5475 - pose_output_loss: 0.5373 - emotion_output_loss: 0.3886 - gender_output_acc: 0.6533 - image_quality_output_acc: 0.7025 - age_output_acc: 0.7998 - weight_output_acc: 0.8180 - bag_output_acc: 0.7178 - footwear_output_acc: 0.7207 - pose_output_acc: 0.7448 - emotion_output_acc: 0.8553 - val_loss: 1.3266 - val_gender_output_loss: 0.6357 - val_image_quality_output_loss: 0.5727 - val_age_output_loss: 0.4583 - val_weight_output_loss: 0.4152 - val_bag_output_loss: 0.5316 - val_footwear_output_loss: 0.5340 - val_pose_output_loss: 0.5355 - val_emotion_output_loss: 0.3804 - val_gender_output_acc: 0.6257 - val_image_quality_output_acc: 0.7050 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8180 - val_bag_output_acc: 0.7259 - val_footwear_output_acc: 0.7310 - val_pose_output_acc: 0.7475 - val_emotion_output_acc: 0.8601
# Epoch 7/200
# 360/360 [==============================] - 184s 510ms/step - loss: 1.3302 - gender_output_loss: 0.6147 - image_quality_output_loss: 0.5735 - age_output_loss: 0.4527 - weight_output_loss: 0.4205 - bag_output_loss: 0.5360 - footwear_output_loss: 0.5478 - pose_output_loss: 0.5355 - emotion_output_loss: 0.3872 - gender_output_acc: 0.6585 - image_quality_output_acc: 0.7008 - age_output_acc: 0.7996 - weight_output_acc: 0.8175 - bag_output_acc: 0.7209 - footwear_output_acc: 0.7197 - pose_output_acc: 0.7466 - emotion_output_acc: 0.8552 - val_loss: 1.9157 - val_gender_output_loss: 0.8713 - val_image_quality_output_loss: 0.7638 - val_age_output_loss: 0.6334 - val_weight_output_loss: 0.6096 - val_bag_output_loss: 0.7725 - val_footwear_output_loss: 0.7838 - val_pose_output_loss: 0.7969 - val_emotion_output_loss: 0.6146 - val_gender_output_acc: 0.5687 - val_image_quality_output_acc: 0.7025 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8177 - val_bag_output_acc: 0.7232 - val_footwear_output_acc: 0.6806 - val_pose_output_acc: 0.7512 - val_emotion_output_acc: 0.8601
# Epoch 8/200
# 360/360 [==============================] - 183s 509ms/step - loss: 1.3242 - gender_output_loss: 0.6128 - image_quality_output_loss: 0.5747 - age_output_loss: 0.4513 - weight_output_loss: 0.4190 - bag_output_loss: 0.5343 - footwear_output_loss: 0.5407 - pose_output_loss: 0.5299 - emotion_output_loss: 0.3864 - gender_output_acc: 0.6604 - image_quality_output_acc: 0.7013 - age_output_acc: 0.7997 - weight_output_acc: 0.8181 - bag_output_acc: 0.7227 - footwear_output_acc: 0.7251 - pose_output_acc: 0.7502 - emotion_output_acc: 0.8552 - val_loss: 1.4556 - val_gender_output_loss: 0.6155 - val_image_quality_output_loss: 0.6397 - val_age_output_loss: 0.5094 - val_weight_output_loss: 0.4537 - val_bag_output_loss: 0.6002 - val_footwear_output_loss: 0.5878 - val_pose_output_loss: 0.5610 - val_emotion_output_loss: 0.4493 - val_gender_output_acc: 0.6830 - val_image_quality_output_acc: 0.7080 - val_age_output_acc: 0.8001 - val_weight_output_acc: 0.8116 - val_bag_output_acc: 0.7265 - val_footwear_output_acc: 0.7159 - val_pose_output_acc: 0.7631 - val_emotion_output_acc: 0.8601
# Epoch 9/200
# 360/360 [==============================] - 184s 511ms/step - loss: 1.3208 - gender_output_loss: 0.6087 - image_quality_output_loss: 0.5738 - age_output_loss: 0.4512 - weight_output_loss: 0.4198 - bag_output_loss: 0.5317 - footwear_output_loss: 0.5388 - pose_output_loss: 0.5254 - emotion_output_loss: 0.3867 - gender_output_acc: 0.6609 - image_quality_output_acc: 0.7024 - age_output_acc: 0.7996 - weight_output_acc: 0.8166 - bag_output_acc: 0.7232 - footwear_output_acc: 0.7258 - pose_output_acc: 0.7512 - emotion_output_acc: 0.8549 - val_loss: 1.3205 - val_gender_output_loss: 0.6248 - val_image_quality_output_loss: 0.5780 - val_age_output_loss: 0.4563 - val_weight_output_loss: 0.4128 - val_bag_output_loss: 0.5304 - val_footwear_output_loss: 0.5474 - val_pose_output_loss: 0.5161 - val_emotion_output_loss: 0.3769 - val_gender_output_acc: 0.6503 - val_image_quality_output_acc: 0.7012 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8173 - val_bag_output_acc: 0.7267 - val_footwear_output_acc: 0.7242 - val_pose_output_acc: 0.7631 - val_emotion_output_acc: 0.8601
# Epoch 10/200
# 360/360 [==============================] - 184s 510ms/step - loss: 1.3150 - gender_output_loss: 0.5970 - image_quality_output_loss: 0.5730 - age_output_loss: 0.4508 - weight_output_loss: 0.4190 - bag_output_loss: 0.5325 - footwear_output_loss: 0.5382 - pose_output_loss: 0.5185 - emotion_output_loss: 0.3849 - gender_output_acc: 0.6737 - image_quality_output_acc: 0.7017 - age_output_acc: 0.8000 - weight_output_acc: 0.8175 - bag_output_acc: 0.7251 - footwear_output_acc: 0.7294 - pose_output_acc: 0.7558 - emotion_output_acc: 0.8552 - val_loss: 1.3228 - val_gender_output_loss: 0.6648 - val_image_quality_output_loss: 0.5745 - val_age_output_loss: 0.4621 - val_weight_output_loss: 0.4138 - val_bag_output_loss: 0.5243 - val_footwear_output_loss: 0.5357 - val_pose_output_loss: 0.5071 - val_emotion_output_loss: 0.3770 - val_gender_output_acc: 0.5997 - val_image_quality_output_acc: 0.6971 - val_age_output_acc: 0.7992 - val_weight_output_acc: 0.8177 - val_bag_output_acc: 0.7338 - val_footwear_output_acc: 0.7245 - val_pose_output_acc: 0.7655 - val_emotion_output_acc: 0.8601
# Epoch 11/200
# 360/360 [==============================] - 183s 507ms/step - loss: 1.3106 - gender_output_loss: 0.5931 - image_quality_output_loss: 0.5715 - age_output_loss: 0.4501 - weight_output_loss: 0.4185 - bag_output_loss: 0.5316 - footwear_output_loss: 0.5364 - pose_output_loss: 0.5126 - emotion_output_loss: 0.3846 - gender_output_acc: 0.6717 - image_quality_output_acc: 0.7028 - age_output_acc: 0.7993 - weight_output_acc: 0.8185 - bag_output_acc: 0.7249 - footwear_output_acc: 0.7295 - pose_output_acc: 0.7588 - emotion_output_acc: 0.8552 - val_loss: 1.2806 - val_gender_output_loss: 0.5698 - val_image_quality_output_loss: 0.5705 - val_age_output_loss: 0.4501 - val_weight_output_loss: 0.4101 - val_bag_output_loss: 0.5205 - val_footwear_output_loss: 0.5157 - val_pose_output_loss: 0.4850 - val_emotion_output_loss: 0.3750 - val_gender_output_acc: 0.6922 - val_image_quality_output_acc: 0.7039 - val_age_output_acc: 0.8006 - val_weight_output_acc: 0.8199 - val_bag_output_acc: 0.7379 - val_footwear_output_acc: 0.7393 - val_pose_output_acc: 0.7735 - val_emotion_output_acc: 0.8601
# Epoch 12/200
# 360/360 [==============================] - 183s 507ms/step - loss: 1.2967 - gender_output_loss: 0.5746 - image_quality_output_loss: 0.5704 - age_output_loss: 0.4498 - weight_output_loss: 0.4185 - bag_output_loss: 0.5297 - footwear_output_loss: 0.5267 - pose_output_loss: 0.4938 - emotion_output_loss: 0.3831 - gender_output_acc: 0.6917 - image_quality_output_acc: 0.7017 - age_output_acc: 0.7998 - weight_output_acc: 0.8176 - bag_output_acc: 0.7286 - footwear_output_acc: 0.7364 - pose_output_acc: 0.7688 - emotion_output_acc: 0.8553 - val_loss: 1.2705 - val_gender_output_loss: 0.5262 - val_image_quality_output_loss: 0.5730 - val_age_output_loss: 0.4511 - val_weight_output_loss: 0.4121 - val_bag_output_loss: 0.5238 - val_footwear_output_loss: 0.5332 - val_pose_output_loss: 0.4587 - val_emotion_output_loss: 0.3705 - val_gender_output_acc: 0.7222 - val_image_quality_output_acc: 0.7042 - val_age_output_acc: 0.7983 - val_weight_output_acc: 0.8177 - val_bag_output_acc: 0.7290 - val_footwear_output_acc: 0.7272 - val_pose_output_acc: 0.7948 - val_emotion_output_acc: 0.8601
# Epoch 13/200
# 360/360 [==============================] - 182s 507ms/step - loss: 1.2856 - gender_output_loss: 0.5598 - image_quality_output_loss: 0.5699 - age_output_loss: 0.4492 - weight_output_loss: 0.4187 - bag_output_loss: 0.5269 - footwear_output_loss: 0.5249 - pose_output_loss: 0.4765 - emotion_output_loss: 0.3805 - gender_output_acc: 0.7085 - image_quality_output_acc: 0.7035 - age_output_acc: 0.7997 - weight_output_acc: 0.8179 - bag_output_acc: 0.7301 - footwear_output_acc: 0.7374 - pose_output_acc: 0.7784 - emotion_output_acc: 0.8550 - val_loss: 1.3144 - val_gender_output_loss: 0.6214 - val_image_quality_output_loss: 0.5754 - val_age_output_loss: 0.4582 - val_weight_output_loss: 0.4166 - val_bag_output_loss: 0.5462 - val_footwear_output_loss: 0.5278 - val_pose_output_loss: 0.4979 - val_emotion_output_loss: 0.3755 - val_gender_output_acc: 0.6699 - val_image_quality_output_acc: 0.7040 - val_age_output_acc: 0.8004 - val_weight_output_acc: 0.8224 - val_bag_output_acc: 0.7221 - val_footwear_output_acc: 0.7312 - val_pose_output_acc: 0.7902 - val_emotion_output_acc: 0.8601
# Epoch 14/200
# 360/360 [==============================] - 182s 507ms/step - loss: 1.2817 - gender_output_loss: 0.5527 - image_quality_output_loss: 0.5683 - age_output_loss: 0.4488 - weight_output_loss: 0.4168 - bag_output_loss: 0.5265 - footwear_output_loss: 0.5251 - pose_output_loss: 0.4737 - emotion_output_loss: 0.3799 - gender_output_acc: 0.7059 - image_quality_output_acc: 0.7026 - age_output_acc: 0.7996 - weight_output_acc: 0.8172 - bag_output_acc: 0.7322 - footwear_output_acc: 0.7374 - pose_output_acc: 0.7787 - emotion_output_acc: 0.8552 - val_loss: 1.2515 - val_gender_output_loss: 0.4873 - val_image_quality_output_loss: 0.5679 - val_age_output_loss: 0.4514 - val_weight_output_loss: 0.4104 - val_bag_output_loss: 0.5138 - val_footwear_output_loss: 0.5085 - val_pose_output_loss: 0.4631 - val_emotion_output_loss: 0.3705 - val_gender_output_acc: 0.7574 - val_image_quality_output_acc: 0.7063 - val_age_output_acc: 0.7983 - val_weight_output_acc: 0.8212 - val_bag_output_acc: 0.7368 - val_footwear_output_acc: 0.7459 - val_pose_output_acc: 0.7846 - val_emotion_output_acc: 0.8601
# Epoch 15/200
# 360/360 [==============================] - 182s 506ms/step - loss: 1.2687 - gender_output_loss: 0.5281 - image_quality_output_loss: 0.5691 - age_output_loss: 0.4498 - weight_output_loss: 0.4183 - bag_output_loss: 0.5222 - footwear_output_loss: 0.5217 - pose_output_loss: 0.4517 - emotion_output_loss: 0.3786 - gender_output_acc: 0.7293 - image_quality_output_acc: 0.7024 - age_output_acc: 0.7990 - weight_output_acc: 0.8182 - bag_output_acc: 0.7343 - footwear_output_acc: 0.7410 - pose_output_acc: 0.7924 - emotion_output_acc: 0.8550 - val_loss: 1.2307 - val_gender_output_loss: 0.4704 - val_image_quality_output_loss: 0.5665 - val_age_output_loss: 0.4501 - val_weight_output_loss: 0.4114 - val_bag_output_loss: 0.5101 - val_footwear_output_loss: 0.5141 - val_pose_output_loss: 0.4108 - val_emotion_output_loss: 0.3664 - val_gender_output_acc: 0.7684 - val_image_quality_output_acc: 0.7016 - val_age_output_acc: 0.8012 - val_weight_output_acc: 0.8207 - val_bag_output_acc: 0.7381 - val_footwear_output_acc: 0.7427 - val_pose_output_acc: 0.8132 - val_emotion_output_acc: 0.8601
# Epoch 16/200
# 360/360 [==============================] - 182s 507ms/step - loss: 1.2640 - gender_output_loss: 0.5205 - image_quality_output_loss: 0.5676 - age_output_loss: 0.4480 - weight_output_loss: 0.4171 - bag_output_loss: 0.5218 - footwear_output_loss: 0.5239 - pose_output_loss: 0.4454 - emotion_output_loss: 0.3785 - gender_output_acc: 0.7342 - image_quality_output_acc: 0.7031 - age_output_acc: 0.7996 - weight_output_acc: 0.8174 - bag_output_acc: 0.7363 - footwear_output_acc: 0.7386 - pose_output_acc: 0.7943 - emotion_output_acc: 0.8552 - val_loss: 1.2350 - val_gender_output_loss: 0.4791 - val_image_quality_output_loss: 0.5671 - val_age_output_loss: 0.4502 - val_weight_output_loss: 0.4120 - val_bag_output_loss: 0.5120 - val_footwear_output_loss: 0.5192 - val_pose_output_loss: 0.4088 - val_emotion_output_loss: 0.3678 - val_gender_output_acc: 0.7505 - val_image_quality_output_acc: 0.7063 - val_age_output_acc: 0.7994 - val_weight_output_acc: 0.8208 - val_bag_output_acc: 0.7414 - val_footwear_output_acc: 0.7313 - val_pose_output_acc: 0.8069 - val_emotion_output_acc: 0.8601
# Epoch 17/200
# 360/360 [==============================] - 182s 505ms/step - loss: 1.2641 - gender_output_loss: 0.5221 - image_quality_output_loss: 0.5675 - age_output_loss: 0.4482 - weight_output_loss: 0.4166 - bag_output_loss: 0.5229 - footwear_output_loss: 0.5213 - pose_output_loss: 0.4465 - emotion_output_loss: 0.3787 - gender_output_acc: 0.7334 - image_quality_output_acc: 0.7022 - age_output_acc: 0.7991 - weight_output_acc: 0.8186 - bag_output_acc: 0.7313 - footwear_output_acc: 0.7407 - pose_output_acc: 0.7890 - emotion_output_acc: 0.8551 - val_loss: 1.2681 - val_gender_output_loss: 0.5834 - val_image_quality_output_loss: 0.5667 - val_age_output_loss: 0.4515 - val_weight_output_loss: 0.4124 - val_bag_output_loss: 0.5195 - val_footwear_output_loss: 0.5213 - val_pose_output_loss: 0.4294 - val_emotion_output_loss: 0.3741 - val_gender_output_acc: 0.6694 - val_image_quality_output_acc: 0.7037 - val_age_output_acc: 0.8002 - val_weight_output_acc: 0.8167 - val_bag_output_acc: 0.7356 - val_footwear_output_acc: 0.7354 - val_pose_output_acc: 0.7991 - val_emotion_output_acc: 0.8601
# Epoch 18/200
# 360/360 [==============================] - 182s 505ms/step - loss: 1.2567 - gender_output_loss: 0.5127 - image_quality_output_loss: 0.5661 - age_output_loss: 0.4479 - weight_output_loss: 0.4161 - bag_output_loss: 0.5228 - footwear_output_loss: 0.5213 - pose_output_loss: 0.4334 - emotion_output_loss: 0.3767 - gender_output_acc: 0.7358 - image_quality_output_acc: 0.7030 - age_output_acc: 0.7995 - weight_output_acc: 0.8183 - bag_output_acc: 0.7340 - footwear_output_acc: 0.7442 - pose_output_acc: 0.7981 - emotion_output_acc: 0.8551 - val_loss: 1.3178 - val_gender_output_loss: 0.6343 - val_image_quality_output_loss: 0.5719 - val_age_output_loss: 0.4534 - val_weight_output_loss: 0.4220 - val_bag_output_loss: 0.5211 - val_footwear_output_loss: 0.6179 - val_pose_output_loss: 0.4453 - val_emotion_output_loss: 0.3712 - val_gender_output_acc: 0.6436 - val_image_quality_output_acc: 0.7042 - val_age_output_acc: 0.8005 - val_weight_output_acc: 0.8192 - val_bag_output_acc: 0.7262 - val_footwear_output_acc: 0.6682 - val_pose_output_acc: 0.8090 - val_emotion_output_acc: 0.8601
# Epoch 19/200
# 360/360 [==============================] - 182s 507ms/step - loss: 1.2437 - gender_output_loss: 0.4901 - image_quality_output_loss: 0.5647 - age_output_loss: 0.4473 - weight_output_loss: 0.4162 - bag_output_loss: 0.5178 - footwear_output_loss: 0.5118 - pose_output_loss: 0.4229 - emotion_output_loss: 0.3760 - gender_output_acc: 0.7559 - image_quality_output_acc: 0.7048 - age_output_acc: 0.7994 - weight_output_acc: 0.8180 - bag_output_acc: 0.7375 - footwear_output_acc: 0.7491 - pose_output_acc: 0.8045 - emotion_output_acc: 0.8551 - val_loss: 1.2214 - val_gender_output_loss: 0.4433 - val_image_quality_output_loss: 0.5763 - val_age_output_loss: 0.4506 - val_weight_output_loss: 0.4109 - val_bag_output_loss: 0.5107 - val_footwear_output_loss: 0.4951 - val_pose_output_loss: 0.4094 - val_emotion_output_loss: 0.3640 - val_gender_output_acc: 0.7904 - val_image_quality_output_acc: 0.7075 - val_age_output_acc: 0.8002 - val_weight_output_acc: 0.8212 - val_bag_output_acc: 0.7393 - val_footwear_output_acc: 0.7568 - val_pose_output_acc: 0.8099 - val_emotion_output_acc: 0.8601
# Epoch 20/200
# 360/360 [==============================] - 182s 505ms/step - loss: 1.2333 - gender_output_loss: 0.4714 - image_quality_output_loss: 0.5636 - age_output_loss: 0.4471 - weight_output_loss: 0.4152 - bag_output_loss: 0.5160 - footwear_output_loss: 0.5081 - pose_output_loss: 0.4097 - emotion_output_loss: 0.3755 - gender_output_acc: 0.7628 - image_quality_output_acc: 0.7021 - age_output_acc: 0.7999 - weight_output_acc: 0.8182 - bag_output_acc: 0.7386 - footwear_output_acc: 0.7474 - pose_output_acc: 0.8106 - emotion_output_acc: 0.8553 - val_loss: 1.2169 - val_gender_output_loss: 0.4583 - val_image_quality_output_loss: 0.5683 - val_age_output_loss: 0.4531 - val_weight_output_loss: 0.4134 - val_bag_output_loss: 0.5062 - val_footwear_output_loss: 0.5191 - val_pose_output_loss: 0.3671 - val_emotion_output_loss: 0.3627 - val_gender_output_acc: 0.7810 - val_image_quality_output_acc: 0.7032 - val_age_output_acc: 0.7990 - val_weight_output_acc: 0.8180 - val_bag_output_acc: 0.7485 - val_footwear_output_acc: 0.7328 - val_pose_output_acc: 0.8318 - val_emotion_output_acc: 0.8601
# Epoch 21/200
# 360/360 [==============================] - 183s 508ms/step - loss: 1.2326 - gender_output_loss: 0.4744 - image_quality_output_loss: 0.5618 - age_output_loss: 0.4467 - weight_output_loss: 0.4162 - bag_output_loss: 0.5151 - footwear_output_loss: 0.5101 - pose_output_loss: 0.4058 - emotion_output_loss: 0.3752 - gender_output_acc: 0.7670 - image_quality_output_acc: 0.7043 - age_output_acc: 0.7998 - weight_output_acc: 0.8180 - bag_output_acc: 0.7376 - footwear_output_acc: 0.7490 - pose_output_acc: 0.8123 - emotion_output_acc: 0.8553 - val_loss: 1.4514 - val_gender_output_loss: 0.5400 - val_image_quality_output_loss: 0.6325 - val_age_output_loss: 0.5322 - val_weight_output_loss: 0.4971 - val_bag_output_loss: 0.5555 - val_footwear_output_loss: 0.6159 - val_pose_output_loss: 0.4988 - val_emotion_output_loss: 0.4691 - val_gender_output_acc: 0.6992 - val_image_quality_output_acc: 0.7037 - val_age_output_acc: 0.7909 - val_weight_output_acc: 0.8177 - val_bag_output_acc: 0.7226 - val_footwear_output_acc: 0.7298 - val_pose_output_acc: 0.7961 - val_emotion_output_acc: 0.8601
# Epoch 22/200
# 360/360 [==============================] - 183s 508ms/step - loss: 1.2343 - gender_output_loss: 0.4807 - image_quality_output_loss: 0.5615 - age_output_loss: 0.4473 - weight_output_loss: 0.4159 - bag_output_loss: 0.5185 - footwear_output_loss: 0.5084 - pose_output_loss: 0.4046 - emotion_output_loss: 0.3756 - gender_output_acc: 0.7579 - image_quality_output_acc: 0.7045 - age_output_acc: 0.7995 - weight_output_acc: 0.8178 - bag_output_acc: 0.7361 - footwear_output_acc: 0.7513 - pose_output_acc: 0.8153 - emotion_output_acc: 0.8551 - val_loss: 1.2671 - val_gender_output_loss: 0.5835 - val_image_quality_output_loss: 0.5937 - val_age_output_loss: 0.4505 - val_weight_output_loss: 0.4107 - val_bag_output_loss: 0.5353 - val_footwear_output_loss: 0.5219 - val_pose_output_loss: 0.3934 - val_emotion_output_loss: 0.3689 - val_gender_output_acc: 0.6793 - val_image_quality_output_acc: 0.7042 - val_age_output_acc: 0.8009 - val_weight_output_acc: 0.8171 - val_bag_output_acc: 0.7154 - val_footwear_output_acc: 0.7293 - val_pose_output_acc: 0.8239 - val_emotion_output_acc: 0.8601
# Epoch 23/200
# 360/360 [==============================] - 182s 507ms/step - loss: 1.2275 - gender_output_loss: 0.4635 - image_quality_output_loss: 0.5616 - age_output_loss: 0.4464 - weight_output_loss: 0.4149 - bag_output_loss: 0.5148 - footwear_output_loss: 0.5103 - pose_output_loss: 0.3990 - emotion_output_loss: 0.3749 - gender_output_acc: 0.7696 - image_quality_output_acc: 0.7042 - age_output_acc: 0.8001 - weight_output_acc: 0.8182 - bag_output_acc: 0.7404 - footwear_output_acc: 0.7486 - pose_output_acc: 0.8190 - emotion_output_acc: 0.8551 - val_loss: 1.2136 - val_gender_output_loss: 0.4737 - val_image_quality_output_loss: 0.5654 - val_age_output_loss: 0.4500 - val_weight_output_loss: 0.4097 - val_bag_output_loss: 0.5057 - val_footwear_output_loss: 0.5262 - val_pose_output_loss: 0.3476 - val_emotion_output_loss: 0.3664 - val_gender_output_acc: 0.7743 - val_image_quality_output_acc: 0.7006 - val_age_output_acc: 0.7989 - val_weight_output_acc: 0.8197 - val_bag_output_acc: 0.7495 - val_footwear_output_acc: 0.7336 - val_pose_output_acc: 0.8484 - val_emotion_output_acc: 0.8601
# Epoch 24/200
# 360/360 [==============================] - 183s 508ms/step - loss: 1.2289 - gender_output_loss: 0.4717 - image_quality_output_loss: 0.5606 - age_output_loss: 0.4471 - weight_output_loss: 0.4152 - bag_output_loss: 0.5154 - footwear_output_loss: 0.5107 - pose_output_loss: 0.3955 - emotion_output_loss: 0.3758 - gender_output_acc: 0.7677 - image_quality_output_acc: 0.7045 - age_output_acc: 0.8001 - weight_output_acc: 0.8187 - bag_output_acc: 0.7414 - footwear_output_acc: 0.7473 - pose_output_acc: 0.8209 - emotion_output_acc: 0.8552 - val_loss: 1.2378 - val_gender_output_loss: 0.4849 - val_image_quality_output_loss: 0.5602 - val_age_output_loss: 0.4523 - val_weight_output_loss: 0.4120 - val_bag_output_loss: 0.5064 - val_footwear_output_loss: 0.5405 - val_pose_output_loss: 0.3914 - val_emotion_output_loss: 0.3758 - val_gender_output_acc: 0.7755 - val_image_quality_output_acc: 0.7095 - val_age_output_acc: 0.7991 - val_weight_output_acc: 0.8180 - val_bag_output_acc: 0.7540 - val_footwear_output_acc: 0.7249 - val_pose_output_acc: 0.8269 - val_emotion_output_acc: 0.8601
# Epoch 25/200
# 360/360 [==============================] - 183s 508ms/step - loss: 1.2293 - gender_output_loss: 0.4755 - image_quality_output_loss: 0.5617 - age_output_loss: 0.4460 - weight_output_loss: 0.4159 - bag_output_loss: 0.5139 - footwear_output_loss: 0.5080 - pose_output_loss: 0.3973 - emotion_output_loss: 0.3764 - gender_output_acc: 0.7691 - image_quality_output_acc: 0.7047 - age_output_acc: 0.8001 - weight_output_acc: 0.8184 - bag_output_acc: 0.7418 - footwear_output_acc: 0.7512 - pose_output_acc: 0.8183 - emotion_output_acc: 0.8552 - val_loss: 1.2199 - val_gender_output_loss: 0.4670 - val_image_quality_output_loss: 0.5855 - val_age_output_loss: 0.4512 - val_weight_output_loss: 0.4156 - val_bag_output_loss: 0.5037 - val_footwear_output_loss: 0.5196 - val_pose_output_loss: 0.3526 - val_emotion_output_loss: 0.3656 - val_gender_output_acc: 0.7790 - val_image_quality_output_acc: 0.7017 - val_age_output_acc: 0.8001 - val_weight_output_acc: 0.8203 - val_bag_output_acc: 0.7480 - val_footwear_output_acc: 0.7393 - val_pose_output_acc: 0.8429 - val_emotion_output_acc: 0.8601
# Epoch 26/200
# 360/360 [==============================] - 185s 514ms/step - loss: 1.2148 - gender_output_loss: 0.4537 - image_quality_output_loss: 0.5576 - age_output_loss: 0.4458 - weight_output_loss: 0.4141 - bag_output_loss: 0.5110 - footwear_output_loss: 0.5033 - pose_output_loss: 0.3818 - emotion_output_loss: 0.3737 - gender_output_acc: 0.7780 - image_quality_output_acc: 0.7053 - age_output_acc: 0.7998 - weight_output_acc: 0.8185 - bag_output_acc: 0.7422 - footwear_output_acc: 0.7508 - pose_output_acc: 0.8270 - emotion_output_acc: 0.8554 - val_loss: 1.1818 - val_gender_output_loss: 0.4142 - val_image_quality_output_loss: 0.5497 - val_age_output_loss: 0.4482 - val_weight_output_loss: 0.4100 - val_bag_output_loss: 0.5029 - val_footwear_output_loss: 0.4998 - val_pose_output_loss: 0.3353 - val_emotion_output_loss: 0.3613 - val_gender_output_acc: 0.8127 - val_image_quality_output_acc: 0.7087 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8189 - val_bag_output_acc: 0.7495 - val_footwear_output_acc: 0.7551 - val_pose_output_acc: 0.8552 - val_emotion_output_acc: 0.8602
# Epoch 27/200
# 360/360 [==============================] - 186s 517ms/step - loss: 1.2144 - gender_output_loss: 0.4589 - image_quality_output_loss: 0.5582 - age_output_loss: 0.4453 - weight_output_loss: 0.4138 - bag_output_loss: 0.5120 - footwear_output_loss: 0.5048 - pose_output_loss: 0.3750 - emotion_output_loss: 0.3737 - gender_output_acc: 0.7786 - image_quality_output_acc: 0.7052 - age_output_acc: 0.8003 - weight_output_acc: 0.8207 - bag_output_acc: 0.7442 - footwear_output_acc: 0.7529 - pose_output_acc: 0.8324 - emotion_output_acc: 0.8552 - val_loss: 1.2326 - val_gender_output_loss: 0.4212 - val_image_quality_output_loss: 0.5877 - val_age_output_loss: 0.4479 - val_weight_output_loss: 0.4072 - val_bag_output_loss: 0.4965 - val_footwear_output_loss: 0.4850 - val_pose_output_loss: 0.4791 - val_emotion_output_loss: 0.3677 - val_gender_output_acc: 0.8031 - val_image_quality_output_acc: 0.7047 - val_age_output_acc: 0.8009 - val_weight_output_acc: 0.8196 - val_bag_output_acc: 0.7589 - val_footwear_output_acc: 0.7606 - val_pose_output_acc: 0.7518 - val_emotion_output_acc: 0.8601
# Epoch 28/200
# 360/360 [==============================] - 189s 525ms/step - loss: 1.2013 - gender_output_loss: 0.4306 - image_quality_output_loss: 0.5548 - age_output_loss: 0.4455 - weight_output_loss: 0.4151 - bag_output_loss: 0.5070 - footwear_output_loss: 0.4968 - pose_output_loss: 0.3661 - emotion_output_loss: 0.3726 - gender_output_acc: 0.7927 - image_quality_output_acc: 0.7071 - age_output_acc: 0.8002 - weight_output_acc: 0.8184 - bag_output_acc: 0.7494 - footwear_output_acc: 0.7563 - pose_output_acc: 0.8365 - emotion_output_acc: 0.8550 - val_loss: 1.1887 - val_gender_output_loss: 0.4274 - val_image_quality_output_loss: 0.5556 - val_age_output_loss: 0.4484 - val_weight_output_loss: 0.4084 - val_bag_output_loss: 0.5043 - val_footwear_output_loss: 0.4827 - val_pose_output_loss: 0.3487 - val_emotion_output_loss: 0.3707 - val_gender_output_acc: 0.7966 - val_image_quality_output_acc: 0.7090 - val_age_output_acc: 0.8002 - val_weight_output_acc: 0.8187 - val_bag_output_acc: 0.7482 - val_footwear_output_acc: 0.7621 - val_pose_output_acc: 0.8464 - val_emotion_output_acc: 0.8601
# Epoch 29/200
# 360/360 [==============================] - 189s 525ms/step - loss: 1.1921 - gender_output_loss: 0.4270 - image_quality_output_loss: 0.5514 - age_output_loss: 0.4445 - weight_output_loss: 0.4129 - bag_output_loss: 0.5039 - footwear_output_loss: 0.4929 - pose_output_loss: 0.3546 - emotion_output_loss: 0.3712 - gender_output_acc: 0.7974 - image_quality_output_acc: 0.7087 - age_output_acc: 0.8001 - weight_output_acc: 0.8192 - bag_output_acc: 0.7528 - footwear_output_acc: 0.7622 - pose_output_acc: 0.8438 - emotion_output_acc: 0.8554 - val_loss: 1.1744 - val_gender_output_loss: 0.4014 - val_image_quality_output_loss: 0.5511 - val_age_output_loss: 0.4508 - val_weight_output_loss: 0.4057 - val_bag_output_loss: 0.4820 - val_footwear_output_loss: 0.4890 - val_pose_output_loss: 0.3443 - val_emotion_output_loss: 0.3664 - val_gender_output_acc: 0.8194 - val_image_quality_output_acc: 0.7131 - val_age_output_acc: 0.7993 - val_weight_output_acc: 0.8227 - val_bag_output_acc: 0.7715 - val_footwear_output_acc: 0.7647 - val_pose_output_acc: 0.8444 - val_emotion_output_acc: 0.8595
# Epoch 30/200
# 360/360 [==============================] - 186s 517ms/step - loss: 1.1913 - gender_output_loss: 0.4244 - image_quality_output_loss: 0.5523 - age_output_loss: 0.4444 - weight_output_loss: 0.4130 - bag_output_loss: 0.5038 - footwear_output_loss: 0.4917 - pose_output_loss: 0.3534 - emotion_output_loss: 0.3716 - gender_output_acc: 0.7975 - image_quality_output_acc: 0.7067 - age_output_acc: 0.7995 - weight_output_acc: 0.8184 - bag_output_acc: 0.7511 - footwear_output_acc: 0.7601 - pose_output_acc: 0.8430 - emotion_output_acc: 0.8553 - val_loss: 1.1585 - val_gender_output_loss: 0.3940 - val_image_quality_output_loss: 0.5560 - val_age_output_loss: 0.4469 - val_weight_output_loss: 0.4067 - val_bag_output_loss: 0.4881 - val_footwear_output_loss: 0.4867 - val_pose_output_loss: 0.2977 - val_emotion_output_loss: 0.3625 - val_gender_output_acc: 0.8194 - val_image_quality_output_acc: 0.7105 - val_age_output_acc: 0.8015 - val_weight_output_acc: 0.8225 - val_bag_output_acc: 0.7578 - val_footwear_output_acc: 0.7586 - val_pose_output_acc: 0.8709 - val_emotion_output_acc: 0.8601
# Epoch 31/200
# 360/360 [==============================] - 183s 509ms/step - loss: 1.1851 - gender_output_loss: 0.4063 - image_quality_output_loss: 0.5492 - age_output_loss: 0.4434 - weight_output_loss: 0.4133 - bag_output_loss: 0.5011 - footwear_output_loss: 0.4929 - pose_output_loss: 0.3507 - emotion_output_loss: 0.3717 - gender_output_acc: 0.8125 - image_quality_output_acc: 0.7111 - age_output_acc: 0.7999 - weight_output_acc: 0.8185 - bag_output_acc: 0.7541 - footwear_output_acc: 0.7602 - pose_output_acc: 0.8470 - emotion_output_acc: 0.8551 - val_loss: 1.1977 - val_gender_output_loss: 0.4934 - val_image_quality_output_loss: 0.5463 - val_age_output_loss: 0.4471 - val_weight_output_loss: 0.4088 - val_bag_output_loss: 0.5208 - val_footwear_output_loss: 0.5119 - val_pose_output_loss: 0.3086 - val_emotion_output_loss: 0.3642 - val_gender_output_acc: 0.7994 - val_image_quality_output_acc: 0.7181 - val_age_output_acc: 0.8010 - val_weight_output_acc: 0.8229 - val_bag_output_acc: 0.7462 - val_footwear_output_acc: 0.7497 - val_pose_output_acc: 0.8704 - val_emotion_output_acc: 0.8601
# Epoch 32/200
# 360/360 [==============================] - 184s 510ms/step - loss: 1.1826 - gender_output_loss: 0.4070 - image_quality_output_loss: 0.5503 - age_output_loss: 0.4422 - weight_output_loss: 0.4124 - bag_output_loss: 0.4992 - footwear_output_loss: 0.4921 - pose_output_loss: 0.3456 - emotion_output_loss: 0.3724 - gender_output_acc: 0.8088 - image_quality_output_acc: 0.7095 - age_output_acc: 0.7998 - weight_output_acc: 0.8182 - bag_output_acc: 0.7564 - footwear_output_acc: 0.7599 - pose_output_acc: 0.8462 - emotion_output_acc: 0.8552 - val_loss: 1.1526 - val_gender_output_loss: 0.3732 - val_image_quality_output_loss: 0.5468 - val_age_output_loss: 0.4452 - val_weight_output_loss: 0.4053 - val_bag_output_loss: 0.4763 - val_footwear_output_loss: 0.5012 - val_pose_output_loss: 0.3036 - val_emotion_output_loss: 0.3623 - val_gender_output_acc: 0.8286 - val_image_quality_output_acc: 0.7188 - val_age_output_acc: 0.8006 - val_weight_output_acc: 0.8235 - val_bag_output_acc: 0.7717 - val_footwear_output_acc: 0.7488 - val_pose_output_acc: 0.8702 - val_emotion_output_acc: 0.8601
# Epoch 33/200
# 360/360 [==============================] - 183s 509ms/step - loss: 1.1780 - gender_output_loss: 0.4006 - image_quality_output_loss: 0.5486 - age_output_loss: 0.4438 - weight_output_loss: 0.4114 - bag_output_loss: 0.4974 - footwear_output_loss: 0.4909 - pose_output_loss: 0.3413 - emotion_output_loss: 0.3698 - gender_output_acc: 0.8149 - image_quality_output_acc: 0.7115 - age_output_acc: 0.8001 - weight_output_acc: 0.8189 - bag_output_acc: 0.7569 - footwear_output_acc: 0.7569 - pose_output_acc: 0.8520 - emotion_output_acc: 0.8552 - val_loss: 1.1744 - val_gender_output_loss: 0.4702 - val_image_quality_output_loss: 0.5590 - val_age_output_loss: 0.4470 - val_weight_output_loss: 0.4040 - val_bag_output_loss: 0.4851 - val_footwear_output_loss: 0.4838 - val_pose_output_loss: 0.3063 - val_emotion_output_loss: 0.3627 - val_gender_output_acc: 0.7765 - val_image_quality_output_acc: 0.7088 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8214 - val_bag_output_acc: 0.7627 - val_footwear_output_acc: 0.7677 - val_pose_output_acc: 0.8686 - val_emotion_output_acc: 0.8602
# Epoch 34/200

# %%
model
