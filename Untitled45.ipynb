# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepaManjunath/Assignment1/blob/master/Untitled45.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q '/content/gdrive/My Drive/EIP4/hvc_data.zip'
# look for `hvc_annotations.csv` file and `resized` dir
# %ls '/content/gdrive/My Drive/EIP4/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# hvc_data/  hvc_data.zip

# %%
# %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation , Dropout
from keras.layers import AveragePooling2D, Input, Flatten ,GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.callbacks import ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()
# Out:
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
# 3    male         Good  45-55  ...        Neutral  Front-Frontish  resized/4.jpg
# 4  female         Good  35-45  ...        Neutral  Front-Frontish  resized/5.jpg
#
# [5 rows x 9 columns]

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
import numpy as np


def get_random_eraser(p=0.5, s_l=0.01, s_h=0.2, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=32, shuffle=True,augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.batch_size = batch_size
        #self.labels = labels
        #self.list_IDs = list_IDs
        #self.n_channels = n_channels
        #self.n_classes = n_classes
        #self.shuffle = shuffle
        self.on_epoch_end()
        self.augmentation=augmentation
        
        
        #self.on_epoch_end()

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

            
    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        images = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
        if self.augmentation is not None:
           images=self.augmentation.flow(images,shuffle=False).next()
           
        target = {
                       "gender_output": items[_gender_cols_].values,
                       "image_quality_output": items[_imagequality_cols_].values,
                       "age_output": items[_age_cols_].values,
                       "weight_output": items[_weight_cols_].values,
                       "bag_output": items[_carryingbag_cols_].values,
                       "pose_output": items[_bodypose_cols_].values,
                       "footwear_output": items[_footwear_cols_].values,
                       "emotion_output": items[_emotion_cols_].values,
        }
        return images, target
    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
            
   # def __PersonDataGenerator(self,train_df,batch_size=32,augmentation):
      
    #     train_gen = np.stack(train_df, batch_size=32,augmentation=ImageDataGenerator(featurewise_center=False,
     #                           samplewise_center=False,
      #                          featurewise_std_normalization=False,
       #                         samplewise_std_normalization=False,
        #                        zca_whitening=False,
         #                       zca_epsilon=1e-06,
          #                      rotation_range=25,
           #                     width_shift_range=0.1,
            #                    height_shift_range=0.1,
             #                   brightness_range=None,
              #                  shear_range=0.0,
               #                 zoom_range=0.0,
                #                channel_shift_range=0.0,
                 #               fill_mode='nearest',
                  #              cval=0.0,
                   #             horizontal_flip=True,
                    #            vertical_flip=True,
                     #           rescale=None,
                      #          preprocessing_function=get_random_eraser(v_l=0, v_h=1),
                       #         data_format=None,
                        #        validation_split=0.0
                         #       ))
         #image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
          #    if self.augmentation is not None:
           #  image=self.augmentation.flow(image,shuffle=False).next()

   # def on_epoch_end(self):
    #    """Updates indexes after each epoch"""
     #   if self.shuffle == True:
      #      self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
len(train_df)
# Out:
# 11537

# %%
train_df.head()
# Out:
#               image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 2570    resized/2571.jpg              1  ...                        1              0
# 7824    resized/7825.jpg              0  ...                        1              0
# 11394  resized/11396.jpg              1  ...                        1              0
# 4763    resized/4764.jpg              1  ...                        0              0
# 12944  resized/12946.jpg              0  ...                        1              0
#
# [5 rows x 28 columns]

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df,batch_size=32,
                                augmentation=ImageDataGenerator(rescale=1./255,width_shift_range=0.1,
	                                                              height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
	                                                              horizontal_flip=True, fill_mode="nearest", 
                                                                rotation_range=25,preprocessing_function=get_random_eraser(v_l=0, v_h=1)                                                                 
	                                                                                  ))
                       
                                                            
	                                                                                      

                             
                                                        
                                                          



#train_gen = PersonDataGenerator(train_df, batch_size=32,augmentation=True)
                                
valid_gen = PersonDataGenerator(val_df, batch_size=32, shuffle=False,
                                augmentation=ImageDataGenerator(rescale=1./255))

# %%
# get number of output units from data
images, targets = next(iter(valid_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
#from classification_models.resnet import ResNet18, preprocess_input
import keras.applications.resnet 
from keras.applications.inception_v3 import InceptionV3

from keras.applications.resnet import ResNet50

backbone = InceptionV3(
    weights=None, 
    include_top=False, 
    input_tensor=Input(shape=(224, 224, 3))
)
#backbone = resnet_v1((224,224,3),8)
  


neck = backbone.output
neck = Flatten(name="flatten")(neck)
neck = Dense(512, activation="relu")(neck)


def build_tower(in_layer):
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.092)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.092)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.092)(in_layer)
    neck = Dense(28, activation="relu")(neck)
    
    
    return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="sigmoid",name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("pose", build_tower(neck))


model = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
import numpy as np
import tensorflow as tf
import keras

# %%
EPOCHS=24
LEARNING_RATE=1
BATCH_SIZE1=32
BATCH_SIZE2=64
MOMENTUM=0.9

# %%
len_train=len(train_df)
batches_per_epoch = len_train//BATCH_SIZE1

# %%
lr_schedule = lambda t: np.interp([t], [0, (EPOCHS+1)//5, (EPOCHS)], [0.1, LEARNING_RATE, 0.1] )[0]
print(lr_schedule)

#lr_schedule = lambda t: np.interp([t],[0,(EPOCHS+1)//5, (EPOCHS-6)],[0.4, LEARNING_RATE, 0.4])[0]
global_step = tf.train.get_or_create_global_step()
lr_func = lambda: lr_schedule(global_step/batches_per_epoch)/BATCH_SIZE1
#opt.apply_gradients( global_step=global_step)
#opt = tf.train.MomentumOptimizer(lr_func,momentum=MOMENTUM,use_nesterov=False)
# Out:
# <function <lambda> at 0x7efdc2f9b840>

# %%
#t = time.time()
#test_set = tf.data.Dataset.from_tensor_slices((val_df)).batch(BATCH_SIZE)

def lr_schedule1(epoch):
    for epoch1 in range((EPOCHS)):
    #if epoch<=24:
      
         if epoch==epoch1:
          break
     
   
   # tf.keras.backend.set_learning_phase(1)
         opt = tf.train.MomentumOptimizer(lr_func,momentum=MOMENTUM,use_nesterov=False)
         #opt1 = SGD(lr=lr_schedule(epoch+1),momentum=0.9)
        #if epoch==epoch1:
         # break
          
    print('epoch:', epoch, 'lr:', lr_schedule(epoch))
    return(lr_schedule(epoch))

      
     
    #tf.keras.backend.set_learning_phase(0)
    
      #  print('epoch:', epoch+1, 'lr:', lr_schedule(epoch+1))
  #return (lr_schedule(epoch+1))
    #else:
   
    #tf.keras.backend.set_learning_phase(1)
     #   opt = tf.train.MomentumOptimizer(lr_func1,momentum=MOMENTUM,use_nesterov=False)
      #  opt = SGD(lr=lr_schedule(epoch+1),momentum=0.9)
        #model.compile(
         #           optimizer=opt,
          #          loss="categorical_crossentropy", 
           #         loss_weights=loss_weights, 
            #        metrics=["accuracy"]
             #       )
        #model.fit_generator(
         #            generator=train_gen,
          #           validation_data=valid_gen,
           #          use_multiprocessing=True,
            #         workers=6, 
             #        epochs=10,
              #       verbose=1,
      
               #      callbacks=callbacks
                #         )
        #LRFind.plot_loss()

       
    #tf.keras.backend.set_learning_phase(0)
       # print('epoch:', epoch+1, 'lr:', lr_schedule1(epoch+1))

# %%
# model.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=32, epochs=10)

# %%
import matplotlib.pyplot as plt
import keras.backend as K
from keras.callbacks import Callback


class LRFinder(Callback):
    
    '''
    A simple callback for finding the optimal learning rate range for your model + dataset. 
    
    # Usage
        ```python
            lr_finder = LRFinder(min_lr=1e-5, 
                                 max_lr=1e-2, 
                                 steps_per_epoch=np.ceil(epoch_size/batch_size), 
                                 epochs=3)
            model.fit(X_train, Y_train, callbacks=[lr_finder])
            
            lr_finder.plot_loss()
        ```
    
    # Arguments
        min_lr: The lower bound of the learning rate range for the experiment.
        max_lr: The upper bound of the learning rate range for the experiment.
        steps_per_epoch: Number of mini-batches in the dataset. Calculated as `np.ceil(epoch_size/batch_size)`. 
        epochs: Number of epochs to run experiment. Usually between 2 and 4 epochs is sufficient. 
        
    # References
        Blog post: jeremyjordan.me/nn-learning-rate
        Original paper: https://arxiv.org/abs/1506.01186
    '''
    
    def __init__(self, min_lr=1e-5, max_lr=1e-2, steps_per_epoch=5.625, epochs=24):
        super().__init__()
        
        self.min_lr = min_lr
        self.max_lr = max_lr
        self.total_iterations = steps_per_epoch * epochs
        self.iteration = 0
        self.history = {}
        
    def clr(self):
        '''Calculate the learning rate.'''
        x = self.iteration / self.total_iterations 
        return self.min_lr + (self.max_lr-self.min_lr) * x
        
    def on_train_begin(self, logs=None):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.min_lr)
        
    def on_batch_end(self, epoch, logs=None):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.iteration += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.iteration)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
            
        K.set_value(self.model.optimizer.lr, self.clr())
 
    def plot_lr(self):
        '''Helper function to quickly inspect the learning rate schedule.'''
        plt.plot(self.history['iterations'], self.history['lr'])
        plt.yscale('log')
        plt.xlabel('Iteration')
        plt.ylabel('Learning rate')
        plt.show()
        
    def plot_loss(self):
        '''Helper function to quickly observe the learning rate experiment results.'''
        plt.plot(self.history['lr'], self.history['loss'])
        plt.xscale('log')
        plt.xlabel('Learning rate')
        plt.ylabel('Loss')
        plt.show()

# %%
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
#for i in range(EPOCHS):
#lr_scheduler = LearningRateScheduler(lr_schedule1)

# %%
#lr_schedule = lambda t: np.interp([t], [0, (EPOCHS+1)//5, (EPOCHS-6)], [0.4, LEARNING_RATE, 0.4])[0]
#global_step = tf.train.get_or_create_global_step()
#opt.apply_gradients(zip(grads, var), global_step=global_step

# %%
def lr_Schedule(epoch):
  
   # lr=0.00148 
    lr = 1e-3
    #if epoch > 70:
     # lr*= 1e-3
    #if epoch > 40:
     #   lr *= 1e-1
    #if epoch > 30:
      #  lr *= 1e-0
    #if epoch > 20:
     #  lr *= 1e-0
    if epoch > 10:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'image_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=2,
                             save_best_only=True)
#callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
#from keras.callbacks import ModelCheckpoint,LearningRateScheduler

#LRFind=LRFinder(min_lr=1e-5, max_lr=10, steps_per_epoch=(2036//32), epochs=50)
lr_scheduler = LearningRateScheduler(lr_Schedule)
#LRFind.on_tain_begin()
#for i in range(EPOCHS):
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [checkpoint,lr_scheduler,lr_reducer]

# %%
losses = {
 	"gender_output": "binary_crossentropy",
 	"image_quality_output": "binary_crossentropy",
 	"age_output": "binary_crossentropy",
 	"weight_output": "binary_crossentropy",
  "bag_output": "binary_crossentropy",
  "pose_output": "binary_crossentropy",
  "footwear_output": "binary_crossentropy",   
  "emotion_output": "binary_crossentropy",
       

 }
loss_weights = {"gender_output": 0.2, "image_quality_output": 0.3, "age_output": 0.5, "weight_output": 0.4,"bag_output":0.3,"pose_output":0.3,"footwear_output":0.3,"emotion_output":0.4}
model.summary()

opt = SGD(lr=0.0142,momentum=0.9)
#opt = tf.train.MomentumOptimizer(lr=lr_schedule(epoch+1),momentum=MOMENTUM,use_nesterov=False)
#opt.( global_step=global_step)
model.compile(
    optimizer=opt,
    loss="binary_crossentropy", 
    #from_logits=True,
    #loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
    loss_weights=loss_weights, 
    metrics=["accuracy"]
)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 111, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 111, 111, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 111, 111, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 109, 109, 32) 9216        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 109, 109, 32) 96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 109, 109, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 109, 109, 64) 18432       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 109, 109, 64) 192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 109, 109, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 54, 54, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 54, 54, 80)   5120        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 54, 54, 80)   240         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 54, 54, 80)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 52, 52, 192)  138240      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 52, 52, 192)  576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 52, 52, 192)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 192)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 25, 25, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 25, 25, 64)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 25, 25, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 25, 25, 48)   9216        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 25, 25, 96)   55296       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 25, 25, 48)   144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 25, 25, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 25, 25, 48)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 25, 25, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 25, 25, 192)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 25, 25, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 25, 25, 64)   76800       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 25, 25, 96)   82944       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 25, 25, 32)   6144        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 25, 25, 64)   192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 25, 25, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 25, 25, 96)   288         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 25, 25, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 25, 25, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 25, 25, 96)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 25, 25, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 25, 25, 256)  0           activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 25, 25, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 25, 25, 64)   192         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 25, 25, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 25, 25, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 25, 25, 96)   55296       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 48)   144         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 25, 25, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 25, 25, 48)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 25, 25, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 25, 25, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 25, 25, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 25, 25, 64)   76800       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 25, 25, 96)   82944       activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 25, 25, 64)   16384       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 64)   192         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 25, 25, 96)   288         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 25, 25, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 25, 25, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 25, 25, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 25, 25, 96)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 25, 25, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 25, 25, 288)  0           activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 25, 25, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 25, 25, 64)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 25, 25, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 25, 25, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 25, 25, 96)   55296       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 25, 25, 48)   144         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 25, 25, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 25, 25, 48)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 25, 25, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 25, 25, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 25, 25, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 25, 25, 64)   76800       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 25, 25, 96)   82944       activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 25, 25, 64)   18432       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 25, 25, 64)   192         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 25, 25, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 25, 25, 96)   288         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 25, 25, 64)   192         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 25, 25, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 25, 25, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 25, 25, 96)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 25, 25, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 25, 25, 288)  0           activation_20[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 25, 25, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 25, 25, 64)   192         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 25, 25, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 25, 25, 96)   55296       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 25, 25, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 25, 25, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 12, 12, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 12, 12, 96)   82944       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 12, 12, 384)  1152        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 12, 12, 96)   288         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 12, 12, 384)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 96)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 12, 12, 768)  0           activation_27[0][0]
#                                                                  activation_30[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 12, 12, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 12, 12, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 12, 12, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 12, 12, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 12, 12, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 12, 12, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 12, 12, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 12, 12, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 12, 12, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 12, 12, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 12, 12, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 12, 12, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 12, 12, 128)  114688      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 12, 12, 128)  114688      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 12, 12, 128)  384         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 12, 12, 128)  384         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 12, 12, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 12, 12, 128)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 12, 12, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 12, 12, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 12, 12, 192)  172032      activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 12, 12, 192)  172032      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 12, 12, 192)  576         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 12, 12, 192)  576         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 12, 12, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 12, 12, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 12, 12, 192)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 12, 12, 192)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 12, 12, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 12, 12, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 12, 12, 768)  0           activation_31[0][0]
#                                                                  activation_34[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 12, 12, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 12, 12, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 12, 12, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 12, 12, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 12, 12, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 12, 12, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 12, 12, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 12, 12, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 12, 12, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 12, 12, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 12, 12, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 12, 12, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 12, 12, 160)  179200      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 12, 12, 160)  179200      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 12, 12, 160)  480         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 12, 12, 160)  480         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 12, 12, 160)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 12, 12, 160)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 12, 12, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 12, 12, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 12, 12, 192)  215040      activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 12, 12, 192)  215040      activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 12, 12, 192)  576         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 12, 12, 192)  576         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 12, 12, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 12, 12, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 12, 12, 192)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 12, 12, 192)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 12, 12, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 12, 12, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 12, 12, 768)  0           activation_41[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 12, 12, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 12, 12, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 12, 12, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 12, 12, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 12, 12, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 12, 12, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 12, 12, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 12, 12, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 12, 12, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 12, 12, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 12, 12, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 12, 12, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 12, 12, 160)  179200      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 12, 12, 160)  179200      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 12, 12, 160)  480         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 12, 12, 160)  480         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 12, 12, 160)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 12, 12, 160)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 12, 12, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 12, 12, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 12, 12, 192)  215040      activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 12, 12, 192)  215040      activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 12, 12, 192)  576         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 12, 12, 192)  576         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 12, 12, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 12, 12, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 12, 12, 192)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 12, 12, 192)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 12, 12, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 12, 12, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 12, 12, 768)  0           activation_51[0][0]
#                                                                  activation_54[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_60[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 12, 12, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 12, 12, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 12, 12, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 12, 12, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 12, 12, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 12, 12, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 12, 12, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 12, 12, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 12, 12, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 12, 12, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 12, 12, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 12, 12, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 12, 12, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 12, 12, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 12, 12, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 12, 12, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 12, 12, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 12, 12, 192)  258048      activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 12, 12, 192)  258048      activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 12, 12, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 12, 12, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 12, 12, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 12, 12, 192)  576         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 12, 12, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 12, 12, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 12, 12, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 12, 12, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 12, 12, 768)  0           activation_61[0][0]
#                                                                  activation_64[0][0]
#                                                                  activation_69[0][0]
#                                                                  activation_70[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 5, 5, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 5, 5, 384)    1152        conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 5, 5, 192)    245760      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 5, 5, 320)    960         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 5, 5, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 5, 5, 384)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 5, 5, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 5, 5, 384)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 5, 5, 192)    576         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 5, 5, 320)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 5, 5, 768)    0           activation_79[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 5, 5, 768)    0           activation_83[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 5, 5, 192)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 5, 5, 2048)   0           activation_77[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_85[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 5, 5, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 5, 5, 448)    1344        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 5, 5, 448)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 5, 5, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 5, 5, 384)    1548288     activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 5, 5, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 5, 5, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 5, 5, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 5, 5, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 5, 5, 384)    442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 5, 5, 384)    442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 5, 5, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 5, 5, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 5, 5, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 5, 5, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 5, 5, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 5, 5, 384)    1152        conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 5, 5, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 5, 5, 384)    1152        conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 5, 5, 192)    393216      average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 5, 5, 320)    960         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 5, 5, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 5, 5, 384)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 5, 5, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 5, 5, 384)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 5, 5, 192)    576         conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 5, 5, 320)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 5, 5, 768)    0           activation_88[0][0]
#                                                                  activation_89[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 5, 5, 768)    0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 5, 5, 192)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 5, 5, 2048)   0           activation_86[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_94[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 51200)        0           mixed10[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          26214912    flatten[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 28)           14364       dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 28)           14364       dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 28)           14364       dropout_9[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 28)           14364       dropout_12[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 28)           14364       dropout_15[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 28)           14364       dropout_18[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 28)           14364       dropout_24[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 28)           14364       dropout_21[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            58          dense_4[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Dense)    (None, 3)            87          dense_7[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            145         dense_10[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            116         dense_13[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            87          dense_16[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            87          dense_19[0][0]
# __________________________________________________________________________________________________
# pose_output (Dense)             (None, 3)            87          dense_25[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            116         dense_22[0][0]
# ==================================================================================================
# Total params: 48,133,391
# Trainable params: 48,098,959
# Non-trainable params: 34,432
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
#@title Default title text
#for i in range(EPOCHS):
model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    #validation_steps=2036//32,
    use_multiprocessing=True,
    workers=2, 
    epochs=200,
    verbose=1,
    #callbacks=callbacks
    )
LRFind.plot_loss()
# Out:
# Epoch 1/200
# 360/360 [==============================] - 168s 465ms/step - loss: 1.1021 - gender_output_loss: 0.3176 - image_quality_output_loss: 0.5317 - age_output_loss: 0.4296 - weight_output_loss: 0.3948 - bag_output_loss: 0.4634 - footwear_output_loss: 0.4658 - pose_output_loss: 0.2783 - emotion_output_loss: 0.3603 - gender_output_acc: 0.8632 - image_quality_output_acc: 0.7257 - age_output_acc: 0.8018 - weight_output_acc: 0.8261 - bag_output_acc: 0.7828 - footwear_output_acc: 0.7726 - pose_output_acc: 0.8823 - emotion_output_acc: 0.8569 - val_loss: 1.7364 - val_gender_output_loss: 1.3675 - val_image_quality_output_loss: 0.7000 - val_age_output_loss: 0.5055 - val_weight_output_loss: 0.4641 - val_bag_output_loss: 0.6583 - val_footwear_output_loss: 0.7566 - val_pose_output_loss: 0.6681 - val_emotion_output_loss: 0.4740 - val_gender_output_acc: 0.5556 - val_image_quality_output_acc: 0.6329 - val_age_output_acc: 0.7880 - val_weight_output_acc: 0.8145 - val_bag_output_acc: 0.7330 - val_footwear_output_acc: 0.6658 - val_pose_output_acc: 0.7659 - val_emotion_output_acc: 0.8531
# Epoch 2/200
# 360/360 [==============================] - 170s 473ms/step - loss: 1.0970 - gender_output_loss: 0.3097 - image_quality_output_loss: 0.5333 - age_output_loss: 0.4305 - weight_output_loss: 0.3933 - bag_output_loss: 0.4578 - footwear_output_loss: 0.4602 - pose_output_loss: 0.2780 - emotion_output_loss: 0.3594 - gender_output_acc: 0.8674 - image_quality_output_acc: 0.7217 - age_output_acc: 0.8006 - weight_output_acc: 0.8269 - bag_output_acc: 0.7885 - footwear_output_acc: 0.7751 - pose_output_acc: 0.8847 - emotion_output_acc: 0.8570 - val_loss: 1.1372 - val_gender_output_loss: 0.3693 - val_image_quality_output_loss: 0.5355 - val_age_output_loss: 0.4366 - val_weight_output_loss: 0.3968 - val_bag_output_loss: 0.4745 - val_footwear_output_loss: 0.4559 - val_pose_output_loss: 0.3230 - val_emotion_output_loss: 0.3742 - val_gender_output_acc: 0.8442 - val_image_quality_output_acc: 0.7197 - val_age_output_acc: 0.7977 - val_weight_output_acc: 0.8273 - val_bag_output_acc: 0.7733 - val_footwear_output_acc: 0.7784 - val_pose_output_acc: 0.8682 - val_emotion_output_acc: 0.8533
# Epoch 3/200
# 360/360 [==============================] - 170s 472ms/step - loss: 1.0941 - gender_output_loss: 0.3034 - image_quality_output_loss: 0.5315 - age_output_loss: 0.4290 - weight_output_loss: 0.3924 - bag_output_loss: 0.4564 - footwear_output_loss: 0.4638 - pose_output_loss: 0.2777 - emotion_output_loss: 0.3580 - gender_output_acc: 0.8697 - image_quality_output_acc: 0.7231 - age_output_acc: 0.8007 - weight_output_acc: 0.8275 - bag_output_acc: 0.7874 - footwear_output_acc: 0.7756 - pose_output_acc: 0.8838 - emotion_output_acc: 0.8570 - val_loss: 1.1613 - val_gender_output_loss: 0.3946 - val_image_quality_output_loss: 0.5432 - val_age_output_loss: 0.4480 - val_weight_output_loss: 0.4048 - val_bag_output_loss: 0.4970 - val_footwear_output_loss: 0.4735 - val_pose_output_loss: 0.3120 - val_emotion_output_loss: 0.3719 - val_gender_output_acc: 0.8363 - val_image_quality_output_acc: 0.7148 - val_age_output_acc: 0.7988 - val_weight_output_acc: 0.8255 - val_bag_output_acc: 0.7569 - val_footwear_output_acc: 0.7722 - val_pose_output_acc: 0.8738 - val_emotion_output_acc: 0.8526
# Epoch 4/200
# 360/360 [==============================] - 171s 475ms/step - loss: 1.0903 - gender_output_loss: 0.3001 - image_quality_output_loss: 0.5298 - age_output_loss: 0.4284 - weight_output_loss: 0.3903 - bag_output_loss: 0.4586 - footwear_output_loss: 0.4587 - pose_output_loss: 0.2751 - emotion_output_loss: 0.3582 - gender_output_acc: 0.8720 - image_quality_output_acc: 0.7252 - age_output_acc: 0.7997 - weight_output_acc: 0.8272 - bag_output_acc: 0.7842 - footwear_output_acc: 0.7801 - pose_output_acc: 0.8858 - emotion_output_acc: 0.8564 - val_loss: 1.2112 - val_gender_output_loss: 0.4432 - val_image_quality_output_loss: 0.5821 - val_age_output_loss: 0.4446 - val_weight_output_loss: 0.4013 - val_bag_output_loss: 0.5305 - val_footwear_output_loss: 0.4722 - val_pose_output_loss: 0.3807 - val_emotion_output_loss: 0.3753 - val_gender_output_acc: 0.8356 - val_image_quality_output_acc: 0.6791 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8230 - val_bag_output_acc: 0.7482 - val_footwear_output_acc: 0.7745 - val_pose_output_acc: 0.8555 - val_emotion_output_acc: 0.8485
# Epoch 5/200
# 360/360 [==============================] - 171s 474ms/step - loss: 1.0891 - gender_output_loss: 0.3019 - image_quality_output_loss: 0.5290 - age_output_loss: 0.4275 - weight_output_loss: 0.3915 - bag_output_loss: 0.4575 - footwear_output_loss: 0.4587 - pose_output_loss: 0.2704 - emotion_output_loss: 0.3592 - gender_output_acc: 0.8697 - image_quality_output_acc: 0.7238 - age_output_acc: 0.8017 - weight_output_acc: 0.8272 - bag_output_acc: 0.7870 - footwear_output_acc: 0.7773 - pose_output_acc: 0.8877 - emotion_output_acc: 0.8569 - val_loss: 1.1630 - val_gender_output_loss: 0.3801 - val_image_quality_output_loss: 0.5741 - val_age_output_loss: 0.4371 - val_weight_output_loss: 0.4012 - val_bag_output_loss: 0.4849 - val_footwear_output_loss: 0.4717 - val_pose_output_loss: 0.3298 - val_emotion_output_loss: 0.3746 - val_gender_output_acc: 0.8383 - val_image_quality_output_acc: 0.7001 - val_age_output_acc: 0.7987 - val_weight_output_acc: 0.8276 - val_bag_output_acc: 0.7750 - val_footwear_output_acc: 0.7751 - val_pose_output_acc: 0.8619 - val_emotion_output_acc: 0.8533
# Epoch 6/200
# 360/360 [==============================] - 171s 474ms/step - loss: 1.0865 - gender_output_loss: 0.2967 - image_quality_output_loss: 0.5305 - age_output_loss: 0.4281 - weight_output_loss: 0.3922 - bag_output_loss: 0.4551 - footwear_output_loss: 0.4586 - pose_output_loss: 0.2666 - emotion_output_loss: 0.3573 - gender_output_acc: 0.8720 - image_quality_output_acc: 0.7238 - age_output_acc: 0.8016 - weight_output_acc: 0.8269 - bag_output_acc: 0.7876 - footwear_output_acc: 0.7775 - pose_output_acc: 0.8894 - emotion_output_acc: 0.8569 - val_loss: 1.1620 - val_gender_output_loss: 0.3847 - val_image_quality_output_loss: 0.5464 - val_age_output_loss: 0.4389 - val_weight_output_loss: 0.4001 - val_bag_output_loss: 0.4794 - val_footwear_output_loss: 0.4764 - val_pose_output_loss: 0.3516 - val_emotion_output_loss: 0.3733 - val_gender_output_acc: 0.8229 - val_image_quality_output_acc: 0.7178 - val_age_output_acc: 0.7964 - val_weight_output_acc: 0.8271 - val_bag_output_acc: 0.7715 - val_footwear_output_acc: 0.7679 - val_pose_output_acc: 0.8684 - val_emotion_output_acc: 0.8532
# Epoch 7/200
# 360/360 [==============================] - 170s 473ms/step - loss: 1.0790 - gender_output_loss: 0.2901 - image_quality_output_loss: 0.5271 - age_output_loss: 0.4276 - weight_output_loss: 0.3885 - bag_output_loss: 0.4529 - footwear_output_loss: 0.4587 - pose_output_loss: 0.2567 - emotion_output_loss: 0.3579 - gender_output_acc: 0.8756 - image_quality_output_acc: 0.7263 - age_output_acc: 0.8007 - weight_output_acc: 0.8278 - bag_output_acc: 0.7871 - footwear_output_acc: 0.7772 - pose_output_acc: 0.8926 - emotion_output_acc: 0.8566 - val_loss: 1.1477 - val_gender_output_loss: 0.3941 - val_image_quality_output_loss: 0.5372 - val_age_output_loss: 0.4350 - val_weight_output_loss: 0.3950 - val_bag_output_loss: 0.4782 - val_footwear_output_loss: 0.4720 - val_pose_output_loss: 0.3275 - val_emotion_output_loss: 0.3721 - val_gender_output_acc: 0.8279 - val_image_quality_output_acc: 0.7189 - val_age_output_acc: 0.7977 - val_weight_output_acc: 0.8281 - val_bag_output_acc: 0.7760 - val_footwear_output_acc: 0.7740 - val_pose_output_acc: 0.8672 - val_emotion_output_acc: 0.8514
# Epoch 8/200
# 360/360 [==============================] - 172s 477ms/step - loss: 1.0770 - gender_output_loss: 0.2863 - image_quality_output_loss: 0.5248 - age_output_loss: 0.4265 - weight_output_loss: 0.3914 - bag_output_loss: 0.4506 - footwear_output_loss: 0.4547 - pose_output_loss: 0.2593 - emotion_output_loss: 0.3578 - gender_output_acc: 0.8782 - image_quality_output_acc: 0.7284 - age_output_acc: 0.8017 - weight_output_acc: 0.8271 - bag_output_acc: 0.7902 - footwear_output_acc: 0.7781 - pose_output_acc: 0.8928 - emotion_output_acc: 0.8564 - val_loss: 1.1573 - val_gender_output_loss: 0.3807 - val_image_quality_output_loss: 0.5554 - val_age_output_loss: 0.4361 - val_weight_output_loss: 0.4039 - val_bag_output_loss: 0.4880 - val_footwear_output_loss: 0.4729 - val_pose_output_loss: 0.3179 - val_emotion_output_loss: 0.3781 - val_gender_output_acc: 0.8378 - val_image_quality_output_acc: 0.7012 - val_age_output_acc: 0.7984 - val_weight_output_acc: 0.8227 - val_bag_output_acc: 0.7627 - val_footwear_output_acc: 0.7707 - val_pose_output_acc: 0.8705 - val_emotion_output_acc: 0.8509
# Epoch 9/200
# 360/360 [==============================] - 170s 473ms/step - loss: 1.0766 - gender_output_loss: 0.2875 - image_quality_output_loss: 0.5270 - age_output_loss: 0.4256 - weight_output_loss: 0.3869 - bag_output_loss: 0.4520 - footwear_output_loss: 0.4581 - pose_output_loss: 0.2596 - emotion_output_loss: 0.3564 - gender_output_acc: 0.8783 - image_quality_output_acc: 0.7293 - age_output_acc: 0.8018 - weight_output_acc: 0.8299 - bag_output_acc: 0.7902 - footwear_output_acc: 0.7782 - pose_output_acc: 0.8913 - emotion_output_acc: 0.8573 - val_loss: 1.1908 - val_gender_output_loss: 0.3970 - val_image_quality_output_loss: 0.5531 - val_age_output_loss: 0.4440 - val_weight_output_loss: 0.4083 - val_bag_output_loss: 0.5024 - val_footwear_output_loss: 0.4891 - val_pose_output_loss: 0.3576 - val_emotion_output_loss: 0.3885 - val_gender_output_acc: 0.8388 - val_image_quality_output_acc: 0.7146 - val_age_output_acc: 0.7991 - val_weight_output_acc: 0.8227 - val_bag_output_acc: 0.7642 - val_footwear_output_acc: 0.7607 - val_pose_output_acc: 0.8689 - val_emotion_output_acc: 0.8501
# Epoch 10/200
# 360/360 [==============================] - 171s 476ms/step - loss: 1.0703 - gender_output_loss: 0.2784 - image_quality_output_loss: 0.5274 - age_output_loss: 0.4255 - weight_output_loss: 0.3889 - bag_output_loss: 0.4472 - footwear_output_loss: 0.4538 - pose_output_loss: 0.2519 - emotion_output_loss: 0.3555 - gender_output_acc: 0.8838 - image_quality_output_acc: 0.7277 - age_output_acc: 0.8033 - weight_output_acc: 0.8291 - bag_output_acc: 0.7928 - footwear_output_acc: 0.7796 - pose_output_acc: 0.8967 - emotion_output_acc: 0.8570 - val_loss: 1.1599 - val_gender_output_loss: 0.3560 - val_image_quality_output_loss: 0.5670 - val_age_output_loss: 0.4391 - val_weight_output_loss: 0.4013 - val_bag_output_loss: 0.4814 - val_footwear_output_loss: 0.4764 - val_pose_output_loss: 0.3379 - val_emotion_output_loss: 0.3746 - val_gender_output_acc: 0.8564 - val_image_quality_output_acc: 0.6925 - val_age_output_acc: 0.8013 - val_weight_output_acc: 0.8224 - val_bag_output_acc: 0.7740 - val_footwear_output_acc: 0.7641 - val_pose_output_acc: 0.8720 - val_emotion_output_acc: 0.8501
# Epoch 11/200
# 360/360 [==============================] - 171s 475ms/step - loss: 1.0682 - gender_output_loss: 0.2776 - image_quality_output_loss: 0.5231 - age_output_loss: 0.4256 - weight_output_loss: 0.3850 - bag_output_loss: 0.4470 - footwear_output_loss: 0.4528 - pose_output_loss: 0.2553 - emotion_output_loss: 0.3560 - gender_output_acc: 0.8813 - image_quality_output_acc: 0.7312 - age_output_acc: 0.8014 - weight_output_acc: 0.8303 - bag_output_acc: 0.7938 - footwear_output_acc: 0.7817 - pose_output_acc: 0.8929 - emotion_output_acc: 0.8576 - val_loss: 1.1702 - val_gender_output_loss: 0.3857 - val_image_quality_output_loss: 0.5538 - val_age_output_loss: 0.4374 - val_weight_output_loss: 0.4056 - val_bag_output_loss: 0.4854 - val_footwear_output_loss: 0.4787 - val_pose_output_loss: 0.3486 - val_emotion_output_loss: 0.3804 - val_gender_output_acc: 0.8368 - val_image_quality_output_acc: 0.7141 - val_age_output_acc: 0.7986 - val_weight_output_acc: 0.8116 - val_bag_output_acc: 0.7727 - val_footwear_output_acc: 0.7745 - val_pose_output_acc: 0.8699 - val_emotion_output_acc: 0.8501
# Epoch 12/200
# 360/360 [==============================] - 172s 478ms/step - loss: 1.0641 - gender_output_loss: 0.2725 - image_quality_output_loss: 0.5211 - age_output_loss: 0.4240 - weight_output_loss: 0.3852 - bag_output_loss: 0.4421 - footwear_output_loss: 0.4563 - pose_output_loss: 0.2528 - emotion_output_loss: 0.3546 - gender_output_acc: 0.8835 - image_quality_output_acc: 0.7317 - age_output_acc: 0.8013 - weight_output_acc: 0.8296 - bag_output_acc: 0.7979 - footwear_output_acc: 0.7798 - pose_output_acc: 0.8944 - emotion_output_acc: 0.8567 - val_loss: 1.1779 - val_gender_output_loss: 0.3855 - val_image_quality_output_loss: 0.5437 - val_age_output_loss: 0.4361 - val_weight_output_loss: 0.4019 - val_bag_output_loss: 0.4971 - val_footwear_output_loss: 0.4983 - val_pose_output_loss: 0.3648 - val_emotion_output_loss: 0.3770 - val_gender_output_acc: 0.8403 - val_image_quality_output_acc: 0.7181 - val_age_output_acc: 0.7991 - val_weight_output_acc: 0.8282 - val_bag_output_acc: 0.7760 - val_footwear_output_acc: 0.7646 - val_pose_output_acc: 0.8748 - val_emotion_output_acc: 0.8518
# Epoch 13/200
# 360/360 [==============================] - 168s 467ms/step - loss: 1.0606 - gender_output_loss: 0.2713 - image_quality_output_loss: 0.5224 - age_output_loss: 0.4245 - weight_output_loss: 0.3848 - bag_output_loss: 0.4404 - footwear_output_loss: 0.4513 - pose_output_loss: 0.2476 - emotion_output_loss: 0.3541 - gender_output_acc: 0.8870 - image_quality_output_acc: 0.7306 - age_output_acc: 0.8022 - weight_output_acc: 0.8292 - bag_output_acc: 0.7987 - footwear_output_acc: 0.7828 - pose_output_acc: 0.8968 - emotion_output_acc: 0.8574 - val_loss: 1.1527 - val_gender_output_loss: 0.3660 - val_image_quality_output_loss: 0.5479 - val_age_output_loss: 0.4333 - val_weight_output_loss: 0.3977 - val_bag_output_loss: 0.4877 - val_footwear_output_loss: 0.4716 - val_pose_output_loss: 0.3444 - val_emotion_output_loss: 0.3707 - val_gender_output_acc: 0.8395 - val_image_quality_output_acc: 0.7176 - val_age_output_acc: 0.8019 - val_weight_output_acc: 0.8279 - val_bag_output_acc: 0.7655 - val_footwear_output_acc: 0.7685 - val_pose_output_acc: 0.8733 - val_emotion_output_acc: 0.8506
# Epoch 14/200
# 360/360 [==============================] - 166s 461ms/step - loss: 1.0512 - gender_output_loss: 0.2676 - image_quality_output_loss: 0.5224 - age_output_loss: 0.4208 - weight_output_loss: 0.3807 - bag_output_loss: 0.4336 - footwear_output_loss: 0.4461 - pose_output_loss: 0.2414 - emotion_output_loss: 0.3548 - gender_output_acc: 0.8877 - image_quality_output_acc: 0.7304 - age_output_acc: 0.8035 - weight_output_acc: 0.8326 - bag_output_acc: 0.8029 - footwear_output_acc: 0.7829 - pose_output_acc: 0.9033 - emotion_output_acc: 0.8572 - val_loss: 1.1514 - val_gender_output_loss: 0.3524 - val_image_quality_output_loss: 0.5485 - val_age_output_loss: 0.4407 - val_weight_output_loss: 0.4046 - val_bag_output_loss: 0.5002 - val_footwear_output_loss: 0.4701 - val_pose_output_loss: 0.3093 - val_emotion_output_loss: 0.3756 - val_gender_output_acc: 0.8492 - val_image_quality_output_acc: 0.7138 - val_age_output_acc: 0.7998 - val_weight_output_acc: 0.8250 - val_bag_output_acc: 0.7652 - val_footwear_output_acc: 0.7730 - val_pose_output_acc: 0.8795 - val_emotion_output_acc: 0.8512
# Epoch 15/200
# 360/360 [==============================] - 168s 467ms/step - loss: 1.0469 - gender_output_loss: 0.2616 - image_quality_output_loss: 0.5186 - age_output_loss: 0.4212 - weight_output_loss: 0.3804 - bag_output_loss: 0.4344 - footwear_output_loss: 0.4408 - pose_output_loss: 0.2416 - emotion_output_loss: 0.3531 - gender_output_acc: 0.8906 - image_quality_output_acc: 0.7335 - age_output_acc: 0.8040 - weight_output_acc: 0.8314 - bag_output_acc: 0.8025 - footwear_output_acc: 0.7891 - pose_output_acc: 0.9012 - emotion_output_acc: 0.8574 - val_loss: 1.1623 - val_gender_output_loss: 0.3918 - val_image_quality_output_loss: 0.5577 - val_age_output_loss: 0.4338 - val_weight_output_loss: 0.3988 - val_bag_output_loss: 0.4966 - val_footwear_output_loss: 0.4847 - val_pose_output_loss: 0.3169 - val_emotion_output_loss: 0.3767 - val_gender_output_acc: 0.8395 - val_image_quality_output_acc: 0.7004 - val_age_output_acc: 0.8005 - val_weight_output_acc: 0.8305 - val_bag_output_acc: 0.7755 - val_footwear_output_acc: 0.7695 - val_pose_output_acc: 0.8806 - val_emotion_output_acc: 0.8521
# Epoch 16/200
# 360/360 [==============================] - 168s 467ms/step - loss: 1.0475 - gender_output_loss: 0.2640 - image_quality_output_loss: 0.5188 - age_output_loss: 0.4212 - weight_output_loss: 0.3810 - bag_output_loss: 0.4371 - footwear_output_loss: 0.4450 - pose_output_loss: 0.2328 - emotion_output_loss: 0.3539 - gender_output_acc: 0.8898 - image_quality_output_acc: 0.7337 - age_output_acc: 0.8033 - weight_output_acc: 0.8317 - bag_output_acc: 0.8024 - footwear_output_acc: 0.7843 - pose_output_acc: 0.9046 - emotion_output_acc: 0.8573 - val_loss: 1.1452 - val_gender_output_loss: 0.3431 - val_image_quality_output_loss: 0.5446 - val_age_output_loss: 0.4393 - val_weight_output_loss: 0.3977 - val_bag_output_loss: 0.4874 - val_footwear_output_loss: 0.4733 - val_pose_output_loss: 0.3212 - val_emotion_output_loss: 0.3747 - val_gender_output_acc: 0.8678 - val_image_quality_output_acc: 0.7059 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8278 - val_bag_output_acc: 0.7708 - val_footwear_output_acc: 0.7741 - val_pose_output_acc: 0.8732 - val_emotion_output_acc: 0.8524
# Epoch 17/200
# 360/360 [==============================] - 165s 458ms/step - loss: 1.0416 - gender_output_loss: 0.2489 - image_quality_output_loss: 0.5201 - age_output_loss: 0.4207 - weight_output_loss: 0.3795 - bag_output_loss: 0.4312 - footwear_output_loss: 0.4371 - pose_output_loss: 0.2407 - emotion_output_loss: 0.3524 - gender_output_acc: 0.8957 - image_quality_output_acc: 0.7324 - age_output_acc: 0.8021 - weight_output_acc: 0.8319 - bag_output_acc: 0.8064 - footwear_output_acc: 0.7904 - pose_output_acc: 0.9011 - emotion_output_acc: 0.8587 - val_loss: 1.1800 - val_gender_output_loss: 0.4037 - val_image_quality_output_loss: 0.5439 - val_age_output_loss: 0.4443 - val_weight_output_loss: 0.4116 - val_bag_output_loss: 0.5185 - val_footwear_output_loss: 0.4852 - val_pose_output_loss: 0.3232 - val_emotion_output_loss: 0.3781 - val_gender_output_acc: 0.8418 - val_image_quality_output_acc: 0.7176 - val_age_output_acc: 0.7984 - val_weight_output_acc: 0.8218 - val_bag_output_acc: 0.7654 - val_footwear_output_acc: 0.7664 - val_pose_output_acc: 0.8714 - val_emotion_output_acc: 0.8460
# Epoch 18/200
# 360/360 [==============================] - 162s 451ms/step - loss: 1.0382 - gender_output_loss: 0.2536 - image_quality_output_loss: 0.5160 - age_output_loss: 0.4199 - weight_output_loss: 0.3778 - bag_output_loss: 0.4305 - footwear_output_loss: 0.4397 - pose_output_loss: 0.2341 - emotion_output_loss: 0.3508 - gender_output_acc: 0.8950 - image_quality_output_acc: 0.7337 - age_output_acc: 0.8035 - weight_output_acc: 0.8342 - bag_output_acc: 0.8035 - footwear_output_acc: 0.7885 - pose_output_acc: 0.9037 - emotion_output_acc: 0.8579 - val_loss: 1.1671 - val_gender_output_loss: 0.3840 - val_image_quality_output_loss: 0.5503 - val_age_output_loss: 0.4409 - val_weight_output_loss: 0.4077 - val_bag_output_loss: 0.5012 - val_footwear_output_loss: 0.4670 - val_pose_output_loss: 0.3386 - val_emotion_output_loss: 0.3741 - val_gender_output_acc: 0.8413 - val_image_quality_output_acc: 0.7128 - val_age_output_acc: 0.8001 - val_weight_output_acc: 0.8196 - val_bag_output_acc: 0.7652 - val_footwear_output_acc: 0.7700 - val_pose_output_acc: 0.8651 - val_emotion_output_acc: 0.8517
# Epoch 19/200
# 360/360 [==============================] - 164s 456ms/step - loss: 1.0387 - gender_output_loss: 0.2579 - image_quality_output_loss: 0.5203 - age_output_loss: 0.4194 - weight_output_loss: 0.3771 - bag_output_loss: 0.4286 - footwear_output_loss: 0.4407 - pose_output_loss: 0.2305 - emotion_output_loss: 0.3512 - gender_output_acc: 0.8911 - image_quality_output_acc: 0.7310 - age_output_acc: 0.8041 - weight_output_acc: 0.8317 - bag_output_acc: 0.8058 - footwear_output_acc: 0.7861 - pose_output_acc: 0.9073 - emotion_output_acc: 0.8579 - val_loss: 1.2051 - val_gender_output_loss: 0.4540 - val_image_quality_output_loss: 0.5651 - val_age_output_loss: 0.4473 - val_weight_output_loss: 0.4083 - val_bag_output_loss: 0.5468 - val_footwear_output_loss: 0.4656 - val_pose_output_loss: 0.3393 - val_emotion_output_loss: 0.3807 - val_gender_output_acc: 0.8304 - val_image_quality_output_acc: 0.7057 - val_age_output_acc: 0.7942 - val_weight_output_acc: 0.8220 - val_bag_output_acc: 0.7573 - val_footwear_output_acc: 0.7688 - val_pose_output_acc: 0.8649 - val_emotion_output_acc: 0.8477
# Epoch 20/200
# 360/360 [==============================] - 167s 463ms/step - loss: 1.0281 - gender_output_loss: 0.2406 - image_quality_output_loss: 0.5159 - age_output_loss: 0.4187 - weight_output_loss: 0.3742 - bag_output_loss: 0.4242 - footwear_output_loss: 0.4377 - pose_output_loss: 0.2247 - emotion_output_loss: 0.3506 - gender_output_acc: 0.8997 - image_quality_output_acc: 0.7362 - age_output_acc: 0.8033 - weight_output_acc: 0.8337 - bag_output_acc: 0.8093 - footwear_output_acc: 0.7898 - pose_output_acc: 0.9072 - emotion_output_acc: 0.8578 - val_loss: 1.2269 - val_gender_output_loss: 0.4103 - val_image_quality_output_loss: 0.5867 - val_age_output_loss: 0.4450 - val_weight_output_loss: 0.4245 - val_bag_output_loss: 0.5085 - val_footwear_output_loss: 0.5184 - val_pose_output_loss: 0.3848 - val_emotion_output_loss: 0.3825 - val_gender_output_acc: 0.8442 - val_image_quality_output_acc: 0.6898 - val_age_output_acc: 0.7982 - val_weight_output_acc: 0.8025 - val_bag_output_acc: 0.7586 - val_footwear_output_acc: 0.7679 - val_pose_output_acc: 0.8697 - val_emotion_output_acc: 0.8440
# Epoch 21/200
# 360/360 [==============================] - 169s 470ms/step - loss: 1.0284 - gender_output_loss: 0.2413 - image_quality_output_loss: 0.5170 - age_output_loss: 0.4184 - weight_output_loss: 0.3726 - bag_output_loss: 0.4229 - footwear_output_loss: 0.4373 - pose_output_loss: 0.2285 - emotion_output_loss: 0.3504 - gender_output_acc: 0.9011 - image_quality_output_acc: 0.7334 - age_output_acc: 0.8040 - weight_output_acc: 0.8346 - bag_output_acc: 0.8103 - footwear_output_acc: 0.7926 - pose_output_acc: 0.9088 - emotion_output_acc: 0.8580 - val_loss: 1.1934 - val_gender_output_loss: 0.3969 - val_image_quality_output_loss: 0.5982 - val_age_output_loss: 0.4438 - val_weight_output_loss: 0.4173 - val_bag_output_loss: 0.4885 - val_footwear_output_loss: 0.4841 - val_pose_output_loss: 0.3325 - val_emotion_output_loss: 0.3854 - val_gender_output_acc: 0.8333 - val_image_quality_output_acc: 0.6936 - val_age_output_acc: 0.7973 - val_weight_output_acc: 0.8264 - val_bag_output_acc: 0.7713 - val_footwear_output_acc: 0.7687 - val_pose_output_acc: 0.8694 - val_emotion_output_acc: 0.8512
# Epoch 22/200
# 360/360 [==============================] - 167s 464ms/step - loss: 1.0243 - gender_output_loss: 0.2387 - image_quality_output_loss: 0.5156 - age_output_loss: 0.4179 - weight_output_loss: 0.3716 - bag_output_loss: 0.4219 - footwear_output_loss: 0.4351 - pose_output_loss: 0.2276 - emotion_output_loss: 0.3472 - gender_output_acc: 0.8983 - image_quality_output_acc: 0.7359 - age_output_acc: 0.8050 - weight_output_acc: 0.8366 - bag_output_acc: 0.8098 - footwear_output_acc: 0.7906 - pose_output_acc: 0.9048 - emotion_output_acc: 0.8599 - val_loss: 1.1460 - val_gender_output_loss: 0.3411 - val_image_quality_output_loss: 0.5529 - val_age_output_loss: 0.4354 - val_weight_output_loss: 0.4008 - val_bag_output_loss: 0.4872 - val_footwear_output_loss: 0.4663 - val_pose_output_loss: 0.3208 - val_emotion_output_loss: 0.3790 - val_gender_output_acc: 0.8584 - val_image_quality_output_acc: 0.7100 - val_age_output_acc: 0.7997 - val_weight_output_acc: 0.8265 - val_bag_output_acc: 0.7685 - val_footwear_output_acc: 0.7708 - val_pose_output_acc: 0.8819 - val_emotion_output_acc: 0.8457
# Epoch 23/200
# 360/360 [==============================] - 162s 451ms/step - loss: 1.0137 - gender_output_loss: 0.2349 - image_quality_output_loss: 0.5125 - age_output_loss: 0.4157 - weight_output_loss: 0.3687 - bag_output_loss: 0.4140 - footwear_output_loss: 0.4299 - pose_output_loss: 0.2172 - emotion_output_loss: 0.3482 - gender_output_acc: 0.9016 - image_quality_output_acc: 0.7368 - age_output_acc: 0.8048 - weight_output_acc: 0.8376 - bag_output_acc: 0.8134 - footwear_output_acc: 0.7954 - pose_output_acc: 0.9115 - emotion_output_acc: 0.8590 - val_loss: 1.1631 - val_gender_output_loss: 0.3522 - val_image_quality_output_loss: 0.5420 - val_age_output_loss: 0.4376 - val_weight_output_loss: 0.3970 - val_bag_output_loss: 0.4741 - val_footwear_output_loss: 0.5251 - val_pose_output_loss: 0.3379 - val_emotion_output_loss: 0.3783 - val_gender_output_acc: 0.8527 - val_image_quality_output_acc: 0.7148 - val_age_output_acc: 0.7995 - val_weight_output_acc: 0.8238 - val_bag_output_acc: 0.7852 - val_footwear_output_acc: 0.7550 - val_pose_output_acc: 0.8659 - val_emotion_output_acc: 0.8518
# Epoch 24/200
# 360/360 [==============================] - 164s 456ms/step - loss: 1.0091 - gender_output_loss: 0.2341 - image_quality_output_loss: 0.5111 - age_output_loss: 0.4136 - weight_output_loss: 0.3674 - bag_output_loss: 0.4112 - footwear_output_loss: 0.4295 - pose_output_loss: 0.2152 - emotion_output_loss: 0.3459 - gender_output_acc: 0.9033 - image_quality_output_acc: 0.7406 - age_output_acc: 0.8060 - weight_output_acc: 0.8386 - bag_output_acc: 0.8169 - footwear_output_acc: 0.7926 - pose_output_acc: 0.9138 - emotion_output_acc: 0.8589 - val_loss: 1.2106 - val_gender_output_loss: 0.3942 - val_image_quality_output_loss: 0.5564 - val_age_output_loss: 0.4510 - val_weight_output_loss: 0.4274 - val_bag_output_loss: 0.5130 - val_footwear_output_loss: 0.5024 - val_pose_output_loss: 0.3711 - val_emotion_output_loss: 0.3811 - val_gender_output_acc: 0.8564 - val_image_quality_output_acc: 0.7027 - val_age_output_acc: 0.7969 - val_weight_output_acc: 0.8043 - val_bag_output_acc: 0.7641 - val_footwear_output_acc: 0.7591 - val_pose_output_acc: 0.8575 - val_emotion_output_acc: 0.8469
# Epoch 25/200
# 360/360 [==============================] - 162s 450ms/step - loss: 1.0023 - gender_output_loss: 0.2220 - image_quality_output_loss: 0.5091 - age_output_loss: 0.4123 - weight_output_loss: 0.3635 - bag_output_loss: 0.4112 - footwear_output_loss: 0.4253 - pose_output_loss: 0.2118 - emotion_output_loss: 0.3478 - gender_output_acc: 0.9108 - image_quality_output_acc: 0.7429 - age_output_acc: 0.8053 - weight_output_acc: 0.8378 - bag_output_acc: 0.8157 - footwear_output_acc: 0.7988 - pose_output_acc: 0.9159 - emotion_output_acc: 0.8590 - val_loss: 1.1981 - val_gender_output_loss: 0.4242 - val_image_quality_output_loss: 0.5657 - val_age_output_loss: 0.4415 - val_weight_output_loss: 0.4099 - val_bag_output_loss: 0.5339 - val_footwear_output_loss: 0.4712 - val_pose_output_loss: 0.3568 - val_emotion_output_loss: 0.3755 - val_gender_output_acc: 0.8318 - val_image_quality_output_acc: 0.7130 - val_age_output_acc: 0.7980 - val_weight_output_acc: 0.8188 - val_bag_output_acc: 0.7723 - val_footwear_output_acc: 0.7693 - val_pose_output_acc: 0.8733 - val_emotion_output_acc: 0.8500
# Epoch 26/200
# 360/360 [==============================] - 164s 456ms/step - loss: 0.9977 - gender_output_loss: 0.2247 - image_quality_output_loss: 0.5082 - age_output_loss: 0.4121 - weight_output_loss: 0.3653 - bag_output_loss: 0.4032 - footwear_output_loss: 0.4254 - pose_output_loss: 0.2061 - emotion_output_loss: 0.3445 - gender_output_acc: 0.9100 - image_quality_output_acc: 0.7437 - age_output_acc: 0.8057 - weight_output_acc: 0.8373 - bag_output_acc: 0.8217 - footwear_output_acc: 0.7993 - pose_output_acc: 0.9175 - emotion_output_acc: 0.8586 - val_loss: 1.1928 - val_gender_output_loss: 0.3477 - val_image_quality_output_loss: 0.5768 - val_age_output_loss: 0.4402 - val_weight_output_loss: 0.4137 - val_bag_output_loss: 0.4952 - val_footwear_output_loss: 0.5134 - val_pose_output_loss: 0.3669 - val_emotion_output_loss: 0.3799 - val_gender_output_acc: 0.8604 - val_image_quality_output_acc: 0.7012 - val_age_output_acc: 0.7987 - val_weight_output_acc: 0.8214 - val_bag_output_acc: 0.7745 - val_footwear_output_acc: 0.7450 - val_pose_output_acc: 0.8583 - val_emotion_output_acc: 0.8418
# Epoch 27/200
# 360/360 [==============================] - 160s 443ms/step - loss: 0.9968 - gender_output_loss: 0.2195 - image_quality_output_loss: 0.5065 - age_output_loss: 0.4119 - weight_output_loss: 0.3635 - bag_output_loss: 0.4088 - footwear_output_loss: 0.4200 - pose_output_loss: 0.2083 - emotion_output_loss: 0.3462 - gender_output_acc: 0.9111 - image_quality_output_acc: 0.7447 - age_output_acc: 0.8043 - weight_output_acc: 0.8398 - bag_output_acc: 0.8198 - footwear_output_acc: 0.7998 - pose_output_acc: 0.9143 - emotion_output_acc: 0.8592 - val_loss: 1.2294 - val_gender_output_loss: 0.4201 - val_image_quality_output_loss: 0.6037 - val_age_output_loss: 0.4400 - val_weight_output_loss: 0.4124 - val_bag_output_loss: 0.5320 - val_footwear_output_loss: 0.5107 - val_pose_output_loss: 0.3760 - val_emotion_output_loss: 0.3841 - val_gender_output_acc: 0.8321 - val_image_quality_output_acc: 0.6688 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8188 - val_bag_output_acc: 0.7500 - val_footwear_output_acc: 0.7427 - val_pose_output_acc: 0.8563 - val_emotion_output_acc: 0.8428
# Epoch 28/200
# 359/360 [============================>.] - ETA: 0s - loss: 0.9923 - gender_output_loss: 0.2198 - image_quality_output_loss: 0.5030 - age_output_loss: 0.4106 - weight_output_loss: 0.3589 - bag_output_loss: 0.4038 - footwear_output_loss: 0.4217 - pose_output_loss: 0.2098 - emotion_output_loss: 0.3450 - gender_output_acc: 0.9112 - image_quality_output_acc: 0.7456 - age_output_acc: 0.8060 - weight_output_acc: 0.8411 - bag_output_acc: 0.8214 - footwear_output_acc: 0.7999 - pose_output_acc: 0.9175 - emotion_output_acc: 0.8590Epoch 28/200
# 360/360 [==============================] - 159s 441ms/step - loss: 0.9921 - gender_output_loss: 0.2196 - image_quality_output_loss: 0.5028 - age_output_loss: 0.4106 - weight_output_loss: 0.3587 - bag_output_loss: 0.4040 - footwear_output_loss: 0.4214 - pose_output_loss: 0.2098 - emotion_output_loss: 0.3449 - gender_output_acc: 0.9113 - image_quality_output_acc: 0.7457 - age_output_acc: 0.8060 - weight_output_acc: 0.8412 - bag_output_acc: 0.8214 - footwear_output_acc: 0.8002 - pose_output_acc: 0.9175 - emotion_output_acc: 0.8590 - val_loss: 1.2088 - val_gender_output_loss: 0.3970 - val_image_quality_output_loss: 0.5823 - val_age_output_loss: 0.4463 - val_weight_output_loss: 0.4191 - val_bag_output_loss: 0.5246 - val_footwear_output_loss: 0.4816 - val_pose_output_loss: 0.3745 - val_emotion_output_loss: 0.3743 - val_gender_output_acc: 0.8507 - val_image_quality_output_acc: 0.6956 - val_age_output_acc: 0.7963 - val_weight_output_acc: 0.8249 - val_bag_output_acc: 0.7634 - val_footwear_output_acc: 0.7660 - val_pose_output_acc: 0.8643 - val_emotion_output_acc: 0.8495
# Epoch 29/200
# 360/360 [==============================] - 158s 439ms/step - loss: 0.9887 - gender_output_loss: 0.2218 - image_quality_output_loss: 0.5041 - age_output_loss: 0.4100 - weight_output_loss: 0.3586 - bag_output_loss: 0.4009 - footwear_output_loss: 0.4192 - pose_output_loss: 0.2057 - emotion_output_loss: 0.3423 - gender_output_acc: 0.9079 - image_quality_output_acc: 0.7447 - age_output_acc: 0.8056 - weight_output_acc: 0.8410 - bag_output_acc: 0.8229 - footwear_output_acc: 0.7990 - pose_output_acc: 0.9158 - emotion_output_acc: 0.8592 - val_loss: 1.2085 - val_gender_output_loss: 0.3831 - val_image_quality_output_loss: 0.5477 - val_age_output_loss: 0.4464 - val_weight_output_loss: 0.4200 - val_bag_output_loss: 0.5255 - val_footwear_output_loss: 0.5239 - val_pose_output_loss: 0.3569 - val_emotion_output_loss: 0.3861 - val_gender_output_acc: 0.8571 - val_image_quality_output_acc: 0.7179 - val_age_output_acc: 0.7987 - val_weight_output_acc: 0.8302 - val_bag_output_acc: 0.7677 - val_footwear_output_acc: 0.7612 - val_pose_output_acc: 0.8735 - val_emotion_output_acc: 0.8491
# Epoch 30/200
# 359/360 [============================>.] - ETA: 0s - loss: 0.9820 - gender_output_loss: 0.2211 - image_quality_output_loss: 0.5036 - age_output_loss: 0.4076 - weight_output_loss: 0.3548 - bag_output_loss: 0.3959 - footwear_output_loss: 0.4133 - pose_output_loss: 0.2028 - emotion_output_loss: 0.3435 - gender_output_acc: 0.9089 - image_quality_output_acc: 0.7431 - age_output_acc: 0.8060 - weight_output_acc: 0.8442 - bag_output_acc: 0.8283 - footwear_output_acc: 0.8050 - pose_output_acc: 0.9171 - emotion_output_acc: 0.8594Epoch 30/200
# 360/360 [==============================] - 159s 442ms/step - loss: 0.9821 - gender_output_loss: 0.2213 - image_quality_output_loss: 0.5034 - age_output_loss: 0.4077 - weight_output_loss: 0.3550 - bag_output_loss: 0.3961 - footwear_output_loss: 0.4133 - pose_output_loss: 0.2029 - emotion_output_loss: 0.3435 - gender_output_acc: 0.9087 - image_quality_output_acc: 0.7433 - age_output_acc: 0.8060 - weight_output_acc: 0.8442 - bag_output_acc: 0.8282 - footwear_output_acc: 0.8049 - pose_output_acc: 0.9171 - emotion_output_acc: 0.8594 - val_loss: 1.1950 - val_gender_output_loss: 0.3623 - val_image_quality_output_loss: 0.5651 - val_age_output_loss: 0.4485 - val_weight_output_loss: 0.4088 - val_bag_output_loss: 0.5191 - val_footwear_output_loss: 0.5103 - val_pose_output_loss: 0.3452 - val_emotion_output_loss: 0.3821 - val_gender_output_acc: 0.8571 - val_image_quality_output_acc: 0.7022 - val_age_output_acc: 0.7963 - val_weight_output_acc: 0.8292 - val_bag_output_acc: 0.7688 - val_footwear_output_acc: 0.7586 - val_pose_output_acc: 0.8704 - val_emotion_output_acc: 0.8435
# Epoch 31/200
# 360/360 [==============================] - 158s 438ms/step - loss: 0.9742 - gender_output_loss: 0.2126 - image_quality_output_loss: 0.5010 - age_output_loss: 0.4065 - weight_output_loss: 0.3536 - bag_output_loss: 0.3939 - footwear_output_loss: 0.4163 - pose_output_loss: 0.1926 - emotion_output_loss: 0.3395 - gender_output_acc: 0.9145 - image_quality_output_acc: 0.7457 - age_output_acc: 0.8072 - weight_output_acc: 0.8448 - bag_output_acc: 0.8267 - footwear_output_acc: 0.8018 - pose_output_acc: 0.9216 - emotion_output_acc: 0.8607 - val_loss: 1.2071 - val_gender_output_loss: 0.4111 - val_image_quality_output_loss: 0.5605 - val_age_output_loss: 0.4550 - val_weight_output_loss: 0.4344 - val_bag_output_loss: 0.4962 - val_footwear_output_loss: 0.4887 - val_pose_output_loss: 0.3511 - val_emotion_output_loss: 0.3868 - val_gender_output_acc: 0.8465 - val_image_quality_output_acc: 0.7060 - val_age_output_acc: 0.7939 - val_weight_output_acc: 0.8115 - val_bag_output_acc: 0.7677 - val_footwear_output_acc: 0.7588 - val_pose_output_acc: 0.8776 - val_emotion_output_acc: 0.8480
# Epoch 32/200
# 360/360 [==============================] - 158s 439ms/step - loss: 0.9742 - gender_output_loss: 0.2077 - image_quality_output_loss: 0.4997 - age_output_loss: 0.4074 - weight_output_loss: 0.3558 - bag_output_loss: 0.3951 - footwear_output_loss: 0.4116 - pose_output_loss: 0.1952 - emotion_output_loss: 0.3405 - gender_output_acc: 0.9164 - image_quality_output_acc: 0.7494 - age_output_acc: 0.8057 - weight_output_acc: 0.8437 - bag_output_acc: 0.8255 - footwear_output_acc: 0.8061 - pose_output_acc: 0.9230 - emotion_output_acc: 0.8602 - val_loss: 1.2154 - val_gender_output_loss: 0.3974 - val_image_quality_output_loss: 0.5716 - val_age_output_loss: 0.4533 - val_weight_output_loss: 0.4137 - val_bag_output_loss: 0.5203 - val_footwear_output_loss: 0.5199 - val_pose_output_loss: 0.3646 - val_emotion_output_loss: 0.3772 - val_gender_output_acc: 0.8390 - val_image_quality_output_acc: 0.6997 - val_age_output_acc: 0.7923 - val_weight_output_acc: 0.8266 - val_bag_output_acc: 0.7735 - val_footwear_output_acc: 0.7680 - val_pose_output_acc: 0.8692 - val_emotion_output_acc: 0.8491
# Epoch 32/200
# Epoch 33/200
# 360/360 [==============================] - 157s 436ms/step - loss: 0.9646 - gender_output_loss: 0.2091 - image_quality_output_loss: 0.4938 - age_output_loss: 0.4063 - weight_output_loss: 0.3493 - bag_output_loss: 0.3922 - footwear_output_loss: 0.4058 - pose_output_loss: 0.1888 - emotion_output_loss: 0.3395 - gender_output_acc: 0.9164 - image_quality_output_acc: 0.7506 - age_output_acc: 0.8066 - weight_output_acc: 0.8464 - bag_output_acc: 0.8254 - footwear_output_acc: 0.8093 - pose_output_acc: 0.9232 - emotion_output_acc: 0.8604 - val_loss: 1.2131 - val_gender_output_loss: 0.3927 - val_image_quality_output_loss: 0.5949 - val_age_output_loss: 0.4479 - val_weight_output_loss: 0.4128 - val_bag_output_loss: 0.5188 - val_footwear_output_loss: 0.5152 - val_pose_output_loss: 0.3376 - val_emotion_output_loss: 0.3888 - val_gender_output_acc: 0.8604 - val_image_quality_output_acc: 0.6882 - val_age_output_acc: 0.7934 - val_weight_output_acc: 0.8183 - val_bag_output_acc: 0.7746 - val_footwear_output_acc: 0.7482 - val_pose_output_acc: 0.8803 - val_emotion_output_acc: 0.8480
# Epoch 34/200
# 360/360 [==============================] - 157s 437ms/step - loss: 0.9612 - gender_output_loss: 0.2005 - image_quality_output_loss: 0.4933 - age_output_loss: 0.4057 - weight_output_loss: 0.3485 - bag_output_loss: 0.3855 - footwear_output_loss: 0.4080 - pose_output_loss: 0.1932 - emotion_output_loss: 0.3372 - gender_output_acc: 0.9177 - image_quality_output_acc: 0.7514 - age_output_acc: 0.8070 - weight_output_acc: 0.8458 - bag_output_acc: 0.8302 - footwear_output_acc: 0.8114 - pose_output_acc: 0.9220 - emotion_output_acc: 0.8620 - val_loss: 1.2357 - val_gender_output_loss: 0.4821 - val_image_quality_output_loss: 0.5823 - val_age_output_loss: 0.4539 - val_weight_output_loss: 0.4288 - val_bag_output_loss: 0.5236 - val_footwear_output_loss: 0.4888 - val_pose_output_loss: 0.3552 - val_emotion_output_loss: 0.3897 - val_gender_output_acc: 0.8167 - val_image_quality_output_acc: 0.6961 - val_age_output_acc: 0.7981 - val_weight_output_acc: 0.8074 - val_bag_output_acc: 0.7692 - val_footwear_output_acc: 0.7641 - val_pose_output_acc: 0.8763 - val_emotion_output_acc: 0.8487
# Epoch 35/200
# 360/360 [==============================] - 157s 436ms/step - loss: 0.9546 - gender_output_loss: 0.2018 - image_quality_output_loss: 0.4904 - age_output_loss: 0.4020 - weight_output_loss: 0.3432 - bag_output_loss: 0.3845 - footwear_output_loss: 0.4019 - pose_output_loss: 0.1937 - emotion_output_loss: 0.3371 - gender_output_acc: 0.9171 - image_quality_output_acc: 0.7526 - age_output_acc: 0.8094 - weight_output_acc: 0.8487 - bag_output_acc: 0.8342 - footwear_output_acc: 0.8113 - pose_output_acc: 0.9208 - emotion_output_acc: 0.8620 - val_loss: 1.2331 - val_gender_output_loss: 0.4217 - val_image_quality_output_loss: 0.6030 - val_age_output_loss: 0.4480 - val_weight_output_loss: 0.4321 - val_bag_output_loss: 0.5655 - val_footwear_output_loss: 0.4954 - val_pose_output_loss: 0.3306 - val_emotion_output_loss: 0.3841 - val_gender_output_acc: 0.8477 - val_image_quality_output_acc: 0.6736 - val_age_output_acc: 0.7964 - val_weight_output_acc: 0.8175 - val_bag_output_acc: 0.7358 - val_footwear_output_acc: 0.7603 - val_pose_output_acc: 0.8783 - val_emotion_output_acc: 0.8486
# Epoch 36/200
# 360/360 [==============================] - 157s 435ms/step - loss: 0.9486 - gender_output_loss: 0.2056 - image_quality_output_loss: 0.4893 - age_output_loss: 0.4018 - weight_output_loss: 0.3419 - bag_output_loss: 0.3773 - footwear_output_loss: 0.3997 - pose_output_loss: 0.1867 - emotion_output_loss: 0.3349 - gender_output_acc: 0.9174 - image_quality_output_acc: 0.7584 - age_output_acc: 0.8098 - weight_output_acc: 0.8495 - bag_output_acc: 0.8345 - footwear_output_acc: 0.8135 - pose_output_acc: 0.9233 - emotion_output_acc: 0.8626 - val_loss: 1.2651 - val_gender_output_loss: 0.3884 - val_image_quality_output_loss: 0.6118 - val_age_output_loss: 0.4573 - val_weight_output_loss: 0.4496 - val_bag_output_loss: 0.5347 - val_footwear_output_loss: 0.5237 - val_pose_output_loss: 0.3912 - val_emotion_output_loss: 0.4014 - val_gender_output_acc: 0.8524 - val_image_quality_output_acc: 0.6875 - val_age_output_acc: 0.7930 - val_weight_output_acc: 0.8149 - val_bag_output_acc: 0.7695 - val_footwear_output_acc: 0.7495 - val_pose_output_acc: 0.8684 - val_emotion_output_acc: 0.8423
# Epoch 37/200
# 360/360 [==============================] - 157s 435ms/step - loss: 0.9419 - gender_output_loss: 0.1903 - image_quality_output_loss: 0.4876 - age_output_loss: 0.4014 - weight_output_loss: 0.3416 - bag_output_loss: 0.3728 - footwear_output_loss: 0.3997 - pose_output_loss: 0.1815 - emotion_output_loss: 0.3350 - gender_output_acc: 0.9228 - image_quality_output_acc: 0.7577 - age_output_acc: 0.8079 - weight_output_acc: 0.8484 - bag_output_acc: 0.8382 - footwear_output_acc: 0.8128 - pose_output_acc: 0.9266 - emotion_output_acc: 0.8621 - val_loss: 1.2468 - val_gender_output_loss: 0.4074 - val_image_quality_output_loss: 0.5618 - val_age_output_loss: 0.4496 - val_weight_output_loss: 0.4311 - val_bag_output_loss: 0.5594 - val_footwear_output_loss: 0.5376 - val_pose_output_loss: 0.3917 - val_emotion_output_loss: 0.3824 - val_gender_output_acc: 0.8418 - val_image_quality_output_acc: 0.7106 - val_age_output_acc: 0.7950 - val_weight_output_acc: 0.8201 - val_bag_output_acc: 0.7526 - val_footwear_output_acc: 0.7560 - val_pose_output_acc: 0.8715 - val_emotion_output_acc: 0.8519
# Epoch 38/200
# 360/360 [==============================] - 157s 436ms/step - loss: 0.9390 - gender_output_loss: 0.1917 - image_quality_output_loss: 0.4866 - age_output_loss: 0.3994 - weight_output_loss: 0.3393 - bag_output_loss: 0.3731 - footwear_output_loss: 0.4003 - pose_output_loss: 0.1792 - emotion_output_loss: 0.3336 - gender_output_acc: 0.9210 - image_quality_output_acc: 0.7591 - age_output_acc: 0.8116 - weight_output_acc: 0.8501 - bag_output_acc: 0.8378 - footwear_output_acc: 0.8128 - pose_output_acc: 0.9276 - emotion_output_acc: 0.8634 - val_loss: 1.2486 - val_gender_output_loss: 0.4250 - val_image_quality_output_loss: 0.5669 - val_age_output_loss: 0.4701 - val_weight_output_loss: 0.4622 - val_bag_output_loss: 0.5279 - val_footwear_output_loss: 0.5092 - val_pose_output_loss: 0.3488 - val_emotion_output_loss: 0.3944 - val_gender_output_acc: 0.8299 - val_image_quality_output_acc: 0.6997 - val_age_output_acc: 0.7929 - val_weight_output_acc: 0.7836 - val_bag_output_acc: 0.7710 - val_footwear_output_acc: 0.7622 - val_pose_output_acc: 0.8725 - val_emotion_output_acc: 0.8452
# Epoch 39/200
# 144/360 [===========>..................] - ETA: 1:27 - loss: 0.9222 - gender_output_loss: 0.1757 - image_quality_output_loss: 0.4799 - age_output_loss: 0.3989 - weight_output_loss: 0.3299 - bag_output_loss: 0.3723 - footwear_output_loss: 0.3849 - pose_output_loss: 0.1772 - emotion_output_loss: 0.3286 - gender_output_acc: 0.9300 - image_quality_output_acc: 0.7593 - age_output_acc: 0.8088 - weight_output_acc: 0.8536 - bag_output_acc: 0.8410 - footwear_output_acc: 0.8220 - pose_output_acc: 0.9299 - emotion_output_acc: 0.8640

# %%
https://keras.io/callbacks/#tensorboard
