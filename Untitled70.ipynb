# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepaManjunath/Assignment1/blob/master/Untitled70.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q '/content/gdrive/My Drive/EIP4/hvc_data.zip'
# look for `hvc_annotations.csv` file and `resized` dir
# %ls '/content/gdrive/My Drive/EIP4/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# hvc_data/  hvc_data.zip

# %%
# %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation , Dropout
from keras.layers import AveragePooling2D, Input, Flatten ,GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.callbacks import ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()
# Out:
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
# 3    male         Good  45-55  ...        Neutral  Front-Frontish  resized/4.jpg
# 4  female         Good  35-45  ...        Neutral  Front-Frontish  resized/5.jpg
#
# [5 rows x 9 columns]

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
import numpy as np


def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=32, shuffle=True,augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.batch_size = batch_size
        #self.labels = labels
        #self.list_IDs = list_IDs
        #self.n_channels = n_channels
        #self.n_classes = n_classes
        #self.shuffle = shuffle
        self.on_epoch_end()
        self.augmentation=augmentation
        
        
        #self.on_epoch_end()

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

            
    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        images = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
        if self.augmentation is not None:
           images=self.augmentation.flow(images,shuffle=False).next()
           
        target = {
                       "gender_output": items[_gender_cols_].values,
                       "image_quality_output": items[_imagequality_cols_].values,
                       "age_output": items[_age_cols_].values,
                       "weight_output": items[_weight_cols_].values,
                       "bag_output": items[_carryingbag_cols_].values,
                       "pose_output": items[_bodypose_cols_].values,
                       "footwear_output": items[_footwear_cols_].values,
                       "emotion_output": items[_emotion_cols_].values,
        }
        return images, target
    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
            
   # def __PersonDataGenerator(self,train_df,batch_size=32,augmentation):
      
    #     train_gen = np.stack(train_df, batch_size=32,augmentation=ImageDataGenerator(featurewise_center=False,
     #                           samplewise_center=False,
      #                          featurewise_std_normalization=False,
       #                         samplewise_std_normalization=False,
        #                        zca_whitening=False,
         #                       zca_epsilon=1e-06,
          #                      rotation_range=25,
           #                     width_shift_range=0.1,
            #                    height_shift_range=0.1,
             #                   brightness_range=None,
              #                  shear_range=0.0,
               #                 zoom_range=0.0,
                #                channel_shift_range=0.0,
                 #               fill_mode='nearest',
                  #              cval=0.0,
                   #             horizontal_flip=True,
                    #            vertical_flip=True,
                     #           rescale=None,
                      #          preprocessing_function=get_random_eraser(v_l=0, v_h=1),
                       #         data_format=None,
                        #        validation_split=0.0
                         #       ))
         #image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
          #    if self.augmentation is not None:
           #  image=self.augmentation.flow(image,shuffle=False).next()

   # def on_epoch_end(self):
    #    """Updates indexes after each epoch"""
     #   if self.shuffle == True:
      #      self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
len(train_df)
# Out:
# 11537

# %%
train_df.head()
# Out:
#               image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 12781  resized/12783.jpg              0  ...                        0              1
# 4449    resized/4450.jpg              1  ...                        1              0
# 12607  resized/12609.jpg              0  ...                        1              0
# 3283    resized/3284.jpg              1  ...                        1              0
# 10392  resized/10394.jpg              0  ...                        1              0
#
# [5 rows x 28 columns]

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df,batch_size=32,
                                augmentation=ImageDataGenerator(rescale=1./255, vertical_flip=True,rotation_range=25,                                                                            
	                                                                                    horizontal_flip=True, ))
                       
                                                            
	                                                                                      

                             
                                                        
                                                          



#train_gen = PersonDataGenerator(train_df, batch_size=32,augmentation=True)
                                
valid_gen = PersonDataGenerator(val_df, batch_size=32, shuffle=False,
                                augmentation=ImageDataGenerator(rescale=1./255))

# %%
# get number of output units from data
images, targets = next(iter(valid_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
#from classification_models.resnet import ResNet18, preprocess_input
import keras.applications.resnet 
from keras.applications.inception_v3 import InceptionV3

from keras.applications.resnet import ResNet50

backbone = InceptionV3(
    weights=None, 
    include_top=False, 
    input_tensor=Input(shape=(224, 224, 3))
)
#backbone = resnet_v1((224,224,3),8)
  


neck = backbone.output
neck = Flatten(name="flatten")(neck)
neck = Dense(512, activation="relu")(neck)


def build_tower(in_layer):
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.0712)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.0712)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.0712)(in_layer)
    neck = Dense(28, activation="relu")(neck)
    
    
    return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="sigmoid",name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("pose", build_tower(neck))


model = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
import numpy as np
import tensorflow as tf
import keras

# %%
EPOCHS=100
LEARNING_RATE=0.3
BATCH_SIZE1=32
BATCH_SIZE2=64
MOMENTUM=0.9

# %%
len_train=len(train_df)
batches_per_epoch = len_train//BATCH_SIZE1

# %%
lr_schedule = lambda t: np.interp([t], [0, (EPOCHS+1)//5, (EPOCHS)], [0.009, LEARNING_RATE, 0.009] )[0]
print(lr_schedule)

#lr_schedule = lambda t: np.interp([t],[0,(EPOCHS+1)//5, (EPOCHS-6)],[0.4, LEARNING_RATE, 0.4])[0]
global_step = tf.train.get_or_create_global_step()
lr_func = lambda: lr_schedule(global_step/batches_per_epoch)/BATCH_SIZE1
#opt.apply_gradients( global_step=global_step)
#opt = tf.train.MomentumOptimizer(lr_func,momentum=MOMENTUM,use_nesterov=False)
# Out:
# <function <lambda> at 0x7fa2fbf76b70>

# %%
#t = time.time()
#test_set = tf.data.Dataset.from_tensor_slices((val_df)).batch(BATCH_SIZE)

def lr_schedule1(epoch):
    for epoch1 in range((EPOCHS)):
    #if epoch<=24:
      
         if epoch==epoch1:
          break
     
   
   # tf.keras.backend.set_learning_phase(1)
         opt = tf.train.MomentumOptimizer(lr_func,momentum=MOMENTUM,use_nesterov=False)
         #opt1 = SGD(lr=lr_schedule(epoch+1),momentum=0.9)
        #if epoch==epoch1:
         # break
          
    print('epoch:', epoch, 'lr:', lr_schedule(epoch))
    return(lr_schedule(epoch))

      
     
    #tf.keras.backend.set_learning_phase(0)
    
      #  print('epoch:', epoch+1, 'lr:', lr_schedule(epoch+1))
  #return (lr_schedule(epoch+1))
    #else:
   
    #tf.keras.backend.set_learning_phase(1)
     #   opt = tf.train.MomentumOptimizer(lr_func1,momentum=MOMENTUM,use_nesterov=False)
      #  opt = SGD(lr=lr_schedule(epoch+1),momentum=0.9)
        #model.compile(
         #           optimizer=opt,
          #          loss="categorical_crossentropy", 
           #         loss_weights=loss_weights, 
            #        metrics=["accuracy"]
             #       )
        #model.fit_generator(
         #            generator=train_gen,
          #           validation_data=valid_gen,
           #          use_multiprocessing=True,
            #         workers=6, 
             #        epochs=10,
              #       verbose=1,
      
               #      callbacks=callbacks
                #         )
        #LRFind.plot_loss()

       
    #tf.keras.backend.set_learning_phase(0)
       # print('epoch:', epoch+1, 'lr:', lr_schedule1(epoch+1))

# %%
# model.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=32, epochs=10)

# %%
import matplotlib.pyplot as plt
import keras.backend as K
from keras.callbacks import Callback


class LRFinder(Callback):
    
    '''
    A simple callback for finding the optimal learning rate range for your model + dataset. 
    
    # Usage
        ```python
            lr_finder = LRFinder(min_lr=1e-5, 
                                 max_lr=1e-2, 
                                 steps_per_epoch=np.ceil(epoch_size/batch_size), 
                                 epochs=3)
            model.fit(X_train, Y_train, callbacks=[lr_finder])
            
            lr_finder.plot_loss()
        ```
    
    # Arguments
        min_lr: The lower bound of the learning rate range for the experiment.
        max_lr: The upper bound of the learning rate range for the experiment.
        steps_per_epoch: Number of mini-batches in the dataset. Calculated as `np.ceil(epoch_size/batch_size)`. 
        epochs: Number of epochs to run experiment. Usually between 2 and 4 epochs is sufficient. 
        
    # References
        Blog post: jeremyjordan.me/nn-learning-rate
        Original paper: https://arxiv.org/abs/1506.01186
    '''
    
    def __init__(self, min_lr=1e-5, max_lr=1e-2, steps_per_epoch=5.625, epochs=24):
        super().__init__()
        
        self.min_lr = min_lr
        self.max_lr = max_lr
        self.total_iterations = steps_per_epoch * epochs
        self.iteration = 0
        self.history = {}
        
    def clr(self):
        '''Calculate the learning rate.'''
        x = self.iteration / self.total_iterations 
        return self.min_lr + (self.max_lr-self.min_lr) * x
        
    def on_train_begin(self, logs=None):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.min_lr)
        
    def on_batch_end(self, epoch, logs=None):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.iteration += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.iteration)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
            
        K.set_value(self.model.optimizer.lr, self.clr())
 
    def plot_lr(self):
        '''Helper function to quickly inspect the learning rate schedule.'''
        plt.plot(self.history['iterations'], self.history['lr'])
        plt.yscale('log')
        plt.xlabel('Iteration')
        plt.ylabel('Learning rate')
        plt.show()
        
    def plot_loss(self):
        '''Helper function to quickly observe the learning rate experiment results.'''
        plt.plot(self.history['lr'], self.history['loss'])
        plt.xscale('log')
        plt.xlabel('Learning rate')
        plt.ylabel('Loss')
        plt.show()

# %%
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
#for i in range(EPOCHS):
#lr_scheduler = LearningRateScheduler(lr_schedule1)

# %%
#lr_schedule = lambda t: np.interp([t], [0, (EPOCHS+1)//5, (EPOCHS-6)], [0.4, LEARNING_RATE, 0.4])[0]
#global_step = tf.train.get_or_create_global_step()
#opt.apply_gradients(zip(grads, var), global_step=global_step

# %%
def lr_Schedule(epoch):
  
   # lr=0.00148 
    lr = 1e-3
    #if epoch > 70:
     # lr*= 1e-3
    #if epoch > 40:
     #   lr *= 1e-1
    #if epoch > 30:
      #  lr *= 1e-0
    #if epoch > 20:
     #  lr *= 1e-0
    if epoch > 10:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
#from keras.callbacks import ModelCheckpoint,LearningRateScheduler

LRFind=LRFinder(min_lr=1e-5, max_lr=10, steps_per_epoch=(2036//32), epochs=50)
lr_scheduler = LearningRateScheduler(lr_Schedule)
#LRFind.on_tain_begin()
#for i in range(EPOCHS):
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [lr_scheduler,lr_reducer,LRFind]

# %%
losses = {
 	"gender_output": "binary_crossentropy",
 	"image_quality_output": "binary_crossentropy",
 	"age_output": "binary_crossentropy",
 	"weight_output": "binary_crossentropy",
  "bag_output": "binary_crossentropy",
  "pose_output": "binary_crossentropy",
  "footwear_output": "binary_crossentropy",   
  "emotion_output": "binary_crossentropy",
       

 }
loss_weights = {"gender_output": 0.2, "image_quality_output": 0.3, "age_output": 0.5, "weight_output": 0.4,"bag_output":0.3,"pose_output":0.3,"footwear_output":0.3,"emotion_output":0.4}
model.summary()

opt = SGD(lr=0.00142,momentum=0.9)
#opt = tf.train.MomentumOptimizer(lr=lr_schedule(epoch+1),momentum=MOMENTUM,use_nesterov=False)
#opt.( global_step=global_step)
model.compile(
    optimizer=opt,
    loss="binary_crossentropy", 
    #from_logits=True,
    #loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
    loss_weights=loss_weights, 
    metrics=["accuracy"]
)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 111, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 111, 111, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 111, 111, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 109, 109, 32) 9216        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 109, 109, 32) 96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 109, 109, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 109, 109, 64) 18432       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 109, 109, 64) 192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 109, 109, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 54, 54, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 54, 54, 80)   5120        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 54, 54, 80)   240         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 54, 54, 80)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 52, 52, 192)  138240      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 52, 52, 192)  576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 52, 52, 192)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 192)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 25, 25, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 25, 25, 64)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 25, 25, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 25, 25, 48)   9216        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 25, 25, 96)   55296       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 25, 25, 48)   144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 25, 25, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 25, 25, 48)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 25, 25, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 25, 25, 192)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 25, 25, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 25, 25, 64)   76800       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 25, 25, 96)   82944       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 25, 25, 32)   6144        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 25, 25, 64)   192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 25, 25, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 25, 25, 96)   288         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 25, 25, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 25, 25, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 25, 25, 96)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 25, 25, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 25, 25, 256)  0           activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 25, 25, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 25, 25, 64)   192         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 25, 25, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 25, 25, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 25, 25, 96)   55296       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 48)   144         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 25, 25, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 25, 25, 48)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 25, 25, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 25, 25, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 25, 25, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 25, 25, 64)   76800       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 25, 25, 96)   82944       activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 25, 25, 64)   16384       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 64)   192         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 25, 25, 96)   288         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 25, 25, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 25, 25, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 25, 25, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 25, 25, 96)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 25, 25, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 25, 25, 288)  0           activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 25, 25, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 25, 25, 64)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 25, 25, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 25, 25, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 25, 25, 96)   55296       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 25, 25, 48)   144         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 25, 25, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 25, 25, 48)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 25, 25, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 25, 25, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 25, 25, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 25, 25, 64)   76800       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 25, 25, 96)   82944       activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 25, 25, 64)   18432       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 25, 25, 64)   192         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 25, 25, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 25, 25, 96)   288         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 25, 25, 64)   192         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 25, 25, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 25, 25, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 25, 25, 96)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 25, 25, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 25, 25, 288)  0           activation_20[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 25, 25, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 25, 25, 64)   192         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 25, 25, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 25, 25, 96)   55296       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 25, 25, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 25, 25, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 12, 12, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 12, 12, 96)   82944       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 12, 12, 384)  1152        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 12, 12, 96)   288         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 12, 12, 384)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 96)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 12, 12, 768)  0           activation_27[0][0]
#                                                                  activation_30[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 12, 12, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 12, 12, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 12, 12, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 12, 12, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 12, 12, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 12, 12, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 12, 12, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 12, 12, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 12, 12, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 12, 12, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 12, 12, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 12, 12, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 12, 12, 128)  114688      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 12, 12, 128)  114688      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 12, 12, 128)  384         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 12, 12, 128)  384         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 12, 12, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 12, 12, 128)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 12, 12, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 12, 12, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 12, 12, 192)  172032      activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 12, 12, 192)  172032      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 12, 12, 192)  576         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 12, 12, 192)  576         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 12, 12, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 12, 12, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 12, 12, 192)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 12, 12, 192)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 12, 12, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 12, 12, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 12, 12, 768)  0           activation_31[0][0]
#                                                                  activation_34[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 12, 12, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 12, 12, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 12, 12, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 12, 12, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 12, 12, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 12, 12, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 12, 12, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 12, 12, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 12, 12, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 12, 12, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 12, 12, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 12, 12, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 12, 12, 160)  179200      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 12, 12, 160)  179200      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 12, 12, 160)  480         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 12, 12, 160)  480         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 12, 12, 160)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 12, 12, 160)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 12, 12, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 12, 12, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 12, 12, 192)  215040      activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 12, 12, 192)  215040      activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 12, 12, 192)  576         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 12, 12, 192)  576         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 12, 12, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 12, 12, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 12, 12, 192)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 12, 12, 192)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 12, 12, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 12, 12, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 12, 12, 768)  0           activation_41[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 12, 12, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 12, 12, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 12, 12, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 12, 12, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 12, 12, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 12, 12, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 12, 12, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 12, 12, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 12, 12, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 12, 12, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 12, 12, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 12, 12, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 12, 12, 160)  179200      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 12, 12, 160)  179200      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 12, 12, 160)  480         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 12, 12, 160)  480         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 12, 12, 160)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 12, 12, 160)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 12, 12, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 12, 12, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 12, 12, 192)  215040      activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 12, 12, 192)  215040      activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 12, 12, 192)  576         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 12, 12, 192)  576         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 12, 12, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 12, 12, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 12, 12, 192)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 12, 12, 192)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 12, 12, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 12, 12, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 12, 12, 768)  0           activation_51[0][0]
#                                                                  activation_54[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_60[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 12, 12, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 12, 12, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 12, 12, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 12, 12, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 12, 12, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 12, 12, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 12, 12, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 12, 12, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 12, 12, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 12, 12, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 12, 12, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 12, 12, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 12, 12, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 12, 12, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 12, 12, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 12, 12, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 12, 12, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 12, 12, 192)  258048      activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 12, 12, 192)  258048      activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 12, 12, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 12, 12, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 12, 12, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 12, 12, 192)  576         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 12, 12, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 12, 12, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 12, 12, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 12, 12, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 12, 12, 768)  0           activation_61[0][0]
#                                                                  activation_64[0][0]
#                                                                  activation_69[0][0]
#                                                                  activation_70[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 5, 5, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 5, 5, 384)    1152        conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 5, 5, 192)    245760      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 5, 5, 320)    960         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 5, 5, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 5, 5, 384)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 5, 5, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 5, 5, 384)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 5, 5, 192)    576         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 5, 5, 320)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 5, 5, 768)    0           activation_79[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 5, 5, 768)    0           activation_83[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 5, 5, 192)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 5, 5, 2048)   0           activation_77[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_85[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 5, 5, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 5, 5, 448)    1344        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 5, 5, 448)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 5, 5, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 5, 5, 384)    1548288     activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 5, 5, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 5, 5, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 5, 5, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 5, 5, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 5, 5, 384)    442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 5, 5, 384)    442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 5, 5, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 5, 5, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 5, 5, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 5, 5, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 5, 5, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 5, 5, 384)    1152        conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 5, 5, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 5, 5, 384)    1152        conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 5, 5, 192)    393216      average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 5, 5, 320)    960         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 5, 5, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 5, 5, 384)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 5, 5, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 5, 5, 384)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 5, 5, 192)    576         conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 5, 5, 320)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 5, 5, 768)    0           activation_88[0][0]
#                                                                  activation_89[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 5, 5, 768)    0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 5, 5, 192)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 5, 5, 2048)   0           activation_86[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_94[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 51200)        0           mixed10[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          26214912    flatten[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 28)           14364       dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 28)           14364       dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 28)           14364       dropout_9[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 28)           14364       dropout_12[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 28)           14364       dropout_15[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 28)           14364       dropout_18[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 28)           14364       dropout_24[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 28)           14364       dropout_21[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            58          dense_4[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Dense)    (None, 3)            87          dense_7[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            145         dense_10[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            116         dense_13[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            87          dense_16[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            87          dense_19[0][0]
# __________________________________________________________________________________________________
# pose_output (Dense)             (None, 3)            87          dense_25[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            116         dense_22[0][0]
# ==================================================================================================
# Total params: 48,133,391
# Trainable params: 48,098,959
# Non-trainable params: 34,432
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
#for i in range(EPOCHS):
model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    #validation_steps=2036//32,
    use_multiprocessing=True,
    workers=2, 
    epochs=200,
    verbose=1,
   # callbacks=callbacks
    )
#LRFind.plot_loss()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/200
# 360/360 [==============================] - 176s 488ms/step - loss: 1.4115 - gender_output_loss: 0.6912 - image_quality_output_loss: 0.5930 - age_output_loss: 0.4709 - weight_output_loss: 0.4412 - bag_output_loss: 0.5616 - footwear_output_loss: 0.6177 - pose_output_loss: 0.5620 - emotion_output_loss: 0.4026 - gender_output_acc: 0.5485 - image_quality_output_acc: 0.6888 - age_output_acc: 0.7888 - weight_output_acc: 0.8064 - bag_output_acc: 0.6986 - footwear_output_acc: 0.6565 - pose_output_acc: 0.7372 - emotion_output_acc: 0.8466 - val_loss: 1.4192 - val_gender_output_loss: 0.6817 - val_image_quality_output_loss: 0.5981 - val_age_output_loss: 0.4871 - val_weight_output_loss: 0.4326 - val_bag_output_loss: 0.5716 - val_footwear_output_loss: 0.6219 - val_pose_output_loss: 0.5676 - val_emotion_output_loss: 0.3964 - val_gender_output_acc: 0.5657 - val_image_quality_output_acc: 0.6885 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8217 - val_bag_output_acc: 0.6916 - val_footwear_output_acc: 0.6711 - val_pose_output_acc: 0.7437 - val_emotion_output_acc: 0.8565
# Epoch 2/200
# 360/360 [==============================] - 152s 421ms/step - loss: 1.3749 - gender_output_loss: 0.6819 - image_quality_output_loss: 0.5813 - age_output_loss: 0.4582 - weight_output_loss: 0.4290 - bag_output_loss: 0.5517 - footwear_output_loss: 0.5916 - pose_output_loss: 0.5497 - emotion_output_loss: 0.3888 - gender_output_acc: 0.5596 - image_quality_output_acc: 0.6940 - age_output_acc: 0.7989 - weight_output_acc: 0.8137 - bag_output_acc: 0.7059 - footwear_output_acc: 0.6844 - pose_output_acc: 0.7441 - emotion_output_acc: 0.8554 - val_loss: 1.3623 - val_gender_output_loss: 0.6757 - val_image_quality_output_loss: 0.5745 - val_age_output_loss: 0.4583 - val_weight_output_loss: 0.4179 - val_bag_output_loss: 0.5509 - val_footwear_output_loss: 0.5821 - val_pose_output_loss: 0.5493 - val_emotion_output_loss: 0.3844 - val_gender_output_acc: 0.5737 - val_image_quality_output_acc: 0.7045 - val_age_output_acc: 0.8001 - val_weight_output_acc: 0.8208 - val_bag_output_acc: 0.7001 - val_footwear_output_acc: 0.6883 - val_pose_output_acc: 0.7426 - val_emotion_output_acc: 0.8568
# Epoch 3/200
# 360/360 [==============================] - 152s 423ms/step - loss: 1.3658 - gender_output_loss: 0.6787 - image_quality_output_loss: 0.5774 - age_output_loss: 0.4568 - weight_output_loss: 0.4260 - bag_output_loss: 0.5507 - footwear_output_loss: 0.5764 - pose_output_loss: 0.5488 - emotion_output_loss: 0.3882 - gender_output_acc: 0.5628 - image_quality_output_acc: 0.6958 - age_output_acc: 0.7993 - weight_output_acc: 0.8159 - bag_output_acc: 0.7058 - footwear_output_acc: 0.6999 - pose_output_acc: 0.7443 - emotion_output_acc: 0.8554 - val_loss: 1.3546 - val_gender_output_loss: 0.6781 - val_image_quality_output_loss: 0.5728 - val_age_output_loss: 0.4566 - val_weight_output_loss: 0.4172 - val_bag_output_loss: 0.5479 - val_footwear_output_loss: 0.5691 - val_pose_output_loss: 0.5464 - val_emotion_output_loss: 0.3822 - val_gender_output_acc: 0.5697 - val_image_quality_output_acc: 0.7078 - val_age_output_acc: 0.8001 - val_weight_output_acc: 0.8225 - val_bag_output_acc: 0.7037 - val_footwear_output_acc: 0.7016 - val_pose_output_acc: 0.7434 - val_emotion_output_acc: 0.8566
# Epoch 4/200
# 360/360 [==============================] - 152s 422ms/step - loss: 1.3611 - gender_output_loss: 0.6777 - image_quality_output_loss: 0.5773 - age_output_loss: 0.4562 - weight_output_loss: 0.4247 - bag_output_loss: 0.5489 - footwear_output_loss: 0.5687 - pose_output_loss: 0.5475 - emotion_output_loss: 0.3871 - gender_output_acc: 0.5634 - image_quality_output_acc: 0.6991 - age_output_acc: 0.7995 - weight_output_acc: 0.8155 - bag_output_acc: 0.7068 - footwear_output_acc: 0.7043 - pose_output_acc: 0.7446 - emotion_output_acc: 0.8557 - val_loss: 1.3567 - val_gender_output_loss: 0.6763 - val_image_quality_output_loss: 0.5725 - val_age_output_loss: 0.4558 - val_weight_output_loss: 0.4167 - val_bag_output_loss: 0.5502 - val_footwear_output_loss: 0.5741 - val_pose_output_loss: 0.5472 - val_emotion_output_loss: 0.3840 - val_gender_output_acc: 0.5692 - val_image_quality_output_acc: 0.7098 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8230 - val_bag_output_acc: 0.7047 - val_footwear_output_acc: 0.6936 - val_pose_output_acc: 0.7434 - val_emotion_output_acc: 0.8566
# Epoch 5/200
# 360/360 [==============================] - 152s 423ms/step - loss: 1.3578 - gender_output_loss: 0.6737 - image_quality_output_loss: 0.5771 - age_output_loss: 0.4559 - weight_output_loss: 0.4231 - bag_output_loss: 0.5478 - footwear_output_loss: 0.5648 - pose_output_loss: 0.5462 - emotion_output_loss: 0.3878 - gender_output_acc: 0.5731 - image_quality_output_acc: 0.6982 - age_output_acc: 0.7994 - weight_output_acc: 0.8160 - bag_output_acc: 0.7099 - footwear_output_acc: 0.7048 - pose_output_acc: 0.7446 - emotion_output_acc: 0.8556 - val_loss: 1.3486 - val_gender_output_loss: 0.6731 - val_image_quality_output_loss: 0.5712 - val_age_output_loss: 0.4567 - val_weight_output_loss: 0.4170 - val_bag_output_loss: 0.5454 - val_footwear_output_loss: 0.5571 - val_pose_output_loss: 0.5455 - val_emotion_output_loss: 0.3827 - val_gender_output_acc: 0.5811 - val_image_quality_output_acc: 0.7083 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8227 - val_bag_output_acc: 0.7068 - val_footwear_output_acc: 0.7110 - val_pose_output_acc: 0.7434 - val_emotion_output_acc: 0.8566
# Epoch 6/200
# 360/360 [==============================] - 152s 422ms/step - loss: 1.3544 - gender_output_loss: 0.6722 - image_quality_output_loss: 0.5753 - age_output_loss: 0.4547 - weight_output_loss: 0.4228 - bag_output_loss: 0.5466 - footwear_output_loss: 0.5608 - pose_output_loss: 0.5457 - emotion_output_loss: 0.3874 - gender_output_acc: 0.5792 - image_quality_output_acc: 0.6972 - age_output_acc: 0.7998 - weight_output_acc: 0.8159 - bag_output_acc: 0.7082 - footwear_output_acc: 0.7075 - pose_output_acc: 0.7449 - emotion_output_acc: 0.8555 - val_loss: 1.3469 - val_gender_output_loss: 0.6759 - val_image_quality_output_loss: 0.5705 - val_age_output_loss: 0.4555 - val_weight_output_loss: 0.4139 - val_bag_output_loss: 0.5449 - val_footwear_output_loss: 0.5555 - val_pose_output_loss: 0.5455 - val_emotion_output_loss: 0.3838 - val_gender_output_acc: 0.5580 - val_image_quality_output_acc: 0.7087 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8225 - val_bag_output_acc: 0.7070 - val_footwear_output_acc: 0.7149 - val_pose_output_acc: 0.7434 - val_emotion_output_acc: 0.8566
# Epoch 7/200
# 360/360 [==============================] - 153s 424ms/step - loss: 1.3512 - gender_output_loss: 0.6688 - image_quality_output_loss: 0.5751 - age_output_loss: 0.4545 - weight_output_loss: 0.4210 - bag_output_loss: 0.5455 - footwear_output_loss: 0.5586 - pose_output_loss: 0.5443 - emotion_output_loss: 0.3869 - gender_output_acc: 0.5846 - image_quality_output_acc: 0.6970 - age_output_acc: 0.7995 - weight_output_acc: 0.8165 - bag_output_acc: 0.7107 - footwear_output_acc: 0.7080 - pose_output_acc: 0.7455 - emotion_output_acc: 0.8557 - val_loss: 1.3427 - val_gender_output_loss: 0.6677 - val_image_quality_output_loss: 0.5704 - val_age_output_loss: 0.4542 - val_weight_output_loss: 0.4136 - val_bag_output_loss: 0.5444 - val_footwear_output_loss: 0.5529 - val_pose_output_loss: 0.5448 - val_emotion_output_loss: 0.3824 - val_gender_output_acc: 0.5727 - val_image_quality_output_acc: 0.7085 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8227 - val_bag_output_acc: 0.7042 - val_footwear_output_acc: 0.7131 - val_pose_output_acc: 0.7434 - val_emotion_output_acc: 0.8566
# Epoch 8/200
# 360/360 [==============================] - 152s 422ms/step - loss: 1.3489 - gender_output_loss: 0.6659 - image_quality_output_loss: 0.5744 - age_output_loss: 0.4539 - weight_output_loss: 0.4217 - bag_output_loss: 0.5449 - footwear_output_loss: 0.5546 - pose_output_loss: 0.5446 - emotion_output_loss: 0.3863 - gender_output_acc: 0.5872 - image_quality_output_acc: 0.6981 - age_output_acc: 0.7993 - weight_output_acc: 0.8161 - bag_output_acc: 0.7096 - footwear_output_acc: 0.7132 - pose_output_acc: 0.7452 - emotion_output_acc: 0.8558 - val_loss: 1.3429 - val_gender_output_loss: 0.6593 - val_image_quality_output_loss: 0.5697 - val_age_output_loss: 0.4553 - val_weight_output_loss: 0.4135 - val_bag_output_loss: 0.5435 - val_footwear_output_loss: 0.5578 - val_pose_output_loss: 0.5449 - val_emotion_output_loss: 0.3831 - val_gender_output_acc: 0.5925 - val_image_quality_output_acc: 0.7072 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7083 - val_footwear_output_acc: 0.7067 - val_pose_output_acc: 0.7434 - val_emotion_output_acc: 0.8566
# Epoch 9/200
# 360/360 [==============================] - 154s 429ms/step - loss: 1.3470 - gender_output_loss: 0.6662 - image_quality_output_loss: 0.5733 - age_output_loss: 0.4534 - weight_output_loss: 0.4205 - bag_output_loss: 0.5433 - footwear_output_loss: 0.5537 - pose_output_loss: 0.5435 - emotion_output_loss: 0.3868 - gender_output_acc: 0.5854 - image_quality_output_acc: 0.6991 - age_output_acc: 0.8005 - weight_output_acc: 0.8169 - bag_output_acc: 0.7101 - footwear_output_acc: 0.7128 - pose_output_acc: 0.7454 - emotion_output_acc: 0.8556 - val_loss: 1.3364 - val_gender_output_loss: 0.6523 - val_image_quality_output_loss: 0.5683 - val_age_output_loss: 0.4537 - val_weight_output_loss: 0.4141 - val_bag_output_loss: 0.5435 - val_footwear_output_loss: 0.5483 - val_pose_output_loss: 0.5427 - val_emotion_output_loss: 0.3816 - val_gender_output_acc: 0.6114 - val_image_quality_output_acc: 0.7073 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8225 - val_bag_output_acc: 0.7085 - val_footwear_output_acc: 0.7126 - val_pose_output_acc: 0.7434 - val_emotion_output_acc: 0.8566
# Epoch 10/200
# 360/360 [==============================] - 153s 424ms/step - loss: 1.3427 - gender_output_loss: 0.6623 - image_quality_output_loss: 0.5721 - age_output_loss: 0.4529 - weight_output_loss: 0.4198 - bag_output_loss: 0.5429 - footwear_output_loss: 0.5481 - pose_output_loss: 0.5424 - emotion_output_loss: 0.3856 - gender_output_acc: 0.5924 - image_quality_output_acc: 0.7005 - age_output_acc: 0.8001 - weight_output_acc: 0.8165 - bag_output_acc: 0.7107 - footwear_output_acc: 0.7155 - pose_output_acc: 0.7452 - emotion_output_acc: 0.8557 - val_loss: 1.3375 - val_gender_output_loss: 0.6576 - val_image_quality_output_loss: 0.5671 - val_age_output_loss: 0.4545 - val_weight_output_loss: 0.4132 - val_bag_output_loss: 0.5414 - val_footwear_output_loss: 0.5516 - val_pose_output_loss: 0.5421 - val_emotion_output_loss: 0.3820 - val_gender_output_acc: 0.5960 - val_image_quality_output_acc: 0.7085 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8224 - val_bag_output_acc: 0.7102 - val_footwear_output_acc: 0.7141 - val_pose_output_acc: 0.7434 - val_emotion_output_acc: 0.8566
# Epoch 11/200
# Epoch 10/200
# 360/360 [==============================] - 152s 422ms/step - loss: 1.3409 - gender_output_loss: 0.6582 - image_quality_output_loss: 0.5715 - age_output_loss: 0.4531 - weight_output_loss: 0.4196 - bag_output_loss: 0.5416 - footwear_output_loss: 0.5467 - pose_output_loss: 0.5428 - emotion_output_loss: 0.3851 - gender_output_acc: 0.5989 - image_quality_output_acc: 0.6992 - age_output_acc: 0.7995 - weight_output_acc: 0.8159 - bag_output_acc: 0.7127 - footwear_output_acc: 0.7200 - pose_output_acc: 0.7456 - emotion_output_acc: 0.8558 - val_loss: 1.3356 - val_gender_output_loss: 0.6531 - val_image_quality_output_loss: 0.5656 - val_age_output_loss: 0.4535 - val_weight_output_loss: 0.4149 - val_bag_output_loss: 0.5443 - val_footwear_output_loss: 0.5472 - val_pose_output_loss: 0.5413 - val_emotion_output_loss: 0.3819 - val_gender_output_acc: 0.6086 - val_image_quality_output_acc: 0.7087 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8214 - val_bag_output_acc: 0.7073 - val_footwear_output_acc: 0.7168 - val_pose_output_acc: 0.7434 - val_emotion_output_acc: 0.8566
# Epoch 12/200
# 360/360 [==============================] - 152s 424ms/step - loss: 1.3379 - gender_output_loss: 0.6539 - image_quality_output_loss: 0.5710 - age_output_loss: 0.4522 - weight_output_loss: 0.4192 - bag_output_loss: 0.5410 - footwear_output_loss: 0.5443 - pose_output_loss: 0.5413 - emotion_output_loss: 0.3851 - gender_output_acc: 0.6068 - image_quality_output_acc: 0.6999 - age_output_acc: 0.8000 - weight_output_acc: 0.8159 - bag_output_acc: 0.7112 - footwear_output_acc: 0.7213 - pose_output_acc: 0.7452 - emotion_output_acc: 0.8557 - val_loss: 1.3333 - val_gender_output_loss: 0.6444 - val_image_quality_output_loss: 0.5650 - val_age_output_loss: 0.4530 - val_weight_output_loss: 0.4124 - val_bag_output_loss: 0.5440 - val_footwear_output_loss: 0.5490 - val_pose_output_loss: 0.5420 - val_emotion_output_loss: 0.3826 - val_gender_output_acc: 0.6124 - val_image_quality_output_acc: 0.7082 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8219 - val_bag_output_acc: 0.7059 - val_footwear_output_acc: 0.7183 - val_pose_output_acc: 0.7434 - val_emotion_output_acc: 0.8566
# Epoch 13/200
# 360/360 [==============================] - 153s 426ms/step - loss: 1.3352 - gender_output_loss: 0.6504 - image_quality_output_loss: 0.5705 - age_output_loss: 0.4524 - weight_output_loss: 0.4189 - bag_output_loss: 0.5399 - footwear_output_loss: 0.5406 - pose_output_loss: 0.5400 - emotion_output_loss: 0.3851 - gender_output_acc: 0.6111 - image_quality_output_acc: 0.6993 - age_output_acc: 0.8003 - weight_output_acc: 0.8167 - bag_output_acc: 0.7143 - footwear_output_acc: 0.7238 - pose_output_acc: 0.7456 - emotion_output_acc: 0.8556 - val_loss: 1.3299 - val_gender_output_loss: 0.6414 - val_image_quality_output_loss: 0.5682 - val_age_output_loss: 0.4516 - val_weight_output_loss: 0.4125 - val_bag_output_loss: 0.5408 - val_footwear_output_loss: 0.5431 - val_pose_output_loss: 0.5413 - val_emotion_output_loss: 0.3821 - val_gender_output_acc: 0.6208 - val_image_quality_output_acc: 0.7085 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8224 - val_bag_output_acc: 0.7121 - val_footwear_output_acc: 0.7199 - val_pose_output_acc: 0.7427 - val_emotion_output_acc: 0.8566
# Epoch 14/200
# 360/360 [==============================] - 152s 422ms/step - loss: 1.3332 - gender_output_loss: 0.6493 - image_quality_output_loss: 0.5698 - age_output_loss: 0.4517 - weight_output_loss: 0.4187 - bag_output_loss: 0.5392 - footwear_output_loss: 0.5383 - pose_output_loss: 0.5400 - emotion_output_loss: 0.3845 - gender_output_acc: 0.6124 - image_quality_output_acc: 0.6998 - age_output_acc: 0.8000 - weight_output_acc: 0.8160 - bag_output_acc: 0.7152 - footwear_output_acc: 0.7245 - pose_output_acc: 0.7450 - emotion_output_acc: 0.8555 - val_loss: 1.3265 - val_gender_output_loss: 0.6447 - val_image_quality_output_loss: 0.5637 - val_age_output_loss: 0.4521 - val_weight_output_loss: 0.4122 - val_bag_output_loss: 0.5387 - val_footwear_output_loss: 0.5376 - val_pose_output_loss: 0.5392 - val_emotion_output_loss: 0.3822 - val_gender_output_acc: 0.6228 - val_image_quality_output_acc: 0.7077 - val_age_output_acc: 0.7997 - val_weight_output_acc: 0.8227 - val_bag_output_acc: 0.7103 - val_footwear_output_acc: 0.7242 - val_pose_output_acc: 0.7422 - val_emotion_output_acc: 0.8566
# Epoch 15/200
# 359/360 [============================>.] - ETA: 0s - loss: 1.3314 - gender_output_loss: 0.6459 - image_quality_output_loss: 0.5700 - age_output_loss: 0.4514 - weight_output_loss: 0.4169 - bag_output_loss: 0.5387 - footwear_output_loss: 0.5394 - pose_output_loss: 0.5385 - emotion_output_loss: 0.3845 - gender_output_acc: 0.6161 - image_quality_output_acc: 0.6990 - age_output_acc: 0.7998 - weight_output_acc: 0.8163 - bag_output_acc: 0.7157 - footwear_output_acc: 0.7235 - pose_output_acc: 0.7454 - emotion_output_acc: 0.8556Epoch 15/200
# 360/360 [==============================] - 152s 423ms/step - loss: 1.3313 - gender_output_loss: 0.6460 - image_quality_output_loss: 0.5698 - age_output_loss: 0.4514 - weight_output_loss: 0.4169 - bag_output_loss: 0.5386 - footwear_output_loss: 0.5393 - pose_output_loss: 0.5384 - emotion_output_loss: 0.3844 - gender_output_acc: 0.6160 - image_quality_output_acc: 0.6992 - age_output_acc: 0.7999 - weight_output_acc: 0.8163 - bag_output_acc: 0.7160 - footwear_output_acc: 0.7236 - pose_output_acc: 0.7453 - emotion_output_acc: 0.8557 - val_loss: 1.3279 - val_gender_output_loss: 0.6422 - val_image_quality_output_loss: 0.5642 - val_age_output_loss: 0.4525 - val_weight_output_loss: 0.4143 - val_bag_output_loss: 0.5390 - val_footwear_output_loss: 0.5392 - val_pose_output_loss: 0.5397 - val_emotion_output_loss: 0.3821 - val_gender_output_acc: 0.6230 - val_image_quality_output_acc: 0.7087 - val_age_output_acc: 0.8001 - val_weight_output_acc: 0.8222 - val_bag_output_acc: 0.7168 - val_footwear_output_acc: 0.7288 - val_pose_output_acc: 0.7434 - val_emotion_output_acc: 0.8566
# Epoch 16/200
# 360/360 [==============================] - 152s 422ms/step - loss: 1.3291 - gender_output_loss: 0.6424 - image_quality_output_loss: 0.5685 - age_output_loss: 0.4506 - weight_output_loss: 0.4181 - bag_output_loss: 0.5370 - footwear_output_loss: 0.5379 - pose_output_loss: 0.5380 - emotion_output_loss: 0.3841 - gender_output_acc: 0.6216 - image_quality_output_acc: 0.7012 - age_output_acc: 0.7996 - weight_output_acc: 0.8156 - bag_output_acc: 0.7155 - footwear_output_acc: 0.7258 - pose_output_acc: 0.7456 - emotion_output_acc: 0.8555 - val_loss: 1.3330 - val_gender_output_loss: 0.6404 - val_image_quality_output_loss: 0.5658 - val_age_output_loss: 0.4534 - val_weight_output_loss: 0.4157 - val_bag_output_loss: 0.5401 - val_footwear_output_loss: 0.5525 - val_pose_output_loss: 0.5383 - val_emotion_output_loss: 0.3825 - val_gender_output_acc: 0.6153 - val_image_quality_output_acc: 0.7088 - val_age_output_acc: 0.7983 - val_weight_output_acc: 0.8232 - val_bag_output_acc: 0.7097 - val_footwear_output_acc: 0.7221 - val_pose_output_acc: 0.7419 - val_emotion_output_acc: 0.8566
# Epoch 17/200
# 360/360 [==============================] - 151s 421ms/step - loss: 1.3271 - gender_output_loss: 0.6373 - image_quality_output_loss: 0.5679 - age_output_loss: 0.4510 - weight_output_loss: 0.4181 - bag_output_loss: 0.5365 - footwear_output_loss: 0.5345 - pose_output_loss: 0.5376 - emotion_output_loss: 0.3850 - gender_output_acc: 0.6296 - image_quality_output_acc: 0.7007 - age_output_acc: 0.7993 - weight_output_acc: 0.8163 - bag_output_acc: 0.7173 - footwear_output_acc: 0.7269 - pose_output_acc: 0.7462 - emotion_output_acc: 0.8555 - val_loss: 1.3210 - val_gender_output_loss: 0.6337 - val_image_quality_output_loss: 0.5619 - val_age_output_loss: 0.4522 - val_weight_output_loss: 0.4133 - val_bag_output_loss: 0.5367 - val_footwear_output_loss: 0.5319 - val_pose_output_loss: 0.5374 - val_emotion_output_loss: 0.3811 - val_gender_output_acc: 0.6310 - val_image_quality_output_acc: 0.7100 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8239 - val_bag_output_acc: 0.7171 - val_footwear_output_acc: 0.7302 - val_pose_output_acc: 0.7431 - val_emotion_output_acc: 0.8566
# Epoch 18/200
# 360/360 [==============================] - 152s 422ms/step - loss: 1.3245 - gender_output_loss: 0.6341 - image_quality_output_loss: 0.5677 - age_output_loss: 0.4509 - weight_output_loss: 0.4165 - bag_output_loss: 0.5352 - footwear_output_loss: 0.5329 - pose_output_loss: 0.5373 - emotion_output_loss: 0.3843 - gender_output_acc: 0.6349 - image_quality_output_acc: 0.6999 - age_output_acc: 0.8001 - weight_output_acc: 0.8172 - bag_output_acc: 0.7198 - footwear_output_acc: 0.7287 - pose_output_acc: 0.7459 - emotion_output_acc: 0.8556 - val_loss: 1.3188 - val_gender_output_loss: 0.6264 - val_image_quality_output_loss: 0.5614 - val_age_output_loss: 0.4513 - val_weight_output_loss: 0.4144 - val_bag_output_loss: 0.5345 - val_footwear_output_loss: 0.5328 - val_pose_output_loss: 0.5362 - val_emotion_output_loss: 0.3816 - val_gender_output_acc: 0.6359 - val_image_quality_output_acc: 0.7110 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8181 - val_bag_output_acc: 0.7196 - val_footwear_output_acc: 0.7265 - val_pose_output_acc: 0.7436 - val_emotion_output_acc: 0.8566
# Epoch 19/200
# 359/360 [============================>.] - ETA: 0s - loss: 1.3206 - gender_output_loss: 0.6286 - image_quality_output_loss: 0.5660 - age_output_loss: 0.4500 - weight_output_loss: 0.4163 - bag_output_loss: 0.5345 - footwear_output_loss: 0.5314 - pose_output_loss: 0.5339 - emotion_output_loss: 0.3840 - gender_output_acc: 0.6371 - image_quality_output_acc: 0.7015 - age_output_acc: 0.7998 - weight_output_acc: 0.8172 - bag_output_acc: 0.7197 - footwear_output_acc: 0.7300 - pose_output_acc: 0.7468 - emotion_output_acc: 0.8556
# 360/360 [==============================] - 151s 420ms/step - loss: 1.3206 - gender_output_loss: 0.6288 - image_quality_output_loss: 0.5660 - age_output_loss: 0.4501 - weight_output_loss: 0.4161 - bag_output_loss: 0.5346 - footwear_output_loss: 0.5313 - pose_output_loss: 0.5338 - emotion_output_loss: 0.3842 - gender_output_acc: 0.6371 - image_quality_output_acc: 0.7015 - age_output_acc: 0.7998 - weight_output_acc: 0.8173 - bag_output_acc: 0.7196 - footwear_output_acc: 0.7301 - pose_output_acc: 0.7468 - emotion_output_acc: 0.8555 - val_loss: 1.3203 - val_gender_output_loss: 0.6304 - val_image_quality_output_loss: 0.5634 - val_age_output_loss: 0.4515 - val_weight_output_loss: 0.4137 - val_bag_output_loss: 0.5332 - val_footwear_output_loss: 0.5329 - val_pose_output_loss: 0.5366 - val_emotion_output_loss: 0.3830 - val_gender_output_acc: 0.6357 - val_image_quality_output_acc: 0.7098 - val_age_output_acc: 0.7996 - val_weight_output_acc: 0.8218 - val_bag_output_acc: 0.7189 - val_footwear_output_acc: 0.7297 - val_pose_output_acc: 0.7445 - val_emotion_output_acc: 0.8566
# Epoch 20/200
# 360/360 [==============================] - 151s 419ms/step - loss: 1.3189 - gender_output_loss: 0.6254 - image_quality_output_loss: 0.5657 - age_output_loss: 0.4501 - weight_output_loss: 0.4166 - bag_output_loss: 0.5333 - footwear_output_loss: 0.5292 - pose_output_loss: 0.5327 - emotion_output_loss: 0.3846 - gender_output_acc: 0.6467 - image_quality_output_acc: 0.7009 - age_output_acc: 0.8001 - weight_output_acc: 0.8166 - bag_output_acc: 0.7198 - footwear_output_acc: 0.7310 - pose_output_acc: 0.7473 - emotion_output_acc: 0.8556 - val_loss: 1.3206 - val_gender_output_loss: 0.6278 - val_image_quality_output_loss: 0.5612 - val_age_output_loss: 0.4522 - val_weight_output_loss: 0.4141 - val_bag_output_loss: 0.5362 - val_footwear_output_loss: 0.5388 - val_pose_output_loss: 0.5328 - val_emotion_output_loss: 0.3814 - val_gender_output_acc: 0.6431 - val_image_quality_output_acc: 0.7083 - val_age_output_acc: 0.7990 - val_weight_output_acc: 0.8222 - val_bag_output_acc: 0.7188 - val_footwear_output_acc: 0.7247 - val_pose_output_acc: 0.7439 - val_emotion_output_acc: 0.8566
# Epoch 21/200
# 360/360 [==============================] - 151s 420ms/step - loss: 1.3149 - gender_output_loss: 0.6201 - image_quality_output_loss: 0.5643 - age_output_loss: 0.4497 - weight_output_loss: 0.4158 - bag_output_loss: 0.5314 - footwear_output_loss: 0.5268 - pose_output_loss: 0.5309 - emotion_output_loss: 0.3843 - gender_output_acc: 0.6478 - image_quality_output_acc: 0.7010 - age_output_acc: 0.7996 - weight_output_acc: 0.8174 - bag_output_acc: 0.7228 - footwear_output_acc: 0.7323 - pose_output_acc: 0.7481 - emotion_output_acc: 0.8557 - val_loss: 1.3848 - val_gender_output_loss: 0.6747 - val_image_quality_output_loss: 0.5822 - val_age_output_loss: 0.4602 - val_weight_output_loss: 0.4233 - val_bag_output_loss: 0.5704 - val_footwear_output_loss: 0.6267 - val_pose_output_loss: 0.5405 - val_emotion_output_loss: 0.3864 - val_gender_output_acc: 0.6245 - val_image_quality_output_acc: 0.7030 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8134 - val_bag_output_acc: 0.7097 - val_footwear_output_acc: 0.6660 - val_pose_output_acc: 0.7444 - val_emotion_output_acc: 0.8566
# Epoch 22/200
# 360/360 [==============================] - 151s 420ms/step - loss: 1.3133 - gender_output_loss: 0.6163 - image_quality_output_loss: 0.5653 - age_output_loss: 0.4497 - weight_output_loss: 0.4149 - bag_output_loss: 0.5301 - footwear_output_loss: 0.5260 - pose_output_loss: 0.5312 - emotion_output_loss: 0.3836 - gender_output_acc: 0.6500 - image_quality_output_acc: 0.7016 - age_output_acc: 0.7994 - weight_output_acc: 0.8176 - bag_output_acc: 0.7238 - footwear_output_acc: 0.7338 - pose_output_acc: 0.7475 - emotion_output_acc: 0.8557 - val_loss: 1.3098 - val_gender_output_loss: 0.6070 - val_image_quality_output_loss: 0.5635 - val_age_output_loss: 0.4502 - val_weight_output_loss: 0.4103 - val_bag_output_loss: 0.5326 - val_footwear_output_loss: 0.5319 - val_pose_output_loss: 0.5292 - val_emotion_output_loss: 0.3799 - val_gender_output_acc: 0.6572 - val_image_quality_output_acc: 0.7110 - val_age_output_acc: 0.8002 - val_weight_output_acc: 0.8227 - val_bag_output_acc: 0.7226 - val_footwear_output_acc: 0.7300 - val_pose_output_acc: 0.7449 - val_emotion_output_acc: 0.8566
# Epoch 23/200
# 360/360 [==============================] - 151s 420ms/step - loss: 1.3097 - gender_output_loss: 0.6104 - image_quality_output_loss: 0.5645 - age_output_loss: 0.4491 - weight_output_loss: 0.4146 - bag_output_loss: 0.5284 - footwear_output_loss: 0.5233 - pose_output_loss: 0.5295 - emotion_output_loss: 0.3838 - gender_output_acc: 0.6595 - image_quality_output_acc: 0.6989 - age_output_acc: 0.7992 - weight_output_acc: 0.8176 - bag_output_acc: 0.7259 - footwear_output_acc: 0.7391 - pose_output_acc: 0.7482 - emotion_output_acc: 0.8556 - val_loss: 1.3151 - val_gender_output_loss: 0.6155 - val_image_quality_output_loss: 0.5603 - val_age_output_loss: 0.4520 - val_weight_output_loss: 0.4122 - val_bag_output_loss: 0.5343 - val_footwear_output_loss: 0.5386 - val_pose_output_loss: 0.5294 - val_emotion_output_loss: 0.3808 - val_gender_output_acc: 0.6523 - val_image_quality_output_acc: 0.7098 - val_age_output_acc: 0.7997 - val_weight_output_acc: 0.8211 - val_bag_output_acc: 0.7235 - val_footwear_output_acc: 0.7255 - val_pose_output_acc: 0.7462 - val_emotion_output_acc: 0.8566
# Epoch 24/200
# 360/360 [==============================] - 152s 421ms/step - loss: 1.3077 - gender_output_loss: 0.6097 - image_quality_output_loss: 0.5637 - age_output_loss: 0.4489 - weight_output_loss: 0.4141 - bag_output_loss: 0.5274 - footwear_output_loss: 0.5217 - pose_output_loss: 0.5287 - emotion_output_loss: 0.3830 - gender_output_acc: 0.6615 - image_quality_output_acc: 0.7016 - age_output_acc: 0.8003 - weight_output_acc: 0.8184 - bag_output_acc: 0.7270 - footwear_output_acc: 0.7384 - pose_output_acc: 0.7475 - emotion_output_acc: 0.8555 - val_loss: 1.3088 - val_gender_output_loss: 0.6043 - val_image_quality_output_loss: 0.5614 - val_age_output_loss: 0.4503 - val_weight_output_loss: 0.4112 - val_bag_output_loss: 0.5313 - val_footwear_output_loss: 0.5345 - val_pose_output_loss: 0.5263 - val_emotion_output_loss: 0.3806 - val_gender_output_acc: 0.6572 - val_image_quality_output_acc: 0.7093 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8204 - val_bag_output_acc: 0.7209 - val_footwear_output_acc: 0.7285 - val_pose_output_acc: 0.7421 - val_emotion_output_acc: 0.8566
# Epoch 25/200
# 360/360 [==============================] - 151s 420ms/step - loss: 1.3050 - gender_output_loss: 0.6025 - image_quality_output_loss: 0.5631 - age_output_loss: 0.4488 - weight_output_loss: 0.4145 - bag_output_loss: 0.5280 - footwear_output_loss: 0.5208 - pose_output_loss: 0.5262 - emotion_output_loss: 0.3821 - gender_output_acc: 0.6703 - image_quality_output_acc: 0.6997 - age_output_acc: 0.7999 - weight_output_acc: 0.8173 - bag_output_acc: 0.7260 - footwear_output_acc: 0.7359 - pose_output_acc: 0.7491 - emotion_output_acc: 0.8556 - val_loss: 1.3823 - val_gender_output_loss: 0.6745 - val_image_quality_output_loss: 0.5798 - val_age_output_loss: 0.4581 - val_weight_output_loss: 0.4249 - val_bag_output_loss: 0.5642 - val_footwear_output_loss: 0.6296 - val_pose_output_loss: 0.5378 - val_emotion_output_loss: 0.3875 - val_gender_output_acc: 0.6409 - val_image_quality_output_acc: 0.7067 - val_age_output_acc: 0.8001 - val_weight_output_acc: 0.8053 - val_bag_output_acc: 0.7161 - val_footwear_output_acc: 0.6721 - val_pose_output_acc: 0.7450 - val_emotion_output_acc: 0.8566
# Epoch 26/200
# 360/360 [==============================] - 150s 417ms/step - loss: 1.3030 - gender_output_loss: 0.5980 - image_quality_output_loss: 0.5621 - age_output_loss: 0.4485 - weight_output_loss: 0.4137 - bag_output_loss: 0.5272 - footwear_output_loss: 0.5213 - pose_output_loss: 0.5246 - emotion_output_loss: 0.3828 - gender_output_acc: 0.6677 - image_quality_output_acc: 0.7010 - age_output_acc: 0.7997 - weight_output_acc: 0.8182 - bag_output_acc: 0.7284 - footwear_output_acc: 0.7400 - pose_output_acc: 0.7507 - emotion_output_acc: 0.8557 - val_loss: 1.3093 - val_gender_output_loss: 0.5971 - val_image_quality_output_loss: 0.5695 - val_age_output_loss: 0.4500 - val_weight_output_loss: 0.4124 - val_bag_output_loss: 0.5285 - val_footwear_output_loss: 0.5346 - val_pose_output_loss: 0.5231 - val_emotion_output_loss: 0.3831 - val_gender_output_acc: 0.6664 - val_image_quality_output_acc: 0.7067 - val_age_output_acc: 0.8004 - val_weight_output_acc: 0.8219 - val_bag_output_acc: 0.7308 - val_footwear_output_acc: 0.7312 - val_pose_output_acc: 0.7465 - val_emotion_output_acc: 0.8566
# Epoch 27/200
# 360/360 [==============================] - 151s 421ms/step - loss: 1.2980 - gender_output_loss: 0.5893 - image_quality_output_loss: 0.5619 - age_output_loss: 0.4477 - weight_output_loss: 0.4136 - bag_output_loss: 0.5241 - footwear_output_loss: 0.5174 - pose_output_loss: 0.5233 - emotion_output_loss: 0.3820 - gender_output_acc: 0.6826 - image_quality_output_acc: 0.7014 - age_output_acc: 0.7995 - weight_output_acc: 0.8175 - bag_output_acc: 0.7307 - footwear_output_acc: 0.7427 - pose_output_acc: 0.7513 - emotion_output_acc: 0.8556 - val_loss: 1.3279 - val_gender_output_loss: 0.6306 - val_image_quality_output_loss: 0.5665 - val_age_output_loss: 0.4540 - val_weight_output_loss: 0.4186 - val_bag_output_loss: 0.5408 - val_footwear_output_loss: 0.5477 - val_pose_output_loss: 0.5269 - val_emotion_output_loss: 0.3818 - val_gender_output_acc: 0.6339 - val_image_quality_output_acc: 0.7100 - val_age_output_acc: 0.7987 - val_weight_output_acc: 0.8222 - val_bag_output_acc: 0.7092 - val_footwear_output_acc: 0.7270 - val_pose_output_acc: 0.7470 - val_emotion_output_acc: 0.8566
# Epoch 28/200
# 360/360 [==============================] - 152s 421ms/step - loss: 1.2945 - gender_output_loss: 0.5857 - image_quality_output_loss: 0.5606 - age_output_loss: 0.4475 - weight_output_loss: 0.4131 - bag_output_loss: 0.5221 - footwear_output_loss: 0.5148 - pose_output_loss: 0.5211 - emotion_output_loss: 0.3819 - gender_output_acc: 0.6868 - image_quality_output_acc: 0.7027 - age_output_acc: 0.7991 - weight_output_acc: 0.8180 - bag_output_acc: 0.7298 - footwear_output_acc: 0.7425 - pose_output_acc: 0.7521 - emotion_output_acc: 0.8556 - val_loss: 1.3013 - val_gender_output_loss: 0.5930 - val_image_quality_output_loss: 0.5568 - val_age_output_loss: 0.4501 - val_weight_output_loss: 0.4108 - val_bag_output_loss: 0.5256 - val_footwear_output_loss: 0.5319 - val_pose_output_loss: 0.5226 - val_emotion_output_loss: 0.3806 - val_gender_output_acc: 0.6768 - val_image_quality_output_acc: 0.7135 - val_age_output_acc: 0.7991 - val_weight_output_acc: 0.8189 - val_bag_output_acc: 0.7269 - val_footwear_output_acc: 0.7338 - val_pose_output_acc: 0.7505 - val_emotion_output_acc: 0.8566
# Epoch 29/200
# 360/360 [==============================] - 152s 421ms/step - loss: 1.2918 - gender_output_loss: 0.5831 - image_quality_output_loss: 0.5588 - age_output_loss: 0.4472 - weight_output_loss: 0.4120 - bag_output_loss: 0.5221 - footwear_output_loss: 0.5125 - pose_output_loss: 0.5205 - emotion_output_loss: 0.3813 - gender_output_acc: 0.6862 - image_quality_output_acc: 0.7030 - age_output_acc: 0.7997 - weight_output_acc: 0.8186 - bag_output_acc: 0.7311 - footwear_output_acc: 0.7440 - pose_output_acc: 0.7534 - emotion_output_acc: 0.8556 - val_loss: 1.3507 - val_gender_output_loss: 0.6698 - val_image_quality_output_loss: 0.5633 - val_age_output_loss: 0.4560 - val_weight_output_loss: 0.4189 - val_bag_output_loss: 0.5691 - val_footwear_output_loss: 0.5681 - val_pose_output_loss: 0.5259 - val_emotion_output_loss: 0.3832 - val_gender_output_acc: 0.6491 - val_image_quality_output_acc: 0.7087 - val_age_output_acc: 0.7998 - val_weight_output_acc: 0.8104 - val_bag_output_acc: 0.7153 - val_footwear_output_acc: 0.7126 - val_pose_output_acc: 0.7507 - val_emotion_output_acc: 0.8566
# Epoch 30/200
# 360/360 [==============================] - 153s 425ms/step - loss: 1.2913 - gender_output_loss: 0.5812 - image_quality_output_loss: 0.5586 - age_output_loss: 0.4461 - weight_output_loss: 0.4125 - bag_output_loss: 0.5228 - footwear_output_loss: 0.5166 - pose_output_loss: 0.5171 - emotion_output_loss: 0.3812 - gender_output_acc: 0.6845 - image_quality_output_acc: 0.7012 - age_output_acc: 0.8004 - weight_output_acc: 0.8182 - bag_output_acc: 0.7333 - footwear_output_acc: 0.7413 - pose_output_acc: 0.7556 - emotion_output_acc: 0.8556 - val_loss: 1.3993 - val_gender_output_loss: 0.7205 - val_image_quality_output_loss: 0.5909 - val_age_output_loss: 0.4548 - val_weight_output_loss: 0.4176 - val_bag_output_loss: 0.5759 - val_footwear_output_loss: 0.6419 - val_pose_output_loss: 0.5415 - val_emotion_output_loss: 0.3894 - val_gender_output_acc: 0.6173 - val_image_quality_output_acc: 0.7025 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8132 - val_bag_output_acc: 0.7123 - val_footwear_output_acc: 0.6804 - val_pose_output_acc: 0.7307 - val_emotion_output_acc: 0.8566
# Epoch 31/200
# 360/360 [==============================] - 152s 423ms/step - loss: 1.2871 - gender_output_loss: 0.5711 - image_quality_output_loss: 0.5580 - age_output_loss: 0.4465 - weight_output_loss: 0.4117 - bag_output_loss: 0.5206 - footwear_output_loss: 0.5135 - pose_output_loss: 0.5157 - emotion_output_loss: 0.3817 - gender_output_acc: 0.6994 - image_quality_output_acc: 0.7039 - age_output_acc: 0.7995 - weight_output_acc: 0.8183 - bag_output_acc: 0.7336 - footwear_output_acc: 0.7445 - pose_output_acc: 0.7555 - emotion_output_acc: 0.8556 - val_loss: 1.2954 - val_gender_output_loss: 0.5777 - val_image_quality_output_loss: 0.5582 - val_age_output_loss: 0.4484 - val_weight_output_loss: 0.4109 - val_bag_output_loss: 0.5310 - val_footwear_output_loss: 0.5267 - val_pose_output_loss: 0.5159 - val_emotion_output_loss: 0.3795 - val_gender_output_acc: 0.6942 - val_image_quality_output_acc: 0.7103 - val_age_output_acc: 0.7988 - val_weight_output_acc: 0.8216 - val_bag_output_acc: 0.7247 - val_footwear_output_acc: 0.7440 - val_pose_output_acc: 0.7512 - val_emotion_output_acc: 0.8566
# Epoch 32/200
# 360/360 [==============================] - 153s 424ms/step - loss: 1.2824 - gender_output_loss: 0.5647 - image_quality_output_loss: 0.5559 - age_output_loss: 0.4467 - weight_output_loss: 0.4115 - bag_output_loss: 0.5184 - footwear_output_loss: 0.5116 - pose_output_loss: 0.5112 - emotion_output_loss: 0.3809 - gender_output_acc: 0.7053 - image_quality_output_acc: 0.7051 - age_output_acc: 0.7999 - weight_output_acc: 0.8193 - bag_output_acc: 0.7371 - footwear_output_acc: 0.7447 - pose_output_acc: 0.7583 - emotion_output_acc: 0.8555 - val_loss: 1.3307 - val_gender_output_loss: 0.6112 - val_image_quality_output_loss: 0.5602 - val_age_output_loss: 0.4522 - val_weight_output_loss: 0.4212 - val_bag_output_loss: 0.5542 - val_footwear_output_loss: 0.5513 - val_pose_output_loss: 0.5356 - val_emotion_output_loss: 0.3837 - val_gender_output_acc: 0.6788 - val_image_quality_output_acc: 0.7097 - val_age_output_acc: 0.7998 - val_weight_output_acc: 0.8116 - val_bag_output_acc: 0.7179 - val_footwear_output_acc: 0.7247 - val_pose_output_acc: 0.7462 - val_emotion_output_acc: 0.8566
# Epoch 33/200
# 360/360 [==============================] - 154s 426ms/step - loss: 1.2816 - gender_output_loss: 0.5654 - image_quality_output_loss: 0.5566 - age_output_loss: 0.4466 - weight_output_loss: 0.4121 - bag_output_loss: 0.5182 - footwear_output_loss: 0.5096 - pose_output_loss: 0.5095 - emotion_output_loss: 0.3806 - gender_output_acc: 0.7016 - image_quality_output_acc: 0.7042 - age_output_acc: 0.8005 - weight_output_acc: 0.8177 - bag_output_acc: 0.7370 - footwear_output_acc: 0.7477 - pose_output_acc: 0.7598 - emotion_output_acc: 0.8557 - val_loss: 1.2991 - val_gender_output_loss: 0.5664 - val_image_quality_output_loss: 0.5572 - val_age_output_loss: 0.4502 - val_weight_output_loss: 0.4124 - val_bag_output_loss: 0.5325 - val_footwear_output_loss: 0.5332 - val_pose_output_loss: 0.5239 - val_emotion_output_loss: 0.3794 - val_gender_output_acc: 0.7076 - val_image_quality_output_acc: 0.7115 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8207 - val_bag_output_acc: 0.7183 - val_footwear_output_acc: 0.7376 - val_pose_output_acc: 0.7485 - val_emotion_output_acc: 0.8566
# Epoch 34/200
# 360/360 [==============================] - 151s 421ms/step - loss: 1.2777 - gender_output_loss: 0.5578 - image_quality_output_loss: 0.5556 - age_output_loss: 0.4460 - weight_output_loss: 0.4123 - bag_output_loss: 0.5159 - footwear_output_loss: 0.5048 - pose_output_loss: 0.5097 - emotion_output_loss: 0.3811 - gender_output_acc: 0.7088 - image_quality_output_acc: 0.7042 - age_output_acc: 0.7996 - weight_output_acc: 0.8186 - bag_output_acc: 0.7393 - footwear_output_acc: 0.7483 - pose_output_acc: 0.7586 - emotion_output_acc: 0.8557 - val_loss: 1.2913 - val_gender_output_loss: 0.5746 - val_image_quality_output_loss: 0.5559 - val_age_output_loss: 0.4486 - val_weight_output_loss: 0.4127 - val_bag_output_loss: 0.5284 - val_footwear_output_loss: 0.5267 - val_pose_output_loss: 0.5067 - val_emotion_output_loss: 0.3791 - val_gender_output_acc: 0.6969 - val_image_quality_output_acc: 0.7121 - val_age_output_acc: 0.7988 - val_weight_output_acc: 0.8208 - val_bag_output_acc: 0.7188 - val_footwear_output_acc: 0.7379 - val_pose_output_acc: 0.7578 - val_emotion_output_acc: 0.8568
# Epoch 35/200
# 360/360 [==============================] - 153s 424ms/step - loss: 1.2743 - gender_output_loss: 0.5510 - image_quality_output_loss: 0.5541 - age_output_loss: 0.4462 - weight_output_loss: 0.4115 - bag_output_loss: 0.5153 - footwear_output_loss: 0.5058 - pose_output_loss: 0.5064 - emotion_output_loss: 0.3798 - gender_output_acc: 0.7125 - image_quality_output_acc: 0.7057 - age_output_acc: 0.7998 - weight_output_acc: 0.8181 - bag_output_acc: 0.7395 - footwear_output_acc: 0.7493 - pose_output_acc: 0.7602 - emotion_output_acc: 0.8555 - val_loss: 1.2966 - val_gender_output_loss: 0.5782 - val_image_quality_output_loss: 0.5558 - val_age_output_loss: 0.4495 - val_weight_output_loss: 0.4111 - val_bag_output_loss: 0.5315 - val_footwear_output_loss: 0.5316 - val_pose_output_loss: 0.5155 - val_emotion_output_loss: 0.3786 - val_gender_output_acc: 0.6863 - val_image_quality_output_acc: 0.7070 - val_age_output_acc: 0.7996 - val_weight_output_acc: 0.8220 - val_bag_output_acc: 0.7173 - val_footwear_output_acc: 0.7320 - val_pose_output_acc: 0.7483 - val_emotion_output_acc: 0.8566
# Epoch 36/200
# 360/360 [==============================] - 152s 422ms/step - loss: 1.2731 - gender_output_loss: 0.5499 - image_quality_output_loss: 0.5546 - age_output_loss: 0.4462 - weight_output_loss: 0.4111 - bag_output_loss: 0.5142 - footwear_output_loss: 0.5062 - pose_output_loss: 0.5032 - emotion_output_loss: 0.3804 - gender_output_acc: 0.7137 - image_quality_output_acc: 0.7044 - age_output_acc: 0.7997 - weight_output_acc: 0.8184 - bag_output_acc: 0.7419 - footwear_output_acc: 0.7513 - pose_output_acc: 0.7635 - emotion_output_acc: 0.8556 - val_loss: 1.2973 - val_gender_output_loss: 0.5833 - val_image_quality_output_loss: 0.5568 - val_age_output_loss: 0.4520 - val_weight_output_loss: 0.4120 - val_bag_output_loss: 0.5290 - val_footwear_output_loss: 0.5327 - val_pose_output_loss: 0.5098 - val_emotion_output_loss: 0.3784 - val_gender_output_acc: 0.6912 - val_image_quality_output_acc: 0.7082 - val_age_output_acc: 0.7991 - val_weight_output_acc: 0.8232 - val_bag_output_acc: 0.7212 - val_footwear_output_acc: 0.7336 - val_pose_output_acc: 0.7536 - val_emotion_output_acc: 0.8566
# Epoch 37/200
# 360/360 [==============================] - 151s 420ms/step - loss: 1.2697 - gender_output_loss: 0.5457 - image_quality_output_loss: 0.5536 - age_output_loss: 0.4457 - weight_output_loss: 0.4112 - bag_output_loss: 0.5136 - footwear_output_loss: 0.5027 - pose_output_loss: 0.5017 - emotion_output_loss: 0.3793 - gender_output_acc: 0.7169 - image_quality_output_acc: 0.7060 - age_output_acc: 0.8002 - weight_output_acc: 0.8180 - bag_output_acc: 0.7398 - footwear_output_acc: 0.7523 - pose_output_acc: 0.7609 - emotion_output_acc: 0.8556 - val_loss: 1.2884 - val_gender_output_loss: 0.5488 - val_image_quality_output_loss: 0.5548 - val_age_output_loss: 0.4495 - val_weight_output_loss: 0.4134 - val_bag_output_loss: 0.5312 - val_footwear_output_loss: 0.5274 - val_pose_output_loss: 0.5067 - val_emotion_output_loss: 0.3811 - val_gender_output_acc: 0.7235 - val_image_quality_output_acc: 0.7087 - val_age_output_acc: 0.7993 - val_weight_output_acc: 0.8222 - val_bag_output_acc: 0.7178 - val_footwear_output_acc: 0.7421 - val_pose_output_acc: 0.7556 - val_emotion_output_acc: 0.8565
# Epoch 38/200
#
# 360/360 [==============================] - 151s 420ms/step - loss: 1.2668 - gender_output_loss: 0.5366 - image_quality_output_loss: 0.5530 - age_output_loss: 0.4451 - weight_output_loss: 0.4098 - bag_output_loss: 0.5134 - footwear_output_loss: 0.5054 - pose_output_loss: 0.4989 - emotion_output_loss: 0.3794 - gender_output_acc: 0.7269 - image_quality_output_acc: 0.7048 - age_output_acc: 0.8001 - weight_output_acc: 0.8189 - bag_output_acc: 0.7400 - footwear_output_acc: 0.7510 - pose_output_acc: 0.7639 - emotion_output_acc: 0.8556 - val_loss: 1.2921 - val_gender_output_loss: 0.5533 - val_image_quality_output_loss: 0.5601 - val_age_output_loss: 0.4518 - val_weight_output_loss: 0.4125 - val_bag_output_loss: 0.5348 - val_footwear_output_loss: 0.5251 - val_pose_output_loss: 0.5090 - val_emotion_output_loss: 0.3796 - val_gender_output_acc: 0.7125 - val_image_quality_output_acc: 0.7065 - val_age_output_acc: 0.7997 - val_weight_output_acc: 0.8201 - val_bag_output_acc: 0.7240 - val_footwear_output_acc: 0.7414 - val_pose_output_acc: 0.7563 - val_emotion_output_acc: 0.8568
# Epoch 39/200
# 360/360 [==============================] - 151s 419ms/step - loss: 1.2622 - gender_output_loss: 0.5320 - image_quality_output_loss: 0.5506 - age_output_loss: 0.4449 - weight_output_loss: 0.4103 - bag_output_loss: 0.5106 - footwear_output_loss: 0.5031 - pose_output_loss: 0.4947 - emotion_output_loss: 0.3788 - gender_output_acc: 0.7276 - image_quality_output_acc: 0.7082 - age_output_acc: 0.8002 - weight_output_acc: 0.8187 - bag_output_acc: 0.7449 - footwear_output_acc: 0.7521 - pose_output_acc: 0.7660 - emotion_output_acc: 0.8558 - val_loss: 1.2892 - val_gender_output_loss: 0.5635 - val_image_quality_output_loss: 0.5529 - val_age_output_loss: 0.4511 - val_weight_output_loss: 0.4151 - val_bag_output_loss: 0.5396 - val_footwear_output_loss: 0.5250 - val_pose_output_loss: 0.4924 - val_emotion_output_loss: 0.3799 - val_gender_output_acc: 0.7059 - val_image_quality_output_acc: 0.7068 - val_age_output_acc: 0.7993 - val_weight_output_acc: 0.8208 - val_bag_output_acc: 0.7047 - val_footwear_output_acc: 0.7394 - val_pose_output_acc: 0.7650 - val_emotion_output_acc: 0.8566
# Epoch 40/200
#
# 360/360 [==============================] - 151s 420ms/step - loss: 1.2611 - gender_output_loss: 0.5301 - image_quality_output_loss: 0.5514 - age_output_loss: 0.4448 - weight_output_loss: 0.4096 - bag_output_loss: 0.5098 - footwear_output_loss: 0.5010 - pose_output_loss: 0.4955 - emotion_output_loss: 0.3788 - gender_output_acc: 0.7286 - image_quality_output_acc: 0.7065 - age_output_acc: 0.7992 - weight_output_acc: 0.8182 - bag_output_acc: 0.7453 - footwear_output_acc: 0.7525 - pose_output_acc: 0.7656 - emotion_output_acc: 0.8555 - val_loss: 1.3174 - val_gender_output_loss: 0.5969 - val_image_quality_output_loss: 0.5536 - val_age_output_loss: 0.4513 - val_weight_output_loss: 0.4157 - val_bag_output_loss: 0.5495 - val_footwear_output_loss: 0.5280 - val_pose_output_loss: 0.5491 - val_emotion_output_loss: 0.3799 - val_gender_output_acc: 0.6758 - val_image_quality_output_acc: 0.7103 - val_age_output_acc: 0.7994 - val_weight_output_acc: 0.8214 - val_bag_output_acc: 0.6954 - val_footwear_output_acc: 0.7388 - val_pose_output_acc: 0.7523 - val_emotion_output_acc: 0.8566
# Epoch 41/200
# 360/360 [==============================] - 152s 421ms/step - loss: 1.2580 - gender_output_loss: 0.5242 - image_quality_output_loss: 0.5517 - age_output_loss: 0.4449 - weight_output_loss: 0.4092 - bag_output_loss: 0.5090 - footwear_output_loss: 0.4972 - pose_output_loss: 0.4935 - emotion_output_loss: 0.3790 - gender_output_acc: 0.7348 - image_quality_output_acc: 0.7084 - age_output_acc: 0.8008 - weight_output_acc: 0.8187 - bag_output_acc: 0.7473 - footwear_output_acc: 0.7559 - pose_output_acc: 0.7671 - emotion_output_acc: 0.8557 - val_loss: 1.3001 - val_gender_output_loss: 0.5794 - val_image_quality_output_loss: 0.5711 - val_age_output_loss: 0.4504 - val_weight_output_loss: 0.4096 - val_bag_output_loss: 0.5374 - val_footwear_output_loss: 0.5294 - val_pose_output_loss: 0.5034 - val_emotion_output_loss: 0.3821 - val_gender_output_acc: 0.6994 - val_image_quality_output_acc: 0.7019 - val_age_output_acc: 0.7998 - val_weight_output_acc: 0.8235 - val_bag_output_acc: 0.7197 - val_footwear_output_acc: 0.7379 - val_pose_output_acc: 0.7583 - val_emotion_output_acc: 0.8566
# Epoch 42/200
# 360/360 [==============================] - 152s 421ms/step - loss: 1.2557 - gender_output_loss: 0.5241 - image_quality_output_loss: 0.5489 - age_output_loss: 0.4444 - weight_output_loss: 0.4087 - bag_output_loss: 0.5096 - footwear_output_loss: 0.4974 - pose_output_loss: 0.4908 - emotion_output_loss: 0.3780 - gender_output_acc: 0.7348 - image_quality_output_acc: 0.7100 - age_output_acc: 0.7999 - weight_output_acc: 0.8193 - bag_output_acc: 0.7440 - footwear_output_acc: 0.7576 - pose_output_acc: 0.7700 - emotion_output_acc: 0.8557 - val_loss: 1.2735 - val_gender_output_loss: 0.5290 - val_image_quality_output_loss: 0.5562 - val_age_output_loss: 0.4477 - val_weight_output_loss: 0.4111 - val_bag_output_loss: 0.5266 - val_footwear_output_loss: 0.5198 - val_pose_output_loss: 0.4917 - val_emotion_output_loss: 0.3777 - val_gender_output_acc: 0.7307 - val_image_quality_output_acc: 0.7049 - val_age_output_acc: 0.7991 - val_weight_output_acc: 0.8222 - val_bag_output_acc: 0.7257 - val_footwear_output_acc: 0.7431 - val_pose_output_acc: 0.7675 - val_emotion_output_acc: 0.8566
# Epoch 43/200
# ...
# Epoch 118/200
# 360/360 [==============================] - 150s 418ms/step - loss: 0.9464 - gender_output_loss: 0.2158 - image_quality_output_loss: 0.4671 - age_output_loss: 0.4052 - weight_output_loss: 0.3414 - bag_output_loss: 0.3915 - footwear_output_loss: 0.3678 - pose_output_loss: 0.2227 - emotion_output_loss: 0.3235 - gender_output_acc: 0.9118 - image_quality_output_acc: 0.7736 - age_output_acc: 0.8126 - weight_output_acc: 0.8485 - bag_output_acc: 0.8270 - footwear_output_acc: 0.8317 - pose_output_acc: 0.9080 - emotion_output_acc: 0.8666 - val_loss: 1.3719 - val_gender_output_loss: 0.6458 - val_image_quality_output_loss: 0.6076 - val_age_output_loss: 0.4641 - val_weight_output_loss: 0.4418 - val_bag_output_loss: 0.6537 - val_footwear_output_loss: 0.5659 - val_pose_output_loss: 0.4335 - val_emotion_output_loss: 0.3892 - val_gender_output_acc: 0.7560 - val_image_quality_output_acc: 0.6594 - val_age_output_acc: 0.7922 - val_weight_output_acc: 0.8069 - val_bag_output_acc: 0.7374 - val_footwear_output_acc: 0.7411 - val_pose_output_acc: 0.8282 - val_emotion_output_acc: 0.8553
# Epoch 119/200
# 360/360 [==============================] - 151s 419ms/step - loss: 0.9465 - gender_output_loss: 0.2194 - image_quality_output_loss: 0.4653 - age_output_loss: 0.4057 - weight_output_loss: 0.3405 - bag_output_loss: 0.3836 - footwear_output_loss: 0.3745 - pose_output_loss: 0.2263 - emotion_output_loss: 0.3217 - gender_output_acc: 0.9112 - image_quality_output_acc: 0.7699 - age_output_acc: 0.8141 - weight_output_acc: 0.8497 - bag_output_acc: 0.8284 - footwear_output_acc: 0.8269 - pose_output_acc: 0.9046 - emotion_output_acc: 0.8670 - val_loss: 1.3320 - val_gender_output_loss: 0.5523 - val_image_quality_output_loss: 0.6290 - val_age_output_loss: 0.4587 - val_weight_output_loss: 0.4469 - val_bag_output_loss: 0.5830 - val_footwear_output_loss: 0.5505 - val_pose_output_loss: 0.4232 - val_emotion_output_loss: 0.3942 - val_gender_output_acc: 0.7971 - val_image_quality_output_acc: 0.6591 - val_age_output_acc: 0.7874 - val_weight_output_acc: 0.7987 - val_bag_output_acc: 0.7272 - val_footwear_output_acc: 0.7470 - val_pose_output_acc: 0.8317 - val_emotion_output_acc: 0.8349
# Epoch 120/200
# 360/360 [==============================] - 151s 419ms/step - loss: 0.9394 - gender_output_loss: 0.2152 - image_quality_output_loss: 0.4634 - age_output_loss: 0.4034 - weight_output_loss: 0.3385 - bag_output_loss: 0.3809 - footwear_output_loss: 0.3660 - pose_output_loss: 0.2266 - emotion_output_loss: 0.3207 - gender_output_acc: 0.9154 - image_quality_output_acc: 0.7727 - age_output_acc: 0.8141 - weight_output_acc: 0.8527 - bag_output_acc: 0.8313 - footwear_output_acc: 0.8340 - pose_output_acc: 0.9058 - emotion_output_acc: 0.8680 - val_loss: 1.3529 - val_gender_output_loss: 0.5351 - val_image_quality_output_loss: 0.6094 - val_age_output_loss: 0.4589 - val_weight_output_loss: 0.4480 - val_bag_output_loss: 0.5985 - val_footwear_output_loss: 0.5701 - val_pose_output_loss: 0.4850 - val_emotion_output_loss: 0.3960 - val_gender_output_acc: 0.7991 - val_image_quality_output_acc: 0.6766 - val_age_output_acc: 0.7885 - val_weight_output_acc: 0.7992 - val_bag_output_acc: 0.7346 - val_footwear_output_acc: 0.7321 - val_pose_output_acc: 0.8256 - val_emotion_output_acc: 0.8379
# Epoch 121/200
# 359/360 [============================>.] - ETA: 0s - loss: 0.9357 - gender_output_loss: 0.2164 - image_quality_output_loss: 0.4597 - age_output_loss: 0.4031 - weight_output_loss: 0.3369 - bag_output_loss: 0.3785 - footwear_output_loss: 0.3638 - pose_output_loss: 0.2248 - emotion_output_loss: 0.3202 - gender_output_acc: 0.9119 - image_quality_output_acc: 0.7791 - age_output_acc: 0.8160 - weight_output_acc: 0.8516 - bag_output_acc: 0.8342 - footwear_output_acc: 0.8348 - pose_output_acc: 0.9074 - emotion_output_acc: 0.8684Epoch 121/200
# 360/360 [==============================] - 152s 421ms/step - loss: 0.9355 - gender_output_loss: 0.2163 - image_quality_output_loss: 0.4595 - age_output_loss: 0.4030 - weight_output_loss: 0.3368 - bag_output_loss: 0.3785 - footwear_output_loss: 0.3636 - pose_output_loss: 0.2249 - emotion_output_loss: 0.3201 - gender_output_acc: 0.9120 - image_quality_output_acc: 0.7793 - age_output_acc: 0.8160 - weight_output_acc: 0.8517 - bag_output_acc: 0.8341 - footwear_output_acc: 0.8349 - pose_output_acc: 0.9073 - emotion_output_acc: 0.8684 - val_loss: 1.3423 - val_gender_output_loss: 0.5421 - val_image_quality_output_loss: 0.6088 - val_age_output_loss: 0.4613 - val_weight_output_loss: 0.4500 - val_bag_output_loss: 0.5903 - val_footwear_output_loss: 0.5683 - val_pose_output_loss: 0.4548 - val_emotion_output_loss: 0.3915 - val_gender_output_acc: 0.7780 - val_image_quality_output_acc: 0.6763 - val_age_output_acc: 0.7917 - val_weight_output_acc: 0.8077 - val_bag_output_acc: 0.7436 - val_footwear_output_acc: 0.7330 - val_pose_output_acc: 0.8128 - val_emotion_output_acc: 0.8531
# Epoch 122/200
# 359/360 [============================>.] - ETA: 0s - loss: 0.9289 - gender_output_loss: 0.2085 - image_quality_output_loss: 0.4619 - age_output_loss: 0.4018 - weight_output_loss: 0.3342 - bag_output_loss: 0.3739 - footwear_output_loss: 0.3682 - pose_output_loss: 0.2163 - emotion_output_loss: 0.3165 - gender_output_acc: 0.9136 - image_quality_output_acc: 0.7768 - age_output_acc: 0.8158 - weight_output_acc: 0.8520 - bag_output_acc: 0.8338 - footwear_output_acc: 0.8308 - pose_output_acc: 0.9104 - emotion_output_acc: 0.8705Epoch 122/200
# 360/360 [==============================] - 152s 422ms/step - loss: 0.9289 - gender_output_loss: 0.2086 - image_quality_output_loss: 0.4622 - age_output_loss: 0.4017 - weight_output_loss: 0.3339 - bag_output_loss: 0.3739 - footwear_output_loss: 0.3681 - pose_output_loss: 0.2165 - emotion_output_loss: 0.3164 - gender_output_acc: 0.9136 - image_quality_output_acc: 0.7766 - age_output_acc: 0.8158 - weight_output_acc: 0.8522 - bag_output_acc: 0.8337 - footwear_output_acc: 0.8309 - pose_output_acc: 0.9103 - emotion_output_acc: 0.8706 - val_loss: 1.3483 - val_gender_output_loss: 0.6081 - val_image_quality_output_loss: 0.6309 - val_age_output_loss: 0.4617 - val_weight_output_loss: 0.4417 - val_bag_output_loss: 0.5754 - val_footwear_output_loss: 0.5644 - val_pose_output_loss: 0.4411 - val_emotion_output_loss: 0.3890 - val_gender_output_acc: 0.7686 - val_image_quality_output_acc: 0.6543 - val_age_output_acc: 0.7861 - val_weight_output_acc: 0.8095 - val_bag_output_acc: 0.7354 - val_footwear_output_acc: 0.7440 - val_pose_output_acc: 0.8203 - val_emotion_output_acc: 0.8457
# Epoch 123/200
# 360/360 [==============================] - 151s 419ms/step - loss: 0.9279 - gender_output_loss: 0.2177 - image_quality_output_loss: 0.4599 - age_output_loss: 0.4013 - weight_output_loss: 0.3340 - bag_output_loss: 0.3706 - footwear_output_loss: 0.3610 - pose_output_loss: 0.2193 - emotion_output_loss: 0.3173 - gender_output_acc: 0.9109 - image_quality_output_acc: 0.7747 - age_output_acc: 0.8163 - weight_output_acc: 0.8529 - bag_output_acc: 0.8380 - footwear_output_acc: 0.8363 - pose_output_acc: 0.9082 - emotion_output_acc: 0.8692 - val_loss: 1.3783 - val_gender_output_loss: 0.6779 - val_image_quality_output_loss: 0.6198 - val_age_output_loss: 0.4599 - val_weight_output_loss: 0.4537 - val_bag_output_loss: 0.6068 - val_footwear_output_loss: 0.5796 - val_pose_output_loss: 0.4469 - val_emotion_output_loss: 0.3882 - val_gender_output_acc: 0.7631 - val_image_quality_output_acc: 0.6675 - val_age_output_acc: 0.7932 - val_weight_output_acc: 0.7904 - val_bag_output_acc: 0.7354 - val_footwear_output_acc: 0.7416 - val_pose_output_acc: 0.8247 - val_emotion_output_acc: 0.8431
# Epoch 124/200
# 360/360 [==============================] - 151s 420ms/step - loss: 0.9180 - gender_output_loss: 0.2058 - image_quality_output_loss: 0.4540 - age_output_loss: 0.3977 - weight_output_loss: 0.3305 - bag_output_loss: 0.3683 - footwear_output_loss: 0.3605 - pose_output_loss: 0.2169 - emotion_output_loss: 0.3147 - gender_output_acc: 0.9163 - image_quality_output_acc: 0.7807 - age_output_acc: 0.8176 - weight_output_acc: 0.8545 - bag_output_acc: 0.8385 - footwear_output_acc: 0.8356 - pose_output_acc: 0.9107 - emotion_output_acc: 0.8704 - val_loss: 1.3913 - val_gender_output_loss: 0.5926 - val_image_quality_output_loss: 0.6166 - val_age_output_loss: 0.4786 - val_weight_output_loss: 0.4735 - val_bag_output_loss: 0.6287 - val_footwear_output_loss: 0.5646 - val_pose_output_loss: 0.4742 - val_emotion_output_loss: 0.3971 - val_gender_output_acc: 0.7696 - val_image_quality_output_acc: 0.6764 - val_age_output_acc: 0.7843 - val_weight_output_acc: 0.7990 - val_bag_output_acc: 0.7121 - val_footwear_output_acc: 0.7323 - val_pose_output_acc: 0.8287 - val_emotion_output_acc: 0.8392
# Epoch 125/200
# 360/360 [==============================] - 152s 422ms/step - loss: 0.9108 - gender_output_loss: 0.2040 - image_quality_output_loss: 0.4509 - age_output_loss: 0.3966 - weight_output_loss: 0.3265 - bag_output_loss: 0.3664 - footwear_output_loss: 0.3555 - pose_output_loss: 0.2148 - emotion_output_loss: 0.3121 - gender_output_acc: 0.9156 - image_quality_output_acc: 0.7815 - age_output_acc: 0.8179 - weight_output_acc: 0.8569 - bag_output_acc: 0.8392 - footwear_output_acc: 0.8408 - pose_output_acc: 0.9118 - emotion_output_acc: 0.8717 - val_loss: 1.3719 - val_gender_output_loss: 0.5567 - val_image_quality_output_loss: 0.6073 - val_age_output_loss: 0.4673 - val_weight_output_loss: 0.4520 - val_bag_output_loss: 0.6019 - val_footwear_output_loss: 0.5934 - val_pose_output_loss: 0.4892 - val_emotion_output_loss: 0.3964 - val_gender_output_acc: 0.7989 - val_image_quality_output_acc: 0.6915 - val_age_output_acc: 0.7914 - val_weight_output_acc: 0.8030 - val_bag_output_acc: 0.7386 - val_footwear_output_acc: 0.7393 - val_pose_output_acc: 0.8228 - val_emotion_output_acc: 0.8459
# Epoch 126/200
# 360/360 [==============================] - 151s 419ms/step - loss: 0.9015 - gender_output_loss: 0.1998 - image_quality_output_loss: 0.4486 - age_output_loss: 0.3951 - weight_output_loss: 0.3254 - bag_output_loss: 0.3569 - footwear_output_loss: 0.3546 - pose_output_loss: 0.2035 - emotion_output_loss: 0.3118 - gender_output_acc: 0.9187 - image_quality_output_acc: 0.7841 - age_output_acc: 0.8196 - weight_output_acc: 0.8565 - bag_output_acc: 0.8422 - footwear_output_acc: 0.8402 - pose_output_acc: 0.9171 - emotion_output_acc: 0.8723 - val_loss: 1.3569 - val_gender_output_loss: 0.5648 - val_image_quality_output_loss: 0.6077 - val_age_output_loss: 0.4695 - val_weight_output_loss: 0.4568 - val_bag_output_loss: 0.5990 - val_footwear_output_loss: 0.5648 - val_pose_output_loss: 0.4525 - val_emotion_output_loss: 0.3980 - val_gender_output_acc: 0.7907 - val_image_quality_output_acc: 0.7002 - val_age_output_acc: 0.7836 - val_weight_output_acc: 0.7991 - val_bag_output_acc: 0.7411 - val_footwear_output_acc: 0.7316 - val_pose_output_acc: 0.8266 - val_emotion_output_acc: 0.8428
# Epoch 127/200
# 360/360 [==============================] - 151s 419ms/step - loss: 0.8956 - gender_output_loss: 0.1981 - image_quality_output_loss: 0.4410 - age_output_loss: 0.3958 - weight_output_loss: 0.3253 - bag_output_loss: 0.3583 - footwear_output_loss: 0.3477 - pose_output_loss: 0.1988 - emotion_output_loss: 0.3105 - gender_output_acc: 0.9205 - image_quality_output_acc: 0.7879 - age_output_acc: 0.8185 - weight_output_acc: 0.8564 - bag_output_acc: 0.8425 - footwear_output_acc: 0.8444 - pose_output_acc: 0.9182 - emotion_output_acc: 0.8718 - val_loss: 1.3924 - val_gender_output_loss: 0.5695 - val_image_quality_output_loss: 0.6692 - val_age_output_loss: 0.4724 - val_weight_output_loss: 0.4669 - val_bag_output_loss: 0.6082 - val_footwear_output_loss: 0.5836 - val_pose_output_loss: 0.4702 - val_emotion_output_loss: 0.3905 - val_gender_output_acc: 0.7798 - val_image_quality_output_acc: 0.6571 - val_age_output_acc: 0.7853 - val_weight_output_acc: 0.7811 - val_bag_output_acc: 0.7378 - val_footwear_output_acc: 0.7373 - val_pose_output_acc: 0.8135 - val_emotion_output_acc: 0.8404
# Epoch 128/200
# 360/360 [==============================] - 151s 419ms/step - loss: 0.8903 - gender_output_loss: 0.1959 - image_quality_output_loss: 0.4416 - age_output_loss: 0.3939 - weight_output_loss: 0.3196 - bag_output_loss: 0.3513 - footwear_output_loss: 0.3454 - pose_output_loss: 0.2062 - emotion_output_loss: 0.3074 - gender_output_acc: 0.9215 - image_quality_output_acc: 0.7896 - age_output_acc: 0.8197 - weight_output_acc: 0.8592 - bag_output_acc: 0.8475 - footwear_output_acc: 0.8443 - pose_output_acc: 0.9142 - emotion_output_acc: 0.8735 - val_loss: 1.4553 - val_gender_output_loss: 0.6972 - val_image_quality_output_loss: 0.6213 - val_age_output_loss: 0.4701 - val_weight_output_loss: 0.4564 - val_bag_output_loss: 0.7726 - val_footwear_output_loss: 0.5606 - val_pose_output_loss: 0.5053 - val_emotion_output_loss: 0.4008 - val_gender_output_acc: 0.7825 - val_image_quality_output_acc: 0.6777 - val_age_output_acc: 0.7883 - val_weight_output_acc: 0.7897 - val_bag_output_acc: 0.7321 - val_footwear_output_acc: 0.7396 - val_pose_output_acc: 0.7966 - val_emotion_output_acc: 0.8418
# Epoch 129/200
# 360/360 [==============================] - 152s 421ms/step - loss: 0.8823 - gender_output_loss: 0.1882 - image_quality_output_loss: 0.4416 - age_output_loss: 0.3918 - weight_output_loss: 0.3155 - bag_output_loss: 0.3520 - footwear_output_loss: 0.3405 - pose_output_loss: 0.1966 - emotion_output_loss: 0.3082 - gender_output_acc: 0.9246 - image_quality_output_acc: 0.7901 - age_output_acc: 0.8206 - weight_output_acc: 0.8610 - bag_output_acc: 0.8458 - footwear_output_acc: 0.8485 - pose_output_acc: 0.9210 - emotion_output_acc: 0.8720 - val_loss: 1.3987 - val_gender_output_loss: 0.5744 - val_image_quality_output_loss: 0.6241 - val_age_output_loss: 0.4686 - val_weight_output_loss: 0.4812 - val_bag_output_loss: 0.6237 - val_footwear_output_loss: 0.5875 - val_pose_output_loss: 0.4890 - val_emotion_output_loss: 0.3995 - val_gender_output_acc: 0.7798 - val_image_quality_output_acc: 0.6812 - val_age_output_acc: 0.7854 - val_weight_output_acc: 0.8187 - val_bag_output_acc: 0.7277 - val_footwear_output_acc: 0.7351 - val_pose_output_acc: 0.8237 - val_emotion_output_acc: 0.8442
# Epoch 130/200
# 360/360 [==============================] - 151s 420ms/step - loss: 0.8760 - gender_output_loss: 0.1879 - image_quality_output_loss: 0.4357 - age_output_loss: 0.3888 - weight_output_loss: 0.3141 - bag_output_loss: 0.3474 - footwear_output_loss: 0.3389 - pose_output_loss: 0.2025 - emotion_output_loss: 0.3025 - gender_output_acc: 0.9250 - image_quality_output_acc: 0.7936 - age_output_acc: 0.8210 - weight_output_acc: 0.8631 - bag_output_acc: 0.8479 - footwear_output_acc: 0.8488 - pose_output_acc: 0.9173 - emotion_output_acc: 0.8755 - val_loss: 1.4049 - val_gender_output_loss: 0.6288 - val_image_quality_output_loss: 0.6316 - val_age_output_loss: 0.4731 - val_weight_output_loss: 0.4698 - val_bag_output_loss: 0.6342 - val_footwear_output_loss: 0.5733 - val_pose_output_loss: 0.4783 - val_emotion_output_loss: 0.3987 - val_gender_output_acc: 0.7746 - val_image_quality_output_acc: 0.6701 - val_age_output_acc: 0.7813 - val_weight_output_acc: 0.8146 - val_bag_output_acc: 0.7427 - val_footwear_output_acc: 0.7388 - val_pose_output_acc: 0.8108 - val_emotion_output_acc: 0.8506
# Epoch 131/200
# 308/360 [========================>.....] - ETA: 20s - loss: 0.8669 - gender_output_loss: 0.1874 - image_quality_output_loss: 0.4304 - age_output_loss: 0.3886 - weight_output_loss: 0.3139 - bag_output_loss: 0.3408 - footwear_output_loss: 0.3336 - pose_output_loss: 0.1945 - emotion_output_loss: 0.2995 - gender_output_acc: 0.9208 - image_quality_output_acc: 0.7959 - age_output_acc: 0.8223 - weight_output_acc: 0.8630 - bag_output_acc: 0.8526 - footwear_output_acc: 0.8518 - pose_output_acc: 0.9201 - emotion_output_acc: 0.8765

# %%
model
