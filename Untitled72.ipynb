# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepaManjunath/Assignment1/blob/master/Untitled72.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q '/content/gdrive/My Drive/EIP4/hvc_data.zip'
# look for `hvc_annotations.csv` file and `resized` dir
# %ls '/content/gdrive/My Drive/EIP4/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# hvc_data/  hvc_data.zip

# %%
# %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation , Dropout
from keras.layers import AveragePooling2D, Input, Flatten ,GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.callbacks import ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()
# Out:
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
# 3    male         Good  45-55  ...        Neutral  Front-Frontish  resized/4.jpg
# 4  female         Good  35-45  ...        Neutral  Front-Frontish  resized/5.jpg
#
# [5 rows x 9 columns]

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
import numpy as np


def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=32, shuffle=True,augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.batch_size = batch_size
        #self.labels = labels
        #self.list_IDs = list_IDs
        #self.n_channels = n_channels
        #self.n_classes = n_classes
        #self.shuffle = shuffle
        self.on_epoch_end()
        self.augmentation=augmentation
        
        
        #self.on_epoch_end()

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

            
    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        images = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
        if self.augmentation is not None:
           images=self.augmentation.flow(images,shuffle=False).next()
           
        target = {
                       "gender_output": items[_gender_cols_].values,
                       "image_quality_output": items[_imagequality_cols_].values,
                       "age_output": items[_age_cols_].values,
                       "weight_output": items[_weight_cols_].values,
                       "bag_output": items[_carryingbag_cols_].values,
                       "pose_output": items[_bodypose_cols_].values,
                       "footwear_output": items[_footwear_cols_].values,
                       "emotion_output": items[_emotion_cols_].values,
        }
        return images, target
    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
            
   # def __PersonDataGenerator(self,train_df,batch_size=32,augmentation):
      
    #     train_gen = np.stack(train_df, batch_size=32,augmentation=ImageDataGenerator(featurewise_center=False,
     #                           samplewise_center=False,
      #                          featurewise_std_normalization=False,
       #                         samplewise_std_normalization=False,
        #                        zca_whitening=False,
         #                       zca_epsilon=1e-06,
          #                      rotation_range=25,
           #                     width_shift_range=0.1,
            #                    height_shift_range=0.1,
             #                   brightness_range=None,
              #                  shear_range=0.0,
               #                 zoom_range=0.0,
                #                channel_shift_range=0.0,
                 #               fill_mode='nearest',
                  #              cval=0.0,
                   #             horizontal_flip=True,
                    #            vertical_flip=True,
                     #           rescale=None,
                      #          preprocessing_function=get_random_eraser(v_l=0, v_h=1),
                       #         data_format=None,
                        #        validation_split=0.0
                         #       ))
         #image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
          #    if self.augmentation is not None:
           #  image=self.augmentation.flow(image,shuffle=False).next()

   # def on_epoch_end(self):
    #    """Updates indexes after each epoch"""
     #   if self.shuffle == True:
      #      self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
len(train_df)
# Out:
# 11537

# %%
train_df.head()
# Out:
#               image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 12664  resized/12666.jpg              1  ...                        0              1
# 5830    resized/5831.jpg              1  ...                        1              0
# 13123  resized/13125.jpg              1  ...                        1              0
# 4885    resized/4886.jpg              0  ...                        0              1
# 700      resized/701.jpg              0  ...                        1              0
#
# [5 rows x 28 columns]

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df,batch_size=32,
                                augmentation=ImageDataGenerator(rescale=1./255,width_shift_range=0.1,
	                                                              height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
	                                                              horizontal_flip=True, fill_mode="nearest", 
                                                                rotation_range=25,preprocessing_function=get_random_eraser(v_l=0, v_h=1)                                                                    
	                                                                                  ))
                       
                                                            
	                                                                                      

                             
                                                        
                                                          



#train_gen = PersonDataGenerator(train_df, batch_size=32,augmentation=True)
                                
valid_gen = PersonDataGenerator(val_df, batch_size=32, shuffle=False,
                                augmentation=ImageDataGenerator(rescale=1./255))

# %%
# get number of output units from data
images, targets = next(iter(valid_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
#from classification_models.resnet import ResNet18, preprocess_input
import keras.applications.resnet 
from keras.applications.inception_v3 import InceptionV3

from keras.applications.resnet import ResNet50

backbone = InceptionV3(
    weights=None, 
    include_top=False, 
    input_tensor=Input(shape=(224, 224, 3))
)
#backbone = resnet_v1((224,224,3),8)
  


neck = backbone.output
neck = Flatten(name="flatten")(neck)
neck = Dense(512, activation="relu")(neck)


def build_tower(in_layer):
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.0812)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.0812)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.0812)(in_layer)
    neck = Dense(28, activation="relu")(neck)
    
    
    return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="sigmoid",name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("pose", build_tower(neck))


model = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
import numpy as np
import tensorflow as tf
import keras

# %%
EPOCHS=24
LEARNING_RATE=1
BATCH_SIZE1=32
BATCH_SIZE2=64
MOMENTUM=0.9

# %%
len_train=len(train_df)
batches_per_epoch = len_train//BATCH_SIZE1

# %%
lr_schedule = lambda t: np.interp([t], [0, (EPOCHS+1)//5, (EPOCHS)], [0.1, LEARNING_RATE, 0.1] )[0]
print(lr_schedule)

#lr_schedule = lambda t: np.interp([t],[0,(EPOCHS+1)//5, (EPOCHS-6)],[0.4, LEARNING_RATE, 0.4])[0]
global_step = tf.train.get_or_create_global_step()
lr_func = lambda: lr_schedule(global_step/batches_per_epoch)/BATCH_SIZE1
#opt.apply_gradients( global_step=global_step)
#opt = tf.train.MomentumOptimizer(lr_func,momentum=MOMENTUM,use_nesterov=False)
# Out:
# <function <lambda> at 0x7f3d9f5e5f28>

# %%
#t = time.time()
#test_set = tf.data.Dataset.from_tensor_slices((val_df)).batch(BATCH_SIZE)

def lr_schedule1(epoch):
    for epoch1 in range((EPOCHS)):
    #if epoch<=24:
      
         if epoch==epoch1:
          break
     
   
   # tf.keras.backend.set_learning_phase(1)
         opt = tf.train.MomentumOptimizer(lr_func,momentum=MOMENTUM,use_nesterov=False)
         #opt1 = SGD(lr=lr_schedule(epoch+1),momentum=0.9)
        #if epoch==epoch1:
         # break
          
    print('epoch:', epoch, 'lr:', lr_schedule(epoch))
    return(lr_schedule(epoch))

      
     
    #tf.keras.backend.set_learning_phase(0)
    
      #  print('epoch:', epoch+1, 'lr:', lr_schedule(epoch+1))
  #return (lr_schedule(epoch+1))
    #else:
   
    #tf.keras.backend.set_learning_phase(1)
     #   opt = tf.train.MomentumOptimizer(lr_func1,momentum=MOMENTUM,use_nesterov=False)
      #  opt = SGD(lr=lr_schedule(epoch+1),momentum=0.9)
        #model.compile(
         #           optimizer=opt,
          #          loss="categorical_crossentropy", 
           #         loss_weights=loss_weights, 
            #        metrics=["accuracy"]
             #       )
        #model.fit_generator(
         #            generator=train_gen,
          #           validation_data=valid_gen,
           #          use_multiprocessing=True,
            #         workers=6, 
             #        epochs=10,
              #       verbose=1,
      
               #      callbacks=callbacks
                #         )
        #LRFind.plot_loss()

       
    #tf.keras.backend.set_learning_phase(0)
       # print('epoch:', epoch+1, 'lr:', lr_schedule1(epoch+1))

# %%
# model.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=32, epochs=10)

# %%
import matplotlib.pyplot as plt
import keras.backend as K
from keras.callbacks import Callback


class LRFinder(Callback):
    
    '''
    A simple callback for finding the optimal learning rate range for your model + dataset. 
    
    # Usage
        ```python
            lr_finder = LRFinder(min_lr=1e-5, 
                                 max_lr=1e-2, 
                                 steps_per_epoch=np.ceil(epoch_size/batch_size), 
                                 epochs=3)
            model.fit(X_train, Y_train, callbacks=[lr_finder])
            
            lr_finder.plot_loss()
        ```
    
    # Arguments
        min_lr: The lower bound of the learning rate range for the experiment.
        max_lr: The upper bound of the learning rate range for the experiment.
        steps_per_epoch: Number of mini-batches in the dataset. Calculated as `np.ceil(epoch_size/batch_size)`. 
        epochs: Number of epochs to run experiment. Usually between 2 and 4 epochs is sufficient. 
        
    # References
        Blog post: jeremyjordan.me/nn-learning-rate
        Original paper: https://arxiv.org/abs/1506.01186
    '''
    
    def __init__(self, min_lr=1e-5, max_lr=1e-2, steps_per_epoch=5.625, epochs=24):
        super().__init__()
        
        self.min_lr = min_lr
        self.max_lr = max_lr
        self.total_iterations = steps_per_epoch * epochs
        self.iteration = 0
        self.history = {}
        
    def clr(self):
        '''Calculate the learning rate.'''
        x = self.iteration / self.total_iterations 
        return self.min_lr + (self.max_lr-self.min_lr) * x
        
    def on_train_begin(self, logs=None):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.min_lr)
        
    def on_batch_end(self, epoch, logs=None):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.iteration += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.iteration)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
            
        K.set_value(self.model.optimizer.lr, self.clr())
 
    def plot_lr(self):
        '''Helper function to quickly inspect the learning rate schedule.'''
        plt.plot(self.history['iterations'], self.history['lr'])
        plt.yscale('log')
        plt.xlabel('Iteration')
        plt.ylabel('Learning rate')
        plt.show()
        
    def plot_loss(self):
        '''Helper function to quickly observe the learning rate experiment results.'''
        plt.plot(self.history['lr'], self.history['loss'])
        plt.xscale('log')
        plt.xlabel('Learning rate')
        plt.ylabel('Loss')
        plt.show()

# %%
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
#for i in range(EPOCHS):
#lr_scheduler = LearningRateScheduler(lr_schedule1)

# %%
#lr_schedule = lambda t: np.interp([t], [0, (EPOCHS+1)//5, (EPOCHS-6)], [0.4, LEARNING_RATE, 0.4])[0]
#global_step = tf.train.get_or_create_global_step()
#opt.apply_gradients(zip(grads, var), global_step=global_step

# %%
def lr_Schedule(epoch):
  
   # lr=0.00148 
    lr = 1e-3
    #if epoch > 70:
     # lr*= 1e-3
    #if epoch > 40:
     #   lr *= 1e-1
    #if epoch > 30:
      #  lr *= 1e-0
    #if epoch > 20:
     #  lr *= 1e-0
    if epoch > 10:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
#from keras.callbacks import ModelCheckpoint,LearningRateScheduler

#LRFind=LRFinder(min_lr=1e-5, max_lr=10, steps_per_epoch=(2036//32), epochs=50)
lr_scheduler = LearningRateScheduler(lr_Schedule)
#LRFind.on_tain_begin()
#for i in range(EPOCHS):
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [lr_scheduler,lr_reducer]

# %%
losses = {
 	"gender_output": "binary_crossentropy",
 	"image_quality_output": "binary_crossentropy",
 	"age_output": "binary_crossentropy",
 	"weight_output": "binary_crossentropy",
  "bag_output": "binary_crossentropy",
  "pose_output": "binary_crossentropy",
  "footwear_output": "binary_crossentropy",   
  "emotion_output": "binary_crossentropy",
       

 }
loss_weights = {"gender_output": 0.2, "image_quality_output": 0.3, "age_output": 0.5, "weight_output": 0.4,"bag_output":0.3,"pose_output":0.3,"footwear_output":0.3,"emotion_output":0.4}
model.summary()

opt = SGD(lr=0.0142,momentum=0.9)
#opt = tf.train.MomentumOptimizer(lr=lr_schedule(epoch+1),momentum=MOMENTUM,use_nesterov=False)
#opt.( global_step=global_step)
model.compile(
    optimizer=opt,
    loss="binary_crossentropy", 
    #from_logits=True,
    #loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
    loss_weights=loss_weights, 
    metrics=["accuracy"]
)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 111, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 111, 111, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 111, 111, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 109, 109, 32) 9216        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 109, 109, 32) 96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 109, 109, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 109, 109, 64) 18432       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 109, 109, 64) 192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 109, 109, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 54, 54, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 54, 54, 80)   5120        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 54, 54, 80)   240         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 54, 54, 80)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 52, 52, 192)  138240      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 52, 52, 192)  576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 52, 52, 192)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 192)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 25, 25, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 25, 25, 64)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 25, 25, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 25, 25, 48)   9216        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 25, 25, 96)   55296       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 25, 25, 48)   144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 25, 25, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 25, 25, 48)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 25, 25, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 25, 25, 192)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 25, 25, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 25, 25, 64)   76800       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 25, 25, 96)   82944       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 25, 25, 32)   6144        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 25, 25, 64)   192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 25, 25, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 25, 25, 96)   288         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 25, 25, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 25, 25, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 25, 25, 96)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 25, 25, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 25, 25, 256)  0           activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 25, 25, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 25, 25, 64)   192         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 25, 25, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 25, 25, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 25, 25, 96)   55296       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 48)   144         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 25, 25, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 25, 25, 48)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 25, 25, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 25, 25, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 25, 25, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 25, 25, 64)   76800       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 25, 25, 96)   82944       activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 25, 25, 64)   16384       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 64)   192         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 25, 25, 96)   288         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 25, 25, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 25, 25, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 25, 25, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 25, 25, 96)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 25, 25, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 25, 25, 288)  0           activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 25, 25, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 25, 25, 64)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 25, 25, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 25, 25, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 25, 25, 96)   55296       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 25, 25, 48)   144         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 25, 25, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 25, 25, 48)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 25, 25, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 25, 25, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 25, 25, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 25, 25, 64)   76800       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 25, 25, 96)   82944       activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 25, 25, 64)   18432       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 25, 25, 64)   192         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 25, 25, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 25, 25, 96)   288         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 25, 25, 64)   192         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 25, 25, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 25, 25, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 25, 25, 96)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 25, 25, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 25, 25, 288)  0           activation_20[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 25, 25, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 25, 25, 64)   192         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 25, 25, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 25, 25, 96)   55296       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 25, 25, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 25, 25, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 12, 12, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 12, 12, 96)   82944       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 12, 12, 384)  1152        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 12, 12, 96)   288         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 12, 12, 384)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 96)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 12, 12, 768)  0           activation_27[0][0]
#                                                                  activation_30[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 12, 12, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 12, 12, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 12, 12, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 12, 12, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 12, 12, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 12, 12, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 12, 12, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 12, 12, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 12, 12, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 12, 12, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 12, 12, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 12, 12, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 12, 12, 128)  114688      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 12, 12, 128)  114688      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 12, 12, 128)  384         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 12, 12, 128)  384         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 12, 12, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 12, 12, 128)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 12, 12, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 12, 12, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 12, 12, 192)  172032      activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 12, 12, 192)  172032      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 12, 12, 192)  576         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 12, 12, 192)  576         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 12, 12, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 12, 12, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 12, 12, 192)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 12, 12, 192)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 12, 12, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 12, 12, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 12, 12, 768)  0           activation_31[0][0]
#                                                                  activation_34[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 12, 12, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 12, 12, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 12, 12, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 12, 12, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 12, 12, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 12, 12, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 12, 12, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 12, 12, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 12, 12, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 12, 12, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 12, 12, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 12, 12, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 12, 12, 160)  179200      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 12, 12, 160)  179200      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 12, 12, 160)  480         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 12, 12, 160)  480         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 12, 12, 160)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 12, 12, 160)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 12, 12, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 12, 12, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 12, 12, 192)  215040      activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 12, 12, 192)  215040      activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 12, 12, 192)  576         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 12, 12, 192)  576         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 12, 12, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 12, 12, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 12, 12, 192)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 12, 12, 192)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 12, 12, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 12, 12, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 12, 12, 768)  0           activation_41[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 12, 12, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 12, 12, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 12, 12, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 12, 12, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 12, 12, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 12, 12, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 12, 12, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 12, 12, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 12, 12, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 12, 12, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 12, 12, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 12, 12, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 12, 12, 160)  179200      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 12, 12, 160)  179200      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 12, 12, 160)  480         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 12, 12, 160)  480         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 12, 12, 160)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 12, 12, 160)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 12, 12, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 12, 12, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 12, 12, 192)  215040      activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 12, 12, 192)  215040      activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 12, 12, 192)  576         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 12, 12, 192)  576         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 12, 12, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 12, 12, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 12, 12, 192)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 12, 12, 192)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 12, 12, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 12, 12, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 12, 12, 768)  0           activation_51[0][0]
#                                                                  activation_54[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_60[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 12, 12, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 12, 12, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 12, 12, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 12, 12, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 12, 12, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 12, 12, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 12, 12, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 12, 12, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 12, 12, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 12, 12, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 12, 12, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 12, 12, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 12, 12, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 12, 12, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 12, 12, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 12, 12, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 12, 12, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 12, 12, 192)  258048      activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 12, 12, 192)  258048      activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 12, 12, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 12, 12, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 12, 12, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 12, 12, 192)  576         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 12, 12, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 12, 12, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 12, 12, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 12, 12, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 12, 12, 768)  0           activation_61[0][0]
#                                                                  activation_64[0][0]
#                                                                  activation_69[0][0]
#                                                                  activation_70[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 5, 5, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 5, 5, 384)    1152        conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 5, 5, 192)    245760      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 5, 5, 320)    960         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 5, 5, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 5, 5, 384)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 5, 5, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 5, 5, 384)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 5, 5, 192)    576         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 5, 5, 320)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 5, 5, 768)    0           activation_79[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 5, 5, 768)    0           activation_83[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 5, 5, 192)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 5, 5, 2048)   0           activation_77[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_85[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 5, 5, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 5, 5, 448)    1344        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 5, 5, 448)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 5, 5, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 5, 5, 384)    1548288     activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 5, 5, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 5, 5, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 5, 5, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 5, 5, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 5, 5, 384)    442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 5, 5, 384)    442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 5, 5, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 5, 5, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 5, 5, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 5, 5, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 5, 5, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 5, 5, 384)    1152        conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 5, 5, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 5, 5, 384)    1152        conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 5, 5, 192)    393216      average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 5, 5, 320)    960         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 5, 5, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 5, 5, 384)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 5, 5, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 5, 5, 384)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 5, 5, 192)    576         conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 5, 5, 320)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 5, 5, 768)    0           activation_88[0][0]
#                                                                  activation_89[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 5, 5, 768)    0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 5, 5, 192)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 5, 5, 2048)   0           activation_86[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_94[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 51200)        0           mixed10[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          26214912    flatten[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 28)           14364       dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 28)           14364       dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 28)           14364       dropout_9[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 28)           14364       dropout_12[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 28)           14364       dropout_15[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 28)           14364       dropout_18[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 28)           14364       dropout_24[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 28)           14364       dropout_21[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            58          dense_4[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Dense)    (None, 3)            87          dense_7[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            145         dense_10[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            116         dense_13[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            87          dense_16[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            87          dense_19[0][0]
# __________________________________________________________________________________________________
# pose_output (Dense)             (None, 3)            87          dense_25[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            116         dense_22[0][0]
# ==================================================================================================
# Total params: 48,133,391
# Trainable params: 48,098,959
# Non-trainable params: 34,432
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
#for i in range(EPOCHS):
model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    #validation_steps=2036//32,
    use_multiprocessing=True,
    workers=2, 
    epochs=200,
    verbose=1,
    #callbacks=callbacks
    )
LRFind.plot_loss()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/200
# 360/360 [==============================] - 190s 527ms/step - loss: 1.4061 - gender_output_loss: 0.6887 - image_quality_output_loss: 0.5912 - age_output_loss: 0.4688 - weight_output_loss: 0.4364 - bag_output_loss: 0.5632 - footwear_output_loss: 0.6184 - pose_output_loss: 0.5592 - emotion_output_loss: 0.3996 - gender_output_acc: 0.5583 - image_quality_output_acc: 0.6918 - age_output_acc: 0.7958 - weight_output_acc: 0.8138 - bag_output_acc: 0.7008 - footwear_output_acc: 0.6595 - pose_output_acc: 0.7412 - emotion_output_acc: 0.8529 - val_loss: 1.3883 - val_gender_output_loss: 0.6746 - val_image_quality_output_loss: 0.5831 - val_age_output_loss: 0.4634 - val_weight_output_loss: 0.4263 - val_bag_output_loss: 0.5475 - val_footwear_output_loss: 0.6083 - val_pose_output_loss: 0.5617 - val_emotion_output_loss: 0.4025 - val_gender_output_acc: 0.5737 - val_image_quality_output_acc: 0.7022 - val_age_output_acc: 0.8001 - val_weight_output_acc: 0.8182 - val_bag_output_acc: 0.7120 - val_footwear_output_acc: 0.6670 - val_pose_output_acc: 0.7404 - val_emotion_output_acc: 0.8482
# Epoch 2/200
# 360/360 [==============================] - 159s 442ms/step - loss: 1.3749 - gender_output_loss: 0.6776 - image_quality_output_loss: 0.5793 - age_output_loss: 0.4583 - weight_output_loss: 0.4250 - bag_output_loss: 0.5522 - footwear_output_loss: 0.6046 - pose_output_loss: 0.5479 - emotion_output_loss: 0.3876 - gender_output_acc: 0.5607 - image_quality_output_acc: 0.7002 - age_output_acc: 0.7997 - weight_output_acc: 0.8174 - bag_output_acc: 0.7063 - footwear_output_acc: 0.6661 - pose_output_acc: 0.7451 - emotion_output_acc: 0.8570 - val_loss: 1.3723 - val_gender_output_loss: 0.6739 - val_image_quality_output_loss: 0.5757 - val_age_output_loss: 0.4546 - val_weight_output_loss: 0.4190 - val_bag_output_loss: 0.5442 - val_footwear_output_loss: 0.5927 - val_pose_output_loss: 0.5638 - val_emotion_output_loss: 0.3991 - val_gender_output_acc: 0.5756 - val_image_quality_output_acc: 0.7029 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8182 - val_bag_output_acc: 0.7118 - val_footwear_output_acc: 0.6728 - val_pose_output_acc: 0.7404 - val_emotion_output_acc: 0.8482
# Epoch 3/200
# 360/360 [==============================] - 157s 437ms/step - loss: 1.3671 - gender_output_loss: 0.6737 - image_quality_output_loss: 0.5784 - age_output_loss: 0.4567 - weight_output_loss: 0.4234 - bag_output_loss: 0.5497 - footwear_output_loss: 0.5908 - pose_output_loss: 0.5476 - emotion_output_loss: 0.3868 - gender_output_acc: 0.5651 - image_quality_output_acc: 0.7008 - age_output_acc: 0.7999 - weight_output_acc: 0.8175 - bag_output_acc: 0.7067 - footwear_output_acc: 0.6825 - pose_output_acc: 0.7451 - emotion_output_acc: 0.8571 - val_loss: 1.3598 - val_gender_output_loss: 0.6700 - val_image_quality_output_loss: 0.5749 - val_age_output_loss: 0.4533 - val_weight_output_loss: 0.4214 - val_bag_output_loss: 0.5406 - val_footwear_output_loss: 0.5728 - val_pose_output_loss: 0.5506 - val_emotion_output_loss: 0.3972 - val_gender_output_acc: 0.5632 - val_image_quality_output_acc: 0.7057 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8176 - val_bag_output_acc: 0.7125 - val_footwear_output_acc: 0.7034 - val_pose_output_acc: 0.7404 - val_emotion_output_acc: 0.8482
# Epoch 4/200
# 360/360 [==============================] - 157s 435ms/step - loss: 1.3615 - gender_output_loss: 0.6701 - image_quality_output_loss: 0.5782 - age_output_loss: 0.4563 - weight_output_loss: 0.4222 - bag_output_loss: 0.5482 - footwear_output_loss: 0.5819 - pose_output_loss: 0.5457 - emotion_output_loss: 0.3857 - gender_output_acc: 0.5695 - image_quality_output_acc: 0.7010 - age_output_acc: 0.8001 - weight_output_acc: 0.8171 - bag_output_acc: 0.7086 - footwear_output_acc: 0.6902 - pose_output_acc: 0.7455 - emotion_output_acc: 0.8573 - val_loss: 1.3523 - val_gender_output_loss: 0.6605 - val_image_quality_output_loss: 0.5716 - val_age_output_loss: 0.4534 - val_weight_output_loss: 0.4187 - val_bag_output_loss: 0.5430 - val_footwear_output_loss: 0.5593 - val_pose_output_loss: 0.5508 - val_emotion_output_loss: 0.3964 - val_gender_output_acc: 0.5756 - val_image_quality_output_acc: 0.7057 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8181 - val_bag_output_acc: 0.7085 - val_footwear_output_acc: 0.7151 - val_pose_output_acc: 0.7404 - val_emotion_output_acc: 0.8482
# Epoch 5/200
# 360/360 [==============================] - 156s 433ms/step - loss: 1.3554 - gender_output_loss: 0.6628 - image_quality_output_loss: 0.5765 - age_output_loss: 0.4549 - weight_output_loss: 0.4222 - bag_output_loss: 0.5457 - footwear_output_loss: 0.5724 - pose_output_loss: 0.5469 - emotion_output_loss: 0.3852 - gender_output_acc: 0.5926 - image_quality_output_acc: 0.7010 - age_output_acc: 0.7998 - weight_output_acc: 0.8176 - bag_output_acc: 0.7102 - footwear_output_acc: 0.6955 - pose_output_acc: 0.7459 - emotion_output_acc: 0.8571 - val_loss: 1.3515 - val_gender_output_loss: 0.6667 - val_image_quality_output_loss: 0.5710 - val_age_output_loss: 0.4534 - val_weight_output_loss: 0.4235 - val_bag_output_loss: 0.5374 - val_footwear_output_loss: 0.5493 - val_pose_output_loss: 0.5522 - val_emotion_output_loss: 0.3979 - val_gender_output_acc: 0.5970 - val_image_quality_output_acc: 0.7047 - val_age_output_acc: 0.8003 - val_weight_output_acc: 0.8182 - val_bag_output_acc: 0.7131 - val_footwear_output_acc: 0.7179 - val_pose_output_acc: 0.7404 - val_emotion_output_acc: 0.8482
# Epoch 6/200
# 360/360 [==============================] - 156s 432ms/step - loss: 1.3494 - gender_output_loss: 0.6534 - image_quality_output_loss: 0.5763 - age_output_loss: 0.4547 - weight_output_loss: 0.4219 - bag_output_loss: 0.5428 - footwear_output_loss: 0.5642 - pose_output_loss: 0.5445 - emotion_output_loss: 0.3858 - gender_output_acc: 0.6036 - image_quality_output_acc: 0.7005 - age_output_acc: 0.7999 - weight_output_acc: 0.8174 - bag_output_acc: 0.7122 - footwear_output_acc: 0.7050 - pose_output_acc: 0.7457 - emotion_output_acc: 0.8571 - val_loss: 1.3370 - val_gender_output_loss: 0.6351 - val_image_quality_output_loss: 0.5697 - val_age_output_loss: 0.4517 - val_weight_output_loss: 0.4199 - val_bag_output_loss: 0.5318 - val_footwear_output_loss: 0.5401 - val_pose_output_loss: 0.5518 - val_emotion_output_loss: 0.3953 - val_gender_output_acc: 0.6290 - val_image_quality_output_acc: 0.7057 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8181 - val_bag_output_acc: 0.7201 - val_footwear_output_acc: 0.7252 - val_pose_output_acc: 0.7404 - val_emotion_output_acc: 0.8482
# Epoch 7/200
# 360/360 [==============================] - 156s 432ms/step - loss: 1.3444 - gender_output_loss: 0.6447 - image_quality_output_loss: 0.5757 - age_output_loss: 0.4543 - weight_output_loss: 0.4219 - bag_output_loss: 0.5422 - footwear_output_loss: 0.5599 - pose_output_loss: 0.5413 - emotion_output_loss: 0.3846 - gender_output_acc: 0.6138 - image_quality_output_acc: 0.7016 - age_output_acc: 0.7999 - weight_output_acc: 0.8174 - bag_output_acc: 0.7121 - footwear_output_acc: 0.7122 - pose_output_acc: 0.7460 - emotion_output_acc: 0.8572 - val_loss: 1.3295 - val_gender_output_loss: 0.6196 - val_image_quality_output_loss: 0.5708 - val_age_output_loss: 0.4542 - val_weight_output_loss: 0.4180 - val_bag_output_loss: 0.5278 - val_footwear_output_loss: 0.5290 - val_pose_output_loss: 0.5434 - val_emotion_output_loss: 0.4000 - val_gender_output_acc: 0.6344 - val_image_quality_output_acc: 0.7057 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8182 - val_bag_output_acc: 0.7188 - val_footwear_output_acc: 0.7336 - val_pose_output_acc: 0.7397 - val_emotion_output_acc: 0.8482
# Epoch 8/200
# 360/360 [==============================] - 155s 431ms/step - loss: 1.3367 - gender_output_loss: 0.6346 - image_quality_output_loss: 0.5749 - age_output_loss: 0.4538 - weight_output_loss: 0.4193 - bag_output_loss: 0.5384 - footwear_output_loss: 0.5523 - pose_output_loss: 0.5395 - emotion_output_loss: 0.3841 - gender_output_acc: 0.6323 - image_quality_output_acc: 0.7009 - age_output_acc: 0.7997 - weight_output_acc: 0.8173 - bag_output_acc: 0.7188 - footwear_output_acc: 0.7143 - pose_output_acc: 0.7459 - emotion_output_acc: 0.8572 - val_loss: 1.3354 - val_gender_output_loss: 0.6437 - val_image_quality_output_loss: 0.5719 - val_age_output_loss: 0.4501 - val_weight_output_loss: 0.4185 - val_bag_output_loss: 0.5267 - val_footwear_output_loss: 0.5379 - val_pose_output_loss: 0.5493 - val_emotion_output_loss: 0.3962 - val_gender_output_acc: 0.6322 - val_image_quality_output_acc: 0.7059 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8182 - val_bag_output_acc: 0.7196 - val_footwear_output_acc: 0.7224 - val_pose_output_acc: 0.7411 - val_emotion_output_acc: 0.8482
# Epoch 9/200
# 360/360 [==============================] - 155s 430ms/step - loss: 1.3339 - gender_output_loss: 0.6293 - image_quality_output_loss: 0.5746 - age_output_loss: 0.4525 - weight_output_loss: 0.4193 - bag_output_loss: 0.5372 - footwear_output_loss: 0.5520 - pose_output_loss: 0.5380 - emotion_output_loss: 0.3841 - gender_output_acc: 0.6365 - image_quality_output_acc: 0.7008 - age_output_acc: 0.8000 - weight_output_acc: 0.8171 - bag_output_acc: 0.7169 - footwear_output_acc: 0.7167 - pose_output_acc: 0.7468 - emotion_output_acc: 0.8570 - val_loss: 1.3252 - val_gender_output_loss: 0.6160 - val_image_quality_output_loss: 0.5703 - val_age_output_loss: 0.4520 - val_weight_output_loss: 0.4193 - val_bag_output_loss: 0.5287 - val_footwear_output_loss: 0.5292 - val_pose_output_loss: 0.5387 - val_emotion_output_loss: 0.3954 - val_gender_output_acc: 0.6525 - val_image_quality_output_acc: 0.7057 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8125 - val_bag_output_acc: 0.7229 - val_footwear_output_acc: 0.7356 - val_pose_output_acc: 0.7427 - val_emotion_output_acc: 0.8482
# Epoch 10/200
# 360/360 [==============================] - 155s 431ms/step - loss: 1.3304 - gender_output_loss: 0.6208 - image_quality_output_loss: 0.5743 - age_output_loss: 0.4524 - weight_output_loss: 0.4197 - bag_output_loss: 0.5378 - footwear_output_loss: 0.5470 - pose_output_loss: 0.5358 - emotion_output_loss: 0.3843 - gender_output_acc: 0.6474 - image_quality_output_acc: 0.7012 - age_output_acc: 0.7999 - weight_output_acc: 0.8173 - bag_output_acc: 0.7179 - footwear_output_acc: 0.7214 - pose_output_acc: 0.7468 - emotion_output_acc: 0.8572 - val_loss: 1.3107 - val_gender_output_loss: 0.6017 - val_image_quality_output_loss: 0.5701 - val_age_output_loss: 0.4497 - val_weight_output_loss: 0.4160 - val_bag_output_loss: 0.5209 - val_footwear_output_loss: 0.5200 - val_pose_output_loss: 0.5283 - val_emotion_output_loss: 0.3932 - val_gender_output_acc: 0.6684 - val_image_quality_output_acc: 0.7047 - val_age_output_acc: 0.7998 - val_weight_output_acc: 0.8181 - val_bag_output_acc: 0.7288 - val_footwear_output_acc: 0.7326 - val_pose_output_acc: 0.7469 - val_emotion_output_acc: 0.8482
# Epoch 11/200
# 360/360 [==============================] - 155s 432ms/step - loss: 1.3242 - gender_output_loss: 0.6125 - image_quality_output_loss: 0.5726 - age_output_loss: 0.4520 - weight_output_loss: 0.4185 - bag_output_loss: 0.5339 - footwear_output_loss: 0.5443 - pose_output_loss: 0.5323 - emotion_output_loss: 0.3834 - gender_output_acc: 0.6565 - image_quality_output_acc: 0.7007 - age_output_acc: 0.7997 - weight_output_acc: 0.8176 - bag_output_acc: 0.7188 - footwear_output_acc: 0.7240 - pose_output_acc: 0.7487 - emotion_output_acc: 0.8572 - val_loss: 1.3054 - val_gender_output_loss: 0.5994 - val_image_quality_output_loss: 0.5683 - val_age_output_loss: 0.4490 - val_weight_output_loss: 0.4151 - val_bag_output_loss: 0.5149 - val_footwear_output_loss: 0.5128 - val_pose_output_loss: 0.5261 - val_emotion_output_loss: 0.3957 - val_gender_output_acc: 0.6644 - val_image_quality_output_acc: 0.7055 - val_age_output_acc: 0.8001 - val_weight_output_acc: 0.8182 - val_bag_output_acc: 0.7350 - val_footwear_output_acc: 0.7462 - val_pose_output_acc: 0.7480 - val_emotion_output_acc: 0.8482
# Epoch 12/200
# 360/360 [==============================] - 157s 435ms/step - loss: 1.3201 - gender_output_loss: 0.6068 - image_quality_output_loss: 0.5724 - age_output_loss: 0.4519 - weight_output_loss: 0.4172 - bag_output_loss: 0.5318 - footwear_output_loss: 0.5436 - pose_output_loss: 0.5286 - emotion_output_loss: 0.3823 - gender_output_acc: 0.6638 - image_quality_output_acc: 0.7015 - age_output_acc: 0.7998 - weight_output_acc: 0.8172 - bag_output_acc: 0.7220 - footwear_output_acc: 0.7235 - pose_output_acc: 0.7507 - emotion_output_acc: 0.8572 - val_loss: 1.3037 - val_gender_output_loss: 0.5731 - val_image_quality_output_loss: 0.5693 - val_age_output_loss: 0.4527 - val_weight_output_loss: 0.4184 - val_bag_output_loss: 0.5159 - val_footwear_output_loss: 0.5174 - val_pose_output_loss: 0.5231 - val_emotion_output_loss: 0.3942 - val_gender_output_acc: 0.6902 - val_image_quality_output_acc: 0.7042 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8182 - val_bag_output_acc: 0.7297 - val_footwear_output_acc: 0.7406 - val_pose_output_acc: 0.7528 - val_emotion_output_acc: 0.8482
# Epoch 13/200
# 360/360 [==============================] - 156s 433ms/step - loss: 1.3174 - gender_output_loss: 0.6043 - image_quality_output_loss: 0.5719 - age_output_loss: 0.4512 - weight_output_loss: 0.4180 - bag_output_loss: 0.5334 - footwear_output_loss: 0.5393 - pose_output_loss: 0.5256 - emotion_output_loss: 0.3818 - gender_output_acc: 0.6691 - image_quality_output_acc: 0.7015 - age_output_acc: 0.8003 - weight_output_acc: 0.8175 - bag_output_acc: 0.7234 - footwear_output_acc: 0.7247 - pose_output_acc: 0.7527 - emotion_output_acc: 0.8571 - val_loss: 1.3206 - val_gender_output_loss: 0.5952 - val_image_quality_output_loss: 0.5704 - val_age_output_loss: 0.4531 - val_weight_output_loss: 0.4242 - val_bag_output_loss: 0.5183 - val_footwear_output_loss: 0.5255 - val_pose_output_loss: 0.5381 - val_emotion_output_loss: 0.3992 - val_gender_output_acc: 0.6900 - val_image_quality_output_acc: 0.7034 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8182 - val_bag_output_acc: 0.7335 - val_footwear_output_acc: 0.7386 - val_pose_output_acc: 0.7487 - val_emotion_output_acc: 0.8481
# Epoch 14/200
# 360/360 [==============================] - 156s 432ms/step - loss: 1.3118 - gender_output_loss: 0.5956 - image_quality_output_loss: 0.5712 - age_output_loss: 0.4513 - weight_output_loss: 0.4182 - bag_output_loss: 0.5311 - footwear_output_loss: 0.5337 - pose_output_loss: 0.5209 - emotion_output_loss: 0.3817 - gender_output_acc: 0.6691 - image_quality_output_acc: 0.7008 - age_output_acc: 0.8000 - weight_output_acc: 0.8177 - bag_output_acc: 0.7236 - footwear_output_acc: 0.7306 - pose_output_acc: 0.7538 - emotion_output_acc: 0.8571 - val_loss: 1.3046 - val_gender_output_loss: 0.5895 - val_image_quality_output_loss: 0.5743 - val_age_output_loss: 0.4503 - val_weight_output_loss: 0.4175 - val_bag_output_loss: 0.5168 - val_footwear_output_loss: 0.5090 - val_pose_output_loss: 0.5193 - val_emotion_output_loss: 0.3970 - val_gender_output_acc: 0.6855 - val_image_quality_output_acc: 0.7054 - val_age_output_acc: 0.7987 - val_weight_output_acc: 0.8182 - val_bag_output_acc: 0.7351 - val_footwear_output_acc: 0.7515 - val_pose_output_acc: 0.7583 - val_emotion_output_acc: 0.8482
# Epoch 15/200
# 360/360 [==============================] - 156s 432ms/step - loss: 1.3092 - gender_output_loss: 0.5925 - image_quality_output_loss: 0.5693 - age_output_loss: 0.4514 - weight_output_loss: 0.4184 - bag_output_loss: 0.5302 - footwear_output_loss: 0.5329 - pose_output_loss: 0.5176 - emotion_output_loss: 0.3816 - gender_output_acc: 0.6725 - image_quality_output_acc: 0.7003 - age_output_acc: 0.7999 - weight_output_acc: 0.8178 - bag_output_acc: 0.7225 - footwear_output_acc: 0.7286 - pose_output_acc: 0.7544 - emotion_output_acc: 0.8571 - val_loss: 1.3020 - val_gender_output_loss: 0.5780 - val_image_quality_output_loss: 0.5666 - val_age_output_loss: 0.4479 - val_weight_output_loss: 0.4174 - val_bag_output_loss: 0.5177 - val_footwear_output_loss: 0.5085 - val_pose_output_loss: 0.5317 - val_emotion_output_loss: 0.3954 - val_gender_output_acc: 0.6927 - val_image_quality_output_acc: 0.7063 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8182 - val_bag_output_acc: 0.7290 - val_footwear_output_acc: 0.7437 - val_pose_output_acc: 0.7407 - val_emotion_output_acc: 0.8482
# Epoch 16/200
# 360/360 [==============================] - 156s 433ms/step - loss: 1.3033 - gender_output_loss: 0.5846 - image_quality_output_loss: 0.5693 - age_output_loss: 0.4504 - weight_output_loss: 0.4175 - bag_output_loss: 0.5312 - footwear_output_loss: 0.5323 - pose_output_loss: 0.5084 - emotion_output_loss: 0.3796 - gender_output_acc: 0.6814 - image_quality_output_acc: 0.7012 - age_output_acc: 0.8001 - weight_output_acc: 0.8175 - bag_output_acc: 0.7235 - footwear_output_acc: 0.7335 - pose_output_acc: 0.7608 - emotion_output_acc: 0.8570 - val_loss: 1.2909 - val_gender_output_loss: 0.5555 - val_image_quality_output_loss: 0.5671 - val_age_output_loss: 0.4490 - val_weight_output_loss: 0.4168 - val_bag_output_loss: 0.5189 - val_footwear_output_loss: 0.5359 - val_pose_output_loss: 0.4859 - val_emotion_output_loss: 0.3903 - val_gender_output_acc: 0.7143 - val_image_quality_output_acc: 0.7042 - val_age_output_acc: 0.8016 - val_weight_output_acc: 0.8176 - val_bag_output_acc: 0.7321 - val_footwear_output_acc: 0.7255 - val_pose_output_acc: 0.7712 - val_emotion_output_acc: 0.8482
# Epoch 17/200
# 360/360 [==============================] - 156s 432ms/step - loss: 1.3092 - gender_output_loss: 0.5925 - image_quality_output_loss: 0.5693 - age_output_loss: 0.4514 - weight_output_loss: 0.4184 - bag_output_loss: 0.5302 - footwear_output_loss: 0.5329 - pose_output_loss: 0.5176 - emotion_output_loss: 0.3816 - gender_output_acc: 0.6725 - image_quality_output_acc: 0.7003 - age_output_acc: 0.7999 - weight_output_acc: 0.8178 - bag_output_acc: 0.7225 - footwear_output_acc: 0.7286 - pose_output_acc: 0.7544 - emotion_output_acc: 0.8571 - val_loss: 1.3020 - val_gender_output_loss: 0.5780 - val_image_quality_output_loss: 0.5666 - val_age_output_loss: 0.4479 - val_weight_output_loss: 0.4174 - val_bag_output_loss: 0.5177 - val_footwear_output_loss: 0.5085 - val_pose_output_loss: 0.5317 - val_emotion_output_loss: 0.3954 - val_gender_output_acc: 0.6927 - val_image_quality_output_acc: 0.7063 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8182 - val_bag_output_acc: 0.7290 - val_footwear_output_acc: 0.7437 - val_pose_output_acc: 0.7407 - val_emotion_output_acc: 0.8482
# 360/360 [==============================] - 156s 434ms/step - loss: 1.2996 - gender_output_loss: 0.5768 - image_quality_output_loss: 0.5694 - age_output_loss: 0.4505 - weight_output_loss: 0.4172 - bag_output_loss: 0.5305 - footwear_output_loss: 0.5310 - pose_output_loss: 0.5027 - emotion_output_loss: 0.3800 - gender_output_acc: 0.6919 - image_quality_output_acc: 0.7010 - age_output_acc: 0.7996 - weight_output_acc: 0.8175 - bag_output_acc: 0.7262 - footwear_output_acc: 0.7318 - pose_output_acc: 0.7630 - emotion_output_acc: 0.8571 - val_loss: 1.3097 - val_gender_output_loss: 0.5799 - val_image_quality_output_loss: 0.5757 - val_age_output_loss: 0.4551 - val_weight_output_loss: 0.4324 - val_bag_output_loss: 0.5170 - val_footwear_output_loss: 0.5096 - val_pose_output_loss: 0.5005 - val_emotion_output_loss: 0.4057 - val_gender_output_acc: 0.6989 - val_image_quality_output_acc: 0.7054 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8188 - val_bag_output_acc: 0.7391 - val_footwear_output_acc: 0.7502 - val_pose_output_acc: 0.7660 - val_emotion_output_acc: 0.8482
# Epoch 18/200
# 360/360 [==============================] - 155s 432ms/step - loss: 1.2958 - gender_output_loss: 0.5768 - image_quality_output_loss: 0.5697 - age_output_loss: 0.4495 - weight_output_loss: 0.4178 - bag_output_loss: 0.5289 - footwear_output_loss: 0.5269 - pose_output_loss: 0.4974 - emotion_output_loss: 0.3792 - gender_output_acc: 0.6880 - image_quality_output_acc: 0.7016 - age_output_acc: 0.8000 - weight_output_acc: 0.8175 - bag_output_acc: 0.7253 - footwear_output_acc: 0.7372 - pose_output_acc: 0.7677 - emotion_output_acc: 0.8573 - val_loss: 1.3240 - val_gender_output_loss: 0.5766 - val_image_quality_output_loss: 0.5704 - val_age_output_loss: 0.4558 - val_weight_output_loss: 0.4202 - val_bag_output_loss: 0.5199 - val_footwear_output_loss: 0.5500 - val_pose_output_loss: 0.5260 - val_emotion_output_loss: 0.4071 - val_gender_output_acc: 0.7108 - val_image_quality_output_acc: 0.7047 - val_age_output_acc: 0.7992 - val_weight_output_acc: 0.8178 - val_bag_output_acc: 0.7293 - val_footwear_output_acc: 0.7188 - val_pose_output_acc: 0.7553 - val_emotion_output_acc: 0.8482
# Epoch 19/200
# 360/360 [==============================] - 155s 432ms/step - loss: 1.2902 - gender_output_loss: 0.5669 - image_quality_output_loss: 0.5677 - age_output_loss: 0.4498 - weight_output_loss: 0.4166 - bag_output_loss: 0.5289 - footwear_output_loss: 0.5280 - pose_output_loss: 0.4879 - emotion_output_loss: 0.3789 - gender_output_acc: 0.6953 - image_quality_output_acc: 0.7002 - age_output_acc: 0.7995 - weight_output_acc: 0.8178 - bag_output_acc: 0.7274 - footwear_output_acc: 0.7357 - pose_output_acc: 0.7735 - emotion_output_acc: 0.8571 - val_loss: 1.3755 - val_gender_output_loss: 0.6951 - val_image_quality_output_loss: 0.5961 - val_age_output_loss: 0.4694 - val_weight_output_loss: 0.4278 - val_bag_output_loss: 0.5463 - val_footwear_output_loss: 0.5352 - val_pose_output_loss: 0.5269 - val_emotion_output_loss: 0.4234 - val_gender_output_acc: 0.6359 - val_image_quality_output_acc: 0.7030 - val_age_output_acc: 0.8003 - val_weight_output_acc: 0.8192 - val_bag_output_acc: 0.7270 - val_footwear_output_acc: 0.7459 - val_pose_output_acc: 0.7791 - val_emotion_output_acc: 0.8482
# Epoch 20/200
# 360/360 [==============================] - 156s 434ms/step - loss: 1.2857 - gender_output_loss: 0.5566 - image_quality_output_loss: 0.5690 - age_output_loss: 0.4495 - weight_output_loss: 0.4165 - bag_output_loss: 0.5264 - footwear_output_loss: 0.5248 - pose_output_loss: 0.4844 - emotion_output_loss: 0.3790 - gender_output_acc: 0.7074 - image_quality_output_acc: 0.7011 - age_output_acc: 0.7995 - weight_output_acc: 0.8181 - bag_output_acc: 0.7289 - footwear_output_acc: 0.7367 - pose_output_acc: 0.7749 - emotion_output_acc: 0.8571 - val_loss: 1.2762 - val_gender_output_loss: 0.5493 - val_image_quality_output_loss: 0.5647 - val_age_output_loss: 0.4504 - val_weight_output_loss: 0.4165 - val_bag_output_loss: 0.5158 - val_footwear_output_loss: 0.5104 - val_pose_output_loss: 0.4739 - val_emotion_output_loss: 0.3878 - val_gender_output_acc: 0.7143 - val_image_quality_output_acc: 0.7057 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7318 - val_footwear_output_acc: 0.7452 - val_pose_output_acc: 0.7870 - val_emotion_output_acc: 0.8482
# Epoch 21/200
# 360/360 [==============================] - 155s 431ms/step - loss: 1.2822 - gender_output_loss: 0.5529 - image_quality_output_loss: 0.5673 - age_output_loss: 0.4500 - weight_output_loss: 0.4165 - bag_output_loss: 0.5267 - footwear_output_loss: 0.5272 - pose_output_loss: 0.4746 - emotion_output_loss: 0.3783 - gender_output_acc: 0.7091 - image_quality_output_acc: 0.7013 - age_output_acc: 0.7996 - weight_output_acc: 0.8188 - bag_output_acc: 0.7285 - footwear_output_acc: 0.7362 - pose_output_acc: 0.7786 - emotion_output_acc: 0.8570 - val_loss: 1.2432 - val_gender_output_loss: 0.4954 - val_image_quality_output_loss: 0.5617 - val_age_output_loss: 0.4466 - val_weight_output_loss: 0.4148 - val_bag_output_loss: 0.5069 - val_footwear_output_loss: 0.4996 - val_pose_output_loss: 0.4347 - val_emotion_output_loss: 0.3851 - val_gender_output_acc: 0.7617 - val_image_quality_output_acc: 0.7060 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8180 - val_bag_output_acc: 0.7455 - val_footwear_output_acc: 0.7492 - val_pose_output_acc: 0.8036 - val_emotion_output_acc: 0.8482
# Epoch 22/200
# 360/360 [==============================] - 156s 432ms/step - loss: 1.2738 - gender_output_loss: 0.5457 - image_quality_output_loss: 0.5654 - age_output_loss: 0.4484 - weight_output_loss: 0.4148 - bag_output_loss: 0.5250 - footwear_output_loss: 0.5249 - pose_output_loss: 0.4643 - emotion_output_loss: 0.3766 - gender_output_acc: 0.7182 - image_quality_output_acc: 0.7009 - age_output_acc: 0.7999 - weight_output_acc: 0.8176 - bag_output_acc: 0.7299 - footwear_output_acc: 0.7358 - pose_output_acc: 0.7831 - emotion_output_acc: 0.8572 - val_loss: 1.3111 - val_gender_output_loss: 0.6246 - val_image_quality_output_loss: 0.5718 - val_age_output_loss: 0.4588 - val_weight_output_loss: 0.4214 - val_bag_output_loss: 0.5329 - val_footwear_output_loss: 0.5302 - val_pose_output_loss: 0.4769 - val_emotion_output_loss: 0.3868 - val_gender_output_acc: 0.7192 - val_image_quality_output_acc: 0.7078 - val_age_output_acc: 0.8001 - val_weight_output_acc: 0.8139 - val_bag_output_acc: 0.7312 - val_footwear_output_acc: 0.7445 - val_pose_output_acc: 0.7932 - val_emotion_output_acc: 0.8470
# Epoch 23/200
# 360/360 [==============================] - 155s 431ms/step - loss: 1.2675 - gender_output_loss: 0.5361 - image_quality_output_loss: 0.5634 - age_output_loss: 0.4484 - weight_output_loss: 0.4153 - bag_output_loss: 0.5247 - footwear_output_loss: 0.5230 - pose_output_loss: 0.4561 - emotion_output_loss: 0.3744 - gender_output_acc: 0.7198 - image_quality_output_acc: 0.7027 - age_output_acc: 0.7998 - weight_output_acc: 0.8183 - bag_output_acc: 0.7327 - footwear_output_acc: 0.7395 - pose_output_acc: 0.7889 - emotion_output_acc: 0.8570 - val_loss: 1.3590 - val_gender_output_loss: 0.6179 - val_image_quality_output_loss: 0.5824 - val_age_output_loss: 0.4664 - val_weight_output_loss: 0.4495 - val_bag_output_loss: 0.5372 - val_footwear_output_loss: 0.5670 - val_pose_output_loss: 0.4896 - val_emotion_output_loss: 0.4239 - val_gender_output_acc: 0.6322 - val_image_quality_output_acc: 0.6963 - val_age_output_acc: 0.7943 - val_weight_output_acc: 0.8181 - val_bag_output_acc: 0.7141 - val_footwear_output_acc: 0.7131 - val_pose_output_acc: 0.7816 - val_emotion_output_acc: 0.8483
# Epoch 24/200
# 360/360 [==============================] - 156s 433ms/step - loss: 1.2654 - gender_output_loss: 0.5310 - image_quality_output_loss: 0.5631 - age_output_loss: 0.4486 - weight_output_loss: 0.4159 - bag_output_loss: 0.5234 - footwear_output_loss: 0.5211 - pose_output_loss: 0.4537 - emotion_output_loss: 0.3754 - gender_output_acc: 0.7268 - image_quality_output_acc: 0.7019 - age_output_acc: 0.7996 - weight_output_acc: 0.8180 - bag_output_acc: 0.7326 - footwear_output_acc: 0.7408 - pose_output_acc: 0.7879 - emotion_output_acc: 0.8571 - val_loss: 1.2541 - val_gender_output_loss: 0.5013 - val_image_quality_output_loss: 0.5647 - val_age_output_loss: 0.4492 - val_weight_output_loss: 0.4185 - val_bag_output_loss: 0.5112 - val_footwear_output_loss: 0.4985 - val_pose_output_loss: 0.4476 - val_emotion_output_loss: 0.3882 - val_gender_output_acc: 0.7624 - val_image_quality_output_acc: 0.7073 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8172 - val_bag_output_acc: 0.7436 - val_footwear_output_acc: 0.7607 - val_pose_output_acc: 0.8019 - val_emotion_output_acc: 0.8490
# Epoch 25/200
# 360/360 [==============================] - 154s 428ms/step - loss: 1.2615 - gender_output_loss: 0.5281 - image_quality_output_loss: 0.5631 - age_output_loss: 0.4487 - weight_output_loss: 0.4146 - bag_output_loss: 0.5238 - footwear_output_loss: 0.5163 - pose_output_loss: 0.4473 - emotion_output_loss: 0.3763 - gender_output_acc: 0.7327 - image_quality_output_acc: 0.7016 - age_output_acc: 0.7994 - weight_output_acc: 0.8187 - bag_output_acc: 0.7315 - footwear_output_acc: 0.7426 - pose_output_acc: 0.7941 - emotion_output_acc: 0.8570 - val_loss: 1.4018 - val_gender_output_loss: 0.8411 - val_image_quality_output_loss: 0.6097 - val_age_output_loss: 0.4643 - val_weight_output_loss: 0.4315 - val_bag_output_loss: 0.5218 - val_footwear_output_loss: 0.5534 - val_pose_output_loss: 0.5526 - val_emotion_output_loss: 0.3938 - val_gender_output_acc: 0.5402 - val_image_quality_output_acc: 0.6949 - val_age_output_acc: 0.7913 - val_weight_output_acc: 0.8182 - val_bag_output_acc: 0.7293 - val_footwear_output_acc: 0.7032 - val_pose_output_acc: 0.7715 - val_emotion_output_acc: 0.8478
# Epoch 26/200
# 360/360 [==============================] - 155s 431ms/step - loss: 1.2567 - gender_output_loss: 0.5165 - image_quality_output_loss: 0.5613 - age_output_loss: 0.4481 - weight_output_loss: 0.4149 - bag_output_loss: 0.5217 - footwear_output_loss: 0.5181 - pose_output_loss: 0.4432 - emotion_output_loss: 0.3754 - gender_output_acc: 0.7313 - image_quality_output_acc: 0.7029 - age_output_acc: 0.7995 - weight_output_acc: 0.8189 - bag_output_acc: 0.7345 - footwear_output_acc: 0.7451 - pose_output_acc: 0.7931 - emotion_output_acc: 0.8572 - val_loss: 1.2899 - val_gender_output_loss: 0.5315 - val_image_quality_output_loss: 0.5632 - val_age_output_loss: 0.4508 - val_weight_output_loss: 0.4150 - val_bag_output_loss: 0.5266 - val_footwear_output_loss: 0.5532 - val_pose_output_loss: 0.4764 - val_emotion_output_loss: 0.3910 - val_gender_output_acc: 0.7284 - val_image_quality_output_acc: 0.7050 - val_age_output_acc: 0.8004 - val_weight_output_acc: 0.8194 - val_bag_output_acc: 0.7226 - val_footwear_output_acc: 0.7217 - val_pose_output_acc: 0.7902 - val_emotion_output_acc: 0.8482
# Epoch 27/200
# 360/360 [==============================] - 155s 431ms/step - loss: 1.2536 - gender_output_loss: 0.5110 - image_quality_output_loss: 0.5630 - age_output_loss: 0.4486 - weight_output_loss: 0.4144 - bag_output_loss: 0.5207 - footwear_output_loss: 0.5182 - pose_output_loss: 0.4353 - emotion_output_loss: 0.3755 - gender_output_acc: 0.7414 - image_quality_output_acc: 0.7012 - age_output_acc: 0.7997 - weight_output_acc: 0.8179 - bag_output_acc: 0.7349 - footwear_output_acc: 0.7420 - pose_output_acc: 0.7991 - emotion_output_acc: 0.8570 - val_loss: 1.2702 - val_gender_output_loss: 0.5073 - val_image_quality_output_loss: 0.5643 - val_age_output_loss: 0.4489 - val_weight_output_loss: 0.4208 - val_bag_output_loss: 0.5135 - val_footwear_output_loss: 0.5162 - val_pose_output_loss: 0.4632 - val_emotion_output_loss: 0.3970 - val_gender_output_acc: 0.7731 - val_image_quality_output_acc: 0.7072 - val_age_output_acc: 0.7997 - val_weight_output_acc: 0.8154 - val_bag_output_acc: 0.7379 - val_footwear_output_acc: 0.7488 - val_pose_output_acc: 0.7979 - val_emotion_output_acc: 0.8485
# Epoch 28/200
# 360/360 [==============================] - 155s 432ms/step - loss: 1.2442 - gender_output_loss: 0.5001 - image_quality_output_loss: 0.5600 - age_output_loss: 0.4476 - weight_output_loss: 0.4143 - bag_output_loss: 0.5196 - footwear_output_loss: 0.5121 - pose_output_loss: 0.4270 - emotion_output_loss: 0.3725 - gender_output_acc: 0.7489 - image_quality_output_acc: 0.7026 - age_output_acc: 0.8004 - weight_output_acc: 0.8186 - bag_output_acc: 0.7364 - footwear_output_acc: 0.7459 - pose_output_acc: 0.8004 - emotion_output_acc: 0.8572 - val_loss: 1.5502 - val_gender_output_loss: 0.7525 - val_image_quality_output_loss: 0.6282 - val_age_output_loss: 0.5214 - val_weight_output_loss: 0.5099 - val_bag_output_loss: 0.5638 - val_footwear_output_loss: 0.6204 - val_pose_output_loss: 0.6454 - val_emotion_output_loss: 0.4941 - val_gender_output_acc: 0.6806 - val_image_quality_output_acc: 0.7087 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8188 - val_bag_output_acc: 0.7330 - val_footwear_output_acc: 0.6890 - val_pose_output_acc: 0.7727 - val_emotion_output_acc: 0.8482
# Epoch 29/200
# 360/360 [==============================] - 155s 432ms/step - loss: 1.2385 - gender_output_loss: 0.4933 - image_quality_output_loss: 0.5588 - age_output_loss: 0.4470 - weight_output_loss: 0.4141 - bag_output_loss: 0.5167 - footwear_output_loss: 0.5121 - pose_output_loss: 0.4160 - emotion_output_loss: 0.3740 - gender_output_acc: 0.7536 - image_quality_output_acc: 0.7034 - age_output_acc: 0.7995 - weight_output_acc: 0.8185 - bag_output_acc: 0.7383 - footwear_output_acc: 0.7477 - pose_output_acc: 0.8086 - emotion_output_acc: 0.8571 - val_loss: 1.2865 - val_gender_output_loss: 0.6797 - val_image_quality_output_loss: 0.5586 - val_age_output_loss: 0.4460 - val_weight_output_loss: 0.4191 - val_bag_output_loss: 0.5283 - val_footwear_output_loss: 0.5005 - val_pose_output_loss: 0.4271 - val_emotion_output_loss: 0.3891 - val_gender_output_acc: 0.6580 - val_image_quality_output_acc: 0.7065 - val_age_output_acc: 0.8017 - val_weight_output_acc: 0.8201 - val_bag_output_acc: 0.7138 - val_footwear_output_acc: 0.7563 - val_pose_output_acc: 0.8166 - val_emotion_output_acc: 0.8485
# Epoch 30/200
# 360/360 [==============================] - 156s 433ms/step - loss: 1.2316 - gender_output_loss: 0.4819 - image_quality_output_loss: 0.5577 - age_output_loss: 0.4466 - weight_output_loss: 0.4132 - bag_output_loss: 0.5162 - footwear_output_loss: 0.5085 - pose_output_loss: 0.4117 - emotion_output_loss: 0.3712 - gender_output_acc: 0.7638 - image_quality_output_acc: 0.7027 - age_output_acc: 0.7995 - weight_output_acc: 0.8186 - bag_output_acc: 0.7405 - footwear_output_acc: 0.7484 - pose_output_acc: 0.8090 - emotion_output_acc: 0.8573 - val_loss: 1.2173 - val_gender_output_loss: 0.4310 - val_image_quality_output_loss: 0.5634 - val_age_output_loss: 0.4447 - val_weight_output_loss: 0.4133 - val_bag_output_loss: 0.5022 - val_footwear_output_loss: 0.4941 - val_pose_output_loss: 0.4111 - val_emotion_output_loss: 0.3806 - val_gender_output_acc: 0.7865 - val_image_quality_output_acc: 0.7072 - val_age_output_acc: 0.8017 - val_weight_output_acc: 0.8178 - val_bag_output_acc: 0.7411 - val_footwear_output_acc: 0.7598 - val_pose_output_acc: 0.8151 - val_emotion_output_acc: 0.8482
# Epoch 31/200
# 360/360 [==============================] - 155s 430ms/step - loss: 1.2280 - gender_output_loss: 0.4737 - image_quality_output_loss: 0.5547 - age_output_loss: 0.4470 - weight_output_loss: 0.4139 - bag_output_loss: 0.5154 - footwear_output_loss: 0.5064 - pose_output_loss: 0.4088 - emotion_output_loss: 0.3716 - gender_output_acc: 0.7720 - image_quality_output_acc: 0.7050 - age_output_acc: 0.7996 - weight_output_acc: 0.8185 - bag_output_acc: 0.7392 - footwear_output_acc: 0.7504 - pose_output_acc: 0.8133 - emotion_output_acc: 0.8571 - val_loss: 1.2177 - val_gender_output_loss: 0.4429 - val_image_quality_output_loss: 0.5720 - val_age_output_loss: 0.4478 - val_weight_output_loss: 0.4158 - val_bag_output_loss: 0.5122 - val_footwear_output_loss: 0.4870 - val_pose_output_loss: 0.3813 - val_emotion_output_loss: 0.3830 - val_gender_output_acc: 0.7959 - val_image_quality_output_acc: 0.6882 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8171 - val_bag_output_acc: 0.7416 - val_footwear_output_acc: 0.7617 - val_pose_output_acc: 0.8287 - val_emotion_output_acc: 0.8482
# Epoch 32/200
# 360/360 [==============================] - 155s 430ms/step - loss: 1.2289 - gender_output_loss: 0.4794 - image_quality_output_loss: 0.5555 - age_output_loss: 0.4460 - weight_output_loss: 0.4139 - bag_output_loss: 0.5151 - footwear_output_loss: 0.5066 - pose_output_loss: 0.4087 - emotion_output_loss: 0.3718 - gender_output_acc: 0.7631 - image_quality_output_acc: 0.7061 - age_output_acc: 0.8002 - weight_output_acc: 0.8191 - bag_output_acc: 0.7408 - footwear_output_acc: 0.7498 - pose_output_acc: 0.8138 - emotion_output_acc: 0.8571 - val_loss: 1.6537 - val_gender_output_loss: 0.9468 - val_image_quality_output_loss: 0.6321 - val_age_output_loss: 0.5469 - val_weight_output_loss: 0.5418 - val_bag_output_loss: 0.5678 - val_footwear_output_loss: 0.6813 - val_pose_output_loss: 0.7509 - val_emotion_output_loss: 0.4614 - val_gender_output_acc: 0.6000 - val_image_quality_output_acc: 0.6964 - val_age_output_acc: 0.8019 - val_weight_output_acc: 0.8182 - val_bag_output_acc: 0.7103 - val_footwear_output_acc: 0.7183 - val_pose_output_acc: 0.7646 - val_emotion_output_acc: 0.8482
# Epoch 33/200
# 360/360 [==============================] - 155s 430ms/step - loss: 1.2469 - gender_output_loss: 0.5125 - image_quality_output_loss: 0.5577 - age_output_loss: 0.4469 - weight_output_loss: 0.4135 - bag_output_loss: 0.5181 - footwear_output_loss: 0.5125 - pose_output_loss: 0.4311 - emotion_output_loss: 0.3743 - gender_output_acc: 0.7372 - image_quality_output_acc: 0.7052 - age_output_acc: 0.8000 - weight_output_acc: 0.8188 - bag_output_acc: 0.7379 - footwear_output_acc: 0.7418 - pose_output_acc: 0.8008 - emotion_output_acc: 0.8573 - val_loss: 1.9981 - val_gender_output_loss: 1.6545 - val_image_quality_output_loss: 0.7044 - val_age_output_loss: 0.6520 - val_weight_output_loss: 0.6027 - val_bag_output_loss: 0.7026 - val_footwear_output_loss: 0.7048 - val_pose_output_loss: 0.7068 - val_emotion_output_loss: 0.6363 - val_gender_output_acc: 0.6565 - val_image_quality_output_acc: 0.7054 - val_age_output_acc: 0.8002 - val_weight_output_acc: 0.8154 - val_bag_output_acc: 0.6946 - val_footwear_output_acc: 0.6969 - val_pose_output_acc: 0.7723 - val_emotion_output_acc: 0.8482
# Epoch 34/200
# 360/360 [==============================] - 156s 432ms/step - loss: 1.2383 - gender_output_loss: 0.4974 - image_quality_output_loss: 0.5570 - age_output_loss: 0.4463 - weight_output_loss: 0.4134 - bag_output_loss: 0.5171 - footwear_output_loss: 0.5121 - pose_output_loss: 0.4179 - emotion_output_loss: 0.3726 - gender_output_acc: 0.7542 - image_quality_output_acc: 0.7045 - age_output_acc: 0.7996 - weight_output_acc: 0.8184 - bag_output_acc: 0.7385 - footwear_output_acc: 0.7440 - pose_output_acc: 0.8069 - emotion_output_acc: 0.8571 - val_loss: 1.9945 - val_gender_output_loss: 1.2563 - val_image_quality_output_loss: 0.6616 - val_age_output_loss: 0.7239 - val_weight_output_loss: 0.5944 - val_bag_output_loss: 0.8022 - val_footwear_output_loss: 0.7354 - val_pose_output_loss: 0.8337 - val_emotion_output_loss: 0.5841 - val_gender_output_acc: 0.7212 - val_image_quality_output_acc: 0.6781 - val_age_output_acc: 0.8002 - val_weight_output_acc: 0.8186 - val_bag_output_acc: 0.7320 - val_footwear_output_acc: 0.7178 - val_pose_output_acc: 0.8072 - val_emotion_output_acc: 0.8482
# Epoch 35/200
# 360/360 [==============================] - 155s 431ms/step - loss: 1.2311 - gender_output_loss: 0.4892 - image_quality_output_loss: 0.5551 - age_output_loss: 0.4459 - weight_output_loss: 0.4121 - bag_output_loss: 0.5178 - footwear_output_loss: 0.5098 - pose_output_loss: 0.4054 - emotion_output_loss: 0.3727 - gender_output_acc: 0.7560 - image_quality_output_acc: 0.7053 - age_output_acc: 0.7996 - weight_output_acc: 0.8192 - bag_output_acc: 0.7384 - footwear_output_acc: 0.7490 - pose_output_acc: 0.8158 - emotion_output_acc: 0.8571 - val_loss: 1.2245 - val_gender_output_loss: 0.4262 - val_image_quality_output_loss: 0.6076 - val_age_output_loss: 0.4436 - val_weight_output_loss: 0.4132 - val_bag_output_loss: 0.5011 - val_footwear_output_loss: 0.5006 - val_pose_output_loss: 0.3850 - val_emotion_output_loss: 0.3848 - val_gender_output_acc: 0.7944 - val_image_quality_output_acc: 0.6930 - val_age_output_acc: 0.8001 - val_weight_output_acc: 0.8150 - val_bag_output_acc: 0.7479 - val_footwear_output_acc: 0.7517 - val_pose_output_acc: 0.8282 - val_emotion_output_acc: 0.8482
# Epoch 36/200
# 360/360 [==============================] - 156s 434ms/step - loss: 1.2213 - gender_output_loss: 0.4710 - image_quality_output_loss: 0.5536 - age_output_loss: 0.4457 - weight_output_loss: 0.4134 - bag_output_loss: 0.5137 - footwear_output_loss: 0.5056 - pose_output_loss: 0.3940 - emotion_output_loss: 0.3721 - gender_output_acc: 0.7744 - image_quality_output_acc: 0.7082 - age_output_acc: 0.8002 - weight_output_acc: 0.8184 - bag_output_acc: 0.7418 - footwear_output_acc: 0.7491 - pose_output_acc: 0.8199 - emotion_output_acc: 0.8572 - val_loss: 1.3319 - val_gender_output_loss: 0.5605 - val_image_quality_output_loss: 0.5690 - val_age_output_loss: 0.4737 - val_weight_output_loss: 0.4414 - val_bag_output_loss: 0.5301 - val_footwear_output_loss: 0.5081 - val_pose_output_loss: 0.5274 - val_emotion_output_loss: 0.4150 - val_gender_output_acc: 0.7287 - val_image_quality_output_acc: 0.7092 - val_age_output_acc: 0.8011 - val_weight_output_acc: 0.8135 - val_bag_output_acc: 0.7336 - val_footwear_output_acc: 0.7589 - val_pose_output_acc: 0.8107 - val_emotion_output_acc: 0.8482
# Epoch 37/200
# 360/360 [==============================] - 156s 433ms/step - loss: 1.2241 - gender_output_loss: 0.4725 - image_quality_output_loss: 0.5536 - age_output_loss: 0.4461 - weight_output_loss: 0.4140 - bag_output_loss: 0.5133 - footwear_output_loss: 0.5099 - pose_output_loss: 0.3986 - emotion_output_loss: 0.3708 - gender_output_acc: 0.7689 - image_quality_output_acc: 0.7057 - age_output_acc: 0.8001 - weight_output_acc: 0.8184 - bag_output_acc: 0.7437 - footwear_output_acc: 0.7464 - pose_output_acc: 0.8179 - emotion_output_acc: 0.8571 - val_loss: 1.2479 - val_gender_output_loss: 0.5462 - val_image_quality_output_loss: 0.5528 - val_age_output_loss: 0.4469 - val_weight_output_loss: 0.4135 - val_bag_output_loss: 0.5040 - val_footwear_output_loss: 0.4802 - val_pose_output_loss: 0.4566 - val_emotion_output_loss: 0.3793 - val_gender_output_acc: 0.7545 - val_image_quality_output_acc: 0.7097 - val_age_output_acc: 0.8006 - val_weight_output_acc: 0.8163 - val_bag_output_acc: 0.7427 - val_footwear_output_acc: 0.7674 - val_pose_output_acc: 0.8118 - val_emotion_output_acc: 0.8480
# Epoch 38/200
# 360/360 [==============================] - 157s 435ms/step - loss: 1.2163 - gender_output_loss: 0.4679 - image_quality_output_loss: 0.5524 - age_output_loss: 0.4452 - weight_output_loss: 0.4126 - bag_output_loss: 0.5120 - footwear_output_loss: 0.5035 - pose_output_loss: 0.3885 - emotion_output_loss: 0.3705 - gender_output_acc: 0.7698 - image_quality_output_acc: 0.7053 - age_output_acc: 0.8003 - weight_output_acc: 0.8196 - bag_output_acc: 0.7426 - footwear_output_acc: 0.7519 - pose_output_acc: 0.8203 - emotion_output_acc: 0.8570 - val_loss: 1.2419 - val_gender_output_loss: 0.4506 - val_image_quality_output_loss: 0.5648 - val_age_output_loss: 0.4479 - val_weight_output_loss: 0.4180 - val_bag_output_loss: 0.5074 - val_footwear_output_loss: 0.5040 - val_pose_output_loss: 0.4346 - val_emotion_output_loss: 0.3934 - val_gender_output_acc: 0.8093 - val_image_quality_output_acc: 0.7092 - val_age_output_acc: 0.8006 - val_weight_output_acc: 0.8178 - val_bag_output_acc: 0.7429 - val_footwear_output_acc: 0.7591 - val_pose_output_acc: 0.8194 - val_emotion_output_acc: 0.8482
# Epoch 39/200
# 360/360 [==============================] - 156s 433ms/step - loss: 1.2130 - gender_output_loss: 0.4564 - image_quality_output_loss: 0.5528 - age_output_loss: 0.4442 - weight_output_loss: 0.4114 - bag_output_loss: 0.5099 - footwear_output_loss: 0.5040 - pose_output_loss: 0.3883 - emotion_output_loss: 0.3713 - gender_output_acc: 0.7774 - image_quality_output_acc: 0.7065 - age_output_acc: 0.7999 - weight_output_acc: 0.8194 - bag_output_acc: 0.7468 - footwear_output_acc: 0.7525 - pose_output_acc: 0.8230 - emotion_output_acc: 0.8571 - val_loss: 1.2227 - val_gender_output_loss: 0.4189 - val_image_quality_output_loss: 0.6078 - val_age_output_loss: 0.4424 - val_weight_output_loss: 0.4125 - val_bag_output_loss: 0.5098 - val_footwear_output_loss: 0.4828 - val_pose_output_loss: 0.3828 - val_emotion_output_loss: 0.3945 - val_gender_output_acc: 0.8073 - val_image_quality_output_acc: 0.6867 - val_age_output_acc: 0.8012 - val_weight_output_acc: 0.8197 - val_bag_output_acc: 0.7401 - val_footwear_output_acc: 0.7670 - val_pose_output_acc: 0.8249 - val_emotion_output_acc: 0.8482
# Epoch 40/200
# 360/360 [==============================] - 157s 435ms/step - loss: 1.2120 - gender_output_loss: 0.4556 - image_quality_output_loss: 0.5516 - age_output_loss: 0.4448 - weight_output_loss: 0.4119 - bag_output_loss: 0.5121 - footwear_output_loss: 0.5025 - pose_output_loss: 0.3856 - emotion_output_loss: 0.3705 - gender_output_acc: 0.7807 - image_quality_output_acc: 0.7071 - age_output_acc: 0.8003 - weight_output_acc: 0.8204 - bag_output_acc: 0.7434 - footwear_output_acc: 0.7519 - pose_output_acc: 0.8229 - emotion_output_acc: 0.8572 - val_loss: 1.3183 - val_gender_output_loss: 0.7911 - val_image_quality_output_loss: 0.5636 - val_age_output_loss: 0.4578 - val_weight_output_loss: 0.4241 - val_bag_output_loss: 0.5088 - val_footwear_output_loss: 0.5598 - val_pose_output_loss: 0.3898 - val_emotion_output_loss: 0.3874 - val_gender_output_acc: 0.6332 - val_image_quality_output_acc: 0.7044 - val_age_output_acc: 0.7997 - val_weight_output_acc: 0.8182 - val_bag_output_acc: 0.7384 - val_footwear_output_acc: 0.7011 - val_pose_output_acc: 0.8317 - val_emotion_output_acc: 0.8482
# Epoch 41/200
# 360/360 [==============================] - 155s 431ms/step - loss: 1.2035 - gender_output_loss: 0.4415 - image_quality_output_loss: 0.5495 - age_output_loss: 0.4441 - weight_output_loss: 0.4120 - bag_output_loss: 0.5083 - footwear_output_loss: 0.5026 - pose_output_loss: 0.3751 - emotion_output_loss: 0.3693 - gender_output_acc: 0.7920 - image_quality_output_acc: 0.7087 - age_output_acc: 0.7997 - weight_output_acc: 0.8193 - bag_output_acc: 0.7502 - footwear_output_acc: 0.7521 - pose_output_acc: 0.8326 - emotion_output_acc: 0.8572 - val_loss: 1.2318 - val_gender_output_loss: 0.4221 - val_image_quality_output_loss: 0.5630 - val_age_output_loss: 0.4431 - val_weight_output_loss: 0.4141 - val_bag_output_loss: 0.4986 - val_footwear_output_loss: 0.5151 - val_pose_output_loss: 0.4504 - val_emotion_output_loss: 0.3803 - val_gender_output_acc: 0.7994 - val_image_quality_output_acc: 0.7070 - val_age_output_acc: 0.8005 - val_weight_output_acc: 0.8192 - val_bag_output_acc: 0.7469 - val_footwear_output_acc: 0.7368 - val_pose_output_acc: 0.8110 - val_emotion_output_acc: 0.8482
# Epoch 42/200
# 360/360 [==============================] - 155s 431ms/step - loss: 1.2043 - gender_output_loss: 0.4349 - image_quality_output_loss: 0.5509 - age_output_loss: 0.4437 - weight_output_loss: 0.4112 - bag_output_loss: 0.5078 - footwear_output_loss: 0.5023 - pose_output_loss: 0.3811 - emotion_output_loss: 0.3709 - gender_output_acc: 0.7943 - image_quality_output_acc: 0.7089 - age_output_acc: 0.7998 - weight_output_acc: 0.8189 - bag_output_acc: 0.7487 - footwear_output_acc: 0.7503 - pose_output_acc: 0.8271 - emotion_output_acc: 0.8571 - val_loss: 1.2475 - val_gender_output_loss: 0.5477 - val_image_quality_output_loss: 0.5712 - val_age_output_loss: 0.4488 - val_weight_output_loss: 0.4192 - val_bag_output_loss: 0.5277 - val_footwear_output_loss: 0.4860 - val_pose_output_loss: 0.3944 - val_emotion_output_loss: 0.3800 - val_gender_output_acc: 0.7579 - val_image_quality_output_acc: 0.7016 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8100 - val_bag_output_acc: 0.7354 - val_footwear_output_acc: 0.7662 - val_pose_output_acc: 0.8297 - val_emotion_output_acc: 0.8465
# Epoch 43/200
# ...
# Epoch 51/200
# 360/360 [==============================] - 155s 431ms/step - loss: 1.1704 - gender_output_loss: 0.3927 - image_quality_output_loss: 0.5434 - age_output_loss: 0.4403 - weight_output_loss: 0.4078 - bag_output_loss: 0.4930 - footwear_output_loss: 0.4879 - pose_output_loss: 0.3473 - emotion_output_loss: 0.3676 - gender_output_acc: 0.8215 - image_quality_output_acc: 0.7123 - age_output_acc: 0.7999 - weight_output_acc: 0.8207 - bag_output_acc: 0.7596 - footwear_output_acc: 0.7594 - pose_output_acc: 0.8478 - emotion_output_acc: 0.8572 - val_loss: 1.1866 - val_gender_output_loss: 0.3995 - val_image_quality_output_loss: 0.5443 - val_age_output_loss: 0.4387 - val_weight_output_loss: 0.4131 - val_bag_output_loss: 0.4977 - val_footwear_output_loss: 0.4839 - val_pose_output_loss: 0.3724 - val_emotion_output_loss: 0.3815 - val_gender_output_acc: 0.8266 - val_image_quality_output_acc: 0.7146 - val_age_output_acc: 0.7988 - val_weight_output_acc: 0.8203 - val_bag_output_acc: 0.7515 - val_footwear_output_acc: 0.7677 - val_pose_output_acc: 0.8485 - val_emotion_output_acc: 0.8482
# Epoch 52/200
# 359/360 [============================>.] - ETA: 0s - loss: 1.1682 - gender_output_loss: 0.3864 - image_quality_output_loss: 0.5433 - age_output_loss: 0.4401 - weight_output_loss: 0.4088 - bag_output_loss: 0.4951 - footwear_output_loss: 0.4871 - pose_output_loss: 0.3443 - emotion_output_loss: 0.3660 - gender_output_acc: 0.8253 - image_quality_output_acc: 0.7154 - age_output_acc: 0.7996 - weight_output_acc: 0.8202 - bag_output_acc: 0.7580 - footwear_output_acc: 0.7618 - pose_output_acc: 0.8482 - emotion_output_acc: 0.8573Epoch 52/200
# 360/360 [==============================] - 156s 432ms/step - loss: 1.1682 - gender_output_loss: 0.3865 - image_quality_output_loss: 0.5434 - age_output_loss: 0.4399 - weight_output_loss: 0.4088 - bag_output_loss: 0.4952 - footwear_output_loss: 0.4871 - pose_output_loss: 0.3441 - emotion_output_loss: 0.3661 - gender_output_acc: 0.8255 - image_quality_output_acc: 0.7152 - age_output_acc: 0.7996 - weight_output_acc: 0.8202 - bag_output_acc: 0.7578 - footwear_output_acc: 0.7619 - pose_output_acc: 0.8484 - emotion_output_acc: 0.8572 - val_loss: 1.1802 - val_gender_output_loss: 0.3813 - val_image_quality_output_loss: 0.5429 - val_age_output_loss: 0.4435 - val_weight_output_loss: 0.4068 - val_bag_output_loss: 0.4975 - val_footwear_output_loss: 0.4742 - val_pose_output_loss: 0.3708 - val_emotion_output_loss: 0.3843 - val_gender_output_acc: 0.8264 - val_image_quality_output_acc: 0.7140 - val_age_output_acc: 0.7996 - val_weight_output_acc: 0.8198 - val_bag_output_acc: 0.7546 - val_footwear_output_acc: 0.7801 - val_pose_output_acc: 0.8519 - val_emotion_output_acc: 0.8471
# Epoch 53/200
# 360/360 [==============================] - 155s 432ms/step - loss: 1.1641 - gender_output_loss: 0.3820 - image_quality_output_loss: 0.5432 - age_output_loss: 0.4405 - weight_output_loss: 0.4086 - bag_output_loss: 0.4937 - footwear_output_loss: 0.4821 - pose_output_loss: 0.3397 - emotion_output_loss: 0.3661 - gender_output_acc: 0.8198 - image_quality_output_acc: 0.7122 - age_output_acc: 0.7993 - weight_output_acc: 0.8207 - bag_output_acc: 0.7579 - footwear_output_acc: 0.7656 - pose_output_acc: 0.8519 - emotion_output_acc: 0.8570 - val_loss: 1.1747 - val_gender_output_loss: 0.4121 - val_image_quality_output_loss: 0.5400 - val_age_output_loss: 0.4404 - val_weight_output_loss: 0.4096 - val_bag_output_loss: 0.4957 - val_footwear_output_loss: 0.4719 - val_pose_output_loss: 0.3467 - val_emotion_output_loss: 0.3798 - val_gender_output_acc: 0.8080 - val_image_quality_output_acc: 0.7143 - val_age_output_acc: 0.8001 - val_weight_output_acc: 0.8194 - val_bag_output_acc: 0.7517 - val_footwear_output_acc: 0.7789 - val_pose_output_acc: 0.8441 - val_emotion_output_acc: 0.8482
# Epoch 54/200
# 360/360 [==============================] - 156s 433ms/step - loss: 1.1631 - gender_output_loss: 0.3822 - image_quality_output_loss: 0.5427 - age_output_loss: 0.4397 - weight_output_loss: 0.4076 - bag_output_loss: 0.4905 - footwear_output_loss: 0.4829 - pose_output_loss: 0.3417 - emotion_output_loss: 0.3661 - gender_output_acc: 0.8250 - image_quality_output_acc: 0.7139 - age_output_acc: 0.8004 - weight_output_acc: 0.8211 - bag_output_acc: 0.7629 - footwear_output_acc: 0.7651 - pose_output_acc: 0.8525 - emotion_output_acc: 0.8571 - val_loss: 1.1726 - val_gender_output_loss: 0.3818 - val_image_quality_output_loss: 0.5437 - val_age_output_loss: 0.4397 - val_weight_output_loss: 0.4104 - val_bag_output_loss: 0.4856 - val_footwear_output_loss: 0.4715 - val_pose_output_loss: 0.3708 - val_emotion_output_loss: 0.3770 - val_gender_output_acc: 0.8306 - val_image_quality_output_acc: 0.7062 - val_age_output_acc: 0.8013 - val_weight_output_acc: 0.8209 - val_bag_output_acc: 0.7621 - val_footwear_output_acc: 0.7736 - val_pose_output_acc: 0.8461 - val_emotion_output_acc: 0.8482
# Epoch 55/200
# 360/360 [==============================] - 155s 431ms/step - loss: 1.1587 - gender_output_loss: 0.3831 - image_quality_output_loss: 0.5420 - age_output_loss: 0.4387 - weight_output_loss: 0.4070 - bag_output_loss: 0.4913 - footwear_output_loss: 0.4781 - pose_output_loss: 0.3337 - emotion_output_loss: 0.3660 - gender_output_acc: 0.8261 - image_quality_output_acc: 0.7144 - age_output_acc: 0.8000 - weight_output_acc: 0.8218 - bag_output_acc: 0.7612 - footwear_output_acc: 0.7692 - pose_output_acc: 0.8554 - emotion_output_acc: 0.8571 - val_loss: 1.2094 - val_gender_output_loss: 0.3976 - val_image_quality_output_loss: 0.5539 - val_age_output_loss: 0.4680 - val_weight_output_loss: 0.4283 - val_bag_output_loss: 0.5310 - val_footwear_output_loss: 0.4748 - val_pose_output_loss: 0.3425 - val_emotion_output_loss: 0.3847 - val_gender_output_acc: 0.8328 - val_image_quality_output_acc: 0.7148 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8207 - val_bag_output_acc: 0.7566 - val_footwear_output_acc: 0.7745 - val_pose_output_acc: 0.8533 - val_emotion_output_acc: 0.8477
# Epoch 56/200
# 360/360 [==============================] - 156s 433ms/step - loss: 1.1578 - gender_output_loss: 0.3774 - image_quality_output_loss: 0.5409 - age_output_loss: 0.4383 - weight_output_loss: 0.4051 - bag_output_loss: 0.4889 - footwear_output_loss: 0.4824 - pose_output_loss: 0.3374 - emotion_output_loss: 0.3656 - gender_output_acc: 0.8280 - image_quality_output_acc: 0.7142 - age_output_acc: 0.8008 - weight_output_acc: 0.8214 - bag_output_acc: 0.7653 - footwear_output_acc: 0.7670 - pose_output_acc: 0.8537 - emotion_output_acc: 0.8573 - val_loss: 1.1896 - val_gender_output_loss: 0.4254 - val_image_quality_output_loss: 0.5438 - val_age_output_loss: 0.4472 - val_weight_output_loss: 0.4100 - val_bag_output_loss: 0.4903 - val_footwear_output_loss: 0.4913 - val_pose_output_loss: 0.3572 - val_emotion_output_loss: 0.3805 - val_gender_output_acc: 0.8217 - val_image_quality_output_acc: 0.7102 - val_age_output_acc: 0.7998 - val_weight_output_acc: 0.8197 - val_bag_output_acc: 0.7551 - val_footwear_output_acc: 0.7652 - val_pose_output_acc: 0.8558 - val_emotion_output_acc: 0.8482
# Epoch 57/200
# 360/360 [==============================] - 156s 432ms/step - loss: 1.1563 - gender_output_loss: 0.3746 - image_quality_output_loss: 0.5412 - age_output_loss: 0.4385 - weight_output_loss: 0.4061 - bag_output_loss: 0.4914 - footwear_output_loss: 0.4799 - pose_output_loss: 0.3316 - emotion_output_loss: 0.3661 - gender_output_acc: 0.8297 - image_quality_output_acc: 0.7128 - age_output_acc: 0.7992 - weight_output_acc: 0.8204 - bag_output_acc: 0.7614 - footwear_output_acc: 0.7643 - pose_output_acc: 0.8563 - emotion_output_acc: 0.8572 - val_loss: 1.1690 - val_gender_output_loss: 0.3818 - val_image_quality_output_loss: 0.5466 - val_age_output_loss: 0.4417 - val_weight_output_loss: 0.4081 - val_bag_output_loss: 0.4883 - val_footwear_output_loss: 0.4862 - val_pose_output_loss: 0.3313 - val_emotion_output_loss: 0.3821 - val_gender_output_acc: 0.8333 - val_image_quality_output_acc: 0.7171 - val_age_output_acc: 0.7992 - val_weight_output_acc: 0.8183 - val_bag_output_acc: 0.7603 - val_footwear_output_acc: 0.7692 - val_pose_output_acc: 0.8593 - val_emotion_output_acc: 0.8486
# Epoch 58/200
# 360/360 [==============================] - 156s 432ms/step - loss: 1.1499 - gender_output_loss: 0.3658 - image_quality_output_loss: 0.5382 - age_output_loss: 0.4381 - weight_output_loss: 0.4055 - bag_output_loss: 0.4862 - footwear_output_loss: 0.4774 - pose_output_loss: 0.3296 - emotion_output_loss: 0.3652 - gender_output_acc: 0.8348 - image_quality_output_acc: 0.7173 - age_output_acc: 0.8005 - weight_output_acc: 0.8217 - bag_output_acc: 0.7652 - footwear_output_acc: 0.7700 - pose_output_acc: 0.8568 - emotion_output_acc: 0.8573 - val_loss: 1.1604 - val_gender_output_loss: 0.3603 - val_image_quality_output_loss: 0.5476 - val_age_output_loss: 0.4421 - val_weight_output_loss: 0.4137 - val_bag_output_loss: 0.4899 - val_footwear_output_loss: 0.4670 - val_pose_output_loss: 0.3280 - val_emotion_output_loss: 0.3800 - val_gender_output_acc: 0.8507 - val_image_quality_output_acc: 0.7012 - val_age_output_acc: 0.8020 - val_weight_output_acc: 0.8118 - val_bag_output_acc: 0.7591 - val_footwear_output_acc: 0.7774 - val_pose_output_acc: 0.8639 - val_emotion_output_acc: 0.8482
# Epoch 59/200
# 359/360 [============================>.] - ETA: 0s - loss: 1.1495 - gender_output_loss: 0.3657 - image_quality_output_loss: 0.5403 - age_output_loss: 0.4376 - weight_output_loss: 0.4038 - bag_output_loss: 0.4867 - footwear_output_loss: 0.4812 - pose_output_loss: 0.3262 - emotion_output_loss: 0.3641 - gender_output_acc: 0.8368 - image_quality_output_acc: 0.7156 - age_output_acc: 0.8006 - weight_output_acc: 0.8224 - bag_output_acc: 0.7652 - footwear_output_acc: 0.7665 - pose_output_acc: 0.8608 - emotion_output_acc: 0.8572Epoch 59/200
# 360/360 [==============================] - 156s 432ms/step - loss: 1.1493 - gender_output_loss: 0.3660 - image_quality_output_loss: 0.5404 - age_output_loss: 0.4374 - weight_output_loss: 0.4036 - bag_output_loss: 0.4865 - footwear_output_loss: 0.4810 - pose_output_loss: 0.3267 - emotion_output_loss: 0.3639 - gender_output_acc: 0.8366 - image_quality_output_acc: 0.7154 - age_output_acc: 0.8008 - weight_output_acc: 0.8225 - bag_output_acc: 0.7653 - footwear_output_acc: 0.7665 - pose_output_acc: 0.8605 - emotion_output_acc: 0.8573 - val_loss: 1.3206 - val_gender_output_loss: 0.8051 - val_image_quality_output_loss: 0.5746 - val_age_output_loss: 0.4589 - val_weight_output_loss: 0.4511 - val_bag_output_loss: 0.5379 - val_footwear_output_loss: 0.4892 - val_pose_output_loss: 0.3437 - val_emotion_output_loss: 0.4151 - val_gender_output_acc: 0.7597 - val_image_quality_output_acc: 0.7039 - val_age_output_acc: 0.7979 - val_weight_output_acc: 0.8224 - val_bag_output_acc: 0.7269 - val_footwear_output_acc: 0.7692 - val_pose_output_acc: 0.8477 - val_emotion_output_acc: 0.8482
# Epoch 60/200
# 360/360 [==============================] - 156s 433ms/step - loss: 1.1407 - gender_output_loss: 0.3576 - image_quality_output_loss: 0.5377 - age_output_loss: 0.4376 - weight_output_loss: 0.4033 - bag_output_loss: 0.4838 - footwear_output_loss: 0.4756 - pose_output_loss: 0.3154 - emotion_output_loss: 0.3632 - gender_output_acc: 0.8391 - image_quality_output_acc: 0.7182 - age_output_acc: 0.7998 - weight_output_acc: 0.8228 - bag_output_acc: 0.7677 - footwear_output_acc: 0.7684 - pose_output_acc: 0.8635 - emotion_output_acc: 0.8573 - val_loss: 1.1885 - val_gender_output_loss: 0.3890 - val_image_quality_output_loss: 0.5691 - val_age_output_loss: 0.4428 - val_weight_output_loss: 0.4104 - val_bag_output_loss: 0.4907 - val_footwear_output_loss: 0.4853 - val_pose_output_loss: 0.3668 - val_emotion_output_loss: 0.3789 - val_gender_output_acc: 0.8266 - val_image_quality_output_acc: 0.6981 - val_age_output_acc: 0.7984 - val_weight_output_acc: 0.8217 - val_bag_output_acc: 0.7624 - val_footwear_output_acc: 0.7655 - val_pose_output_acc: 0.8578 - val_emotion_output_acc: 0.8477
# Epoch 61/200
# 360/360 [==============================] - 155s 432ms/step - loss: 1.1415 - gender_output_loss: 0.3583 - image_quality_output_loss: 0.5390 - age_output_loss: 0.4360 - weight_output_loss: 0.4040 - bag_output_loss: 0.4819 - footwear_output_loss: 0.4755 - pose_output_loss: 0.3184 - emotion_output_loss: 0.3646 - gender_output_acc: 0.8390 - image_quality_output_acc: 0.7152 - age_output_acc: 0.8002 - weight_output_acc: 0.8228 - bag_output_acc: 0.7683 - footwear_output_acc: 0.7703 - pose_output_acc: 0.8598 - emotion_output_acc: 0.8571 - val_loss: 1.1600 - val_gender_output_loss: 0.3914 - val_image_quality_output_loss: 0.5438 - val_age_output_loss: 0.4386 - val_weight_output_loss: 0.4088 - val_bag_output_loss: 0.4894 - val_footwear_output_loss: 0.4682 - val_pose_output_loss: 0.3264 - val_emotion_output_loss: 0.3762 - val_gender_output_acc: 0.8202 - val_image_quality_output_acc: 0.6981 - val_age_output_acc: 0.8017 - val_weight_output_acc: 0.8199 - val_bag_output_acc: 0.7551 - val_footwear_output_acc: 0.7774 - val_pose_output_acc: 0.8583 - val_emotion_output_acc: 0.8480
# Epoch 62/200
# 360/360 [==============================] - 155s 432ms/step - loss: 1.1356 - gender_output_loss: 0.3482 - image_quality_output_loss: 0.5393 - age_output_loss: 0.4362 - weight_output_loss: 0.4037 - bag_output_loss: 0.4796 - footwear_output_loss: 0.4730 - pose_output_loss: 0.3118 - emotion_output_loss: 0.3631 - gender_output_acc: 0.8459 - image_quality_output_acc: 0.7152 - age_output_acc: 0.8005 - weight_output_acc: 0.8231 - bag_output_acc: 0.7702 - footwear_output_acc: 0.7712 - pose_output_acc: 0.8661 - emotion_output_acc: 0.8572 - val_loss: 1.1971 - val_gender_output_loss: 0.3677 - val_image_quality_output_loss: 0.6201 - val_age_output_loss: 0.4396 - val_weight_output_loss: 0.4165 - val_bag_output_loss: 0.4832 - val_footwear_output_loss: 0.4826 - val_pose_output_loss: 0.3598 - val_emotion_output_loss: 0.3836 - val_gender_output_acc: 0.8316 - val_image_quality_output_acc: 0.6472 - val_age_output_acc: 0.8007 - val_weight_output_acc: 0.8176 - val_bag_output_acc: 0.7624 - val_footwear_output_acc: 0.7707 - val_pose_output_acc: 0.8608 - val_emotion_output_acc: 0.8483
# Epoch 63/200
# 360/360 [==============================] - 155s 430ms/step - loss: 1.1329 - gender_output_loss: 0.3495 - image_quality_output_loss: 0.5351 - age_output_loss: 0.4357 - weight_output_loss: 0.4039 - bag_output_loss: 0.4790 - footwear_output_loss: 0.4703 - pose_output_loss: 0.3108 - emotion_output_loss: 0.3624 - gender_output_acc: 0.8386 - image_quality_output_acc: 0.7184 - age_output_acc: 0.8006 - weight_output_acc: 0.8233 - bag_output_acc: 0.7727 - footwear_output_acc: 0.7740 - pose_output_acc: 0.8663 - emotion_output_acc: 0.8573 - val_loss: 1.2074 - val_gender_output_loss: 0.4078 - val_image_quality_output_loss: 0.5581 - val_age_output_loss: 0.4456 - val_weight_output_loss: 0.4322 - val_bag_output_loss: 0.5094 - val_footwear_output_loss: 0.4942 - val_pose_output_loss: 0.3444 - val_emotion_output_loss: 0.3958 - val_gender_output_acc: 0.8306 - val_image_quality_output_acc: 0.7116 - val_age_output_acc: 0.8005 - val_weight_output_acc: 0.8157 - val_bag_output_acc: 0.7603 - val_footwear_output_acc: 0.7748 - val_pose_output_acc: 0.8573 - val_emotion_output_acc: 0.8485
# Epoch 64/200
# 258/360 [====================>.........] - ETA: 41s - loss: 1.1319 - gender_output_loss: 0.3448 - image_quality_output_loss: 0.5379 - age_output_loss: 0.4347 - weight_output_loss: 0.4032 - bag_output_loss: 0.4772 - footwear_output_loss: 0.4695 - pose_output_loss: 0.3102 - emotion_output_loss: 0.3646 - gender_output_acc: 0.8463 - image_quality_output_acc: 0.7165 - age_output_acc: 0.8008 - weight_output_acc: 0.8218 - bag_output_acc: 0.7752 - footwear_output_acc: 0.7739 - pose_output_acc: 0.8672 - emotion_output_acc: 0.8556Buffered data was truncated after reaching the output size limit.

# %%
model
