# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepaManjunath/Assignment1/blob/master/Untitled37.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q '/content/gdrive/My Drive/EIP4/hvc_data.zip'
# look for `hvc_annotations.csv` file and `resized` dir
# %ls '/content/gdrive/My Drive/EIP4/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# hvc_data/  hvc_data.zip

# %%
# %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation , Dropout
from keras.layers import AveragePooling2D, Input, Flatten ,GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.callbacks import ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()
# Out:
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
# 3    male         Good  45-55  ...        Neutral  Front-Frontish  resized/4.jpg
# 4  female         Good  35-45  ...        Neutral  Front-Frontish  resized/5.jpg
#
# [5 rows x 9 columns]

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
import numpy as np


def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=32, shuffle=True,augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.batch_size = batch_size
        #self.labels = labels
        #self.list_IDs = list_IDs
        #self.n_channels = n_channels
        #self.n_classes = n_classes
        #self.shuffle = shuffle
        self.on_epoch_end()
        self.augmentation=augmentation
        
        
        #self.on_epoch_end()

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

            
    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        images = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
        if self.augmentation is not None:
           images=self.augmentation.flow(images,shuffle=False).next()
           
        target = {
                       "gender_output": items[_gender_cols_].values,
                       "image_quality_output": items[_imagequality_cols_].values,
                       "age_output": items[_age_cols_].values,
                       "weight_output": items[_weight_cols_].values,
                       "bag_output": items[_carryingbag_cols_].values,
                       "pose_output": items[_bodypose_cols_].values,
                       "footwear_output": items[_footwear_cols_].values,
                       "emotion_output": items[_emotion_cols_].values,
        }
        return images, target
    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
            
   # def __PersonDataGenerator(self,train_df,batch_size=32,augmentation):
      
    #     train_gen = np.stack(train_df, batch_size=32,augmentation=ImageDataGenerator(featurewise_center=False,
     #                           samplewise_center=False,
      #                          featurewise_std_normalization=False,
       #                         samplewise_std_normalization=False,
        #                        zca_whitening=False,
         #                       zca_epsilon=1e-06,
          #                      rotation_range=25,
           #                     width_shift_range=0.1,
            #                    height_shift_range=0.1,
             #                   brightness_range=None,
              #                  shear_range=0.0,
               #                 zoom_range=0.0,
                #                channel_shift_range=0.0,
                 #               fill_mode='nearest',
                  #              cval=0.0,
                   #             horizontal_flip=True,
                    #            vertical_flip=True,
                     #           rescale=None,
                      #          preprocessing_function=get_random_eraser(v_l=0, v_h=1),
                       #         data_format=None,
                        #        validation_split=0.0
                         #       ))
         #image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
          #    if self.augmentation is not None:
           #  image=self.augmentation.flow(image,shuffle=False).next()

   # def on_epoch_end(self):
    #    """Updates indexes after each epoch"""
     #   if self.shuffle == True:
      #      self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
len(train_df)
# Out:
# 11537

# %%
train_df.head()
# Out:
#               image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 6013    resized/6014.jpg              1  ...                        1              0
# 1029    resized/1030.jpg              1  ...                        0              1
# 2145    resized/2146.jpg              0  ...                        1              0
# 9388    resized/9389.jpg              1  ...                        1              0
# 12746  resized/12748.jpg              0  ...                        0              0
#
# [5 rows x 28 columns]

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df,batch_size=32,
                                augmentation=ImageDataGenerator(rescale=1./255, vertical_flip=True,rotation_range=25,                                                                            
	                                                                                    horizontal_flip=True, ))
                       
                                                            
	                                                                                      

                             
                                                        
                                                          



#train_gen = PersonDataGenerator(train_df, batch_size=32,augmentation=True)
                                
valid_gen = PersonDataGenerator(val_df, batch_size=32, shuffle=False,
                                augmentation=ImageDataGenerator(rescale=1./255))

# %%
# get number of output units from data
images, targets = next(iter(valid_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
#from classification_models.resnet import ResNet18, preprocess_input
import keras.applications.resnet 
from keras.applications.inception_v3 import InceptionV3

from keras.applications.resnet import ResNet50

backbone = InceptionV3(
    weights=None, 
    include_top=False, 
    input_tensor=Input(shape=(224, 224, 3))
)
#backbone = resnet_v1((224,224,3),8)
  


neck = backbone.output
neck = Flatten(name="flatten")(neck)
neck = Dense(512, activation="relu")(neck)


def build_tower(in_layer):
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.0712)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.0712)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.0712)(in_layer)
    neck = Dense(28, activation="relu")(neck)
    
    
    return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="sigmoid",name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("pose", build_tower(neck))


model = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
import numpy as np
import tensorflow as tf
import keras

# %%
EPOCHS=100
LEARNING_RATE=0.3
BATCH_SIZE1=32
BATCH_SIZE2=64
MOMENTUM=0.9

# %%
len_train=len(train_df)
batches_per_epoch = len_train//BATCH_SIZE1

# %%
lr_schedule = lambda t: np.interp([t], [0, (EPOCHS+1)//5, (EPOCHS)], [0.009, LEARNING_RATE, 0.009] )[0]
print(lr_schedule)

#lr_schedule = lambda t: np.interp([t],[0,(EPOCHS+1)//5, (EPOCHS-6)],[0.4, LEARNING_RATE, 0.4])[0]
global_step = tf.train.get_or_create_global_step()
lr_func = lambda: lr_schedule(global_step/batches_per_epoch)/BATCH_SIZE1
#opt.apply_gradients( global_step=global_step)
#opt = tf.train.MomentumOptimizer(lr_func,momentum=MOMENTUM,use_nesterov=False)
# Out:
# <function <lambda> at 0x7f1c1ee23ae8>

# %%
#t = time.time()
#test_set = tf.data.Dataset.from_tensor_slices((val_df)).batch(BATCH_SIZE)

def lr_schedule1(epoch):
    for epoch1 in range((EPOCHS)):
    #if epoch<=24:
      
         if epoch==epoch1:
          break
     
   
   # tf.keras.backend.set_learning_phase(1)
         opt = tf.train.MomentumOptimizer(lr_func,momentum=MOMENTUM,use_nesterov=False)
         #opt1 = SGD(lr=lr_schedule(epoch+1),momentum=0.9)
        #if epoch==epoch1:
         # break
          
    print('epoch:', epoch, 'lr:', lr_schedule(epoch))
    return(lr_schedule(epoch))

      
     
    #tf.keras.backend.set_learning_phase(0)
    
      #  print('epoch:', epoch+1, 'lr:', lr_schedule(epoch+1))
  #return (lr_schedule(epoch+1))
    #else:
   
    #tf.keras.backend.set_learning_phase(1)
     #   opt = tf.train.MomentumOptimizer(lr_func1,momentum=MOMENTUM,use_nesterov=False)
      #  opt = SGD(lr=lr_schedule(epoch+1),momentum=0.9)
        #model.compile(
         #           optimizer=opt,
          #          loss="categorical_crossentropy", 
           #         loss_weights=loss_weights, 
            #        metrics=["accuracy"]
             #       )
        #model.fit_generator(
         #            generator=train_gen,
          #           validation_data=valid_gen,
           #          use_multiprocessing=True,
            #         workers=6, 
             #        epochs=10,
              #       verbose=1,
      
               #      callbacks=callbacks
                #         )
        #LRFind.plot_loss()

       
    #tf.keras.backend.set_learning_phase(0)
       # print('epoch:', epoch+1, 'lr:', lr_schedule1(epoch+1))

# %%
# model.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=32, epochs=10)

# %%
import matplotlib.pyplot as plt
import keras.backend as K
from keras.callbacks import Callback


class LRFinder(Callback):
    
    '''
    A simple callback for finding the optimal learning rate range for your model + dataset. 
    
    # Usage
        ```python
            lr_finder = LRFinder(min_lr=1e-5, 
                                 max_lr=1e-2, 
                                 steps_per_epoch=np.ceil(epoch_size/batch_size), 
                                 epochs=3)
            model.fit(X_train, Y_train, callbacks=[lr_finder])
            
            lr_finder.plot_loss()
        ```
    
    # Arguments
        min_lr: The lower bound of the learning rate range for the experiment.
        max_lr: The upper bound of the learning rate range for the experiment.
        steps_per_epoch: Number of mini-batches in the dataset. Calculated as `np.ceil(epoch_size/batch_size)`. 
        epochs: Number of epochs to run experiment. Usually between 2 and 4 epochs is sufficient. 
        
    # References
        Blog post: jeremyjordan.me/nn-learning-rate
        Original paper: https://arxiv.org/abs/1506.01186
    '''
    
    def __init__(self, min_lr=1e-5, max_lr=1e-2, steps_per_epoch=5.625, epochs=24):
        super().__init__()
        
        self.min_lr = min_lr
        self.max_lr = max_lr
        self.total_iterations = steps_per_epoch * epochs
        self.iteration = 0
        self.history = {}
        
    def clr(self):
        '''Calculate the learning rate.'''
        x = self.iteration / self.total_iterations 
        return self.min_lr + (self.max_lr-self.min_lr) * x
        
    def on_train_begin(self, logs=None):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.min_lr)
        
    def on_batch_end(self, epoch, logs=None):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.iteration += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.iteration)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
            
        K.set_value(self.model.optimizer.lr, self.clr())
 
    def plot_lr(self):
        '''Helper function to quickly inspect the learning rate schedule.'''
        plt.plot(self.history['iterations'], self.history['lr'])
        plt.yscale('log')
        plt.xlabel('Iteration')
        plt.ylabel('Learning rate')
        plt.show()
        
    def plot_loss(self):
        '''Helper function to quickly observe the learning rate experiment results.'''
        plt.plot(self.history['lr'], self.history['loss'])
        plt.xscale('log')
        plt.xlabel('Learning rate')
        plt.ylabel('Loss')
        plt.show()

# %%
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
#for i in range(EPOCHS):
#lr_scheduler = LearningRateScheduler(lr_schedule1)

# %%
#lr_schedule = lambda t: np.interp([t], [0, (EPOCHS+1)//5, (EPOCHS-6)], [0.4, LEARNING_RATE, 0.4])[0]
#global_step = tf.train.get_or_create_global_step()
#opt.apply_gradients(zip(grads, var), global_step=global_step

# %%
def lr_Schedule(epoch):
  
   # lr=0.00148 
    lr = 1e-3
    #if epoch > 70:
     # lr*= 1e-3
    #if epoch > 40:
     #   lr *= 1e-1
    #if epoch > 30:
      #  lr *= 1e-0
    #if epoch > 20:
     #  lr *= 1e-0
    if epoch > 10:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
#from keras.callbacks import ModelCheckpoint,LearningRateScheduler

LRFind=LRFinder(min_lr=1e-5, max_lr=10, steps_per_epoch=(2036//32), epochs=50)
lr_scheduler = LearningRateScheduler(lr_Schedule)
#LRFind.on_tain_begin()
#for i in range(EPOCHS):
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [lr_scheduler,lr_reducer,LRFind]

# %%
losses = {
 	"gender_output": "binary_crossentropy",
 	"image_quality_output": "binary_crossentropy",
 	"age_output": "binary_crossentropy",
 	"weight_output": "binary_crossentropy",
  "bag_output": "binary_crossentropy",
  "pose_output": "binary_crossentropy",
  "footwear_output": "binary_crossentropy",   
  "emotion_output": "binary_crossentropy",
       

 }
loss_weights = {"gender_output": 0.2, "image_quality_output": 0.3, "age_output": 0.5, "weight_output": 0.4,"bag_output":0.3,"pose_output":0.3,"footwear_output":0.3,"emotion_output":0.4}
model.summary()

opt = SGD(lr=0.00142,momentum=0.9)
#opt = tf.train.MomentumOptimizer(lr=lr_schedule(epoch+1),momentum=MOMENTUM,use_nesterov=False)
#opt.( global_step=global_step)
model.compile(
    optimizer=opt,
    loss="binary_crossentropy", 
    #from_logits=True,
    #loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
    loss_weights=loss_weights, 
    metrics=["accuracy"]
)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 111, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 111, 111, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 111, 111, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 109, 109, 32) 9216        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 109, 109, 32) 96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 109, 109, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 109, 109, 64) 18432       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 109, 109, 64) 192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 109, 109, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 54, 54, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 54, 54, 80)   5120        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 54, 54, 80)   240         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 54, 54, 80)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 52, 52, 192)  138240      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 52, 52, 192)  576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 52, 52, 192)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 192)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 25, 25, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 25, 25, 64)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 25, 25, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 25, 25, 48)   9216        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 25, 25, 96)   55296       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 25, 25, 48)   144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 25, 25, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 25, 25, 48)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 25, 25, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 25, 25, 192)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 25, 25, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 25, 25, 64)   76800       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 25, 25, 96)   82944       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 25, 25, 32)   6144        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 25, 25, 64)   192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 25, 25, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 25, 25, 96)   288         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 25, 25, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 25, 25, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 25, 25, 96)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 25, 25, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 25, 25, 256)  0           activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 25, 25, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 25, 25, 64)   192         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 25, 25, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 25, 25, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 25, 25, 96)   55296       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 48)   144         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 25, 25, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 25, 25, 48)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 25, 25, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 25, 25, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 25, 25, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 25, 25, 64)   76800       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 25, 25, 96)   82944       activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 25, 25, 64)   16384       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 64)   192         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 25, 25, 96)   288         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 25, 25, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 25, 25, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 25, 25, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 25, 25, 96)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 25, 25, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 25, 25, 288)  0           activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 25, 25, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 25, 25, 64)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 25, 25, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 25, 25, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 25, 25, 96)   55296       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 25, 25, 48)   144         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 25, 25, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 25, 25, 48)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 25, 25, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 25, 25, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 25, 25, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 25, 25, 64)   76800       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 25, 25, 96)   82944       activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 25, 25, 64)   18432       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 25, 25, 64)   192         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 25, 25, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 25, 25, 96)   288         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 25, 25, 64)   192         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 25, 25, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 25, 25, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 25, 25, 96)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 25, 25, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 25, 25, 288)  0           activation_20[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 25, 25, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 25, 25, 64)   192         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 25, 25, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 25, 25, 96)   55296       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 25, 25, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 25, 25, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 12, 12, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 12, 12, 96)   82944       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 12, 12, 384)  1152        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 12, 12, 96)   288         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 12, 12, 384)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 96)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 12, 12, 768)  0           activation_27[0][0]
#                                                                  activation_30[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 12, 12, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 12, 12, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 12, 12, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 12, 12, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 12, 12, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 12, 12, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 12, 12, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 12, 12, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 12, 12, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 12, 12, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 12, 12, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 12, 12, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 12, 12, 128)  114688      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 12, 12, 128)  114688      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 12, 12, 128)  384         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 12, 12, 128)  384         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 12, 12, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 12, 12, 128)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 12, 12, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 12, 12, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 12, 12, 192)  172032      activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 12, 12, 192)  172032      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 12, 12, 192)  576         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 12, 12, 192)  576         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 12, 12, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 12, 12, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 12, 12, 192)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 12, 12, 192)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 12, 12, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 12, 12, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 12, 12, 768)  0           activation_31[0][0]
#                                                                  activation_34[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 12, 12, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 12, 12, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 12, 12, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 12, 12, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 12, 12, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 12, 12, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 12, 12, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 12, 12, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 12, 12, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 12, 12, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 12, 12, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 12, 12, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 12, 12, 160)  179200      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 12, 12, 160)  179200      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 12, 12, 160)  480         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 12, 12, 160)  480         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 12, 12, 160)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 12, 12, 160)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 12, 12, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 12, 12, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 12, 12, 192)  215040      activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 12, 12, 192)  215040      activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 12, 12, 192)  576         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 12, 12, 192)  576         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 12, 12, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 12, 12, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 12, 12, 192)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 12, 12, 192)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 12, 12, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 12, 12, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 12, 12, 768)  0           activation_41[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 12, 12, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 12, 12, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 12, 12, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 12, 12, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 12, 12, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 12, 12, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 12, 12, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 12, 12, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 12, 12, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 12, 12, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 12, 12, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 12, 12, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 12, 12, 160)  179200      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 12, 12, 160)  179200      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 12, 12, 160)  480         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 12, 12, 160)  480         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 12, 12, 160)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 12, 12, 160)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 12, 12, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 12, 12, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 12, 12, 192)  215040      activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 12, 12, 192)  215040      activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 12, 12, 192)  576         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 12, 12, 192)  576         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 12, 12, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 12, 12, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 12, 12, 192)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 12, 12, 192)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 12, 12, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 12, 12, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 12, 12, 768)  0           activation_51[0][0]
#                                                                  activation_54[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_60[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 12, 12, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 12, 12, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 12, 12, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 12, 12, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 12, 12, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 12, 12, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 12, 12, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 12, 12, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 12, 12, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 12, 12, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 12, 12, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 12, 12, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 12, 12, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 12, 12, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 12, 12, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 12, 12, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 12, 12, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 12, 12, 192)  258048      activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 12, 12, 192)  258048      activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 12, 12, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 12, 12, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 12, 12, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 12, 12, 192)  576         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 12, 12, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 12, 12, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 12, 12, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 12, 12, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 12, 12, 768)  0           activation_61[0][0]
#                                                                  activation_64[0][0]
#                                                                  activation_69[0][0]
#                                                                  activation_70[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 5, 5, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 5, 5, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 5, 5, 384)    1152        conv2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 5, 5, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 5, 5, 384)    1152        conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 5, 5, 192)    245760      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 5, 5, 320)    960         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 5, 5, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 5, 5, 384)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 5, 5, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 5, 5, 384)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 5, 5, 192)    576         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 5, 5, 320)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 5, 5, 768)    0           activation_79[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 5, 5, 768)    0           activation_83[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 5, 5, 192)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 5, 5, 2048)   0           activation_77[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_85[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 5, 5, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 5, 5, 448)    1344        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 5, 5, 448)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 5, 5, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 5, 5, 384)    1548288     activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 5, 5, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 5, 5, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 5, 5, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 5, 5, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 5, 5, 384)    442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 5, 5, 384)    442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 5, 5, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 5, 5, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 5, 5, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 5, 5, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 5, 5, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 5, 5, 384)    1152        conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 5, 5, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 5, 5, 384)    1152        conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 5, 5, 192)    393216      average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 5, 5, 320)    960         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 5, 5, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 5, 5, 384)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 5, 5, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 5, 5, 384)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 5, 5, 192)    576         conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 5, 5, 320)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 5, 5, 768)    0           activation_88[0][0]
#                                                                  activation_89[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 5, 5, 768)    0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 5, 5, 192)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 5, 5, 2048)   0           activation_86[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_94[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 51200)        0           mixed10[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          26214912    flatten[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 28)           14364       dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 28)           14364       dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 28)           14364       dropout_9[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 28)           14364       dropout_12[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 28)           14364       dropout_15[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 28)           14364       dropout_18[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 28)           14364       dropout_24[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 28)           14364       dropout_21[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            58          dense_4[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Dense)    (None, 3)            87          dense_7[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            145         dense_10[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            116         dense_13[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            87          dense_16[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            87          dense_19[0][0]
# __________________________________________________________________________________________________
# pose_output (Dense)             (None, 3)            87          dense_25[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            116         dense_22[0][0]
# ==================================================================================================
# Total params: 48,133,391
# Trainable params: 48,098,959
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
#for i in range(EPOCHS):
model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    validation_steps=2036//32,
    use_multiprocessing=True,
    workers=2, 
    epochs=100,
    verbose=1,
   # callbacks=callbacks
    )
LRFind.plot_loss()
# Out:
# Epoch 1/100
# 360/360 [==============================] - 195s 541ms/step - loss: 1.3905 - gender_output_loss: 0.6869 - image_quality_output_loss: 0.6034 - age_output_loss: 0.4605 - weight_output_loss: 0.4227 - bag_output_loss: 0.5506 - footwear_output_loss: 0.6128 - pose_output_loss: 0.5629 - emotion_output_loss: 0.3872 - gender_output_acc: 0.5598 - image_quality_output_acc: 0.6667 - age_output_acc: 0.8000 - weight_output_acc: 0.8184 - bag_output_acc: 0.7083 - footwear_output_acc: 0.6667 - pose_output_acc: 0.6667 - emotion_output_acc: 0.8553 - val_loss: 1.3876 - val_gender_output_loss: 0.6810 - val_image_quality_output_loss: 0.5981 - val_age_output_loss: 0.4627 - val_weight_output_loss: 0.4285 - val_bag_output_loss: 0.5517 - val_footwear_output_loss: 0.6085 - val_pose_output_loss: 0.5650 - val_emotion_output_loss: 0.3791 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.6667 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.6667 - val_emotion_output_acc: 0.8594
# Epoch 2/100
# 360/360 [==============================] - 173s 482ms/step - loss: 1.3864 - gender_output_loss: 0.6867 - image_quality_output_loss: 0.5978 - age_output_loss: 0.4595 - weight_output_loss: 0.4222 - bag_output_loss: 0.5501 - footwear_output_loss: 0.6119 - pose_output_loss: 0.5591 - emotion_output_loss: 0.3869 - gender_output_acc: 0.5599 - image_quality_output_acc: 0.6667 - age_output_acc: 0.8000 - weight_output_acc: 0.8183 - bag_output_acc: 0.7084 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7062 - emotion_output_acc: 0.8554 - val_loss: 1.3840 - val_gender_output_loss: 0.6810 - val_image_quality_output_loss: 0.5931 - val_age_output_loss: 0.4619 - val_weight_output_loss: 0.4279 - val_bag_output_loss: 0.5513 - val_footwear_output_loss: 0.6078 - val_pose_output_loss: 0.5616 - val_emotion_output_loss: 0.3791 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.6667 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 3/100
# 360/360 [==============================] - 173s 481ms/step - loss: 1.3832 - gender_output_loss: 0.6865 - image_quality_output_loss: 0.5934 - age_output_loss: 0.4588 - weight_output_loss: 0.4217 - bag_output_loss: 0.5497 - footwear_output_loss: 0.6112 - pose_output_loss: 0.5561 - emotion_output_loss: 0.3868 - gender_output_acc: 0.5601 - image_quality_output_acc: 0.6667 - age_output_acc: 0.8000 - weight_output_acc: 0.8183 - bag_output_acc: 0.7082 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7454 - emotion_output_acc: 0.8554 - val_loss: 1.3812 - val_gender_output_loss: 0.6810 - val_image_quality_output_loss: 0.5892 - val_age_output_loss: 0.4612 - val_weight_output_loss: 0.4274 - val_bag_output_loss: 0.5510 - val_footwear_output_loss: 0.6072 - val_pose_output_loss: 0.5590 - val_emotion_output_loss: 0.3790 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.6667 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 4/100
# 360/360 [==============================] - 173s 481ms/step - loss: 1.3806 - gender_output_loss: 0.6865 - image_quality_output_loss: 0.5900 - age_output_loss: 0.4582 - weight_output_loss: 0.4213 - bag_output_loss: 0.5493 - footwear_output_loss: 0.6107 - pose_output_loss: 0.5538 - emotion_output_loss: 0.3865 - gender_output_acc: 0.5595 - image_quality_output_acc: 0.6667 - age_output_acc: 0.8000 - weight_output_acc: 0.8182 - bag_output_acc: 0.7082 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7453 - emotion_output_acc: 0.8555 - val_loss: 1.3790 - val_gender_output_loss: 0.6810 - val_image_quality_output_loss: 0.5861 - val_age_output_loss: 0.4606 - val_weight_output_loss: 0.4270 - val_bag_output_loss: 0.5508 - val_footwear_output_loss: 0.6067 - val_pose_output_loss: 0.5570 - val_emotion_output_loss: 0.3789 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.6667 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 5/100
# 360/360 [==============================] - 174s 484ms/step - loss: 1.3786 - gender_output_loss: 0.6863 - image_quality_output_loss: 0.5873 - age_output_loss: 0.4577 - weight_output_loss: 0.4209 - bag_output_loss: 0.5490 - footwear_output_loss: 0.6103 - pose_output_loss: 0.5519 - emotion_output_loss: 0.3864 - gender_output_acc: 0.5598 - image_quality_output_acc: 0.6667 - age_output_acc: 0.8000 - weight_output_acc: 0.8183 - bag_output_acc: 0.7082 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7453 - emotion_output_acc: 0.8555 - val_loss: 1.3773 - val_gender_output_loss: 0.6810 - val_image_quality_output_loss: 0.5837 - val_age_output_loss: 0.4601 - val_weight_output_loss: 0.4267 - val_bag_output_loss: 0.5506 - val_footwear_output_loss: 0.6063 - val_pose_output_loss: 0.5554 - val_emotion_output_loss: 0.3789 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.6667 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 6/100
# 360/360 [==============================] - 173s 480ms/step - loss: 1.3769 - gender_output_loss: 0.6862 - image_quality_output_loss: 0.5851 - age_output_loss: 0.4571 - weight_output_loss: 0.4205 - bag_output_loss: 0.5487 - footwear_output_loss: 0.6099 - pose_output_loss: 0.5504 - emotion_output_loss: 0.3865 - gender_output_acc: 0.5598 - image_quality_output_acc: 0.6667 - age_output_acc: 0.8000 - weight_output_acc: 0.8183 - bag_output_acc: 0.7083 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7454 - emotion_output_acc: 0.8553 - val_loss: 1.3759 - val_gender_output_loss: 0.6811 - val_image_quality_output_loss: 0.5818 - val_age_output_loss: 0.4597 - val_weight_output_loss: 0.4264 - val_bag_output_loss: 0.5505 - val_footwear_output_loss: 0.6061 - val_pose_output_loss: 0.5541 - val_emotion_output_loss: 0.3788 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.6667 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 7/100
# 360/360 [==============================] - 175s 485ms/step - loss: 1.3756 - gender_output_loss: 0.6861 - image_quality_output_loss: 0.5835 - age_output_loss: 0.4569 - weight_output_loss: 0.4204 - bag_output_loss: 0.5485 - footwear_output_loss: 0.6097 - pose_output_loss: 0.5494 - emotion_output_loss: 0.3861 - gender_output_acc: 0.5600 - image_quality_output_acc: 0.6667 - age_output_acc: 0.8000 - weight_output_acc: 0.8182 - bag_output_acc: 0.7083 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7453 - emotion_output_acc: 0.8555 - val_loss: 1.3748 - val_gender_output_loss: 0.6811 - val_image_quality_output_loss: 0.5803 - val_age_output_loss: 0.4593 - val_weight_output_loss: 0.4261 - val_bag_output_loss: 0.5504 - val_footwear_output_loss: 0.6058 - val_pose_output_loss: 0.5531 - val_emotion_output_loss: 0.3788 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.6667 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 8/100
# 360/360 [==============================] - 173s 482ms/step - loss: 1.3746 - gender_output_loss: 0.6862 - image_quality_output_loss: 0.5823 - age_output_loss: 0.4566 - weight_output_loss: 0.4200 - bag_output_loss: 0.5484 - footwear_output_loss: 0.6094 - pose_output_loss: 0.5484 - emotion_output_loss: 0.3863 - gender_output_acc: 0.5596 - image_quality_output_acc: 0.6667 - age_output_acc: 0.8000 - weight_output_acc: 0.8183 - bag_output_acc: 0.7083 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7453 - emotion_output_acc: 0.8553 - val_loss: 1.3739 - val_gender_output_loss: 0.6812 - val_image_quality_output_loss: 0.5791 - val_age_output_loss: 0.4591 - val_weight_output_loss: 0.4259 - val_bag_output_loss: 0.5504 - val_footwear_output_loss: 0.6057 - val_pose_output_loss: 0.5523 - val_emotion_output_loss: 0.3787 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.6667 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 9/100
# 360/360 [==============================] - 173s 480ms/step - loss: 1.3739 - gender_output_loss: 0.6861 - image_quality_output_loss: 0.5812 - age_output_loss: 0.4564 - weight_output_loss: 0.4200 - bag_output_loss: 0.5485 - footwear_output_loss: 0.6093 - pose_output_loss: 0.5476 - emotion_output_loss: 0.3863 - gender_output_acc: 0.5598 - image_quality_output_acc: 0.6667 - age_output_acc: 0.8000 - weight_output_acc: 0.8183 - bag_output_acc: 0.7080 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7455 - emotion_output_acc: 0.8553 - val_loss: 1.3732 - val_gender_output_loss: 0.6812 - val_image_quality_output_loss: 0.5782 - val_age_output_loss: 0.4588 - val_weight_output_loss: 0.4258 - val_bag_output_loss: 0.5503 - val_footwear_output_loss: 0.6055 - val_pose_output_loss: 0.5517 - val_emotion_output_loss: 0.3787 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.6667 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 10/100
# 360/360 [==============================] - 173s 481ms/step - loss: 1.3732 - gender_output_loss: 0.6861 - image_quality_output_loss: 0.5803 - age_output_loss: 0.4561 - weight_output_loss: 0.4199 - bag_output_loss: 0.5483 - footwear_output_loss: 0.6092 - pose_output_loss: 0.5470 - emotion_output_loss: 0.3862 - gender_output_acc: 0.5598 - image_quality_output_acc: 0.6694 - age_output_acc: 0.8000 - weight_output_acc: 0.8182 - bag_output_acc: 0.7083 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7455 - emotion_output_acc: 0.8553 - val_loss: 1.3726 - val_gender_output_loss: 0.6812 - val_image_quality_output_loss: 0.5774 - val_age_output_loss: 0.4586 - val_weight_output_loss: 0.4256 - val_bag_output_loss: 0.5503 - val_footwear_output_loss: 0.6054 - val_pose_output_loss: 0.5512 - val_emotion_output_loss: 0.3787 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.7030 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 11/100
# 360/360 [==============================] - 172s 478ms/step - loss: 1.3726 - gender_output_loss: 0.6861 - image_quality_output_loss: 0.5797 - age_output_loss: 0.4560 - weight_output_loss: 0.4198 - bag_output_loss: 0.5481 - footwear_output_loss: 0.6091 - pose_output_loss: 0.5467 - emotion_output_loss: 0.3861 - gender_output_acc: 0.5597 - image_quality_output_acc: 0.7018 - age_output_acc: 0.8000 - weight_output_acc: 0.8182 - bag_output_acc: 0.7083 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7454 - emotion_output_acc: 0.8553 - val_loss: 1.3721 - val_gender_output_loss: 0.6813 - val_image_quality_output_loss: 0.5768 - val_age_output_loss: 0.4584 - val_weight_output_loss: 0.4255 - val_bag_output_loss: 0.5503 - val_footwear_output_loss: 0.6054 - val_pose_output_loss: 0.5508 - val_emotion_output_loss: 0.3786 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.7030 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 12/100
# 360/360 [==============================] - 173s 479ms/step - loss: 1.3720 - gender_output_loss: 0.6860 - image_quality_output_loss: 0.5793 - age_output_loss: 0.4558 - weight_output_loss: 0.4193 - bag_output_loss: 0.5481 - footwear_output_loss: 0.6089 - pose_output_loss: 0.5465 - emotion_output_loss: 0.3859 - gender_output_acc: 0.5599 - image_quality_output_acc: 0.7017 - age_output_acc: 0.8000 - weight_output_acc: 0.8185 - bag_output_acc: 0.7082 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7451 - emotion_output_acc: 0.8554 - val_loss: 1.3717 - val_gender_output_loss: 0.6813 - val_image_quality_output_loss: 0.5764 - val_age_output_loss: 0.4583 - val_weight_output_loss: 0.4254 - val_bag_output_loss: 0.5503 - val_footwear_output_loss: 0.6053 - val_pose_output_loss: 0.5505 - val_emotion_output_loss: 0.3786 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.7030 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 13/100
# 360/360 [==============================] - 173s 481ms/step - loss: 1.3717 - gender_output_loss: 0.6860 - image_quality_output_loss: 0.5788 - age_output_loss: 0.4557 - weight_output_loss: 0.4193 - bag_output_loss: 0.5482 - footwear_output_loss: 0.6090 - pose_output_loss: 0.5458 - emotion_output_loss: 0.3861 - gender_output_acc: 0.5601 - image_quality_output_acc: 0.7018 - age_output_acc: 0.8000 - weight_output_acc: 0.8185 - bag_output_acc: 0.7080 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7457 - emotion_output_acc: 0.8553 - val_loss: 1.3714 - val_gender_output_loss: 0.6814 - val_image_quality_output_loss: 0.5760 - val_age_output_loss: 0.4581 - val_weight_output_loss: 0.4253 - val_bag_output_loss: 0.5503 - val_footwear_output_loss: 0.6052 - val_pose_output_loss: 0.5502 - val_emotion_output_loss: 0.3786 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.7030 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 14/100
# 360/360 [==============================] - 173s 480ms/step - loss: 1.3715 - gender_output_loss: 0.6860 - image_quality_output_loss: 0.5785 - age_output_loss: 0.4556 - weight_output_loss: 0.4197 - bag_output_loss: 0.5480 - footwear_output_loss: 0.6089 - pose_output_loss: 0.5458 - emotion_output_loss: 0.3856 - gender_output_acc: 0.5597 - image_quality_output_acc: 0.7017 - age_output_acc: 0.8000 - weight_output_acc: 0.8181 - bag_output_acc: 0.7082 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7453 - emotion_output_acc: 0.8556 - val_loss: 1.3712 - val_gender_output_loss: 0.6814 - val_image_quality_output_loss: 0.5757 - val_age_output_loss: 0.4580 - val_weight_output_loss: 0.4253 - val_bag_output_loss: 0.5503 - val_footwear_output_loss: 0.6052 - val_pose_output_loss: 0.5500 - val_emotion_output_loss: 0.3786 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.7030 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 15/100
# 360/360 [==============================] - 172s 477ms/step - loss: 1.3712 - gender_output_loss: 0.6860 - image_quality_output_loss: 0.5782 - age_output_loss: 0.4555 - weight_output_loss: 0.4194 - bag_output_loss: 0.5478 - footwear_output_loss: 0.6089 - pose_output_loss: 0.5455 - emotion_output_loss: 0.3858 - gender_output_acc: 0.5599 - image_quality_output_acc: 0.7019 - age_output_acc: 0.8000 - weight_output_acc: 0.8183 - bag_output_acc: 0.7084 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7454 - emotion_output_acc: 0.8554 - val_loss: 1.3710 - val_gender_output_loss: 0.6814 - val_image_quality_output_loss: 0.5755 - val_age_output_loss: 0.4579 - val_weight_output_loss: 0.4252 - val_bag_output_loss: 0.5503 - val_footwear_output_loss: 0.6052 - val_pose_output_loss: 0.5498 - val_emotion_output_loss: 0.3786 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.7030 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 16/100
# 360/360 [==============================] - 171s 476ms/step - loss: 1.3711 - gender_output_loss: 0.6861 - image_quality_output_loss: 0.5779 - age_output_loss: 0.4553 - weight_output_loss: 0.4194 - bag_output_loss: 0.5479 - footwear_output_loss: 0.6088 - pose_output_loss: 0.5454 - emotion_output_loss: 0.3860 - gender_output_acc: 0.5595 - image_quality_output_acc: 0.7020 - age_output_acc: 0.8000 - weight_output_acc: 0.8183 - bag_output_acc: 0.7082 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7454 - emotion_output_acc: 0.8553 - val_loss: 1.3708 - val_gender_output_loss: 0.6814 - val_image_quality_output_loss: 0.5753 - val_age_output_loss: 0.4578 - val_weight_output_loss: 0.4252 - val_bag_output_loss: 0.5503 - val_footwear_output_loss: 0.6051 - val_pose_output_loss: 0.5497 - val_emotion_output_loss: 0.3785 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.7030 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 17/100
# 360/360 [==============================] - 172s 477ms/step - loss: 1.3708 - gender_output_loss: 0.6860 - image_quality_output_loss: 0.5780 - age_output_loss: 0.4553 - weight_output_loss: 0.4192 - bag_output_loss: 0.5480 - footwear_output_loss: 0.6088 - pose_output_loss: 0.5452 - emotion_output_loss: 0.3857 - gender_output_acc: 0.5599 - image_quality_output_acc: 0.7017 - age_output_acc: 0.8000 - weight_output_acc: 0.8184 - bag_output_acc: 0.7081 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7455 - emotion_output_acc: 0.8554 - val_loss: 1.3707 - val_gender_output_loss: 0.6814 - val_image_quality_output_loss: 0.5751 - val_age_output_loss: 0.4577 - val_weight_output_loss: 0.4251 - val_bag_output_loss: 0.5503 - val_footwear_output_loss: 0.6051 - val_pose_output_loss: 0.5496 - val_emotion_output_loss: 0.3785 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.7030 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 18/100
# 360/360 [==============================] - 171s 476ms/step - loss: 1.3707 - gender_output_loss: 0.6860 - image_quality_output_loss: 0.5777 - age_output_loss: 0.4552 - weight_output_loss: 0.4193 - bag_output_loss: 0.5479 - footwear_output_loss: 0.6088 - pose_output_loss: 0.5452 - emotion_output_loss: 0.3858 - gender_output_acc: 0.5598 - image_quality_output_acc: 0.7019 - age_output_acc: 0.8000 - weight_output_acc: 0.8183 - bag_output_acc: 0.7082 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7454 - emotion_output_acc: 0.8553 - val_loss: 1.3706 - val_gender_output_loss: 0.6815 - val_image_quality_output_loss: 0.5750 - val_age_output_loss: 0.4576 - val_weight_output_loss: 0.4251 - val_bag_output_loss: 0.5503 - val_footwear_output_loss: 0.6051 - val_pose_output_loss: 0.5495 - val_emotion_output_loss: 0.3785 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.7030 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 19/100
# 360/360 [==============================] - 175s 486ms/step - loss: 1.3707 - gender_output_loss: 0.6861 - image_quality_output_loss: 0.5775 - age_output_loss: 0.4552 - weight_output_loss: 0.4193 - bag_output_loss: 0.5480 - footwear_output_loss: 0.6087 - pose_output_loss: 0.5452 - emotion_output_loss: 0.3858 - gender_output_acc: 0.5595 - image_quality_output_acc: 0.7020 - age_output_acc: 0.8000 - weight_output_acc: 0.8183 - bag_output_acc: 0.7082 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7453 - emotion_output_acc: 0.8553 - val_loss: 1.3705 - val_gender_output_loss: 0.6815 - val_image_quality_output_loss: 0.5749 - val_age_output_loss: 0.4576 - val_weight_output_loss: 0.4251 - val_bag_output_loss: 0.5504 - val_footwear_output_loss: 0.6051 - val_pose_output_loss: 0.5495 - val_emotion_output_loss: 0.3785 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.7030 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 20/100
# 360/360 [==============================] - 176s 488ms/step - loss: 1.3704 - gender_output_loss: 0.6859 - image_quality_output_loss: 0.5776 - age_output_loss: 0.4551 - weight_output_loss: 0.4192 - bag_output_loss: 0.5480 - footwear_output_loss: 0.6087 - pose_output_loss: 0.5451 - emotion_output_loss: 0.3855 - gender_output_acc: 0.5601 - image_quality_output_acc: 0.7019 - age_output_acc: 0.8000 - weight_output_acc: 0.8183 - bag_output_acc: 0.7081 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7453 - emotion_output_acc: 0.8555 - val_loss: 1.3704 - val_gender_output_loss: 0.6815 - val_image_quality_output_loss: 0.5748 - val_age_output_loss: 0.4575 - val_weight_output_loss: 0.4250 - val_bag_output_loss: 0.5504 - val_footwear_output_loss: 0.6051 - val_pose_output_loss: 0.5494 - val_emotion_output_loss: 0.3785 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.7030 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 21/100
# 360/360 [==============================] - 174s 484ms/step - loss: 1.3703 - gender_output_loss: 0.6859 - image_quality_output_loss: 0.5774 - age_output_loss: 0.4551 - weight_output_loss: 0.4192 - bag_output_loss: 0.5478 - footwear_output_loss: 0.6087 - pose_output_loss: 0.5449 - emotion_output_loss: 0.3856 - gender_output_acc: 0.5602 - image_quality_output_acc: 0.7020 - age_output_acc: 0.8000 - weight_output_acc: 0.8183 - bag_output_acc: 0.7083 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7454 - emotion_output_acc: 0.8554 - val_loss: 1.3703 - val_gender_output_loss: 0.6815 - val_image_quality_output_loss: 0.5747 - val_age_output_loss: 0.4575 - val_weight_output_loss: 0.4250 - val_bag_output_loss: 0.5504 - val_footwear_output_loss: 0.6051 - val_pose_output_loss: 0.5494 - val_emotion_output_loss: 0.3785 - val_gender_output_acc: 0.5779 - val_image_quality_output_acc: 0.7030 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7133 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8594
# Epoch 22/100
# 216/360 [=================>............] - ETA: 1:04 - loss: 1.3695 - gender_output_loss: 0.6869 - image_quality_output_loss: 0.5735 - age_output_loss: 0.4547 - weight_output_loss: 0.4153 - bag_output_loss: 0.5520 - footwear_output_loss: 0.6077 - pose_output_loss: 0.5443 - emotion_output_loss: 0.3885 - gender_output_acc: 0.5563 - image_quality_output_acc: 0.7075 - age_output_acc: 0.8000 - weight_output_acc: 0.8206 - bag_output_acc: 0.7036 - footwear_output_acc: 0.6667 - pose_output_acc: 0.7465 - emotion_output_acc: 0.8534

# %%
model
