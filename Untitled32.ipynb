# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepaManjunath/Assignment1/blob/master/Untitled32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q '/content/gdrive/My Drive/EIP4/hvc_data.zip'
# look for `hvc_annotations.csv` file and `resized` dir
# %ls '/content/gdrive/My Drive/EIP4/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# hvc_data/  hvc_data.zip

# %%
# %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation , Dropout
from keras.layers import AveragePooling2D, Input, Flatten ,GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()
# Out:
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
# 3    male         Good  45-55  ...        Neutral  Front-Frontish  resized/4.jpg
# 4  female         Good  35-45  ...        Neutral  Front-Frontish  resized/5.jpg
#
# [5 rows x 9 columns]

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
import numpy as np


def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=32, shuffle=True,augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.batch_size = batch_size
        #self.labels = labels
        #self.list_IDs = list_IDs
        #self.n_channels = n_channels
        #self.n_classes = n_classes
        #self.shuffle = shuffle
        self.on_epoch_end()
        self.augmentation=augmentation
        
        
        #self.on_epoch_end()

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

            
    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        images = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
       # if self.augmentation is not None:
        #   images=self.augmentation.flow(images,shuffle=False).next()
        target = {
                       "gender_output": items[_gender_cols_].values,
                       "image_quality_output": items[_imagequality_cols_].values,
                       "age_output": items[_age_cols_].values,
                       "weight_output": items[_weight_cols_].values,
                       "bag_output": items[_carryingbag_cols_].values,
                       "pose_output": items[_bodypose_cols_].values,
                       "footwear_output": items[_footwear_cols_].values,
                       "emotion_output": items[_emotion_cols_].values,
        }
        return images, target
    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
            
   # def __PersonDataGenerator(self,train_df,batch_size=32,augmentation):
      
    #     train_gen = np.stack(train_df, batch_size=32,augmentation=ImageDataGenerator(featurewise_center=False,
     #                           samplewise_center=False,
      #                          featurewise_std_normalization=False,
       #                         samplewise_std_normalization=False,
        #                        zca_whitening=False,
         #                       zca_epsilon=1e-06,
          #                      rotation_range=25,
           #                     width_shift_range=0.1,
            #                    height_shift_range=0.1,
             #                   brightness_range=None,
              #                  shear_range=0.0,
               #                 zoom_range=0.0,
                #                channel_shift_range=0.0,
                 #               fill_mode='nearest',
                  #              cval=0.0,
                   #             horizontal_flip=True,
                    #            vertical_flip=True,
                     #           rescale=None,
                      #          preprocessing_function=get_random_eraser(v_l=0, v_h=1),
                       #         data_format=None,
                        #        validation_split=0.0
                         #       ))
         #image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
          #    if self.augmentation is not None:
           #  image=self.augmentation.flow(image,shuffle=False).next()

   # def on_epoch_end(self):
    #    """Updates indexes after each epoch"""
     #   if self.shuffle == True:
      #      self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
len(train_df)
# Out:
# 11537

# %%
train_df.head()
# Out:
#             image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 7537  resized/7538.jpg              1  ...                        1              0
# 7680  resized/7681.jpg              0  ...                        0              1
# 8368  resized/8369.jpg              0  ...                        1              0
# 7600  resized/7601.jpg              1  ...                        0              1
# 9477  resized/9478.jpg              0  ...                        0              0
#
# [5 rows x 28 columns]

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df,batch_size=32,augmentation=ImageDataGenerator(vertical_flip=True,horizontal_flip=True,rescale=1./255))
	                                                                                      

                             
                                                        
                                                          



#train_gen = PersonDataGenerator(train_df, batch_size=32,augmentation=True)
                                
valid_gen = PersonDataGenerator(val_df, batch_size=64, shuffle=False,augmentation=ImageDataGenerator(rescale=1./255))

# %%
# get number of output units from data
images, targets = next(iter(train_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# Training parameters
batch_size = 32  # orig paper trained all networks with batch_size=128
epochs = 24
num_classes = 8

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)


def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, num_classes=8):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    outputs = (x)
   # outputs = Dense(num_classes,
                    #activation='softmax',
                    #kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
#from classification_models.resnet import ResNet18, preprocess_input
import keras.applications.resnet 
from keras.applications.inception_v3 import InceptionV3

from keras.applications.resnet import ResNet50

backbone = InceptionV3(
    weights=None, 
    include_top=False, 
    input_tensor=Input(shape=(224, 224, 3))
)
#backbone = resnet_v1((224,224,3),8)
  


neck = backbone.output
neck = Flatten(name="flatten")(neck)
neck = Dense(512, activation="relu")(neck)


def build_tower(in_layer):
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.0955)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.0955)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = BatchNormalization(momentum=0.355)(in_layer)
    neck = Dropout(0.0955)(in_layer)
    neck = Dense(28, activation="relu")(neck)
    
    
    return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="sigmoid",name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("pose", build_tower(neck))


model = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
import numpy as np
import tensorflow as tf
import keras

# %%
EPOCHS=100
LEARNING_RATE=0.3
BATCH_SIZE1=32
BATCH_SIZE2=64
MOMENTUM=0.9

# %%
len_train=len(train_df)
batches_per_epoch = len_train//BATCH_SIZE1

# %%
lr_schedule = lambda t: np.interp([t], [0, (EPOCHS+1)//5, (EPOCHS)], [0.009, LEARNING_RATE, 0.009] )[0]
print(lr_schedule)

#lr_schedule = lambda t: np.interp([t],[0,(EPOCHS+1)//5, (EPOCHS-6)],[0.4, LEARNING_RATE, 0.4])[0]
global_step = tf.train.get_or_create_global_step()
lr_func = lambda: lr_schedule(global_step/batches_per_epoch)/BATCH_SIZE1
#opt.apply_gradients( global_step=global_step)
#opt = tf.train.MomentumOptimizer(lr_func,momentum=MOMENTUM,use_nesterov=False)
# Out:
# <function <lambda> at 0x7fb1f200cc80>

# %%
#t = time.time()
#test_set = tf.data.Dataset.from_tensor_slices((val_df)).batch(BATCH_SIZE)

def lr_schedule1(epoch):
    for epoch1 in range((EPOCHS)):
    #if epoch<=24:
      
         if epoch==epoch1:
          break
     
   
   # tf.keras.backend.set_learning_phase(1)
         opt = tf.train.MomentumOptimizer(lr_func,momentum=MOMENTUM,use_nesterov=False)
         #opt1 = SGD(lr=lr_schedule(epoch+1),momentum=0.9)
        #if epoch==epoch1:
         # break
          
    print('epoch:', epoch, 'lr:', lr_schedule(epoch))
    return(lr_schedule(epoch))

      
     
    #tf.keras.backend.set_learning_phase(0)
    
      #  print('epoch:', epoch+1, 'lr:', lr_schedule(epoch+1))
  #return (lr_schedule(epoch+1))
    #else:
   
    #tf.keras.backend.set_learning_phase(1)
     #   opt = tf.train.MomentumOptimizer(lr_func1,momentum=MOMENTUM,use_nesterov=False)
      #  opt = SGD(lr=lr_schedule(epoch+1),momentum=0.9)
        #model.compile(
         #           optimizer=opt,
          #          loss="categorical_crossentropy", 
           #         loss_weights=loss_weights, 
            #        metrics=["accuracy"]
             #       )
        #model.fit_generator(
         #            generator=train_gen,
          #           validation_data=valid_gen,
           #          use_multiprocessing=True,
            #         workers=6, 
             #        epochs=10,
              #       verbose=1,
      
               #      callbacks=callbacks
                #         )
        #LRFind.plot_loss()

       
    #tf.keras.backend.set_learning_phase(0)
       # print('epoch:', epoch+1, 'lr:', lr_schedule1(epoch+1))

# %%
losses = {
 	"gender_output": "binary_crossentropy",
 	"image_quality_output": "binary_crossentropy",
 	"age_output": "binary_crossentropy",
 	"weight_output": "binary_crossentropy",
  "bag_output": "binary_crossentropy",
  "pose_output": "binary_crossentropy",
  "footwear_output": "binary_crossentropy",   
  "emotion_output": "binary_crossentropy",
       

 }
loss_weights = {"gender_output": 0.2, "image_quality_output": 0.3, "age_output": 0.5, "weight_output": 0.4,"bag_output":0.3,"pose_output":0.3,"footwear_output":0.3,"emotion_output":0.4}
model.summary()

opt = SGD(lr=0.00148,momentum=0.9)
#opt = tf.train.MomentumOptimizer(lr=lr_schedule(epoch+1),momentum=MOMENTUM,use_nesterov=False)
#opt.( global_step=global_step)
model.compile(
    optimizer=opt,
    loss="binary_crossentropy", 
    #from_logits=True,
    #loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
    loss_weights=loss_weights, 
    metrics=["accuracy"]
)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 111, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 111, 111, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 111, 111, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 109, 109, 32) 9216        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 109, 109, 32) 96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 109, 109, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 109, 109, 64) 18432       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 109, 109, 64) 192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 109, 109, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 54, 54, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 54, 54, 80)   5120        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 54, 54, 80)   240         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 54, 54, 80)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 52, 52, 192)  138240      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 52, 52, 192)  576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 52, 52, 192)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 192)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 25, 25, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 25, 25, 64)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 25, 25, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 25, 25, 48)   9216        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 25, 25, 96)   55296       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 25, 25, 48)   144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 25, 25, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 25, 25, 48)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 25, 25, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 25, 25, 192)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 25, 25, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 25, 25, 64)   76800       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 25, 25, 96)   82944       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 25, 25, 32)   6144        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 25, 25, 64)   192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 25, 25, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 25, 25, 96)   288         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 25, 25, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 25, 25, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 25, 25, 96)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 25, 25, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 25, 25, 256)  0           activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 25, 25, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 25, 25, 64)   192         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 25, 25, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 25, 25, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 25, 25, 96)   55296       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 48)   144         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 25, 25, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 25, 25, 48)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 25, 25, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 25, 25, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 25, 25, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 25, 25, 64)   76800       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 25, 25, 96)   82944       activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 25, 25, 64)   16384       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 64)   192         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 25, 25, 96)   288         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 25, 25, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 25, 25, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 25, 25, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 25, 25, 96)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 25, 25, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 25, 25, 288)  0           activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 25, 25, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 25, 25, 64)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 25, 25, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 25, 25, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 25, 25, 96)   55296       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 25, 25, 48)   144         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 25, 25, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 25, 25, 48)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 25, 25, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 25, 25, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 25, 25, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 25, 25, 64)   76800       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 25, 25, 96)   82944       activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 25, 25, 64)   18432       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 25, 25, 64)   192         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 25, 25, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 25, 25, 96)   288         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 25, 25, 64)   192         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 25, 25, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 25, 25, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 25, 25, 96)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 25, 25, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 25, 25, 288)  0           activation_20[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 25, 25, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 25, 25, 64)   192         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 25, 25, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 25, 25, 96)   55296       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 25, 25, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 25, 25, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 12, 12, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 12, 12, 96)   82944       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 12, 12, 384)  1152        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 12, 12, 96)   288         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 12, 12, 384)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 96)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 12, 12, 768)  0           activation_27[0][0]
#                                                                  activation_30[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 12, 12, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 12, 12, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 12, 12, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 12, 12, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 12, 12, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 12, 12, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 12, 12, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 12, 12, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 12, 12, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 12, 12, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 12, 12, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 12, 12, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 12, 12, 128)  114688      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 12, 12, 128)  114688      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 12, 12, 128)  384         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 12, 12, 128)  384         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 12, 12, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 12, 12, 128)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 12, 12, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 12, 12, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 12, 12, 192)  172032      activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 12, 12, 192)  172032      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 12, 12, 192)  576         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 12, 12, 192)  576         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 12, 12, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 12, 12, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 12, 12, 192)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 12, 12, 192)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 12, 12, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 12, 12, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 12, 12, 768)  0           activation_31[0][0]
#                                                                  activation_34[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 12, 12, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 12, 12, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 12, 12, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 12, 12, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 12, 12, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 12, 12, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 12, 12, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 12, 12, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 12, 12, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 12, 12, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 12, 12, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 12, 12, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 12, 12, 160)  179200      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 12, 12, 160)  179200      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 12, 12, 160)  480         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 12, 12, 160)  480         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 12, 12, 160)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 12, 12, 160)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 12, 12, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 12, 12, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 12, 12, 192)  215040      activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 12, 12, 192)  215040      activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 12, 12, 192)  576         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 12, 12, 192)  576         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 12, 12, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 12, 12, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 12, 12, 192)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 12, 12, 192)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 12, 12, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 12, 12, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 12, 12, 768)  0           activation_41[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 12, 12, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 12, 12, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 12, 12, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 12, 12, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 12, 12, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 12, 12, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 12, 12, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 12, 12, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 12, 12, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 12, 12, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 12, 12, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 12, 12, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 12, 12, 160)  179200      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 12, 12, 160)  179200      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 12, 12, 160)  480         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 12, 12, 160)  480         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 12, 12, 160)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 12, 12, 160)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 12, 12, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 12, 12, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 12, 12, 192)  215040      activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 12, 12, 192)  215040      activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 12, 12, 192)  576         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 12, 12, 192)  576         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 12, 12, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 12, 12, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 12, 12, 192)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 12, 12, 192)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 12, 12, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 12, 12, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 12, 12, 768)  0           activation_51[0][0]
#                                                                  activation_54[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_60[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 12, 12, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 12, 12, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 12, 12, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 12, 12, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 12, 12, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 12, 12, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 12, 12, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 12, 12, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 12, 12, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 12, 12, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 12, 12, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 12, 12, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 12, 12, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 12, 12, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 12, 12, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 12, 12, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 12, 12, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 12, 12, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 12, 12, 192)  258048      activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 12, 12, 192)  258048      activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 12, 12, 192)  147456      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 12, 12, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 12, 12, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 12, 12, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 12, 12, 192)  576         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 12, 12, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 12, 12, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 12, 12, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 12, 12, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 12, 12, 768)  0           activation_61[0][0]
#                                                                  activation_64[0][0]
#                                                                  activation_69[0][0]
#                                                                  activation_70[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 5, 5, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 5, 5, 384)    1152        conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 5, 5, 192)    245760      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 5, 5, 320)    960         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 5, 5, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 5, 5, 384)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 5, 5, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 5, 5, 384)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 5, 5, 192)    576         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 5, 5, 320)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 5, 5, 768)    0           activation_79[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 5, 5, 768)    0           activation_83[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 5, 5, 192)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 5, 5, 2048)   0           activation_77[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_85[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 5, 5, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 5, 5, 448)    1344        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 5, 5, 448)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 5, 5, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 5, 5, 384)    1548288     activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 5, 5, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 5, 5, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 5, 5, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 5, 5, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 5, 5, 384)    442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 5, 5, 384)    442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 5, 5, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 5, 5, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 5, 5, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 5, 5, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 5, 5, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 5, 5, 384)    1152        conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 5, 5, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 5, 5, 384)    1152        conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 5, 5, 192)    393216      average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 5, 5, 320)    960         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 5, 5, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 5, 5, 384)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 5, 5, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 5, 5, 384)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 5, 5, 192)    576         conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 5, 5, 320)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 5, 5, 768)    0           activation_88[0][0]
#                                                                  activation_89[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 5, 5, 768)    0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 5, 5, 192)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 5, 5, 2048)   0           activation_86[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_94[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 51200)        0           mixed10[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          26214912    flatten[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 28)           14364       dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 28)           14364       dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 28)           14364       dropout_9[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 28)           14364       dropout_12[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 28)           14364       dropout_15[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 28)           14364       dropout_18[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 28)           14364       dropout_24[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 28)           14364       dropout_21[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            58          dense_4[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Dense)    (None, 3)            87          dense_7[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            145         dense_10[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            116         dense_13[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            87          dense_16[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            87          dense_19[0][0]
# __________________________________________________________________________________________________
# pose_output (Dense)             (None, 3)            87          dense_25[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            116         dense_22[0][0]
# ==================================================================================================
# Total params: 48,133,391
# Trainable params: 48,098,959
# Non-trainable params: 34,432
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# model.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=32, epochs=10)

# %%
import matplotlib.pyplot as plt
import keras.backend as K
from keras.callbacks import Callback


class LRFinder(Callback):
    
    '''
    A simple callback for finding the optimal learning rate range for your model + dataset. 
    
    # Usage
        ```python
            lr_finder = LRFinder(min_lr=1e-5, 
                                 max_lr=1e-2, 
                                 steps_per_epoch=np.ceil(epoch_size/batch_size), 
                                 epochs=3)
            model.fit(X_train, Y_train, callbacks=[lr_finder])
            
            lr_finder.plot_loss()
        ```
    
    # Arguments
        min_lr: The lower bound of the learning rate range for the experiment.
        max_lr: The upper bound of the learning rate range for the experiment.
        steps_per_epoch: Number of mini-batches in the dataset. Calculated as `np.ceil(epoch_size/batch_size)`. 
        epochs: Number of epochs to run experiment. Usually between 2 and 4 epochs is sufficient. 
        
    # References
        Blog post: jeremyjordan.me/nn-learning-rate
        Original paper: https://arxiv.org/abs/1506.01186
    '''
    
    def __init__(self, min_lr=1e-5, max_lr=1e-2, steps_per_epoch=5.625, epochs=24):
        super().__init__()
        
        self.min_lr = min_lr
        self.max_lr = max_lr
        self.total_iterations = steps_per_epoch * epochs
        self.iteration = 0
        self.history = {}
        
    def clr(self):
        '''Calculate the learning rate.'''
        x = self.iteration / self.total_iterations 
        return self.min_lr + (self.max_lr-self.min_lr) * x
        
    def on_train_begin(self, logs=None):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.min_lr)
        
    def on_batch_end(self, epoch, logs=None):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.iteration += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.iteration)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
            
        K.set_value(self.model.optimizer.lr, self.clr())
 
    def plot_lr(self):
        '''Helper function to quickly inspect the learning rate schedule.'''
        plt.plot(self.history['iterations'], self.history['lr'])
        plt.yscale('log')
        plt.xlabel('Iteration')
        plt.ylabel('Learning rate')
        plt.show()
        
    def plot_loss(self):
        '''Helper function to quickly observe the learning rate experiment results.'''
        plt.plot(self.history['lr'], self.history['loss'])
        plt.xscale('log')
        plt.xlabel('Learning rate')
        plt.ylabel('Loss')
        plt.show()

# %%
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
#for i in range(EPOCHS):
lr_scheduler = LearningRateScheduler(lr_schedule1)

# %%
#lr_schedule = lambda t: np.interp([t], [0, (EPOCHS+1)//5, (EPOCHS-6)], [0.4, LEARNING_RATE, 0.4])[0]
#global_step = tf.train.get_or_create_global_step()
#opt.apply_gradients(zip(grads, var), global_step=global_step

# %%
#from keras.callbacks import ModelCheckpoint,LearningRateScheduler

LRFind=LRFinder(min_lr=1e-5, max_lr=10, steps_per_epoch=(2036//64), epochs=50)
#lr_scheduler = LearningRateScheduler(lr_schedule)
#LRFind.on_tain_begin()
#for i in range(EPOCHS):
callbacks = [lr_scheduler,LRFind]

# %%
#for i in range(EPOCHS):
model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    validation_steps=2036//64,
    use_multiprocessing=True,
    workers=1, 
    epochs=100,
    verbose=1,
    #callbacks=callbacks
    )
LRFind.plot_loss()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/100
# 359/360 [============================>.] - ETA: 0s - loss: 1.4117 - gender_output_loss: 0.6885 - image_quality_output_loss: 0.5931 - age_output_loss: 0.4722 - weight_output_loss: 0.4403 - bag_output_loss: 0.5663 - footwear_output_loss: 0.6158 - pose_output_loss: 0.5618 - emotion_output_loss: 0.4018 - gender_output_acc: 0.5506 - image_quality_output_acc: 0.6879 - age_output_acc: 0.7900 - weight_output_acc: 0.8066 - bag_output_acc: 0.6928 - footwear_output_acc: 0.6617 - pose_output_acc: 0.7352 - emotion_output_acc: 0.8499
# 360/360 [==============================] - 285s 793ms/step - loss: 1.4115 - gender_output_loss: 0.6884 - image_quality_output_loss: 0.5930 - age_output_loss: 0.4720 - weight_output_loss: 0.4403 - bag_output_loss: 0.5662 - footwear_output_loss: 0.6157 - pose_output_loss: 0.5617 - emotion_output_loss: 0.4018 - gender_output_acc: 0.5509 - image_quality_output_acc: 0.6881 - age_output_acc: 0.7901 - weight_output_acc: 0.8066 - bag_output_acc: 0.6929 - footwear_output_acc: 0.6617 - pose_output_acc: 0.7352 - emotion_output_acc: 0.8499 - val_loss: 1.3936 - val_gender_output_loss: 0.6915 - val_image_quality_output_loss: 0.5937 - val_age_output_loss: 0.4630 - val_weight_output_loss: 0.4233 - val_bag_output_loss: 0.5611 - val_footwear_output_loss: 0.6053 - val_pose_output_loss: 0.5542 - val_emotion_output_loss: 0.4005 - val_gender_output_acc: 0.5532 - val_image_quality_output_acc: 0.6939 - val_age_output_acc: 0.7949 - val_weight_output_acc: 0.8163 - val_bag_output_acc: 0.7171 - val_footwear_output_acc: 0.6741 - val_pose_output_acc: 0.7424 - val_emotion_output_acc: 0.8579
# Epoch 2/100
# 360/360 [==============================] - 258s 718ms/step - loss: 1.3731 - gender_output_loss: 0.6770 - image_quality_output_loss: 0.5813 - age_output_loss: 0.4600 - weight_output_loss: 0.4274 - bag_output_loss: 0.5511 - footwear_output_loss: 0.5875 - pose_output_loss: 0.5489 - emotion_output_loss: 0.3902 - gender_output_acc: 0.5618 - image_quality_output_acc: 0.6981 - age_output_acc: 0.7964 - weight_output_acc: 0.8142 - bag_output_acc: 0.7050 - footwear_output_acc: 0.6860 - pose_output_acc: 0.7418 - emotion_output_acc: 0.8552 - val_loss: 1.3582 - val_gender_output_loss: 0.6776 - val_image_quality_output_loss: 0.5820 - val_age_output_loss: 0.4537 - val_weight_output_loss: 0.4131 - val_bag_output_loss: 0.5480 - val_footwear_output_loss: 0.5773 - val_pose_output_loss: 0.5493 - val_emotion_output_loss: 0.3841 - val_gender_output_acc: 0.5557 - val_image_quality_output_acc: 0.6927 - val_age_output_acc: 0.7984 - val_weight_output_acc: 0.8187 - val_bag_output_acc: 0.7162 - val_footwear_output_acc: 0.6917 - val_pose_output_acc: 0.7423 - val_emotion_output_acc: 0.8571
# Epoch 3/100
# 360/360 [==============================] - 258s 717ms/step - loss: 1.3610 - gender_output_loss: 0.6706 - image_quality_output_loss: 0.5799 - age_output_loss: 0.4571 - weight_output_loss: 0.4240 - bag_output_loss: 0.5471 - footwear_output_loss: 0.5722 - pose_output_loss: 0.5461 - emotion_output_loss: 0.3878 - gender_output_acc: 0.5694 - image_quality_output_acc: 0.6988 - age_output_acc: 0.7981 - weight_output_acc: 0.8152 - bag_output_acc: 0.7087 - footwear_output_acc: 0.6998 - pose_output_acc: 0.7438 - emotion_output_acc: 0.8549 - val_loss: 1.3473 - val_gender_output_loss: 0.6711 - val_image_quality_output_loss: 0.5784 - val_age_output_loss: 0.4528 - val_weight_output_loss: 0.4116 - val_bag_output_loss: 0.5473 - val_footwear_output_loss: 0.5563 - val_pose_output_loss: 0.5444 - val_emotion_output_loss: 0.3852 - val_gender_output_acc: 0.5615 - val_image_quality_output_acc: 0.6922 - val_age_output_acc: 0.8002 - val_weight_output_acc: 0.8160 - val_bag_output_acc: 0.7115 - val_footwear_output_acc: 0.7070 - val_pose_output_acc: 0.7418 - val_emotion_output_acc: 0.8579
# Epoch 4/100
# 360/360 [==============================] - 258s 716ms/step - loss: 1.3519 - gender_output_loss: 0.6635 - image_quality_output_loss: 0.5775 - age_output_loss: 0.4555 - weight_output_loss: 0.4224 - bag_output_loss: 0.5443 - footwear_output_loss: 0.5595 - pose_output_loss: 0.5432 - emotion_output_loss: 0.3878 - gender_output_acc: 0.5879 - image_quality_output_acc: 0.6982 - age_output_acc: 0.7993 - weight_output_acc: 0.8153 - bag_output_acc: 0.7082 - footwear_output_acc: 0.7100 - pose_output_acc: 0.7435 - emotion_output_acc: 0.8553 - val_loss: 1.3386 - val_gender_output_loss: 0.6705 - val_image_quality_output_loss: 0.5808 - val_age_output_loss: 0.4515 - val_weight_output_loss: 0.4086 - val_bag_output_loss: 0.5433 - val_footwear_output_loss: 0.5398 - val_pose_output_loss: 0.5421 - val_emotion_output_loss: 0.3838 - val_gender_output_acc: 0.5628 - val_image_quality_output_acc: 0.6927 - val_age_output_acc: 0.7996 - val_weight_output_acc: 0.8209 - val_bag_output_acc: 0.7130 - val_footwear_output_acc: 0.7243 - val_pose_output_acc: 0.7448 - val_emotion_output_acc: 0.8579
# Epoch 5/100
# 360/360 [==============================] - 256s 711ms/step - loss: 1.3431 - gender_output_loss: 0.6568 - image_quality_output_loss: 0.5782 - age_output_loss: 0.4541 - weight_output_loss: 0.4201 - bag_output_loss: 0.5416 - footwear_output_loss: 0.5491 - pose_output_loss: 0.5401 - emotion_output_loss: 0.3849 - gender_output_acc: 0.5990 - image_quality_output_acc: 0.7003 - age_output_acc: 0.7986 - weight_output_acc: 0.8156 - bag_output_acc: 0.7128 - footwear_output_acc: 0.7175 - pose_output_acc: 0.7459 - emotion_output_acc: 0.8553 - val_loss: 1.3335 - val_gender_output_loss: 0.6630 - val_image_quality_output_loss: 0.5782 - val_age_output_loss: 0.4512 - val_weight_output_loss: 0.4088 - val_bag_output_loss: 0.5412 - val_footwear_output_loss: 0.5338 - val_pose_output_loss: 0.5404 - val_emotion_output_loss: 0.3843 - val_gender_output_acc: 0.5696 - val_image_quality_output_acc: 0.6899 - val_age_output_acc: 0.7982 - val_weight_output_acc: 0.8227 - val_bag_output_acc: 0.7224 - val_footwear_output_acc: 0.7278 - val_pose_output_acc: 0.7433 - val_emotion_output_acc: 0.8579
# Epoch 6/100
# 360/360 [==============================] - 257s 714ms/step - loss: 1.3355 - gender_output_loss: 0.6473 - image_quality_output_loss: 0.5756 - age_output_loss: 0.4516 - weight_output_loss: 0.4183 - bag_output_loss: 0.5385 - footwear_output_loss: 0.5434 - pose_output_loss: 0.5379 - emotion_output_loss: 0.3856 - gender_output_acc: 0.6148 - image_quality_output_acc: 0.7028 - age_output_acc: 0.7989 - weight_output_acc: 0.8162 - bag_output_acc: 0.7157 - footwear_output_acc: 0.7209 - pose_output_acc: 0.7457 - emotion_output_acc: 0.8554 - val_loss: 1.3329 - val_gender_output_loss: 0.6543 - val_image_quality_output_loss: 0.5779 - val_age_output_loss: 0.4515 - val_weight_output_loss: 0.4122 - val_bag_output_loss: 0.5383 - val_footwear_output_loss: 0.5342 - val_pose_output_loss: 0.5434 - val_emotion_output_loss: 0.3831 - val_gender_output_acc: 0.6028 - val_image_quality_output_acc: 0.6920 - val_age_output_acc: 0.7995 - val_weight_output_acc: 0.8189 - val_bag_output_acc: 0.7189 - val_footwear_output_acc: 0.7320 - val_pose_output_acc: 0.7361 - val_emotion_output_acc: 0.8579
# Epoch 7/100
# 360/360 [==============================] - 256s 711ms/step - loss: 1.3281 - gender_output_loss: 0.6382 - image_quality_output_loss: 0.5745 - age_output_loss: 0.4515 - weight_output_loss: 0.4169 - bag_output_loss: 0.5352 - footwear_output_loss: 0.5345 - pose_output_loss: 0.5356 - emotion_output_loss: 0.3851 - gender_output_acc: 0.6287 - image_quality_output_acc: 0.6999 - age_output_acc: 0.7987 - weight_output_acc: 0.8168 - bag_output_acc: 0.7163 - footwear_output_acc: 0.7293 - pose_output_acc: 0.7471 - emotion_output_acc: 0.8554 - val_loss: 1.3296 - val_gender_output_loss: 0.6481 - val_image_quality_output_loss: 0.5782 - val_age_output_loss: 0.4512 - val_weight_output_loss: 0.4122 - val_bag_output_loss: 0.5388 - val_footwear_output_loss: 0.5327 - val_pose_output_loss: 0.5383 - val_emotion_output_loss: 0.3827 - val_gender_output_acc: 0.6079 - val_image_quality_output_acc: 0.6919 - val_age_output_acc: 0.7964 - val_weight_output_acc: 0.8201 - val_bag_output_acc: 0.7189 - val_footwear_output_acc: 0.7300 - val_pose_output_acc: 0.7445 - val_emotion_output_acc: 0.8579
# Epoch 8/100
# 360/360 [==============================] - 256s 711ms/step - loss: 1.3198 - gender_output_loss: 0.6259 - image_quality_output_loss: 0.5729 - age_output_loss: 0.4491 - weight_output_loss: 0.4164 - bag_output_loss: 0.5318 - footwear_output_loss: 0.5315 - pose_output_loss: 0.5309 - emotion_output_loss: 0.3834 - gender_output_acc: 0.6435 - image_quality_output_acc: 0.7003 - age_output_acc: 0.7988 - weight_output_acc: 0.8169 - bag_output_acc: 0.7212 - footwear_output_acc: 0.7324 - pose_output_acc: 0.7505 - emotion_output_acc: 0.8553 - val_loss: 1.3259 - val_gender_output_loss: 0.6416 - val_image_quality_output_loss: 0.5771 - val_age_output_loss: 0.4508 - val_weight_output_loss: 0.4080 - val_bag_output_loss: 0.5390 - val_footwear_output_loss: 0.5354 - val_pose_output_loss: 0.5364 - val_emotion_output_loss: 0.3815 - val_gender_output_acc: 0.6142 - val_image_quality_output_acc: 0.6858 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8250 - val_bag_output_acc: 0.7109 - val_footwear_output_acc: 0.7218 - val_pose_output_acc: 0.7443 - val_emotion_output_acc: 0.8579
# Epoch 9/100
# 360/360 [==============================] - 257s 714ms/step - loss: 1.3115 - gender_output_loss: 0.6144 - image_quality_output_loss: 0.5730 - age_output_loss: 0.4491 - weight_output_loss: 0.4141 - bag_output_loss: 0.5293 - footwear_output_loss: 0.5254 - pose_output_loss: 0.5243 - emotion_output_loss: 0.3820 - gender_output_acc: 0.6565 - image_quality_output_acc: 0.7026 - age_output_acc: 0.7994 - weight_output_acc: 0.8178 - bag_output_acc: 0.7245 - footwear_output_acc: 0.7352 - pose_output_acc: 0.7527 - emotion_output_acc: 0.8555 - val_loss: 1.3149 - val_gender_output_loss: 0.6335 - val_image_quality_output_loss: 0.5776 - val_age_output_loss: 0.4489 - val_weight_output_loss: 0.4124 - val_bag_output_loss: 0.5327 - val_footwear_output_loss: 0.5198 - val_pose_output_loss: 0.5245 - val_emotion_output_loss: 0.3810 - val_gender_output_acc: 0.6371 - val_image_quality_output_acc: 0.6939 - val_age_output_acc: 0.7989 - val_weight_output_acc: 0.8211 - val_bag_output_acc: 0.7241 - val_footwear_output_acc: 0.7414 - val_pose_output_acc: 0.7534 - val_emotion_output_acc: 0.8579
# Epoch 10/100
# 360/360 [==============================] - 257s 714ms/step - loss: 1.3026 - gender_output_loss: 0.6034 - image_quality_output_loss: 0.5715 - age_output_loss: 0.4480 - weight_output_loss: 0.4145 - bag_output_loss: 0.5244 - footwear_output_loss: 0.5198 - pose_output_loss: 0.5158 - emotion_output_loss: 0.3816 - gender_output_acc: 0.6699 - image_quality_output_acc: 0.7019 - age_output_acc: 0.7994 - weight_output_acc: 0.8185 - bag_output_acc: 0.7293 - footwear_output_acc: 0.7376 - pose_output_acc: 0.7563 - emotion_output_acc: 0.8553 - val_loss: 1.3123 - val_gender_output_loss: 0.6266 - val_image_quality_output_loss: 0.5763 - val_age_output_loss: 0.4492 - val_weight_output_loss: 0.4107 - val_bag_output_loss: 0.5351 - val_footwear_output_loss: 0.5179 - val_pose_output_loss: 0.5233 - val_emotion_output_loss: 0.3807 - val_gender_output_acc: 0.6421 - val_image_quality_output_acc: 0.6893 - val_age_output_acc: 0.8002 - val_weight_output_acc: 0.8233 - val_bag_output_acc: 0.7204 - val_footwear_output_acc: 0.7377 - val_pose_output_acc: 0.7532 - val_emotion_output_acc: 0.8580
# Epoch 11/100
# 360/360 [==============================] - 257s 713ms/step - loss: 1.2910 - gender_output_loss: 0.5851 - image_quality_output_loss: 0.5701 - age_output_loss: 0.4464 - weight_output_loss: 0.4117 - bag_output_loss: 0.5205 - footwear_output_loss: 0.5127 - pose_output_loss: 0.5099 - emotion_output_loss: 0.3804 - gender_output_acc: 0.6874 - image_quality_output_acc: 0.7021 - age_output_acc: 0.7994 - weight_output_acc: 0.8188 - bag_output_acc: 0.7341 - footwear_output_acc: 0.7434 - pose_output_acc: 0.7569 - emotion_output_acc: 0.8557 - val_loss: 1.3094 - val_gender_output_loss: 0.6227 - val_image_quality_output_loss: 0.5775 - val_age_output_loss: 0.4527 - val_weight_output_loss: 0.4112 - val_bag_output_loss: 0.5322 - val_footwear_output_loss: 0.5126 - val_pose_output_loss: 0.5164 - val_emotion_output_loss: 0.3810 - val_gender_output_acc: 0.6535 - val_image_quality_output_acc: 0.6924 - val_age_output_acc: 0.7981 - val_weight_output_acc: 0.8228 - val_bag_output_acc: 0.7265 - val_footwear_output_acc: 0.7480 - val_pose_output_acc: 0.7527 - val_emotion_output_acc: 0.8580
# Epoch 12/100
# 360/360 [==============================] - 257s 714ms/step - loss: 1.2832 - gender_output_loss: 0.5774 - image_quality_output_loss: 0.5693 - age_output_loss: 0.4455 - weight_output_loss: 0.4106 - bag_output_loss: 0.5166 - footwear_output_loss: 0.5100 - pose_output_loss: 0.5010 - emotion_output_loss: 0.3792 - gender_output_acc: 0.6950 - image_quality_output_acc: 0.7023 - age_output_acc: 0.8001 - weight_output_acc: 0.8181 - bag_output_acc: 0.7399 - footwear_output_acc: 0.7448 - pose_output_acc: 0.7641 - emotion_output_acc: 0.8556 - val_loss: 1.3298 - val_gender_output_loss: 0.6634 - val_image_quality_output_loss: 0.5840 - val_age_output_loss: 0.4531 - val_weight_output_loss: 0.4097 - val_bag_output_loss: 0.5546 - val_footwear_output_loss: 0.5233 - val_pose_output_loss: 0.5152 - val_emotion_output_loss: 0.3838 - val_gender_output_acc: 0.6424 - val_image_quality_output_acc: 0.6885 - val_age_output_acc: 0.8007 - val_weight_output_acc: 0.8217 - val_bag_output_acc: 0.7177 - val_footwear_output_acc: 0.7493 - val_pose_output_acc: 0.7557 - val_emotion_output_acc: 0.8580
# Epoch 13/100
# 360/360 [==============================] - 257s 715ms/step - loss: 1.2716 - gender_output_loss: 0.5649 - image_quality_output_loss: 0.5671 - age_output_loss: 0.4443 - weight_output_loss: 0.4088 - bag_output_loss: 0.5136 - footwear_output_loss: 0.5034 - pose_output_loss: 0.4894 - emotion_output_loss: 0.3772 - gender_output_acc: 0.7069 - image_quality_output_acc: 0.7050 - age_output_acc: 0.8005 - weight_output_acc: 0.8199 - bag_output_acc: 0.7398 - footwear_output_acc: 0.7502 - pose_output_acc: 0.7684 - emotion_output_acc: 0.8556 - val_loss: 1.3055 - val_gender_output_loss: 0.6369 - val_image_quality_output_loss: 0.5764 - val_age_output_loss: 0.4481 - val_weight_output_loss: 0.4099 - val_bag_output_loss: 0.5317 - val_footwear_output_loss: 0.5113 - val_pose_output_loss: 0.5096 - val_emotion_output_loss: 0.3785 - val_gender_output_acc: 0.6396 - val_image_quality_output_acc: 0.6925 - val_age_output_acc: 0.7986 - val_weight_output_acc: 0.8231 - val_bag_output_acc: 0.7243 - val_footwear_output_acc: 0.7487 - val_pose_output_acc: 0.7571 - val_emotion_output_acc: 0.8579
# Epoch 14/100
# 360/360 [==============================] - 257s 715ms/step - loss: 1.2622 - gender_output_loss: 0.5486 - image_quality_output_loss: 0.5672 - age_output_loss: 0.4429 - weight_output_loss: 0.4075 - bag_output_loss: 0.5096 - footwear_output_loss: 0.5011 - pose_output_loss: 0.4803 - emotion_output_loss: 0.3765 - gender_output_acc: 0.7198 - image_quality_output_acc: 0.7063 - age_output_acc: 0.8001 - weight_output_acc: 0.8198 - bag_output_acc: 0.7445 - footwear_output_acc: 0.7537 - pose_output_acc: 0.7759 - emotion_output_acc: 0.8557 - val_loss: 1.3020 - val_gender_output_loss: 0.6069 - val_image_quality_output_loss: 0.5765 - val_age_output_loss: 0.4495 - val_weight_output_loss: 0.4088 - val_bag_output_loss: 0.5379 - val_footwear_output_loss: 0.5100 - val_pose_output_loss: 0.5094 - val_emotion_output_loss: 0.3805 - val_gender_output_acc: 0.6734 - val_image_quality_output_acc: 0.6946 - val_age_output_acc: 0.7979 - val_weight_output_acc: 0.8242 - val_bag_output_acc: 0.7277 - val_footwear_output_acc: 0.7460 - val_pose_output_acc: 0.7540 - val_emotion_output_acc: 0.8581
# Epoch 15/100
# 360/360 [==============================] - 257s 714ms/step - loss: 1.2522 - gender_output_loss: 0.5341 - image_quality_output_loss: 0.5659 - age_output_loss: 0.4411 - weight_output_loss: 0.4054 - bag_output_loss: 0.5059 - footwear_output_loss: 0.4936 - pose_output_loss: 0.4769 - emotion_output_loss: 0.3750 - gender_output_acc: 0.7328 - image_quality_output_acc: 0.7072 - age_output_acc: 0.8008 - weight_output_acc: 0.8209 - bag_output_acc: 0.7486 - footwear_output_acc: 0.7563 - pose_output_acc: 0.7760 - emotion_output_acc: 0.8559 - val_loss: 1.3005 - val_gender_output_loss: 0.6173 - val_image_quality_output_loss: 0.5786 - val_age_output_loss: 0.4474 - val_weight_output_loss: 0.4097 - val_bag_output_loss: 0.5330 - val_footwear_output_loss: 0.5139 - val_pose_output_loss: 0.5005 - val_emotion_output_loss: 0.3793 - val_gender_output_acc: 0.6661 - val_image_quality_output_acc: 0.6930 - val_age_output_acc: 0.7991 - val_weight_output_acc: 0.8226 - val_bag_output_acc: 0.7238 - val_footwear_output_acc: 0.7433 - val_pose_output_acc: 0.7641 - val_emotion_output_acc: 0.8584
# Epoch 16/100
# 360/360 [==============================] - 257s 715ms/step - loss: 1.2385 - gender_output_loss: 0.5153 - image_quality_output_loss: 0.5640 - age_output_loss: 0.4408 - weight_output_loss: 0.4042 - bag_output_loss: 0.5027 - footwear_output_loss: 0.4868 - pose_output_loss: 0.4599 - emotion_output_loss: 0.3732 - gender_output_acc: 0.7483 - image_quality_output_acc: 0.7073 - age_output_acc: 0.8015 - weight_output_acc: 0.8207 - bag_output_acc: 0.7511 - footwear_output_acc: 0.7622 - pose_output_acc: 0.7848 - emotion_output_acc: 0.8558 - val_loss: 1.2899 - val_gender_output_loss: 0.5916 - val_image_quality_output_loss: 0.5781 - val_age_output_loss: 0.4477 - val_weight_output_loss: 0.4082 - val_bag_output_loss: 0.5267 - val_footwear_output_loss: 0.5104 - val_pose_output_loss: 0.4958 - val_emotion_output_loss: 0.3779 - val_gender_output_acc: 0.6852 - val_image_quality_output_acc: 0.6843 - val_age_output_acc: 0.8003 - val_weight_output_acc: 0.8238 - val_bag_output_acc: 0.7246 - val_footwear_output_acc: 0.7502 - val_pose_output_acc: 0.7655 - val_emotion_output_acc: 0.8580
# Epoch 17/100
# 360/360 [==============================] - 257s 714ms/step - loss: 1.2268 - gender_output_loss: 0.4999 - image_quality_output_loss: 0.5636 - age_output_loss: 0.4395 - weight_output_loss: 0.4030 - bag_output_loss: 0.4978 - footwear_output_loss: 0.4835 - pose_output_loss: 0.4471 - emotion_output_loss: 0.3707 - gender_output_acc: 0.7583 - image_quality_output_acc: 0.7084 - age_output_acc: 0.8009 - weight_output_acc: 0.8217 - bag_output_acc: 0.7546 - footwear_output_acc: 0.7620 - pose_output_acc: 0.7924 - emotion_output_acc: 0.8560 - val_loss: 1.3055 - val_gender_output_loss: 0.5952 - val_image_quality_output_loss: 0.5777 - val_age_output_loss: 0.4508 - val_weight_output_loss: 0.4111 - val_bag_output_loss: 0.5317 - val_footwear_output_loss: 0.5257 - val_pose_output_loss: 0.5114 - val_emotion_output_loss: 0.3815 - val_gender_output_acc: 0.6928 - val_image_quality_output_acc: 0.6939 - val_age_output_acc: 0.7988 - val_weight_output_acc: 0.8180 - val_bag_output_acc: 0.7367 - val_footwear_output_acc: 0.7329 - val_pose_output_acc: 0.7599 - val_emotion_output_acc: 0.8574
# Epoch 18/100
# 360/360 [==============================] - 257s 715ms/step - loss: 1.2132 - gender_output_loss: 0.4813 - image_quality_output_loss: 0.5609 - age_output_loss: 0.4377 - weight_output_loss: 0.4000 - bag_output_loss: 0.4930 - footwear_output_loss: 0.4781 - pose_output_loss: 0.4363 - emotion_output_loss: 0.3689 - gender_output_acc: 0.7699 - image_quality_output_acc: 0.7109 - age_output_acc: 0.8016 - weight_output_acc: 0.8230 - bag_output_acc: 0.7586 - footwear_output_acc: 0.7660 - pose_output_acc: 0.7959 - emotion_output_acc: 0.8567 - val_loss: 1.3442 - val_gender_output_loss: 0.6304 - val_image_quality_output_loss: 0.5801 - val_age_output_loss: 0.4506 - val_weight_output_loss: 0.4194 - val_bag_output_loss: 0.5479 - val_footwear_output_loss: 0.5483 - val_pose_output_loss: 0.5568 - val_emotion_output_loss: 0.3878 - val_gender_output_acc: 0.6653 - val_image_quality_output_acc: 0.6909 - val_age_output_acc: 0.7995 - val_weight_output_acc: 0.8135 - val_bag_output_acc: 0.7248 - val_footwear_output_acc: 0.7196 - val_pose_output_acc: 0.7263 - val_emotion_output_acc: 0.8567
# Epoch 19/100
# 360/360 [==============================] - 257s 714ms/step - loss: 1.2013 - gender_output_loss: 0.4668 - image_quality_output_loss: 0.5602 - age_output_loss: 0.4363 - weight_output_loss: 0.3983 - bag_output_loss: 0.4887 - footwear_output_loss: 0.4706 - pose_output_loss: 0.4264 - emotion_output_loss: 0.3666 - gender_output_acc: 0.7789 - image_quality_output_acc: 0.7080 - age_output_acc: 0.8022 - weight_output_acc: 0.8221 - bag_output_acc: 0.7614 - footwear_output_acc: 0.7723 - pose_output_acc: 0.8018 - emotion_output_acc: 0.8559 - val_loss: 1.2938 - val_gender_output_loss: 0.5858 - val_image_quality_output_loss: 0.5798 - val_age_output_loss: 0.4546 - val_weight_output_loss: 0.4126 - val_bag_output_loss: 0.5335 - val_footwear_output_loss: 0.5050 - val_pose_output_loss: 0.4864 - val_emotion_output_loss: 0.3824 - val_gender_output_acc: 0.7006 - val_image_quality_output_acc: 0.6930 - val_age_output_acc: 0.7997 - val_weight_output_acc: 0.8191 - val_bag_output_acc: 0.7310 - val_footwear_output_acc: 0.7547 - val_pose_output_acc: 0.7723 - val_emotion_output_acc: 0.8553
# Epoch 20/100
# 360/360 [==============================] - 257s 714ms/step - loss: 1.1848 - gender_output_loss: 0.4441 - image_quality_output_loss: 0.5568 - age_output_loss: 0.4336 - weight_output_loss: 0.3975 - bag_output_loss: 0.4845 - footwear_output_loss: 0.4653 - pose_output_loss: 0.4076 - emotion_output_loss: 0.3647 - gender_output_acc: 0.7958 - image_quality_output_acc: 0.7142 - age_output_acc: 0.8040 - weight_output_acc: 0.8241 - bag_output_acc: 0.7637 - footwear_output_acc: 0.7729 - pose_output_acc: 0.8130 - emotion_output_acc: 0.8563 - val_loss: 1.2968 - val_gender_output_loss: 0.6102 - val_image_quality_output_loss: 0.5774 - val_age_output_loss: 0.4497 - val_weight_output_loss: 0.4137 - val_bag_output_loss: 0.5394 - val_footwear_output_loss: 0.5054 - val_pose_output_loss: 0.4806 - val_emotion_output_loss: 0.3841 - val_gender_output_acc: 0.6933 - val_image_quality_output_acc: 0.6959 - val_age_output_acc: 0.7941 - val_weight_output_acc: 0.8202 - val_bag_output_acc: 0.7181 - val_footwear_output_acc: 0.7518 - val_pose_output_acc: 0.7757 - val_emotion_output_acc: 0.8574
# Epoch 21/100
# 360/360 [==============================] - 257s 713ms/step - loss: 1.1739 - gender_output_loss: 0.4370 - image_quality_output_loss: 0.5555 - age_output_loss: 0.4327 - weight_output_loss: 0.3938 - bag_output_loss: 0.4776 - footwear_output_loss: 0.4592 - pose_output_loss: 0.3996 - emotion_output_loss: 0.3628 - gender_output_acc: 0.7957 - image_quality_output_acc: 0.7130 - age_output_acc: 0.8036 - weight_output_acc: 0.8248 - bag_output_acc: 0.7697 - footwear_output_acc: 0.7764 - pose_output_acc: 0.8174 - emotion_output_acc: 0.8572 - val_loss: 1.3672 - val_gender_output_loss: 0.6418 - val_image_quality_output_loss: 0.5880 - val_age_output_loss: 0.4544 - val_weight_output_loss: 0.4132 - val_bag_output_loss: 0.5590 - val_footwear_output_loss: 0.5447 - val_pose_output_loss: 0.6040 - val_emotion_output_loss: 0.3941 - val_gender_output_acc: 0.6797 - val_image_quality_output_acc: 0.6909 - val_age_output_acc: 0.7948 - val_weight_output_acc: 0.8213 - val_bag_output_acc: 0.7245 - val_footwear_output_acc: 0.7315 - val_pose_output_acc: 0.7063 - val_emotion_output_acc: 0.8567
# Epoch 22/100
# 360/360 [==============================] - 258s 717ms/step - loss: 1.1549 - gender_output_loss: 0.4033 - image_quality_output_loss: 0.5524 - age_output_loss: 0.4302 - weight_output_loss: 0.3904 - bag_output_loss: 0.4758 - footwear_output_loss: 0.4502 - pose_output_loss: 0.3847 - emotion_output_loss: 0.3602 - gender_output_acc: 0.8180 - image_quality_output_acc: 0.7158 - age_output_acc: 0.8047 - weight_output_acc: 0.8271 - bag_output_acc: 0.7707 - footwear_output_acc: 0.7825 - pose_output_acc: 0.8245 - emotion_output_acc: 0.8571 - val_loss: 1.3019 - val_gender_output_loss: 0.5967 - val_image_quality_output_loss: 0.5759 - val_age_output_loss: 0.4494 - val_weight_output_loss: 0.4173 - val_bag_output_loss: 0.5316 - val_footwear_output_loss: 0.5128 - val_pose_output_loss: 0.5040 - val_emotion_output_loss: 0.3842 - val_gender_output_acc: 0.6895 - val_image_quality_output_acc: 0.6905 - val_age_output_acc: 0.7969 - val_weight_output_acc: 0.8155 - val_bag_output_acc: 0.7240 - val_footwear_output_acc: 0.7505 - val_pose_output_acc: 0.7740 - val_emotion_output_acc: 0.8535
# Epoch 23/100
# 360/360 [==============================] - 258s 716ms/step - loss: 1.1382 - gender_output_loss: 0.3847 - image_quality_output_loss: 0.5502 - age_output_loss: 0.4281 - weight_output_loss: 0.3885 - bag_output_loss: 0.4683 - footwear_output_loss: 0.4423 - pose_output_loss: 0.3705 - emotion_output_loss: 0.3561 - gender_output_acc: 0.8260 - image_quality_output_acc: 0.7159 - age_output_acc: 0.8047 - weight_output_acc: 0.8270 - bag_output_acc: 0.7768 - footwear_output_acc: 0.7892 - pose_output_acc: 0.8328 - emotion_output_acc: 0.8579 - val_loss: 1.3283 - val_gender_output_loss: 0.6654 - val_image_quality_output_loss: 0.5778 - val_age_output_loss: 0.4515 - val_weight_output_loss: 0.4181 - val_bag_output_loss: 0.5567 - val_footwear_output_loss: 0.5210 - val_pose_output_loss: 0.4992 - val_emotion_output_loss: 0.3895 - val_gender_output_acc: 0.6956 - val_image_quality_output_acc: 0.6922 - val_age_output_acc: 0.7978 - val_weight_output_acc: 0.8102 - val_bag_output_acc: 0.7359 - val_footwear_output_acc: 0.7493 - val_pose_output_acc: 0.7792 - val_emotion_output_acc: 0.8529
# Epoch 24/100
# 360/360 [==============================] - 259s 719ms/step - loss: 1.1189 - gender_output_loss: 0.3702 - image_quality_output_loss: 0.5450 - age_output_loss: 0.4250 - weight_output_loss: 0.3834 - bag_output_loss: 0.4610 - footwear_output_loss: 0.4328 - pose_output_loss: 0.3561 - emotion_output_loss: 0.3515 - gender_output_acc: 0.8350 - image_quality_output_acc: 0.7198 - age_output_acc: 0.8070 - weight_output_acc: 0.8291 - bag_output_acc: 0.7830 - footwear_output_acc: 0.7955 - pose_output_acc: 0.8422 - emotion_output_acc: 0.8590 - val_loss: 1.3552 - val_gender_output_loss: 0.6997 - val_image_quality_output_loss: 0.5794 - val_age_output_loss: 0.4550 - val_weight_output_loss: 0.4207 - val_bag_output_loss: 0.5789 - val_footwear_output_loss: 0.5499 - val_pose_output_loss: 0.5043 - val_emotion_output_loss: 0.3893 - val_gender_output_acc: 0.6943 - val_image_quality_output_acc: 0.6932 - val_age_output_acc: 0.7978 - val_weight_output_acc: 0.8059 - val_bag_output_acc: 0.7231 - val_footwear_output_acc: 0.7322 - val_pose_output_acc: 0.7703 - val_emotion_output_acc: 0.8548
# Epoch 25/100
# 360/360 [==============================] - 258s 718ms/step - loss: 1.0976 - gender_output_loss: 0.3415 - image_quality_output_loss: 0.5409 - age_output_loss: 0.4226 - weight_output_loss: 0.3798 - bag_output_loss: 0.4523 - footwear_output_loss: 0.4263 - pose_output_loss: 0.3360 - emotion_output_loss: 0.3486 - gender_output_acc: 0.8486 - image_quality_output_acc: 0.7229 - age_output_acc: 0.8061 - weight_output_acc: 0.8313 - bag_output_acc: 0.7875 - footwear_output_acc: 0.7969 - pose_output_acc: 0.8515 - emotion_output_acc: 0.8596 - val_loss: 1.3204 - val_gender_output_loss: 0.6048 - val_image_quality_output_loss: 0.5835 - val_age_output_loss: 0.4539 - val_weight_output_loss: 0.4139 - val_bag_output_loss: 0.5477 - val_footwear_output_loss: 0.5336 - val_pose_output_loss: 0.4984 - val_emotion_output_loss: 0.3950 - val_gender_output_acc: 0.6988 - val_image_quality_output_acc: 0.6808 - val_age_output_acc: 0.7974 - val_weight_output_acc: 0.8199 - val_bag_output_acc: 0.7204 - val_footwear_output_acc: 0.7438 - val_pose_output_acc: 0.7639 - val_emotion_output_acc: 0.8528
# Epoch 26/100
# 360/360 [==============================] - 259s 719ms/step - loss: 1.0760 - gender_output_loss: 0.3188 - image_quality_output_loss: 0.5393 - age_output_loss: 0.4182 - weight_output_loss: 0.3743 - bag_output_loss: 0.4414 - footwear_output_loss: 0.4154 - pose_output_loss: 0.3232 - emotion_output_loss: 0.3443 - gender_output_acc: 0.8631 - image_quality_output_acc: 0.7242 - age_output_acc: 0.8106 - weight_output_acc: 0.8326 - bag_output_acc: 0.7954 - footwear_output_acc: 0.8017 - pose_output_acc: 0.8567 - emotion_output_acc: 0.8605 - val_loss: 1.3571 - val_gender_output_loss: 0.6212 - val_image_quality_output_loss: 0.5800 - val_age_output_loss: 0.4594 - val_weight_output_loss: 0.4253 - val_bag_output_loss: 0.5562 - val_footwear_output_loss: 0.5814 - val_pose_output_loss: 0.5298 - val_emotion_output_loss: 0.3970 - val_gender_output_acc: 0.7026 - val_image_quality_output_acc: 0.6883 - val_age_output_acc: 0.7957 - val_weight_output_acc: 0.8214 - val_bag_output_acc: 0.7255 - val_footwear_output_acc: 0.7213 - val_pose_output_acc: 0.7470 - val_emotion_output_acc: 0.8536
# Epoch 27/100
# 360/360 [==============================] - 258s 717ms/step - loss: 1.0560 - gender_output_loss: 0.3000 - image_quality_output_loss: 0.5330 - age_output_loss: 0.4161 - weight_output_loss: 0.3683 - bag_output_loss: 0.4348 - footwear_output_loss: 0.4064 - pose_output_loss: 0.3081 - emotion_output_loss: 0.3399 - gender_output_acc: 0.8708 - image_quality_output_acc: 0.7297 - age_output_acc: 0.8104 - weight_output_acc: 0.8384 - bag_output_acc: 0.7970 - footwear_output_acc: 0.8078 - pose_output_acc: 0.8662 - emotion_output_acc: 0.8622 - val_loss: 1.3703 - val_gender_output_loss: 0.6657 - val_image_quality_output_loss: 0.5768 - val_age_output_loss: 0.4712 - val_weight_output_loss: 0.4268 - val_bag_output_loss: 0.5502 - val_footwear_output_loss: 0.5596 - val_pose_output_loss: 0.5610 - val_emotion_output_loss: 0.3913 - val_gender_output_acc: 0.7089 - val_image_quality_output_acc: 0.6910 - val_age_output_acc: 0.7851 - val_weight_output_acc: 0.8162 - val_bag_output_acc: 0.7213 - val_footwear_output_acc: 0.7384 - val_pose_output_acc: 0.7853 - val_emotion_output_acc: 0.8497
# Epoch 28/100
# 360/360 [==============================] - 259s 718ms/step - loss: 1.0266 - gender_output_loss: 0.2719 - image_quality_output_loss: 0.5299 - age_output_loss: 0.4090 - weight_output_loss: 0.3607 - bag_output_loss: 0.4255 - footwear_output_loss: 0.3922 - pose_output_loss: 0.2855 - emotion_output_loss: 0.3338 - gender_output_acc: 0.8878 - image_quality_output_acc: 0.7321 - age_output_acc: 0.8126 - weight_output_acc: 0.8411 - bag_output_acc: 0.8031 - footwear_output_acc: 0.8177 - pose_output_acc: 0.8784 - emotion_output_acc: 0.8639 - val_loss: 1.3605 - val_gender_output_loss: 0.6426 - val_image_quality_output_loss: 0.5859 - val_age_output_loss: 0.4617 - val_weight_output_loss: 0.4267 - val_bag_output_loss: 0.5577 - val_footwear_output_loss: 0.5449 - val_pose_output_loss: 0.5557 - val_emotion_output_loss: 0.3928 - val_gender_output_acc: 0.7089 - val_image_quality_output_acc: 0.6875 - val_age_output_acc: 0.7904 - val_weight_output_acc: 0.8184 - val_bag_output_acc: 0.7157 - val_footwear_output_acc: 0.7386 - val_pose_output_acc: 0.7636 - val_emotion_output_acc: 0.8482
# Epoch 29/100
# 360/360 [==============================] - 259s 718ms/step - loss: 1.0100 - gender_output_loss: 0.2553 - image_quality_output_loss: 0.5235 - age_output_loss: 0.4046 - weight_output_loss: 0.3574 - bag_output_loss: 0.4179 - footwear_output_loss: 0.3859 - pose_output_loss: 0.2769 - emotion_output_loss: 0.3311 - gender_output_acc: 0.8928 - image_quality_output_acc: 0.7354 - age_output_acc: 0.8155 - weight_output_acc: 0.8433 - bag_output_acc: 0.8088 - footwear_output_acc: 0.8199 - pose_output_acc: 0.8821 - emotion_output_acc: 0.8653 - val_loss: 1.3748 - val_gender_output_loss: 0.7020 - val_image_quality_output_loss: 0.5944 - val_age_output_loss: 0.4665 - val_weight_output_loss: 0.4290 - val_bag_output_loss: 0.5574 - val_footwear_output_loss: 0.5501 - val_pose_output_loss: 0.5369 - val_emotion_output_loss: 0.3949 - val_gender_output_acc: 0.7054 - val_image_quality_output_acc: 0.6877 - val_age_output_acc: 0.7893 - val_weight_output_acc: 0.8039 - val_bag_output_acc: 0.7298 - val_footwear_output_acc: 0.7413 - val_pose_output_acc: 0.7809 - val_emotion_output_acc: 0.8523
# Epoch 30/100
# 360/360 [==============================] - 259s 719ms/step - loss: 0.9881 - gender_output_loss: 0.2444 - image_quality_output_loss: 0.5176 - age_output_loss: 0.3999 - weight_output_loss: 0.3488 - bag_output_loss: 0.4072 - footwear_output_loss: 0.3770 - pose_output_loss: 0.2648 - emotion_output_loss: 0.3243 - gender_output_acc: 0.8997 - image_quality_output_acc: 0.7411 - age_output_acc: 0.8176 - weight_output_acc: 0.8472 - bag_output_acc: 0.8153 - footwear_output_acc: 0.8255 - pose_output_acc: 0.8869 - emotion_output_acc: 0.8675 - val_loss: 1.3899 - val_gender_output_loss: 0.6735 - val_image_quality_output_loss: 0.5873 - val_age_output_loss: 0.4798 - val_weight_output_loss: 0.4520 - val_bag_output_loss: 0.5687 - val_footwear_output_loss: 0.5595 - val_pose_output_loss: 0.5349 - val_emotion_output_loss: 0.3985 - val_gender_output_acc: 0.7099 - val_image_quality_output_acc: 0.6804 - val_age_output_acc: 0.7843 - val_weight_output_acc: 0.8143 - val_bag_output_acc: 0.7223 - val_footwear_output_acc: 0.7240 - val_pose_output_acc: 0.7838 - val_emotion_output_acc: 0.8477
# Epoch 31/100
# 360/360 [==============================] - 258s 716ms/step - loss: 0.9598 - gender_output_loss: 0.2273 - image_quality_output_loss: 0.5075 - age_output_loss: 0.3956 - weight_output_loss: 0.3399 - bag_output_loss: 0.3965 - footwear_output_loss: 0.3627 - pose_output_loss: 0.2423 - emotion_output_loss: 0.3196 - gender_output_acc: 0.9095 - image_quality_output_acc: 0.7468 - age_output_acc: 0.8193 - weight_output_acc: 0.8515 - bag_output_acc: 0.8231 - footwear_output_acc: 0.8349 - pose_output_acc: 0.9013 - emotion_output_acc: 0.8701 - val_loss: 1.5226 - val_gender_output_loss: 1.1042 - val_image_quality_output_loss: 0.5988 - val_age_output_loss: 0.4809 - val_weight_output_loss: 0.4405 - val_bag_output_loss: 0.6232 - val_footwear_output_loss: 0.6021 - val_pose_output_loss: 0.5782 - val_emotion_output_loss: 0.4110 - val_gender_output_acc: 0.6772 - val_image_quality_output_acc: 0.6912 - val_age_output_acc: 0.7864 - val_weight_output_acc: 0.8141 - val_bag_output_acc: 0.7260 - val_footwear_output_acc: 0.7371 - val_pose_output_acc: 0.7419 - val_emotion_output_acc: 0.8497
# Epoch 32/100
# 360/360 [==============================] - 257s 713ms/step - loss: 0.9301 - gender_output_loss: 0.2171 - image_quality_output_loss: 0.4988 - age_output_loss: 0.3892 - weight_output_loss: 0.3277 - bag_output_loss: 0.3801 - footwear_output_loss: 0.3473 - pose_output_loss: 0.2303 - emotion_output_loss: 0.3103 - gender_output_acc: 0.9109 - image_quality_output_acc: 0.7516 - age_output_acc: 0.8225 - weight_output_acc: 0.8567 - bag_output_acc: 0.8314 - footwear_output_acc: 0.8432 - pose_output_acc: 0.9033 - emotion_output_acc: 0.8727 - val_loss: 1.4648 - val_gender_output_loss: 0.8692 - val_image_quality_output_loss: 0.5997 - val_age_output_loss: 0.4711 - val_weight_output_loss: 0.4473 - val_bag_output_loss: 0.6045 - val_footwear_output_loss: 0.6270 - val_pose_output_loss: 0.5413 - val_emotion_output_loss: 0.4116 - val_gender_output_acc: 0.6961 - val_image_quality_output_acc: 0.6830 - val_age_output_acc: 0.7867 - val_weight_output_acc: 0.8096 - val_bag_output_acc: 0.7226 - val_footwear_output_acc: 0.7219 - val_pose_output_acc: 0.7769 - val_emotion_output_acc: 0.8351
# Epoch 33/100
# 360/360 [==============================] - 258s 717ms/step - loss: 0.9001 - gender_output_loss: 0.2010 - image_quality_output_loss: 0.4899 - age_output_loss: 0.3818 - weight_output_loss: 0.3189 - bag_output_loss: 0.3682 - footwear_output_loss: 0.3340 - pose_output_loss: 0.2102 - emotion_output_loss: 0.3018 - gender_output_acc: 0.9171 - image_quality_output_acc: 0.7597 - age_output_acc: 0.8263 - weight_output_acc: 0.8621 - bag_output_acc: 0.8361 - footwear_output_acc: 0.8502 - pose_output_acc: 0.9136 - emotion_output_acc: 0.8747 - val_loss: 1.4841 - val_gender_output_loss: 0.7928 - val_image_quality_output_loss: 0.6179 - val_age_output_loss: 0.4950 - val_weight_output_loss: 0.4604 - val_bag_output_loss: 0.5824 - val_footwear_output_loss: 0.6014 - val_pose_output_loss: 0.6140 - val_emotion_output_loss: 0.4231 - val_gender_output_acc: 0.7122 - val_image_quality_output_acc: 0.6887 - val_age_output_acc: 0.7844 - val_weight_output_acc: 0.8144 - val_bag_output_acc: 0.7270 - val_footwear_output_acc: 0.7216 - val_pose_output_acc: 0.7811 - val_emotion_output_acc: 0.8429
# Epoch 34/100
# 360/360 [==============================] - 259s 720ms/step - loss: 0.8662 - gender_output_loss: 0.1793 - image_quality_output_loss: 0.4760 - age_output_loss: 0.3742 - weight_output_loss: 0.3059 - bag_output_loss: 0.3485 - footwear_output_loss: 0.3183 - pose_output_loss: 0.2002 - emotion_output_loss: 0.2950 - gender_output_acc: 0.9284 - image_quality_output_acc: 0.7692 - age_output_acc: 0.8310 - weight_output_acc: 0.8690 - bag_output_acc: 0.8486 - footwear_output_acc: 0.8579 - pose_output_acc: 0.9173 - emotion_output_acc: 0.8781 - val_loss: 1.5055 - val_gender_output_loss: 0.8057 - val_image_quality_output_loss: 0.6163 - val_age_output_loss: 0.4863 - val_weight_output_loss: 0.4664 - val_bag_output_loss: 0.6299 - val_footwear_output_loss: 0.6191 - val_pose_output_loss: 0.6033 - val_emotion_output_loss: 0.4352 - val_gender_output_acc: 0.7029 - val_image_quality_output_acc: 0.6749 - val_age_output_acc: 0.7857 - val_weight_output_acc: 0.7945 - val_bag_output_acc: 0.7272 - val_footwear_output_acc: 0.7329 - val_pose_output_acc: 0.7443 - val_emotion_output_acc: 0.8506
# Epoch 35/100
# 360/360 [==============================] - 258s 717ms/step - loss: 0.8496 - gender_output_loss: 0.1918 - image_quality_output_loss: 0.4623 - age_output_loss: 0.3682 - weight_output_loss: 0.2995 - bag_output_loss: 0.3432 - footwear_output_loss: 0.3087 - pose_output_loss: 0.1932 - emotion_output_loss: 0.2878 - gender_output_acc: 0.9213 - image_quality_output_acc: 0.7801 - age_output_acc: 0.8339 - weight_output_acc: 0.8714 - bag_output_acc: 0.8516 - footwear_output_acc: 0.8647 - pose_output_acc: 0.9227 - emotion_output_acc: 0.8806 - val_loss: 1.5093 - val_gender_output_loss: 0.8021 - val_image_quality_output_loss: 0.6344 - val_age_output_loss: 0.4905 - val_weight_output_loss: 0.4814 - val_bag_output_loss: 0.6585 - val_footwear_output_loss: 0.6034 - val_pose_output_loss: 0.5796 - val_emotion_output_loss: 0.4207 - val_gender_output_acc: 0.7167 - val_image_quality_output_acc: 0.6872 - val_age_output_acc: 0.7845 - val_weight_output_acc: 0.8032 - val_bag_output_acc: 0.7226 - val_footwear_output_acc: 0.7404 - val_pose_output_acc: 0.7735 - val_emotion_output_acc: 0.8416
# Epoch 36/100
# 360/360 [==============================] - 258s 717ms/step - loss: 0.8148 - gender_output_loss: 0.1788 - image_quality_output_loss: 0.4506 - age_output_loss: 0.3601 - weight_output_loss: 0.2839 - bag_output_loss: 0.3265 - footwear_output_loss: 0.2934 - pose_output_loss: 0.1784 - emotion_output_loss: 0.2768 - gender_output_acc: 0.9243 - image_quality_output_acc: 0.7864 - age_output_acc: 0.8384 - weight_output_acc: 0.8791 - bag_output_acc: 0.8597 - footwear_output_acc: 0.8720 - pose_output_acc: 0.9290 - emotion_output_acc: 0.8845 - val_loss: 1.5824 - val_gender_output_loss: 0.8882 - val_image_quality_output_loss: 0.6457 - val_age_output_loss: 0.4905 - val_weight_output_loss: 0.5039 - val_bag_output_loss: 0.7000 - val_footwear_output_loss: 0.6270 - val_pose_output_loss: 0.6302 - val_emotion_output_loss: 0.4427 - val_gender_output_acc: 0.7056 - val_image_quality_output_acc: 0.6846 - val_age_output_acc: 0.7764 - val_weight_output_acc: 0.8085 - val_bag_output_acc: 0.7246 - val_footwear_output_acc: 0.7305 - val_pose_output_acc: 0.7589 - val_emotion_output_acc: 0.8453
# Epoch 37/100
# 360/360 [==============================] - 258s 717ms/step - loss: 0.7796 - gender_output_loss: 0.1567 - image_quality_output_loss: 0.4304 - age_output_loss: 0.3508 - weight_output_loss: 0.2739 - bag_output_loss: 0.3121 - footwear_output_loss: 0.2809 - pose_output_loss: 0.1651 - emotion_output_loss: 0.2669 - gender_output_acc: 0.9379 - image_quality_output_acc: 0.7987 - age_output_acc: 0.8434 - weight_output_acc: 0.8833 - bag_output_acc: 0.8668 - footwear_output_acc: 0.8794 - pose_output_acc: 0.9352 - emotion_output_acc: 0.8878 - val_loss: 1.5724 - val_gender_output_loss: 0.8750 - val_image_quality_output_loss: 0.6586 - val_age_output_loss: 0.4986 - val_weight_output_loss: 0.4961 - val_bag_output_loss: 0.6315 - val_footwear_output_loss: 0.6274 - val_pose_output_loss: 0.6511 - val_emotion_output_loss: 0.4477 - val_gender_output_acc: 0.6908 - val_image_quality_output_acc: 0.6771 - val_age_output_acc: 0.7840 - val_weight_output_acc: 0.7913 - val_bag_output_acc: 0.7149 - val_footwear_output_acc: 0.7314 - val_pose_output_acc: 0.7787 - val_emotion_output_acc: 0.8425
# Epoch 38/100
# 360/360 [==============================] - 258s 717ms/step - loss: 0.7399 - gender_output_loss: 0.1447 - image_quality_output_loss: 0.4121 - age_output_loss: 0.3389 - weight_output_loss: 0.2612 - bag_output_loss: 0.2932 - footwear_output_loss: 0.2605 - pose_output_loss: 0.1537 - emotion_output_loss: 0.2531 - gender_output_acc: 0.9424 - image_quality_output_acc: 0.8098 - age_output_acc: 0.8501 - weight_output_acc: 0.8892 - bag_output_acc: 0.8750 - footwear_output_acc: 0.8887 - pose_output_acc: 0.9398 - emotion_output_acc: 0.8954 - val_loss: 1.6467 - val_gender_output_loss: 0.8611 - val_image_quality_output_loss: 0.6764 - val_age_output_loss: 0.5032 - val_weight_output_loss: 0.5179 - val_bag_output_loss: 0.7046 - val_footwear_output_loss: 0.6550 - val_pose_output_loss: 0.7478 - val_emotion_output_loss: 0.4514 - val_gender_output_acc: 0.7124 - val_image_quality_output_acc: 0.6687 - val_age_output_acc: 0.7826 - val_weight_output_acc: 0.7843 - val_bag_output_acc: 0.6935 - val_footwear_output_acc: 0.7441 - val_pose_output_acc: 0.7740 - val_emotion_output_acc: 0.8198
# Epoch 39/100
# 360/360 [==============================] - 259s 719ms/step - loss: 0.7016 - gender_output_loss: 0.1341 - image_quality_output_loss: 0.3867 - age_output_loss: 0.3252 - weight_output_loss: 0.2496 - bag_output_loss: 0.2746 - footwear_output_loss: 0.2452 - pose_output_loss: 0.1410 - emotion_output_loss: 0.2453 - gender_output_acc: 0.9477 - image_quality_output_acc: 0.8252 - age_output_acc: 0.8578 - weight_output_acc: 0.8952 - bag_output_acc: 0.8845 - footwear_output_acc: 0.8966 - pose_output_acc: 0.9442 - emotion_output_acc: 0.8984 - val_loss: 1.6537 - val_gender_output_loss: 0.7977 - val_image_quality_output_loss: 0.7090 - val_age_output_loss: 0.5177 - val_weight_output_loss: 0.5289 - val_bag_output_loss: 0.6930 - val_footwear_output_loss: 0.6715 - val_pose_output_loss: 0.7055 - val_emotion_output_loss: 0.4750 - val_gender_output_acc: 0.7243 - val_image_quality_output_acc: 0.6843 - val_age_output_acc: 0.7732 - val_weight_output_acc: 0.7936 - val_bag_output_acc: 0.7152 - val_footwear_output_acc: 0.7293 - val_pose_output_acc: 0.7577 - val_emotion_output_acc: 0.8257
# Epoch 40/100
# 360/360 [==============================] - 258s 718ms/step - loss: 0.6662 - gender_output_loss: 0.1144 - image_quality_output_loss: 0.3678 - age_output_loss: 0.3137 - weight_output_loss: 0.2409 - bag_output_loss: 0.2618 - footwear_output_loss: 0.2259 - pose_output_loss: 0.1325 - emotion_output_loss: 0.2344 - gender_output_acc: 0.9553 - image_quality_output_acc: 0.8332 - age_output_acc: 0.8630 - weight_output_acc: 0.8995 - bag_output_acc: 0.8899 - footwear_output_acc: 0.9068 - pose_output_acc: 0.9483 - emotion_output_acc: 0.9025 - val_loss: 1.7262 - val_gender_output_loss: 0.8873 - val_image_quality_output_loss: 0.7256 - val_age_output_loss: 0.5236 - val_weight_output_loss: 0.5445 - val_bag_output_loss: 0.7132 - val_footwear_output_loss: 0.7062 - val_pose_output_loss: 0.7260 - val_emotion_output_loss: 0.5195 - val_gender_output_acc: 0.7288 - val_image_quality_output_acc: 0.6358 - val_age_output_acc: 0.7807 - val_weight_output_acc: 0.7932 - val_bag_output_acc: 0.7161 - val_footwear_output_acc: 0.7171 - val_pose_output_acc: 0.7349 - val_emotion_output_acc: 0.8410
# Epoch 41/100
# 360/360 [==============================] - 258s 717ms/step - loss: 0.6447 - gender_output_loss: 0.1217 - image_quality_output_loss: 0.3554 - age_output_loss: 0.3047 - weight_output_loss: 0.2307 - bag_output_loss: 0.2491 - footwear_output_loss: 0.2212 - pose_output_loss: 0.1282 - emotion_output_loss: 0.2239 - gender_output_acc: 0.9516 - image_quality_output_acc: 0.8416 - age_output_acc: 0.8681 - weight_output_acc: 0.9032 - bag_output_acc: 0.8955 - footwear_output_acc: 0.9074 - pose_output_acc: 0.9507 - emotion_output_acc: 0.9063 - val_loss: 1.7422 - val_gender_output_loss: 0.9017 - val_image_quality_output_loss: 0.7284 - val_age_output_loss: 0.5343 - val_weight_output_loss: 0.5511 - val_bag_output_loss: 0.7634 - val_footwear_output_loss: 0.6787 - val_pose_output_loss: 0.7392 - val_emotion_output_loss: 0.5034 - val_gender_output_acc: 0.7142 - val_image_quality_output_acc: 0.6294 - val_age_output_acc: 0.7786 - val_weight_output_acc: 0.7912 - val_bag_output_acc: 0.7088 - val_footwear_output_acc: 0.7235 - val_pose_output_acc: 0.7789 - val_emotion_output_acc: 0.8322
# Epoch 42/100
# 360/360 [==============================] - 258s 717ms/step - loss: 0.6076 - gender_output_loss: 0.1271 - image_quality_output_loss: 0.3254 - age_output_loss: 0.2876 - weight_output_loss: 0.2163 - bag_output_loss: 0.2327 - footwear_output_loss: 0.2091 - pose_output_loss: 0.1201 - emotion_output_loss: 0.2142 - gender_output_acc: 0.9507 - image_quality_output_acc: 0.8584 - age_output_acc: 0.8777 - weight_output_acc: 0.9103 - bag_output_acc: 0.9043 - footwear_output_acc: 0.9135 - pose_output_acc: 0.9541 - emotion_output_acc: 0.9119 - val_loss: 1.8250 - val_gender_output_loss: 0.8888 - val_image_quality_output_loss: 0.8023 - val_age_output_loss: 0.5551 - val_weight_output_loss: 0.5877 - val_bag_output_loss: 0.7489 - val_footwear_output_loss: 0.7539 - val_pose_output_loss: 0.7569 - val_emotion_output_loss: 0.5400 - val_gender_output_acc: 0.7223 - val_image_quality_output_acc: 0.6692 - val_age_output_acc: 0.7641 - val_weight_output_acc: 0.8075 - val_bag_output_acc: 0.7102 - val_footwear_output_acc: 0.7196 - val_pose_output_acc: 0.7839 - val_emotion_output_acc: 0.8436
# Epoch 43/100
# 360/360 [==============================] - 258s 717ms/step - loss: 0.5632 - gender_output_loss: 0.1108 - image_quality_output_loss: 0.2937 - age_output_loss: 0.2740 - weight_output_loss: 0.2045 - bag_output_loss: 0.2181 - footwear_output_loss: 0.1823 - pose_output_loss: 0.1089 - emotion_output_loss: 0.2034 - gender_output_acc: 0.9572 - image_quality_output_acc: 0.8740 - age_output_acc: 0.8835 - weight_output_acc: 0.9141 - bag_output_acc: 0.9094 - footwear_output_acc: 0.9262 - pose_output_acc: 0.9581 - emotion_output_acc: 0.9164 - val_loss: 1.8746 - val_gender_output_loss: 0.9565 - val_image_quality_output_loss: 0.7897 - val_age_output_loss: 0.5532 - val_weight_output_loss: 0.6115 - val_bag_output_loss: 0.7913 - val_footwear_output_loss: 0.8075 - val_pose_output_loss: 0.7864 - val_emotion_output_loss: 0.5241 - val_gender_output_acc: 0.7102 - val_image_quality_output_acc: 0.6512 - val_age_output_acc: 0.7723 - val_weight_output_acc: 0.7988 - val_bag_output_acc: 0.7219 - val_footwear_output_acc: 0.7021 - val_pose_output_acc: 0.7749 - val_emotion_output_acc: 0.7996
# Epoch 44/100
# ...
# Epoch 87/100
# 360/360 [==============================] - 257s 713ms/step - loss: 0.0443 - gender_output_loss: 0.0135 - image_quality_output_loss: 0.0223 - age_output_loss: 0.0170 - weight_output_loss: 0.0147 - bag_output_loss: 0.0166 - footwear_output_loss: 0.0175 - pose_output_loss: 0.0151 - emotion_output_loss: 0.0145 - gender_output_acc: 0.9950 - image_quality_output_acc: 0.9923 - age_output_acc: 0.9949 - weight_output_acc: 0.9953 - bag_output_acc: 0.9948 - footwear_output_acc: 0.9946 - pose_output_acc: 0.9950 - emotion_output_acc: 0.9956 - val_loss: 3.5102 - val_gender_output_loss: 1.3838 - val_image_quality_output_loss: 1.7154 - val_age_output_loss: 1.2246 - val_weight_output_loss: 1.2285 - val_bag_output_loss: 1.4621 - val_footwear_output_loss: 1.3595 - val_pose_output_loss: 1.0744 - val_emotion_output_loss: 1.1156 - val_gender_output_acc: 0.7377 - val_image_quality_output_acc: 0.6433 - val_age_output_acc: 0.7528 - val_weight_output_acc: 0.7828 - val_bag_output_acc: 0.7144 - val_footwear_output_acc: 0.7179 - val_pose_output_acc: 0.7702 - val_emotion_output_acc: 0.8112
# Epoch 88/100
# 360/360 [==============================] - 257s 714ms/step - loss: 0.0428 - gender_output_loss: 0.0144 - image_quality_output_loss: 0.0202 - age_output_loss: 0.0174 - weight_output_loss: 0.0154 - bag_output_loss: 0.0176 - footwear_output_loss: 0.0169 - pose_output_loss: 0.0107 - emotion_output_loss: 0.0136 - gender_output_acc: 0.9950 - image_quality_output_acc: 0.9934 - age_output_acc: 0.9942 - weight_output_acc: 0.9949 - bag_output_acc: 0.9940 - footwear_output_acc: 0.9941 - pose_output_acc: 0.9966 - emotion_output_acc: 0.9956 - val_loss: 3.5129 - val_gender_output_loss: 1.4261 - val_image_quality_output_loss: 1.7497 - val_age_output_loss: 1.2518 - val_weight_output_loss: 1.2035 - val_bag_output_loss: 1.3740 - val_footwear_output_loss: 1.3383 - val_pose_output_loss: 1.1020 - val_emotion_output_loss: 1.1280 - val_gender_output_acc: 0.7434 - val_image_quality_output_acc: 0.6494 - val_age_output_acc: 0.7530 - val_weight_output_acc: 0.7584 - val_bag_output_acc: 0.7083 - val_footwear_output_acc: 0.7347 - val_pose_output_acc: 0.7912 - val_emotion_output_acc: 0.8202
# Epoch 89/100
# 360/360 [==============================] - 256s 711ms/step - loss: 0.0416 - gender_output_loss: 0.0116 - image_quality_output_loss: 0.0184 - age_output_loss: 0.0179 - weight_output_loss: 0.0137 - bag_output_loss: 0.0183 - footwear_output_loss: 0.0150 - pose_output_loss: 0.0119 - emotion_output_loss: 0.0145 - gender_output_acc: 0.9957 - image_quality_output_acc: 0.9935 - age_output_acc: 0.9942 - weight_output_acc: 0.9951 - bag_output_acc: 0.9936 - footwear_output_acc: 0.9949 - pose_output_acc: 0.9962 - emotion_output_acc: 0.9955 - val_loss: 3.3973 - val_gender_output_loss: 1.3568 - val_image_quality_output_loss: 1.6823 - val_age_output_loss: 1.2243 - val_weight_output_loss: 1.1629 - val_bag_output_loss: 1.3328 - val_footwear_output_loss: 1.3406 - val_pose_output_loss: 1.0152 - val_emotion_output_loss: 1.0935 - val_gender_output_acc: 0.7452 - val_image_quality_output_acc: 0.6515 - val_age_output_acc: 0.7510 - val_weight_output_acc: 0.7755 - val_bag_output_acc: 0.6930 - val_footwear_output_acc: 0.7226 - val_pose_output_acc: 0.7715 - val_emotion_output_acc: 0.7970
# Epoch 90/100
# 360/360 [==============================] - 256s 711ms/step - loss: 0.0356 - gender_output_loss: 0.0090 - image_quality_output_loss: 0.0187 - age_output_loss: 0.0135 - weight_output_loss: 0.0134 - bag_output_loss: 0.0132 - footwear_output_loss: 0.0150 - pose_output_loss: 0.0109 - emotion_output_loss: 0.0110 - gender_output_acc: 0.9974 - image_quality_output_acc: 0.9933 - age_output_acc: 0.9957 - weight_output_acc: 0.9955 - bag_output_acc: 0.9956 - footwear_output_acc: 0.9947 - pose_output_acc: 0.9963 - emotion_output_acc: 0.9967 - val_loss: 3.6855 - val_gender_output_loss: 1.3925 - val_image_quality_output_loss: 1.8917 - val_age_output_loss: 1.2854 - val_weight_output_loss: 1.2923 - val_bag_output_loss: 1.4751 - val_footwear_output_loss: 1.4062 - val_pose_output_loss: 1.0934 - val_emotion_output_loss: 1.2186 - val_gender_output_acc: 0.7382 - val_image_quality_output_acc: 0.6551 - val_age_output_acc: 0.7592 - val_weight_output_acc: 0.7852 - val_bag_output_acc: 0.7157 - val_footwear_output_acc: 0.7179 - val_pose_output_acc: 0.7913 - val_emotion_output_acc: 0.8178
# Epoch 91/100
# 360/360 [==============================] - 257s 714ms/step - loss: 0.0336 - gender_output_loss: 0.0125 - image_quality_output_loss: 0.0149 - age_output_loss: 0.0143 - weight_output_loss: 0.0118 - bag_output_loss: 0.0120 - footwear_output_loss: 0.0134 - pose_output_loss: 0.0083 - emotion_output_loss: 0.0114 - gender_output_acc: 0.9954 - image_quality_output_acc: 0.9947 - age_output_acc: 0.9953 - weight_output_acc: 0.9965 - bag_output_acc: 0.9964 - footwear_output_acc: 0.9957 - pose_output_acc: 0.9977 - emotion_output_acc: 0.9965 - val_loss: 3.5486 - val_gender_output_loss: 1.4509 - val_image_quality_output_loss: 1.7801 - val_age_output_loss: 1.2136 - val_weight_output_loss: 1.1971 - val_bag_output_loss: 1.4780 - val_footwear_output_loss: 1.3246 - val_pose_output_loss: 1.0566 - val_emotion_output_loss: 1.2025 - val_gender_output_acc: 0.7311 - val_image_quality_output_acc: 0.6462 - val_age_output_acc: 0.7516 - val_weight_output_acc: 0.7833 - val_bag_output_acc: 0.7041 - val_footwear_output_acc: 0.7208 - val_pose_output_acc: 0.7839 - val_emotion_output_acc: 0.8203
# Epoch 92/100
# 360/360 [==============================] - 257s 713ms/step - loss: 0.0463 - gender_output_loss: 0.0145 - image_quality_output_loss: 0.0210 - age_output_loss: 0.0169 - weight_output_loss: 0.0150 - bag_output_loss: 0.0193 - footwear_output_loss: 0.0198 - pose_output_loss: 0.0141 - emotion_output_loss: 0.0167 - gender_output_acc: 0.9950 - image_quality_output_acc: 0.9929 - age_output_acc: 0.9944 - weight_output_acc: 0.9951 - bag_output_acc: 0.9935 - footwear_output_acc: 0.9931 - pose_output_acc: 0.9947 - emotion_output_acc: 0.9943 - val_loss: 3.5212 - val_gender_output_loss: 1.3703 - val_image_quality_output_loss: 1.7636 - val_age_output_loss: 1.2366 - val_weight_output_loss: 1.2027 - val_bag_output_loss: 1.3823 - val_footwear_output_loss: 1.3648 - val_pose_output_loss: 1.1004 - val_emotion_output_loss: 1.1611 - val_gender_output_acc: 0.7371 - val_image_quality_output_acc: 0.6285 - val_age_output_acc: 0.7394 - val_weight_output_acc: 0.7795 - val_bag_output_acc: 0.7266 - val_footwear_output_acc: 0.7201 - val_pose_output_acc: 0.7905 - val_emotion_output_acc: 0.8146
# Epoch 93/100
# 360/360 [==============================] - 256s 710ms/step - loss: 0.0399 - gender_output_loss: 0.0110 - image_quality_output_loss: 0.0175 - age_output_loss: 0.0160 - weight_output_loss: 0.0133 - bag_output_loss: 0.0170 - footwear_output_loss: 0.0174 - pose_output_loss: 0.0120 - emotion_output_loss: 0.0129 - gender_output_acc: 0.9963 - image_quality_output_acc: 0.9938 - age_output_acc: 0.9948 - weight_output_acc: 0.9957 - bag_output_acc: 0.9946 - footwear_output_acc: 0.9939 - pose_output_acc: 0.9958 - emotion_output_acc: 0.9958 - val_loss: 3.6633 - val_gender_output_loss: 1.4964 - val_image_quality_output_loss: 1.7160 - val_age_output_loss: 1.2991 - val_weight_output_loss: 1.2968 - val_bag_output_loss: 1.5083 - val_footwear_output_loss: 1.3452 - val_pose_output_loss: 1.1359 - val_emotion_output_loss: 1.2103 - val_gender_output_acc: 0.7382 - val_image_quality_output_acc: 0.6292 - val_age_output_acc: 0.7487 - val_weight_output_acc: 0.7936 - val_bag_output_acc: 0.7114 - val_footwear_output_acc: 0.7199 - val_pose_output_acc: 0.7917 - val_emotion_output_acc: 0.8085
# Epoch 94/100
# 360/360 [==============================] - 256s 710ms/step - loss: 0.0385 - gender_output_loss: 0.0118 - image_quality_output_loss: 0.0178 - age_output_loss: 0.0143 - weight_output_loss: 0.0139 - bag_output_loss: 0.0156 - footwear_output_loss: 0.0127 - pose_output_loss: 0.0124 - emotion_output_loss: 0.0149 - gender_output_acc: 0.9961 - image_quality_output_acc: 0.9943 - age_output_acc: 0.9953 - weight_output_acc: 0.9949 - bag_output_acc: 0.9947 - footwear_output_acc: 0.9959 - pose_output_acc: 0.9956 - emotion_output_acc: 0.9954 - val_loss: 3.7328 - val_gender_output_loss: 1.3487 - val_image_quality_output_loss: 1.8375 - val_age_output_loss: 1.3323 - val_weight_output_loss: 1.3044 - val_bag_output_loss: 1.5075 - val_footwear_output_loss: 1.3719 - val_pose_output_loss: 1.2378 - val_emotion_output_loss: 1.2218 - val_gender_output_acc: 0.7404 - val_image_quality_output_acc: 0.6319 - val_age_output_acc: 0.7542 - val_weight_output_acc: 0.7829 - val_bag_output_acc: 0.7149 - val_footwear_output_acc: 0.7129 - val_pose_output_acc: 0.7834 - val_emotion_output_acc: 0.8211
# Epoch 95/100
# 360/360 [==============================] - 257s 714ms/step - loss: 0.0380 - gender_output_loss: 0.0127 - image_quality_output_loss: 0.0180 - age_output_loss: 0.0155 - weight_output_loss: 0.0146 - bag_output_loss: 0.0131 - footwear_output_loss: 0.0127 - pose_output_loss: 0.0108 - emotion_output_loss: 0.0138 - gender_output_acc: 0.9958 - image_quality_output_acc: 0.9941 - age_output_acc: 0.9952 - weight_output_acc: 0.9953 - bag_output_acc: 0.9954 - footwear_output_acc: 0.9958 - pose_output_acc: 0.9966 - emotion_output_acc: 0.9956 - val_loss: 3.6596 - val_gender_output_loss: 1.3769 - val_image_quality_output_loss: 1.8734 - val_age_output_loss: 1.3170 - val_weight_output_loss: 1.2079 - val_bag_output_loss: 1.4561 - val_footwear_output_loss: 1.3948 - val_pose_output_loss: 1.1315 - val_emotion_output_loss: 1.2146 - val_gender_output_acc: 0.7341 - val_image_quality_output_acc: 0.6579 - val_age_output_acc: 0.7502 - val_weight_output_acc: 0.7650 - val_bag_output_acc: 0.7233 - val_footwear_output_acc: 0.7127 - val_pose_output_acc: 0.7860 - val_emotion_output_acc: 0.8228
# Epoch 96/100
# 360/360 [==============================] - 257s 714ms/step - loss: 0.0334 - gender_output_loss: 0.0114 - image_quality_output_loss: 0.0180 - age_output_loss: 0.0133 - weight_output_loss: 0.0110 - bag_output_loss: 0.0138 - footwear_output_loss: 0.0122 - pose_output_loss: 0.0087 - emotion_output_loss: 0.0106 - gender_output_acc: 0.9957 - image_quality_output_acc: 0.9939 - age_output_acc: 0.9958 - weight_output_acc: 0.9965 - bag_output_acc: 0.9952 - footwear_output_acc: 0.9960 - pose_output_acc: 0.9973 - emotion_output_acc: 0.9968 - val_loss: 3.7376 - val_gender_output_loss: 1.5306 - val_image_quality_output_loss: 1.7814 - val_age_output_loss: 1.3894 - val_weight_output_loss: 1.2673 - val_bag_output_loss: 1.4498 - val_footwear_output_loss: 1.4182 - val_pose_output_loss: 1.1275 - val_emotion_output_loss: 1.2420 - val_gender_output_acc: 0.7220 - val_image_quality_output_acc: 0.6379 - val_age_output_acc: 0.7568 - val_weight_output_acc: 0.7954 - val_bag_output_acc: 0.7171 - val_footwear_output_acc: 0.7240 - val_pose_output_acc: 0.7900 - val_emotion_output_acc: 0.8217
# Epoch 97/100
# 360/360 [==============================] - 256s 711ms/step - loss: 0.0339 - gender_output_loss: 0.0148 - image_quality_output_loss: 0.0146 - age_output_loss: 0.0144 - weight_output_loss: 0.0107 - bag_output_loss: 0.0126 - footwear_output_loss: 0.0134 - pose_output_loss: 0.0095 - emotion_output_loss: 0.0110 - gender_output_acc: 0.9951 - image_quality_output_acc: 0.9951 - age_output_acc: 0.9952 - weight_output_acc: 0.9966 - bag_output_acc: 0.9959 - footwear_output_acc: 0.9952 - pose_output_acc: 0.9968 - emotion_output_acc: 0.9965 - val_loss: 3.6923 - val_gender_output_loss: 1.5052 - val_image_quality_output_loss: 1.8739 - val_age_output_loss: 1.2735 - val_weight_output_loss: 1.2465 - val_bag_output_loss: 1.5154 - val_footwear_output_loss: 1.3757 - val_pose_output_loss: 1.1493 - val_emotion_output_loss: 1.2041 - val_gender_output_acc: 0.7273 - val_image_quality_output_acc: 0.6405 - val_age_output_acc: 0.7485 - val_weight_output_acc: 0.7888 - val_bag_output_acc: 0.7124 - val_footwear_output_acc: 0.7300 - val_pose_output_acc: 0.7898 - val_emotion_output_acc: 0.8180
# Epoch 98/100
# 360/360 [==============================] - 256s 711ms/step - loss: 0.0359 - gender_output_loss: 0.0153 - image_quality_output_loss: 0.0164 - age_output_loss: 0.0150 - weight_output_loss: 0.0124 - bag_output_loss: 0.0125 - footwear_output_loss: 0.0150 - pose_output_loss: 0.0103 - emotion_output_loss: 0.0105 - gender_output_acc: 0.9952 - image_quality_output_acc: 0.9947 - age_output_acc: 0.9950 - weight_output_acc: 0.9961 - bag_output_acc: 0.9958 - footwear_output_acc: 0.9947 - pose_output_acc: 0.9963 - emotion_output_acc: 0.9968 - val_loss: 3.6185 - val_gender_output_loss: 1.4798 - val_image_quality_output_loss: 1.7591 - val_age_output_loss: 1.2957 - val_weight_output_loss: 1.2136 - val_bag_output_loss: 1.4055 - val_footwear_output_loss: 1.4527 - val_pose_output_loss: 1.1174 - val_emotion_output_loss: 1.1719 - val_gender_output_acc: 0.7308 - val_image_quality_output_acc: 0.6376 - val_age_output_acc: 0.7313 - val_weight_output_acc: 0.7671 - val_bag_output_acc: 0.6959 - val_footwear_output_acc: 0.7277 - val_pose_output_acc: 0.7784 - val_emotion_output_acc: 0.8173
# Epoch 99/100
# 360/360 [==============================] - 256s 712ms/step - loss: 0.0361 - gender_output_loss: 0.0119 - image_quality_output_loss: 0.0156 - age_output_loss: 0.0143 - weight_output_loss: 0.0125 - bag_output_loss: 0.0146 - footwear_output_loss: 0.0146 - pose_output_loss: 0.0103 - emotion_output_loss: 0.0125 - gender_output_acc: 0.9959 - image_quality_output_acc: 0.9947 - age_output_acc: 0.9959 - weight_output_acc: 0.9961 - bag_output_acc: 0.9949 - footwear_output_acc: 0.9951 - pose_output_acc: 0.9966 - emotion_output_acc: 0.9960 - val_loss: 3.6897 - val_gender_output_loss: 1.4034 - val_image_quality_output_loss: 1.8560 - val_age_output_loss: 1.3398 - val_weight_output_loss: 1.2782 - val_bag_output_loss: 1.4447 - val_footwear_output_loss: 1.4277 - val_pose_output_loss: 1.0625 - val_emotion_output_loss: 1.2263 - val_gender_output_acc: 0.7404 - val_image_quality_output_acc: 0.6613 - val_age_output_acc: 0.7476 - val_weight_output_acc: 0.7777 - val_bag_output_acc: 0.7112 - val_footwear_output_acc: 0.7224 - val_pose_output_acc: 0.7786 - val_emotion_output_acc: 0.7762
# Epoch 100/100
# 360/360 [==============================] - 257s 713ms/step - loss: 0.0315 - gender_output_loss: 0.0114 - image_quality_output_loss: 0.0151 - age_output_loss: 0.0113 - weight_output_loss: 0.0107 - bag_output_loss: 0.0121 - footwear_output_loss: 0.0125 - pose_output_loss: 0.0106 - emotion_output_loss: 0.0105 - gender_output_acc: 0.9955 - image_quality_output_acc: 0.9948 - age_output_acc: 0.9964 - weight_output_acc: 0.9966 - bag_output_acc: 0.9956 - footwear_output_acc: 0.9957 - pose_output_acc: 0.9959 - emotion_output_acc: 0.9967 - val_loss: 3.7774 - val_gender_output_loss: 1.4919 - val_image_quality_output_loss: 1.8535 - val_age_output_loss: 1.3656 - val_weight_output_loss: 1.2737 - val_bag_output_loss: 1.5332 - val_footwear_output_loss: 1.5056 - val_pose_output_loss: 1.0571 - val_emotion_output_loss: 1.2549 - val_gender_output_acc: 0.7387 - val_image_quality_output_acc: 0.6107 - val_age_output_acc: 0.7444 - val_weight_output_acc: 0.7748 - val_bag_output_acc: 0.7230 - val_footwear_output_acc: 0.7154 - val_pose_output_acc: 0.7727 - val_emotion_output_acc: 0.8163
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-153e58168182> in <module>()
#       9     #callbacks=callbacks
#      10     )
# ---> 11 LRFind.plot_loss()
#
# NameError: name 'LRFind' is not defined

# %%
model
